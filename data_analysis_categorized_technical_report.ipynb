# %% [markdown]
# ## Data analysis for employment in non-profit organization

# %% [markdown]
# Divided by four datasets instead of two datasets and then later into another two datasets.

# %% [markdown]
# Import all requirement,

# %%
import pandas as pd
import numpy as np
import ydata_profiling as pp  
from ydata_profiling import ProfileReport 
import warnings
import os

warnings.filterwarnings('ignore')

# %% [markdown]
# Import unemployment dataset.

# %%
df = pd.read_csv('36100651.csv')

print(df.info())
print(df.head(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105840 entries, 0 to 105839
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   REF_DATE         105840 non-null  int64
#  1   GEO              105840 non-null  object
#  2   DGUID            105840 non-null  object
#  3   Sector           105840 non-null  object
#  4   Characteristics  105840 non-null  object
#  5   Indicators       105840 non-null  object
#  6   UOM              105840 non-null  object
#  7   UOM_ID           105840 non-null  int64
#  8   SCALAR_FACTOR    105840 non-null  object
#  9   SCALAR_ID        105840 non-null  int64
#  10  VECTOR           105840 non-null  object
#  11  COORDINATE       105840 non-null  object
#  12  VALUE            102816 non-null  float64
#  13  STATUS           3024 non-null    object
#  14  SYMBOL           0 non-null       float64
#  15  TERMINATED       0 non-null       float64
#  16  DECIMALS         105840 non-null  int64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 13.7+ MB
# None
#    REF_DATE     GEO           DGUID                         Sector  \
# 0      2010  Canada  2016A000011124  Total non-profit institutions
# 1      2010  Canada  2016A000011124  Total non-profit institutions
# 2      2010  Canada  2016A000011124  Total non-profit institutions
# 3      2010  Canada  2016A000011124  Total non-profit institutions
# 4      2010  Canada  2016A000011124  Total non-profit institutions
# 5      2010  Canada  2016A000011124  Total non-profit institutions
# 6      2010  Canada  2016A000011124  Total non-profit institutions
# 7      2010  Canada  2016A000011124  Total non-profit institutions
# 8      2010  Canada  2016A000011124  Total non-profit institutions
# 9      2010  Canada  2016A000011124  Total non-profit institutions
#
#     Characteristics                         Indicators      UOM  UOM_ID  \
# 0    Male employees                     Number of jobs     Jobs     190
# 1    Male employees                       Hours worked    Hours     152
# 2    Male employees                 Wages and salaries  Dollars      81
# 3    Male employees        Average annual hours worked    Hours     152
# 4    Male employees        Average weekly hours worked    Hours     152
# 5    Male employees  Average annual wages and salaries  Dollars      81
# 6    Male employees                Average hourly wage  Dollars      81
# 7  Female employees                     Number of jobs     Jobs     190
# 8  Female employees                       Hours worked    Hours     152
# 9  Female employees                 Wages and salaries  Dollars      81
#
#   SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE       VALUE STATUS  SYMBOL  \
# 0         units          0  v1273033811    1.1.1.1   642584.00    NaN     NaN
# 1     thousands          3  v1273033812    1.1.1.2  1048516.00    NaN     NaN
# 2      millions          6  v1273033813    1.1.1.3    30805.00    NaN     NaN
# 3         units          0  v1273033814    1.1.1.4     1632.00    NaN     NaN
# 4         units          0  v1273033815    1.1.1.5       31.00    NaN     NaN
# 5         units          0  v1273033816    1.1.1.6    47940.00    NaN     NaN
# 6         units          0  v1273033817    1.1.1.7       29.38    NaN     NaN
# 7         units          0  v1273033909    1.1.2.1  1500394.00    NaN     NaN
# 8     thousands          3  v1273033910    1.1.2.2  2331018.00    NaN     NaN
# 9      millions          6  v1273033911    1.1.2.3    60943.00    NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0
# 5         NaN         0
# 6         NaN         2
# 7         NaN         0
# 8         NaN         0
# 9         NaN         0

# %% [markdown]
# Filter only the essential columns of the original dataset.

# %%
print("Grab the only the essential part of database.")

# From the original, 
# DGUID, UOM_ID, SCALAR_ID, VECTOR, COORDINATE, STATUS, SYMBOL, TERMINATED, and DECIMALS columns are removed.

df_sorted = df[['REF_DATE','GEO','Sector','Characteristics','Indicators','UOM','SCALAR_FACTOR','VALUE']]

print(df_sorted.head(20))
print(df_sorted.info())

print("Sort by Characteristics")
grouped = df_sorted.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.size]))

print("Sort by Indicator")
grouped = df_sorted.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.size]))
# Out:
# Grab the only the essential part of database.
#     REF_DATE     GEO                         Sector      Characteristics  \
# 0       2010  Canada  Total non-profit institutions       Male employees
# 1       2010  Canada  Total non-profit institutions       Male employees
# 2       2010  Canada  Total non-profit institutions       Male employees
# 3       2010  Canada  Total non-profit institutions       Male employees
# 4       2010  Canada  Total non-profit institutions       Male employees
# 5       2010  Canada  Total non-profit institutions       Male employees
# 6       2010  Canada  Total non-profit institutions       Male employees
# 7       2010  Canada  Total non-profit institutions     Female employees
# 8       2010  Canada  Total non-profit institutions     Female employees
# 9       2010  Canada  Total non-profit institutions     Female employees
# 10      2010  Canada  Total non-profit institutions     Female employees
# 11      2010  Canada  Total non-profit institutions     Female employees
# 12      2010  Canada  Total non-profit institutions     Female employees
# 13      2010  Canada  Total non-profit institutions     Female employees
# 14      2010  Canada  Total non-profit institutions  Immigrant employees
# 15      2010  Canada  Total non-profit institutions  Immigrant employees
# 16      2010  Canada  Total non-profit institutions  Immigrant employees
# 17      2010  Canada  Total non-profit institutions  Immigrant employees
# 18      2010  Canada  Total non-profit institutions  Immigrant employees
# 19      2010  Canada  Total non-profit institutions  Immigrant employees
#
#                            Indicators      UOM SCALAR_FACTOR       VALUE
# 0                      Number of jobs     Jobs         units   642584.00
# 1                        Hours worked    Hours     thousands  1048516.00
# 2                  Wages and salaries  Dollars      millions    30805.00
# 3         Average annual hours worked    Hours         units     1632.00
# 4         Average weekly hours worked    Hours         units       31.00
# 5   Average annual wages and salaries  Dollars         units    47940.00
# 6                 Average hourly wage  Dollars         units       29.38
# 7                      Number of jobs     Jobs         units  1500394.00
# 8                        Hours worked    Hours     thousands  2331018.00
# 9                  Wages and salaries  Dollars      millions    60943.00
# 10        Average annual hours worked    Hours         units     1554.00
# 11        Average weekly hours worked    Hours         units       30.00
# 12  Average annual wages and salaries  Dollars         units    40618.00
# 13                Average hourly wage  Dollars         units       26.14
# 14                     Number of jobs     Jobs         units   503236.00
# 15                       Hours worked    Hours     thousands   802251.00
# 16                 Wages and salaries  Dollars      millions    22212.00
# 17        Average annual hours worked    Hours         units     1594.00
# 18        Average weekly hours worked    Hours         units       31.00
# 19  Average annual wages and salaries  Dollars         units    44138.00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105840 entries, 0 to 105839
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   REF_DATE         105840 non-null  int64
#  1   GEO              105840 non-null  object
#  2   Sector           105840 non-null  object
#  3   Characteristics  105840 non-null  object
#  4   Indicators       105840 non-null  object
#  5   UOM              105840 non-null  object
#  6   SCALAR_FACTOR    105840 non-null  object
#  7   VALUE            102816 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.5+ MB
# None
# Sort by Characteristics
#                                    size
# Characteristics
# 15 to 24 years                     5880
# 25 to 34 years                     5880
# 35 to 44 years                     5880
# 45 to 54 years                     5880
# 55 to 64 years                     5880
# 65 years old and over              5880
# College diploma                    5880
# Female employees                   5880
# High school diploma and less       5880
# Immigrant employees                5880
# Indigenous identity employees      5880
# Male employees                     5880
# Non-immigrant employees            5880
# Non-indigenous identity employees  5880
# Not a visible minority             5880
# Trade certificate                  5880
# University degree and higher       5880
# Visible minority                   5880
# Sort by Indicator
#                                     size
# Indicators
# Average annual hours worked        15120
# Average annual wages and salaries  15120
# Average hourly wage                15120
# Average weekly hours worked        15120
# Hours worked                       15120
# Number of jobs                     15120
# Wages and salaries                 15120

# %% [markdown]
# Check for the missing value from the sorted dataset done above.
# * Notice there is missing value in this dataset.

# %%
print("Original database null counter")
print(df.isnull().sum())
print("\n Modified dataset null counter.")
print(df_sorted.isnull().sum())
# Out:
# Original database null counter
# REF_DATE                0
# GEO                     0
# DGUID                   0
# Sector                  0
# Characteristics         0
# Indicators              0
# UOM                     0
# UOM_ID                  0
# SCALAR_FACTOR           0
# SCALAR_ID               0
# VECTOR                  0
# COORDINATE              0
# VALUE                3024
# STATUS             102816
# SYMBOL             105840
# TERMINATED         105840
# DECIMALS                0
# dtype: int64
#
#  Modified dataset null counter.
# REF_DATE              0
# GEO                   0
# Sector                0
# Characteristics       0
# Indicators            0
# UOM                   0
# SCALAR_FACTOR         0
# VALUE              3024
# dtype: int64

# %% [markdown]
# Dropping missing value from the sorted dataset.

# %%
df_sorted_na = df_sorted.dropna()

# %% [markdown]
# Check now if there's still a missing data inside modified sorted dataset done above.

# %%
print("Modified dataset modification after removing missing value and it's total counter")
print(df_sorted_na.isnull().sum())
# print(df_sorted_na.head(20))

print(df_sorted_na.info())
grouped = df_sorted_na.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.size]))

grouped = df_sorted_na.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.size]))
# Out:
# Modified dataset modification after removing missing value and it's total counter
# REF_DATE           0
# GEO                0
# Sector             0
# Characteristics    0
# Indicators         0
# UOM                0
# SCALAR_FACTOR      0
# VALUE              0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 102816 entries, 0 to 105839
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   REF_DATE         102816 non-null  int64
#  1   GEO              102816 non-null  object
#  2   Sector           102816 non-null  object
#  3   Characteristics  102816 non-null  object
#  4   Indicators       102816 non-null  object
#  5   UOM              102816 non-null  object
#  6   SCALAR_FACTOR    102816 non-null  object
#  7   VALUE            102816 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 7.1+ MB
# None
#                                    size
# Characteristics
# 15 to 24 years                     5376
# 25 to 34 years                     5880
# 35 to 44 years                     5880
# 45 to 54 years                     5880
# 55 to 64 years                     5880
# 65 years old and over              5376
# College diploma                    5880
# Female employees                   5880
# High school diploma and less       5880
# Immigrant employees                5544
# Indigenous identity employees      5544
# Male employees                     5880
# Non-immigrant employees            5544
# Non-indigenous identity employees  5544
# Not a visible minority             5880
# Trade certificate                  5544
# University degree and higher       5544
# Visible minority                   5880
#                                     size
# Indicators
# Average annual hours worked        14688
# Average annual wages and salaries  14688
# Average hourly wage                14688
# Average weekly hours worked        14688
# Hours worked                       14688
# Number of jobs                     14688
# Wages and salaries                 14688

# %% [markdown]
# Panda Profiling for original dataset (CSV file),

# %%
# https://medium.com/analytics-vidhya/pandas-profiling-5ecd0b977ecd

pp = ProfileReport(df, title="Pandas Profiling Report")
pp_df = pp.to_html()

f = open("df_NoMod.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   5%|▍         | 1/22 [00:01<00:41,  1.97s/it, Describe variable:REF_DATE]
# Summarize dataset: 100%|██████████| 31/31 [00:08<00:00,  3.73it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:07<00:00,  7.20s/it]
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]

# %% [markdown]
# Panda Profiling for sorted dataset,

# %%
pp_sorted = ProfileReport(df_sorted, title="Pandas Profiling Report with Columns Sorted")
pp_df_sorted = pp_sorted.to_html()

f = open("df_Sorted.html", "a") # Expert modifying data into html file.
f.write(pp_df_sorted)
f.close()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset: 100%|██████████| 21/21 [00:04<00:00,  4.71it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.68s/it]
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]

# %% [markdown]
# Panda Profiling for modified sorted dataset (missing data removed),

# %%
pp = ProfileReport(df_sorted_na, title="Pandas Profiling Report with Columned Sorted and NA Removed")
pp_df_sorted = pp.to_html()

f = open("df_Sorted-no-na.html", "a") # Expert modifying data into html file.
f.write(pp_df_sorted)
f.close()
# Out:
# Summarize dataset: 100%|██████████| 21/21 [00:04<00:00,  4.68it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.32s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.89it/s]

# %%
# Differences should be, there will be less data to work on.
# Particularly business non-profit organizations and community organizations haven't given more accurate data (more missing values).

# %% [markdown]
# Next step, I will filtered the dataset by all the 'Indicators' given below. All of them done with modified sorted dataset (filtered missing value)
# * Notice there will be seven indicators data inside.
# * Notice there will be divided by seven datasets based on indicators.

# %%
# All columns
print(df_sorted_na.info())

# All indicators
grouped = df_sorted_na.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.size]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102816 entries, 0 to 105839
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   REF_DATE         102816 non-null  int64
#  1   GEO              102816 non-null  object
#  2   Sector           102816 non-null  object
#  3   Characteristics  102816 non-null  object
#  4   Indicators       102816 non-null  object
#  5   UOM              102816 non-null  object
#  6   SCALAR_FACTOR    102816 non-null  object
#  7   VALUE            102816 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 11.1+ MB
# None
#                                     size
# Indicators
# Average annual hours worked        14688
# Average annual wages and salaries  14688
# Average hourly wage                14688
# Average weekly hours worked        14688
# Hours worked                       14688
# Number of jobs                     14688
# Wages and salaries                 14688

# %% [markdown]
# Average annual hours worked from modified sorted dataset.

# %%
# Average annual hours worked        15120
print("\nAverage annual hours worked")
df_AvgAnnHrsWrk = df_sorted_na.loc[
    (df_sorted_na['Indicators'] == 'Average annual hours worked')
]
# grouped = df_AvgAnnHrsWrk.groupby(['GEO'])
grouped = df_AvgAnnHrsWrk.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.sum, np.mean, np.std, np.size]))
print("The total number of this one is ",len(df_AvgAnnHrsWrk.index))
# Out:
# Average annual hours worked
#                                     sum         mean         std   size
# Indicators
# Average annual hours worked  22787494.0  1551.436138  252.784087  14688
# The total number of this one is  14688

# %% [markdown]
# Panda Profiling only for "Average annual hours worked"

# %%
pp = ProfileReport(df_AvgAnnHrsWrk, title="Average annual hours worked")
pp_df = pp.to_html()

f = open("Average annual hours worked.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset: 100%|██████████| 21/21 [00:01<00:00, 11.05it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.20s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]

# %% [markdown]
# Average annual wages and salaries from modified sorted dataset. (Mention above)

# %%
# Average annual wages and salaries  15120
print("\nAverage annual wages and salaries")
df_AvgAnnWages = df_sorted_na.loc[
    (df_sorted_na['Indicators'] == 'Average annual wages and salaries')
]
grouped = df_AvgAnnWages.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.sum, np.mean, np.std, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages.index))
# Out:
# Average annual wages and salaries
#                                            sum          mean           std  \
# Indicators
# Average annual wages and salaries  643404649.0  43804.782748  16620.351087
#
#                                     size
# Indicators
# Average annual wages and salaries  14688
# The total number of this one is  14688

# %% [markdown]
# Panda Profiling only for "Average annual wages and salaries"

# %%
pp = ProfileReport(df_AvgAnnWages, title="Average annual wages and salaries")
pp_df = pp.to_html()

f = open("Average annual wages and salaries.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset: 100%|██████████| 21/21 [00:01<00:00, 12.15it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.97s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]

# %% [markdown]
# Average hourly wage from modified sorted dataset. (Mentions above)

# %%
# Average hourly wage                15120
print("\nAverage hourly wage")
df_AvgHrsWages = df_sorted_na.loc[
    (df_sorted_na['Indicators'] == 'Average hourly wage')
]
grouped = df_AvgHrsWages.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.sum, np.mean, np.std, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages.index))
# Out:
# Average hourly wage
#                            sum       mean       std   size
# Indicators
# Average hourly wage  408702.58  27.825611  8.601721  14688
# The total number of this one is  14688

# %% [markdown]
# Panda Profiling only for "Average hourly wages"

# %%
pp = ProfileReport(df_AvgHrsWages, title="Average hourly wage")
pp_df = pp.to_html()

f = open("Average hourly wages.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset: 100%|██████████| 21/21 [00:01<00:00, 11.72it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.17s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]

# %% [markdown]
# Average weekly hours worked from modified sorted dataset.

# %%
# Average weekly hours worked        15120
print("\nAverage weekly hours worked")
df_AvgWeekHrsWrked = df_sorted_na.loc[
    (df_sorted_na['Indicators'] == 'Average weekly hours worked')
]
grouped = df_AvgWeekHrsWrked.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.sum, np.mean, np.std, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked.index))
# Out:
# Average weekly hours worked
#                                   sum       mean      std   size
# Indicators
# Average weekly hours worked  438169.0  29.831767  4.86689  14688
# The total number of this one is  14688

# %% [markdown]
# Panda Profiling only for "Average weekly hours worked"

# %%
pp = ProfileReport(df_AvgWeekHrsWrked, title="Average weekly hours worked")
pp_df = pp.to_html()

f = open("Average weekly hours worked.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset: 100%|██████████| 21/21 [00:01<00:00, 11.16it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]

# %% [markdown]
# Hours worked from modified sorted dataset.
# * Notice, Skewed left.

# %%
# Hours worked                       15120
print("\nHours worked")
df_Hrs_Wrked = df_sorted_na.loc[
    (df_sorted_na['Indicators'] == 'Hours worked')
]
grouped = df_Hrs_Wrked.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.sum, np.mean, np.std, np.size]))
print(grouped['VALUE'].agg([np.amin, np.amax]))
print("The total number of this one is ",len(df_Hrs_Wrked.index))
# Out:
# Hours worked
#                        sum          mean            std   size
# Indicators
# Hours worked  1.227872e+09  83596.946283  253684.449101  14688
#               amin       amax
# Indicators
# Hours worked   6.0  3857813.0
# The total number of this one is  14688

# %% [markdown]
# Panda Profiling only for "Hours worked" (Skewed left, noticed)

# %%
pp = ProfileReport(df_Hrs_Wrked, title="Hours Worked")
pp_df = pp.to_html()

f = open("Hours worked.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   8%|▊         | 1/13 [00:00<00:01,  9.42it/s, Describe variable:VALUE]
# Summarize dataset: 100%|██████████| 21/21 [00:01<00:00, 10.59it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]

# %% [markdown]
# Number of jobs from modified sorted dataset.
# * Notice, skewed left.

# %%
# Number of jobs                     15120
print("\nNumber of jobs")
df_NumOfJob = df_sorted_na.loc[
    (df_sorted_na['Indicators'] == 'Number of jobs')
]
grouped = df_NumOfJob.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.sum, np.mean, np.std, np.size]))
print(grouped['VALUE'].agg([np.amin, np.amax]))
print("The total number of this one is ",len(df_NumOfJob.index))
# Out:
# Number of jobs
#                         sum          mean            std   size
# Indicators
# Number of jobs  784942325.0  53441.062432  161120.806948  14688
#                 amin       amax
# Indicators
# Number of jobs  11.0  2428289.0
# The total number of this one is  14688

# %% [markdown]
# Panda Profiling only for "Number of the jobs" (Stewed toward left)

# %%
pp = ProfileReport(df_NumOfJob, title="Number of jobs")
pp_df = pp.to_html()

f = open("Number of jobs.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset: 100%|██████████| 21/21 [00:01<00:00, 11.04it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.89s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]

# %% [markdown]
# Wages and salaries from modified sorted dataset.
#
# * Noticed skewed left.

# %%
# Wages and salaries                 15120
print("\nWages and salaries")
df_WagesAndSalaries = df_sorted_na.loc[
    (df_sorted_na['Indicators'] == 'Wages and salaries')
]
grouped = df_WagesAndSalaries.groupby(['Indicators'])
print(grouped['VALUE'].agg([np.sum, np.mean, np.std, np.size]))
print(grouped['VALUE'].agg([np.amin, np.amax]))
print("The total number of this one is ",len(df_WagesAndSalaries.index))
# Out:
# Wages and salaries
#                            sum         mean          std   size
# Indicators
# Wages and salaries  36498479.0  2484.918233  7977.441388  14688
#                     amin      amax
# Indicators
# Wages and salaries   0.0  132601.0
# The total number of this one is  14688

# %% [markdown]
# Panda Profiling only for "Wages and salaries" (Strewed toward left)

# %%
pp = ProfileReport(df_WagesAndSalaries, title="Wages and Salaries")
pp_df = pp.to_html()

f = open("Wages and salaries.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset: 100%|██████████| 21/21 [00:01<00:00, 12.17it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.25s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]

# %% [markdown]
# For next step, I will divide each Indicators dataset into three different datasets.<br />
# They are 2013-2015, 2016-2018, 2019-2021.<br />
# I have dataset prepared before 2010-2012. However, it will not be used after this section, there's too much to analysis to do.<br />
# It will also demonstrate here why.
# Originally, I used divide dataset into 2016-2017, 2018-2019, and 2020-2021 from dataset that was divided from 2016 and up.

# %%
print("There are seven Indicators to analysis,")
grouped = df_sorted_na.groupby('Indicators')
print(grouped['VALUE'].agg([np.size]))

print("\nThe data inside between 2010-2013, there's are # number of data and I will be repeating this seven more time.,")
df_Avg_Sample = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2010) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2011) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2012)
]

grouped = df_Avg_Sample.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.size]))

print("\nTo data inside above 2013 and split into three datasets, I need to repeat this analysis for "+str(7*3)+" (7x3) times.")
print("\nThis is also total of spliting into "+str(7*3)+" datasets.")

df_Avg_Sample_2013 = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2013) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2014) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2015)
]

df_Avg_Sample_2016 = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2016) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2017) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2018)
]

df_Avg_Sample_2019 = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2019) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2020) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2021)
]

grouped = df_Avg_Sample_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.size]))

grouped = df_Avg_Sample_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.size]))

grouped = df_Avg_Sample_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.size]))
# Out:
# There are seven Indicators to analysis,
#                                     size
# Indicators
# Average annual hours worked        14688
# Average annual wages and salaries  14688
# Average hourly wage                14688
# Average weekly hours worked        14688
# Hours worked                       14688
# Number of jobs                     14688
# Wages and salaries                 14688
#
# The data inside between 2010-2013, there's are # number of data and I will be repeating this seven more time.,
#           size
# REF_DATE
# 2010      1224
# 2011      1224
# 2012      1224
#
# To data inside above 2013 and split into three datasets, I need to repeat this analysis for 21 (7x3) times.
#
# This is also total of spliting into 21 datasets.
#           size
# REF_DATE
# 2013      1224
# 2014      1224
# 2015      1224
#           size
# REF_DATE
# 2016      1224
# 2017      1224
# 2018      1224
#           size
# REF_DATE
# 2019      1224
# 2020      1224
# 2021      1224

# %% [markdown]
# Grabbing the year (REF_DATE) from 2010, 2013, 2016, 2018, and 2019 individually for "Average annual hours worked".

# %%
# 2010-2012
df_AvgAnnHrsWrk_2010 = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2010) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2011) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2012)
]

grouped = df_AvgAnnHrsWrk_2010.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
#                 sum  size
# REF_DATE
# 2010      1905000.0  1224
# 2011      1909823.0  1224
# 2012      1915650.0  1224

# %%
print("Grabbing the data from 2013, 2016, and 2019.")

# 2013 - 2015
df_AvgAnnHrsWrk_2013 = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2013) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2014) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2015)
]

# 2016 - 2018
df_AvgAnnHrsWrk_2016 = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2016) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2017) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2018)
]

# 20109- 2021
df_AvgAnnHrsWrk_2019 = df_AvgAnnHrsWrk.loc[
    (df_AvgAnnHrsWrk['REF_DATE'] == 2019) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2020) |
    (df_AvgAnnHrsWrk['REF_DATE'] == 2021)
]

grouped = df_AvgAnnHrsWrk_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgAnnHrsWrk_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgAnnHrsWrk_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
# Grabbing the data from 2013, 2016, and 2019.
#                 sum  size
# REF_DATE
# 2013      1906851.0  1224
# 2014      1898034.0  1224
# 2015      1907286.0  1224
#                 sum  size
# REF_DATE
# 2016      1899738.0  1224
# 2017      1881389.0  1224
# 2018      1894227.0  1224
#                 sum  size
# REF_DATE
# 2019      1894126.0  1224
# 2020      1873544.0  1224
# 2021      1901826.0  1224

# %% [markdown]
# Panda Profiling for year 2016, 2018, and 2020 for "Average annual hours worked".

# %%
# 2016-2017
pp = ProfileReport(df_AvgAnnHrsWrk_2013, title="Average annual hours worked 2013")
pp_df = pp.to_html()

f = open("Average annual hours worked 2016.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

# 2017 - 2019
pp = ProfileReport(df_AvgAnnHrsWrk_2016, title="Average annual hours worked 2016")
pp_df = pp.to_html()

f = open("Average annual hours worked 2018.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

# 2020 - 2021
pp = ProfileReport(df_AvgAnnHrsWrk_2019, title="Average annual hours worked 2019")
pp_df = pp.to_html()

f = open("Average annual hours worked 2020.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:  23%|██▎       | 3/13 [00:00<00:00, 11.96it/s, Describe variable:UOM]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 14.43it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.61it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.59it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 14.17it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.28s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]

# %% [markdown]
# Grabbing the year (REF_DATE) from 2010, 2013, 2016, and 2019 individually for "Average annual wages and salaries".

# %%
# 2010 - 2012
df_AvgAnnWages_2010 = df_AvgAnnWages.loc[
    (df_AvgAnnWages['REF_DATE'] == 2010) |
    (df_AvgAnnWages['REF_DATE'] == 2011) |
    (df_AvgAnnWages['REF_DATE'] == 2012)
]

grouped = df_AvgAnnWages_2010.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
#                  sum  size
# REF_DATE
# 2010      48093832.0  1224
# 2011      49165720.0  1224
# 2012      50085622.0  1224

# %%
print("Grabbing the data from 2017, 2019, and 2021.")

# 2013 - 2015
df_AvgAnnWages_2013 = df_AvgAnnWages.loc[
    (df_AvgAnnWages['REF_DATE'] == 2013) |
    (df_AvgAnnWages['REF_DATE'] == 2014) |
    (df_AvgAnnWages['REF_DATE'] == 2015)
]

# 2016 - 2018
df_AvgAnnWages_2016 = df_AvgAnnWages.loc[
    (df_AvgAnnWages['REF_DATE'] == 2016) |
    (df_AvgAnnWages['REF_DATE'] == 2017) |
    (df_AvgAnnWages['REF_DATE'] == 2018)
]

# 2019 - 2021
df_AvgAnnWages_2019 = df_AvgAnnWages.loc[
    (df_AvgAnnWages['REF_DATE'] == 2019) |
    (df_AvgAnnWages['REF_DATE'] == 2020) |
    (df_AvgAnnWages['REF_DATE'] == 2021)
]

grouped = df_AvgAnnWages_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgAnnWages_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgAnnWages_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
# Grabbing the data from 2017, 2019, and 2021.
#                  sum  size
# REF_DATE
# 2013      50598135.0  1224
# 2014      51805889.0  1224
# 2015      52715143.0  1224
#                  sum  size
# REF_DATE
# 2016      53166285.0  1224
# 2017      53965359.0  1224
# 2018      55525920.0  1224
#                  sum  size
# REF_DATE
# 2019      56997121.0  1224
# 2020      60597775.0  1224
# 2021      60687848.0  1224

# %% [markdown]
# Panda Profiling for year 2013, 2016, and 2019 for "Average annual wages and salaries".

# %%
pp = ProfileReport(df_AvgAnnWages_2013, title="Average annual wages and salaries 2013")
pp_df = pp.to_html()

f = open("Average annual wages and salaries 2013.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_AvgAnnWages_2016, title="Average annual wages and salaries 2016")
pp_df = pp.to_html()

f = open("Average annual wages and salaries 2016.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_AvgAnnWages_2019, title="Average annual wages and salaries 2019")
pp_df = pp.to_html()

f = open("Average annual wages and salaries 2019.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:  23%|██▎       | 3/13 [00:00<00:00, 10.31it/s, Describe variable:Characteristics]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 14.75it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.50it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 13.16it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.90s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.52it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.44it/s]

# %% [markdown]
# Grabbing the year (REF_DATE) from 2010, 2013, 2016, and 2019 individually for "Average hourly wages".

# %%
# 2010 - 2012
df_AvgHrsWages_2010 = df_AvgHrsWages.loc[
    (df_AvgHrsWages['REF_DATE'] == 2010) |
    (df_AvgHrsWages['REF_DATE'] == 2011) |
    (df_AvgHrsWages['REF_DATE'] == 2012)
]

grouped = df_AvgHrsWages_2010.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
#                sum  size
# REF_DATE
# 2010      30453.20  1224
# 2011      31053.73  1224
# 2012      31511.37  1224

# %%
print("Grabbing the data from 2013, 2016, and 2019.")

# 2013 - 2015
df_AvgHrsWages_2013 = df_AvgHrsWages.loc[
    (df_AvgHrsWages['REF_DATE'] == 2013) |
    (df_AvgHrsWages['REF_DATE'] == 2014) |
    (df_AvgHrsWages['REF_DATE'] == 2015)
]

# 2016 - 2018
df_AvgHrsWages_2016 = df_AvgHrsWages.loc[
    (df_AvgHrsWages['REF_DATE'] == 2016) |
    (df_AvgHrsWages['REF_DATE'] == 2017) |
    (df_AvgHrsWages['REF_DATE'] == 2018)
]

# 2019 - 2021
df_AvgHrsWages_2019 = df_AvgHrsWages.loc[
    (df_AvgHrsWages['REF_DATE'] == 2019) |
    (df_AvgHrsWages['REF_DATE'] == 2020) |
    (df_AvgHrsWages['REF_DATE'] == 2021)
]

grouped = df_AvgHrsWages_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgHrsWages_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgHrsWages_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
# Grabbing the data from 2013, 2016, and 2019.
#                sum  size
# REF_DATE
# 2013      31932.19  1224
# 2014      32916.44  1224
# 2015      33362.79  1224
#                sum  size
# REF_DATE
# 2016      33756.84  1224
# 2017      34571.41  1224
# 2018      35356.16  1224
#                sum  size
# REF_DATE
# 2019      36293.34  1224
# 2020      38980.38  1224
# 2021      38514.73  1224

# %% [markdown]
# Panda Profiling for year 2013, 2016, and 2019 for "Average hourly wages".

# %%
pp = ProfileReport(df_AvgHrsWages_2013, title="Average hourly wage 2013")
pp_df = pp.to_html()

f = open("Average hourly wages 2013.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_AvgHrsWages_2016, title="Average hourly wage 2016")
pp_df = pp.to_html()

f = open("Average hourly wages 2016.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_AvgHrsWages_2019, title="Average hourly wage 2019")
pp_df = pp.to_html()

f = open("Average hourly wages 2019.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 14.87it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.24s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.09it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 17.37it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.26s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]

# %% [markdown]
# Grabbing the year (REF_DATE) from 2010, 2013, 2016, and 2019 individually for "Average weekly hours worked".

# %%
# 2010 - 2012
df_AvgWeekHrsWrked_2010 = df_AvgWeekHrsWrked.loc[
    (df_AvgWeekHrsWrked['REF_DATE'] == 2010) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2011) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2012)
]

grouped = df_AvgWeekHrsWrked_2010.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
#               sum  size
# REF_DATE
# 2010      36645.0  1224
# 2011      36732.0  1224
# 2012      36842.0  1224

# %%
print("Grabbing the data from 2013, 2016, and 2019.")

# 2013 - 2015
df_AvgWeekHrsWrked_2013 = df_AvgWeekHrsWrked.loc[
    (df_AvgWeekHrsWrked['REF_DATE'] == 2013) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2014) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2015)
]

# 2016 - 2018
df_AvgWeekHrsWrked_2016 = df_AvgWeekHrsWrked.loc[
    (df_AvgWeekHrsWrked['REF_DATE'] == 2016) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2017) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2018)
]

# 2019 - 2021
df_AvgWeekHrsWrked_2019 = df_AvgWeekHrsWrked.loc[
    (df_AvgWeekHrsWrked['REF_DATE'] == 2019) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2020) |
    (df_AvgWeekHrsWrked['REF_DATE'] == 2021)
]

grouped = df_AvgWeekHrsWrked_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgWeekHrsWrked_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_AvgWeekHrsWrked_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
# Grabbing the data from 2013, 2016, and 2019.
#               sum  size
# REF_DATE
# 2013      36671.0  1224
# 2014      36483.0  1224
# 2015      36678.0  1224
#               sum  size
# REF_DATE
# 2016      36541.0  1224
# 2017      36170.0  1224
# 2018      36416.0  1224
#               sum  size
# REF_DATE
# 2019      36400.0  1224
# 2020      36036.0  1224
# 2021      36555.0  1224

# %% [markdown]
# Panda Profiling for year 2013, 2016, and 2019 for "Average weekly hours worked".

# %%
pp = ProfileReport(df_AvgWeekHrsWrked_2013, title="Average weekly hours worked 2013")
pp_df = pp.to_html()

f = open("Average weekly hours worked 2013.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_AvgWeekHrsWrked_2016, title="Average weekly hours worked 2016")
pp_df = pp.to_html()

f = open("Average weekly hours worked 2016.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_AvgWeekHrsWrked_2019, title="Average weekly hours worked 2019")
pp_df = pp.to_html()

f = open("Average weekly hours worked 2019.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.52it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.93s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 15.84it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.00it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]

# %% [markdown]
# Grabbing the year (REF_DATE) from 2010, 2013, 2016, and 2019 individually for "hours worked".

# %%
# 2010 - 2012
df_Hrs_Wrked_2010 = df_Hrs_Wrked.loc[
    (df_Hrs_Wrked['REF_DATE'] == 2010) |
    (df_Hrs_Wrked['REF_DATE'] == 2011) |
    (df_Hrs_Wrked['REF_DATE'] == 2012)
]

grouped = df_Hrs_Wrked_2010.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
#                  sum  size
# REF_DATE
# 2010      94217881.0  1224
# 2011      95953248.0  1224
# 2012      97724232.0  1224

# %%
print("Grabbing the data from 2013, 2016, and 2019.")

# 2013 - 2015
df_Hrs_Wrked_2013 = df_Hrs_Wrked.loc[
    (df_Hrs_Wrked['REF_DATE'] == 2013) |
    (df_Hrs_Wrked['REF_DATE'] == 2014) |
    (df_Hrs_Wrked['REF_DATE'] == 2015)
]

# 2016 - 2018
df_Hrs_Wrked_2016 = df_Hrs_Wrked.loc[
    (df_Hrs_Wrked['REF_DATE'] == 2016) |
    (df_Hrs_Wrked['REF_DATE'] == 2017) |
    (df_Hrs_Wrked['REF_DATE'] == 2018)
]

# 2019 - 2021
df_Hrs_Wrked_2019 = df_Hrs_Wrked.loc[
    (df_Hrs_Wrked['REF_DATE'] == 2019) |
    (df_Hrs_Wrked['REF_DATE'] == 2020) |
    (df_Hrs_Wrked['REF_DATE'] == 2021)
]

grouped = df_Hrs_Wrked_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_Hrs_Wrked_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_Hrs_Wrked_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
# Grabbing the data from 2013, 2016, and 2019.
#                   sum  size
# REF_DATE
# 2013       98935086.0  1224
# 2014       99777902.0  1224
# 2015      101927894.0  1224
#                   sum  size
# REF_DATE
# 2016      103980992.0  1224
# 2017      103906357.0  1224
# 2018      106885614.0  1224
#                   sum  size
# REF_DATE
# 2019      108384508.0  1224
# 2020      103897606.0  1224
# 2021      112280627.0  1224

# %% [markdown]
# Panda Profiling for year 2013, 2016, and 2019 for "hours worked".

# %%
pp = ProfileReport(df_Hrs_Wrked_2013, title="Hours Worked 2013")
pp_df = pp.to_html()

f = open("Hours worked 2013.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_Hrs_Wrked_2016, title="Hours Worked 2016")
pp_df = pp.to_html()

f = open("Hours worked 2016.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_Hrs_Wrked_2019, title="Hours Worked 2019")
pp_df = pp.to_html()

f = open("Hours worked 2019.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:  23%|██▎       | 3/13 [00:00<00:00, 12.90it/s, Describe variable:UOM]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 13.73it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.34it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.29s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 15.06it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]

# %% [markdown]
# Grabbing the year (REF_DATE) from 2010, 2013, 2016, and 2019 individually for "Number of jobs".

# %%
# 2010 - 2012
df_NumOfJob_2010 = df_NumOfJob.loc[
    (df_NumOfJob['REF_DATE'] == 2010) |
    (df_NumOfJob['REF_DATE'] == 2011) |
    (df_NumOfJob['REF_DATE'] == 2012)
]

grouped = df_NumOfJob_2010.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
#                  sum  size
# REF_DATE
# 2010      59793067.0  1224
# 2011      61122016.0  1224
# 2012      61949430.0  1224

# %%
print("Grabbing the data from 2013, 2016, and 2019.")

# 2013 - 2015
df_NumOfJob_2013 = df_NumOfJob.loc[
    (df_NumOfJob['REF_DATE'] == 2013) |
    (df_NumOfJob['REF_DATE'] == 2014) |
    (df_NumOfJob['REF_DATE'] == 2015)
]

# 2016 - 2018
df_NumOfJob_2016 = df_NumOfJob.loc[
    (df_NumOfJob['REF_DATE'] == 2016) |
    (df_NumOfJob['REF_DATE'] == 2017) |
    (df_NumOfJob['REF_DATE'] == 2018)
]

# 2019 - 2021
df_NumOfJob_2019 = df_NumOfJob.loc[
    (df_NumOfJob['REF_DATE'] == 2019) |
    (df_NumOfJob['REF_DATE'] == 2020) |
    (df_NumOfJob['REF_DATE'] == 2021)
]

grouped = df_NumOfJob_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_NumOfJob_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_NumOfJob_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
# Grabbing the data from 2013, 2016, and 2019.
#                  sum  size
# REF_DATE
# 2013      63161481.0  1224
# 2014      63980381.0  1224
# 2015      65239031.0  1224
#                  sum  size
# REF_DATE
# 2016      66578386.0  1224
# 2017      66979678.0  1224
# 2018      68215341.0  1224
#                  sum  size
# REF_DATE
# 2019      69702012.0  1224
# 2020      67249987.0  1224
# 2021      70971515.0  1224

# %% [markdown]
# Panda Profiling for year 2013, 2016, and 2019for "Number of jobs".

# %%
pp = ProfileReport(df_NumOfJob_2013, title="Number of jobs 2013")
pp_df = pp.to_html()

f = open("Number of jobs 2013.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_NumOfJob_2016, title="Number of jobs 2016")
pp_df = pp.to_html()

f = open("Number of jobs 2016.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_NumOfJob_2019, title="Number of jobs 2019")
pp_df = pp.to_html()

f = open("Number of jobs 2019.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   8%|▊         | 1/13 [00:00<00:02,  5.62it/s, Describe variable:Sector]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 14.47it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.31s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.02it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.09it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.38s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.50it/s]

# %% [markdown]
# Grabbing the year (REF_DATE) from 2010, 2013, 2016, and 2019 individually for "Wages and Salaries".

# %%
# 2010 - 2012
df_WagesAndSalaries_2010 = df_WagesAndSalaries.loc[
    (df_WagesAndSalaries['REF_DATE'] == 2010) |
    (df_WagesAndSalaries['REF_DATE'] == 2011) |
    (df_WagesAndSalaries['REF_DATE'] == 2012)
]

grouped = df_WagesAndSalaries_2010.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
#                 sum  size
# REF_DATE
# 2010      2489681.0  1224
# 2011      2604921.0  1224
# 2012      2687510.0  1224

# %%
print("Grabbing the data from 2013, 2016, and 2019.")

# 2013 - 2015
df_WagesAndSalaries_2013 = df_WagesAndSalaries.loc[
    (df_WagesAndSalaries['REF_DATE'] == 2013) |
    (df_WagesAndSalaries['REF_DATE'] == 2014) |
    (df_WagesAndSalaries['REF_DATE'] == 2015)
]

# 2016 - 2018
df_WagesAndSalaries_2016 = df_WagesAndSalaries.loc[
    (df_WagesAndSalaries['REF_DATE'] == 2016) |
    (df_WagesAndSalaries['REF_DATE'] == 2017) |
    (df_WagesAndSalaries['REF_DATE'] == 2018)
]

# 2019 - 2021
df_WagesAndSalaries_2019 = df_WagesAndSalaries.loc[
    (df_WagesAndSalaries['REF_DATE'] == 2019) |
    (df_WagesAndSalaries['REF_DATE'] == 2020) |
    (df_WagesAndSalaries['REF_DATE'] == 2021)
]

grouped = df_WagesAndSalaries_2013.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_WagesAndSalaries_2016.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))

grouped = df_WagesAndSalaries_2019.groupby(['REF_DATE'])
print(grouped['VALUE'].agg([np.sum, np.size]))
# Out:
# Grabbing the data from 2013, 2016, and 2019.
#                 sum  size
# REF_DATE
# 2013      2746199.0  1224
# 2014      2844225.0  1224
# 2015      2965770.0  1224
#                 sum  size
# REF_DATE
# 2016      3043217.0  1224
# 2017      3118809.0  1224
# 2018      3263527.0  1224
#                 sum  size
# REF_DATE
# 2019      3437480.0  1224
# 2020      3532888.0  1224
# 2021      3764252.0  1224

# %% [markdown]
# Panda Profiling for year 2013, 2016, and 2019 for "Wages and Salaries".

# %%
pp = ProfileReport(df_WagesAndSalaries_2013, title="Wages and Salaries 2013")
pp_df = pp.to_html()

f = open("Wages and Salaries 2013.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_WagesAndSalaries_2016, title="Wages and Salaries 2016")
pp_df = pp.to_html()

f = open("Wages and Salaries 2016.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()

pp = ProfileReport(df_WagesAndSalaries_2019, title="Wages and Salaries 2019")
pp_df = pp.to_html()

f = open("Wages and Salaries 2019.html", "a")  # Expert into html file without modifying any columns in dataset.
f.write(pp_df)
f.close()
# Out:
# Summarize dataset:   8%|▊         | 1/13 [00:00<00:00, 13.02it/s, Describe variable:VALUE]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 14.22it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.46it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.79it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.27s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 17.76it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]

# %% [markdown]
# For next step, I will filtered it by the following group, "age group", "gender level", "education level", "immigrant level" and "Aboriginal status".
# * I have comment, analysis of whole dataset, 2010-2013 (originally, before 2016).
# * I have analysis two training and testing set. (2013-2015), (2016-2018), (2019-2021)
# * There's also other characteristics there as well but I decided to drop them as well.

# %% [markdown]
# Filtered for "Average annual hours worked" by following: "Age group", "Gender level", "Education level", and "Immigration status".<br />
# "Aboriginal status" has been commented.

# %%
# Dataset year in 2010 inside Average Annual Hours Worked

# print("\nAge group in Alberta")
# df_AvgAnnHrsWrk_2010_ByAge = df_AvgAnnHrsWrk_2010.loc[
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == '15 to 24 years') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == '25 to 34 years') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == '35 to 44 years') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == '45 to 54 years') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == '55 to 64 years') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == '65 years old and over')]
# # print(df_AvgAnnHrsWrk_2010_ByAge.head(20))
# grouped = df_AvgAnnHrsWrk_2010_ByAge.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("Total size : ",len(df_AvgAnnHrsWrk_2010_ByAge.index))

# print("\nGender group in Alberta")
# df_AvgAnnHrsWrk_2010_ByGender = df_AvgAnnHrsWrk_2010.loc[
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'Female employees') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'Male employees')
# ]
# # print(df_AvgAnnHrsWrk_2010_ByGender.head(20))
# grouped = df_AvgAnnHrsWrk_2010_ByGender.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("Total size : ",len(df_AvgAnnHrsWrk_2010_ByGender.index))

# print("\nEducation group in Alberta")
# df_AvgAnnHrsWrk_2010_ByEducation = df_AvgAnnHrsWrk_2010.loc[
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'High school diploma and less') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'Trade certificate') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'University degree and higher')
# ]
# # print(df_AvgAnnHrsWrk_2010_ByEducation.head(20))
# grouped = df_AvgAnnHrsWrk_2010_ByEducation.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("Total size : ",len(df_AvgAnnHrsWrk_2010_ByEducation.index))

# print("\nImmigrant group in Alberta")
# df_AvgAnnHrsWrk_2010_ByImmigrant = df_AvgAnnHrsWrk_2010.loc[
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'Immigrant employees') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'Non-immigrant employees')
# ]
# # print(df_AvgAnnHrsWrk_2010_ByImmigrant.head(20))
# grouped = df_AvgAnnHrsWrk_2010_ByImmigrant.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("Total size : ",len(df_AvgAnnHrsWrk_2010_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnHrkWrk_2010_ByIndigenous = df_AvgAnnHrsWrk_2010.loc[
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnHrsWrk_2010['Characteristics'] == 'Non-indigenous identity employees')
# ]
# print(df_AvgAnnHrkWrk_2010_ByIndigenous.head(20))
# # grouped = df_AvgAnnHrkWrk_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnHrkWrk_2010_ByIndigenous.index))

# %%
# Dataset year in 2013 inside Average Annual Hours Worked

print("\nAge group in Alberta")
df_AvgAnnHrsWrk_2013_ByAge = df_AvgAnnHrsWrk_2013.loc[
    (df_AvgAnnHrsWrk_2013['Characteristics'] == '15 to 24 years') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == '25 to 34 years') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == '35 to 44 years') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == '45 to 54 years') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == '55 to 64 years') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == '65 years old and over')]
# print(df_AvgAnnHrsWrk_2013_ByAge.head(20))
grouped = df_AvgAnnHrsWrk_2013_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2013_ByAge.index))

print("\nGender group in Alberta")
df_AvgAnnHrsWrk_2013_ByGender = df_AvgAnnHrsWrk_2013.loc[
    (df_AvgAnnHrsWrk_2013['Characteristics'] == 'Female employees') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == 'Male employees')
]
# print(df_AvgAnnHrsWrk_2013_ByGender.head(20))
grouped = df_AvgAnnHrsWrk_2013_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2013_ByGender.index))

print("\nEducation group in Alberta")
df_AvgAnnHrsWrk_2013_ByEducation = df_AvgAnnHrsWrk_2013.loc[
    (df_AvgAnnHrsWrk_2013['Characteristics'] == 'High school diploma and less') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == 'Trade certificate') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == 'University degree and higher')
]
# print(df_AvgAnnHrsWrk_2013_ByEducation.head(20))
grouped = df_AvgAnnHrsWrk_2013_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2013_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgAnnHrsWrk_2013_ByImmigrant = df_AvgAnnHrsWrk_2013.loc[
    (df_AvgAnnHrsWrk_2013['Characteristics'] == 'Immigrant employees') |
    (df_AvgAnnHrsWrk_2013['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgAnnHrsWrk_2013_ByImmigrant.head(20))
grouped = df_AvgAnnHrsWrk_2013_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2013_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnHrsWrk_2013_ByIndigenous = df_AvgAnnHrsWrk_2013.loc[
#     (df_AvgAnnHrsWrk_2013['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnHrsWrk_2013['Characteristics'] == 'Non-indigenous identity employees')
# ]
# print(df_AvgAnnHrsWrk_2013_ByIndigenous.head(20))
# # grouped = df_AvgAnnHrsWrk_2013_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnHrsWrk_2013_ByIndigenous.index))
# Out:
# Age group in Alberta
#                             sum  size
# Characteristics
# 15 to 24 years         172087.0   192
# 25 to 34 years         340647.0   210
# 35 to 44 years         377140.0   210
# 45 to 54 years         387957.0   210
# 55 to 64 years         352301.0   210
# 65 years old and over  207070.0   192
# Total size :  1224
#
# Gender group in Alberta
#                        sum  size
# Characteristics
# Female employees  322203.0   210
# Male employees    351902.0   210
# Total size :  420
#
# Education group in Alberta
#                                    sum  size
# Characteristics
# High school diploma and less  277682.0   210
# Trade certificate             313663.0   198
# University degree and higher  347222.0   198
# Total size :  606
#
# Immigrant group in Alberta
#                               sum  size
# Characteristics
# Immigrant employees      326890.0   198
# Non-immigrant employees  312119.0   198
# Total size :  396

# %%
# Dataset year in 2016 inside Average Annual Hours Worked

print("\nAge group in Alberta")
df_AvgAnnHrsWrk_2016_ByAge = df_AvgAnnHrsWrk_2016.loc[
    (df_AvgAnnHrsWrk_2016['Characteristics'] == '15 to 24 years') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == '25 to 34 years') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == '35 to 44 years') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == '45 to 54 years') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == '55 to 64 years') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == '65 years old and over')]
# print(df_AvgAnnHrsWrk_2016_ByAge.head(20))
grouped = df_AvgAnnHrsWrk_2016_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2016_ByAge.index))

print("\nGender group in Alberta")
df_AvgAnnHrsWrk_2016_ByGender = df_AvgAnnHrsWrk_2016.loc[
    (df_AvgAnnHrsWrk_2016['Characteristics'] == 'Female employees') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == 'Male employees')
]
# print(df_AvgAnnHrsWrk_2016_ByGender.head(20))
grouped = df_AvgAnnHrsWrk_2016_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2016_ByGender.index))

print("\nEducation group in Alberta")
df_AvgAnnHrsWrk_2016_ByEducation = df_AvgAnnHrsWrk_2016.loc[
    (df_AvgAnnHrsWrk_2016['Characteristics'] == 'High school diploma and less') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == 'Trade certificate') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == 'University degree and higher')
]
# print(df_AvgAnnHrsWrk_2016_ByEducation.head(20))
grouped = df_AvgAnnHrsWrk_2016_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2016_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgAnnHrsWrk_2016_ByImmigrant = df_AvgAnnHrsWrk_2016.loc[
    (df_AvgAnnHrsWrk_2016['Characteristics'] == 'Immigrant employees') |
    (df_AvgAnnHrsWrk_2016['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgAnnHrsWrk_2016_ByImmigrant.head(20))
grouped = df_AvgAnnHrsWrk_2016_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2016_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnHrsWrk_2016_ByIndigenous = df_AvgAnnHrsWrk_2016.loc[
#     (df_AvgAnnHrsWrk_2016['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnHrsWrk_2016['Characteristics'] == 'Non-indigenous identity employees')
# ]
# print(df_AvgAnnHrsWrk_2016_ByIndigenous.head(20))
# # grouped = df_AvgAnnHrsWrk_2016_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnHrsWrk_2016_ByIndigenous.index))
# Out:
# Age group in Alberta
#                             sum  size
# Characteristics
# 15 to 24 years         176153.0   192
# 25 to 34 years         337302.0   210
# 35 to 44 years         373702.0   210
# 45 to 54 years         385915.0   210
# 55 to 64 years         350828.0   210
# 65 years old and over  206428.0   192
# Total size :  1224
#
# Gender group in Alberta
#                        sum  size
# Characteristics
# Female employees  321687.0   210
# Male employees    346749.0   210
# Total size :  420
#
# Education group in Alberta
#                                    sum  size
# Characteristics
# High school diploma and less  276370.0   210
# Trade certificate             307989.0   198
# University degree and higher  343664.0   198
# Total size :  606
#
# Immigrant group in Alberta
#                               sum  size
# Characteristics
# Immigrant employees      321592.0   198
# Non-immigrant employees  310173.0   198
# Total size :  396

# %%
# Dataset year in 2019 inside Average Annual Hours Worked

print("\nAge group in Alberta")
df_AvgAnnHrsWrk_2019_ByAge = df_AvgAnnHrsWrk_2019.loc[
    (df_AvgAnnHrsWrk_2019['Characteristics'] == '15 to 24 years') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == '25 to 34 years') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == '35 to 44 years') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == '45 to 54 years') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == '55 to 64 years') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == '65 years old and over')]
# print(df_AvgAnnHrsWrk_2019_ByAge.head(20))
grouped = df_AvgAnnHrsWrk_2019_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2019_ByAge.index))

print("\nGender group in Alberta")
df_AvgAnnHrsWrk_2019_ByGender = df_AvgAnnHrsWrk_2019.loc[
    (df_AvgAnnHrsWrk_2019['Characteristics'] == 'Female employees') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == 'Male employees')
]
# print(df_AvgAnnHrsWrk_2019_ByGender.head(20))
grouped = df_AvgAnnHrsWrk_2019_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2019_ByGender.index))

print("\nEducation group in Alberta")
df_AvgAnnHrsWrk_2019_ByEducation = df_AvgAnnHrsWrk_2019.loc[
    (df_AvgAnnHrsWrk_2019['Characteristics'] == 'High school diploma and less') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == 'Trade certificate') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == 'University degree and higher')
]
# print(df_AvgAnnHrsWrk_2019_ByEducation.head(20))
grouped = df_AvgAnnHrsWrk_2019_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2019_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgAnnHrsWrk_2019_ByImmigrant = df_AvgAnnHrsWrk_2019.loc[
    (df_AvgAnnHrsWrk_2019['Characteristics'] == 'Immigrant employees') |
    (df_AvgAnnHrsWrk_2019['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgAnnHrsWrk_2019_ByImmigrant.head(20))
grouped = df_AvgAnnHrsWrk_2019_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("Total size : ",len(df_AvgAnnHrsWrk_2019_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnHrsWrk_2019_ByIndigenous = df_AvgAnnHrsWrk_2019.loc[
#     (df_AvgAnnHrsWrk_2019['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnHrsWrk_2019['Characteristics'] == 'Non-indigenous identity employees')
# ]
# print(df_AvgAnnHrsWrk_2019_ByIndigenous.head(20))
# # grouped = df_AvgAnnHrkWrk_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnHrsWrk_2019_ByIndigenous.index))
# Out:
# Age group in Alberta
#                             sum  size
# Characteristics
# 15 to 24 years         179872.0   192
# 25 to 34 years         333662.0   210
# 35 to 44 years         371386.0   210
# 45 to 54 years         384987.0   210
# 55 to 64 years         351843.0   210
# 65 years old and over  206760.0   192
# Total size :  1224
#
# Gender group in Alberta
#                        sum  size
# Characteristics
# Female employees  323755.0   210
# Male employees    343101.0   210
# Total size :  420
#
# Education group in Alberta
#                                    sum  size
# Characteristics
# High school diploma and less  275636.0   210
# Trade certificate             306174.0   198
# University degree and higher  341795.0   198
# Total size :  606
#
# Immigrant group in Alberta
#                               sum  size
# Characteristics
# Immigrant employees      318818.0   198
# Non-immigrant employees  310245.0   198
# Total size :  396

# %% [markdown]
# Filtered for "Average annual wages and salaries" by following: "Age group", "Gender level", "Education level", and "Immigration status".<br />
# "Aboriginal status" has been commented.

# %%
# # Dataset year in 2010 inside Average annual wages and salaries

# print("\nAge group in Alberta")
# df_AvgAnnWages_2010_ByAge = df_AvgAnnWages_2010.loc[
#     (df_AvgAnnWages_2010['Characteristics'] == '15 to 24 years') |
#     (df_AvgAnnWages_2010['Characteristics'] == '25 to 34 years') |
#     (df_AvgAnnWages_2010['Characteristics'] == '35 to 44 years') |
#     (df_AvgAnnWages_2010['Characteristics'] == '45 to 54 years') |
#     (df_AvgAnnWages_2010['Characteristics'] == '55 to 64 years') |
#     (df_AvgAnnWages_2010['Characteristics'] == '65 years old and over')]
# # print(df_AvgAnnWages_2010_ByAge.head(20))
# grouped = df_AvgAnnWages_2010_ByAge.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2010_ByAge.index))

# print("\nGender group in Alberta")
# df_AvgAnnWages_2010_ByGender = df_AvgAnnWages_2010.loc[
#     (df_AvgAnnWages_2010['Characteristics'] == 'Female employees') |
#     (df_AvgAnnWages_2010['Characteristics'] == 'Male employees')
# ]
# # print(df_AvgAnnWages_2010_ByGender.head(20))
# grouped = df_AvgAnnWages_2010_ByGender.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2010_ByGender.index))

# print("\nEducation group in Alberta")
# df_AvgAnnWages_2010_ByEducation = df_AvgAnnWages_2010.loc[
#     (df_AvgAnnWages_2010['Characteristics'] == 'High school diploma and less') |
#     (df_AvgAnnWages_2010['Characteristics'] == 'Trade certificate') |
#     (df_AvgAnnWages_2010['Characteristics'] == 'University degree and higher')
# ]
# # print(df_AvgAnnWages_2010_ByEducation.head(20))
# grouped = df_AvgAnnWages_2010_ByEducation.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2010_ByEducation.index))

# print("\nImmigrant group in Alberta")
# df_AvgAnnWages_2010_ByImmigrant = df_AvgAnnWages_2010.loc[
#     (df_AvgAnnWages_2010['Characteristics'] == 'Immigrant employees') |
#     (df_AvgAnnWages_2010['Characteristics'] == 'Non-immigrant employees')
# ]
# # print(df_AvgAnnWages_2010_ByImmigrant.head(20))
# grouped = df_AvgAnnWages_2010_ByImmigrant.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2010_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnWages_2010_ByIndigenous = df_AvgAnnWages_2010.loc[
#     (df_AvgAnnWages_2010['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnWages_2010['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgAnnHrk_ByIndigenous.head(20))
# grouped = df_AvgAnnWages_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2010_ByIndigenous.index))

# %%
# Dataset year in 2013 inside Average annual wages and salaries

print("\nAge group in Alberta")
df_AvgAnnWages_2013_ByAge = df_AvgAnnWages_2013.loc[
    (df_AvgAnnWages_2013['Characteristics'] == '15 to 24 years') |
    (df_AvgAnnWages_2013['Characteristics'] == '25 to 34 years') |
    (df_AvgAnnWages_2013['Characteristics'] == '35 to 44 years') |
    (df_AvgAnnWages_2013['Characteristics'] == '45 to 54 years') |
    (df_AvgAnnWages_2013['Characteristics'] == '55 to 64 years') |
    (df_AvgAnnWages_2013['Characteristics'] == '65 years old and over')]
# print(df_AvgAnnWages_2013_ByAge.head(20))
grouped = df_AvgAnnWages_2013_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2013_ByAge.index))

print("\nGender group in Alberta")
df_AvgAnnWages_2013_ByGender = df_AvgAnnWages_2013.loc[
    (df_AvgAnnWages_2013['Characteristics'] == 'Female employees') |
    (df_AvgAnnWages_2013['Characteristics'] == 'Male employees')
]
# print(df_AvgAnnWages_2013_ByGender.head(20))
grouped = df_AvgAnnWages_2013_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2013_ByGender.index))

print("\nEducation group in Alberta")
df_AvgAnnWages_2013_ByEducation = df_AvgAnnWages_2013.loc[
    (df_AvgAnnWages_2013['Characteristics'] == 'High school diploma and less') |
    (df_AvgAnnWages_2013['Characteristics'] == 'Trade certificate') |
    (df_AvgAnnWages_2013['Characteristics'] == 'University degree and higher')
]
# print(df_AvgAnnWages_2013_ByEducation.head(20))
grouped = df_AvgAnnWages_2013_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2013_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgAnnWages_2013_ByImmigrant = df_AvgAnnWages_2013.loc[
    (df_AvgAnnWages_2013['Characteristics'] == 'Immigrant employees') |
    (df_AvgAnnWages_2013['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgAnnWages_2013_ByImmigrant.head(20))
grouped = df_AvgAnnWages_2013_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2013_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnWages_2013_ByIndigenous = df_AvgAnnWages_2013.loc[
#     (df_AvgAnnWages_2013['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnWages_2013['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgAnnHrk_ByIndigenous.head(20))
# grouped = df_AvgAnnWages_2013_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2013_ByIndigenous.index))
# Out:
# Age group in Alberta
#                               sum  size
# Characteristics
# 15 to 24 years          2784616.0   192
# 25 to 34 years          7953813.0   210
# 35 to 44 years         10794086.0   210
# 45 to 54 years         11596540.0   210
# 55 to 64 years         11087673.0   210
# 65 years old and over   5949938.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees   8352873.0   210
# Male employees    10560729.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   5903675.0   210
# Trade certificate              7603798.0   198
# University degree and higher  11213834.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                sum  size
# Characteristics
# Immigrant employees      8818758.0   198
# Non-immigrant employees  8495409.0   198
# The total number of this one is  396

# %%
# Dataset year in 2016 inside Average annual wages and salaries

print("\nAge group in Alberta")
df_AvgAnnWages_2016_ByAge = df_AvgAnnWages_2016.loc[
    (df_AvgAnnWages_2016['Characteristics'] == '15 to 24 years') |
    (df_AvgAnnWages_2016['Characteristics'] == '25 to 34 years') |
    (df_AvgAnnWages_2016['Characteristics'] == '35 to 44 years') |
    (df_AvgAnnWages_2016['Characteristics'] == '45 to 54 years') |
    (df_AvgAnnWages_2016['Characteristics'] == '55 to 64 years') |
    (df_AvgAnnWages_2016['Characteristics'] == '65 years old and over')]
# print(df_AvgAnnWages_2016_ByAge.head(20))
grouped = df_AvgAnnWages_2016_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2016_ByAge.index))

print("\nGender group in Alberta")
df_AvgAnnWages_2016_ByGender = df_AvgAnnWages_2016.loc[
    (df_AvgAnnWages_2016['Characteristics'] == 'Female employees') |
    (df_AvgAnnWages_2016['Characteristics'] == 'Male employees')
]
# print(df_AvgAnnWages_2016_ByGender.head(20))
grouped = df_AvgAnnWages_2016_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2016_ByGender.index))

print("\nEducation group in Alberta")
df_AvgAnnWages_2016_ByEducation = df_AvgAnnWages_2016.loc[
    (df_AvgAnnWages_2016['Characteristics'] == 'High school diploma and less') |
    (df_AvgAnnWages_2016['Characteristics'] == 'Trade certificate') |
    (df_AvgAnnWages_2016['Characteristics'] == 'University degree and higher')
]
# print(df_AvgAnnWages_2016_ByEducation.head(20))
grouped = df_AvgAnnWages_2016_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2016_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgAnnWages_2016_ByImmigrant = df_AvgAnnWages_2016.loc[
    (df_AvgAnnWages_2016['Characteristics'] == 'Immigrant employees') |
    (df_AvgAnnWages_2016['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgAnnWages_2016_ByImmigrant.head(20))
grouped = df_AvgAnnWages_2016_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2016_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnWages_2016_ByIndigenous = df_AvgAnnWages_2016.loc[
#     (df_AvgAnnWages_2016['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnWages_2016['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgAnnHrk_ByIndigenous.head(20))
# grouped = df_AvgAnnWages_2016_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2016_ByIndigenous.index))
# Out:
# Age group in Alberta
#                               sum  size
# Characteristics
# 15 to 24 years          3060129.0   192
# 25 to 34 years          8325679.0   210
# 35 to 44 years         11269609.0   210
# 45 to 54 years         12276948.0   210
# 55 to 64 years         11610535.0   210
# 65 years old and over   6249361.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees   8890302.0   210
# Male employees    10887008.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   6237814.0   210
# Trade certificate              7881695.0   198
# University degree and higher  11672583.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                sum  size
# Characteristics
# Immigrant employees      9093448.0   198
# Non-immigrant employees  8954165.0   198
# The total number of this one is  396

# %%
# Dataset year in 2019 inside Average annual wages and salaries

print("\nAge group in Alberta")
df_AvgAnnWages_2019_ByAge = df_AvgAnnWages_2019.loc[
    (df_AvgAnnWages_2019['Characteristics'] == '15 to 24 years') |
    (df_AvgAnnWages_2019['Characteristics'] == '25 to 34 years') |
    (df_AvgAnnWages_2019['Characteristics'] == '35 to 44 years') |
    (df_AvgAnnWages_2019['Characteristics'] == '45 to 54 years') |
    (df_AvgAnnWages_2019['Characteristics'] == '55 to 64 years') |
    (df_AvgAnnWages_2019['Characteristics'] == '65 years old and over')]
# print(df_AvgAnnWages_2019_ByAge.head(20))
grouped = df_AvgAnnWages_2019_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2019_ByAge.index))

print("\nGender group in Alberta")
df_AvgAnnWages_2019_ByGender = df_AvgAnnWages_2019.loc[
    (df_AvgAnnWages_2019['Characteristics'] == 'Female employees') |
    (df_AvgAnnWages_2019['Characteristics'] == 'Male employees')
]
# print(df_AvgAnnWages_2019_ByGender.head(20))
grouped = df_AvgAnnWages_2019_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2019_ByGender.index))

print("\nEducation group in Alberta")
df_AvgAnnWages_2019_ByEducation = df_AvgAnnWages_2019.loc[
    (df_AvgAnnWages_2019['Characteristics'] == 'High school diploma and less') |
    (df_AvgAnnWages_2019['Characteristics'] == 'Trade certificate') |
    (df_AvgAnnWages_2019['Characteristics'] == 'University degree and higher')
]
# print(df_AvgAnnWages_2019_ByEducation.head(20))
grouped = df_AvgAnnWages_2019_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2019_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgAnnWages_2019_ByImmigrant = df_AvgAnnWages_2019.loc[
    (df_AvgAnnWages_2019['Characteristics'] == 'Immigrant employees') |
    (df_AvgAnnWages_2019['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgAnnWages_2019_ByImmigrant.head(20))
grouped = df_AvgAnnWages_2019_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgAnnWages_2019_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnWages_2019_ByIndigenous = df_AvgAnnWages_2019.loc[
#     (df_AvgAnnWages_2019['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgAnnWages_2019['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgAnnHrk_ByIndigenous.head(20))
# grouped = df_AvgAnnWages_2019_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnWages_2019_ByIndigenous.index))
# Out:
# Age group in Alberta
#                               sum  size
# Characteristics
# 15 to 24 years          3482308.0   192
# 25 to 34 years          9108041.0   210
# 35 to 44 years         12296655.0   210
# 45 to 54 years         13595377.0   210
# 55 to 64 years         12592232.0   210
# 65 years old and over   6840988.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees   9929829.0   210
# Male employees    11755264.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   6915927.0   210
# Trade certificate              8609637.0   198
# University degree and higher  12581443.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                sum  size
# Characteristics
# Immigrant employees      9838690.0   198
# Non-immigrant employees  9799014.0   198
# The total number of this one is  396

# %% [markdown]
# Filtered for "Average hourly wage" by following: "Age group", "Gender level", "Education level", and "Immigration status". <br />
# "Aboriginal status" has been commented.

# %%
# # Dataset year of 2010 inside "Average hourly wage"

# print("\nAge group in Alberta")
# df_AvgHrsWages_2010_ByAge = df_AvgHrsWages_2010.loc[
#     (df_AvgHrsWages_2010['Characteristics'] == '15 to 24 years') |
#     (df_AvgHrsWages_2010['Characteristics'] == '25 to 34 years') |
#     (df_AvgHrsWages_2010['Characteristics'] == '35 to 44 years') |
#     (df_AvgHrsWages_2010['Characteristics'] == '45 to 54 years') |
#     (df_AvgHrsWages_2010['Characteristics'] == '55 to 64 years') |
#     (df_AvgHrsWages_2010['Characteristics'] == '65 years old and over')]
# # print(df_AvgHrsWages_2010_ByAge.head(20))
# grouped = df_AvgHrsWages_2010_ByAge.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgHrsWages_2010_ByAge.index))

# print("\nGender group in Alberta")
# df_AvgHrsWages_2010_ByGender = df_AvgHrsWages_2010.loc[
#     (df_AvgHrsWages_2010['Characteristics'] == 'Female employees') |
#     (df_AvgHrsWages_2010['Characteristics'] == 'Male employees')
# ]
# # print(df_AvgHrsWages_2010_ByGender.head(20))
# grouped = df_AvgHrsWages_2010_ByGender.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgHrsWages_2010_ByGender.index))

# print("\nEducation group in Alberta")
# df_AvgHrsWages_2010_ByEducation = df_AvgHrsWages_2010.loc[
#     (df_AvgHrsWages_2010['Characteristics'] == 'High school diploma and less') |
#     (df_AvgHrsWages_2010['Characteristics'] == 'Trade certificate') |
#     (df_AvgHrsWages_2010['Characteristics'] == 'University degree and higher')
# ]
# # print(df_AvgHrsWages_2010_ByEducation.head(20))
# grouped = df_AvgHrsWages_2010_ByEducation.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgHrsWages_2010_ByEducation.index))

# print("\nImmigrant group in Alberta")
# df_AvgHrsWages_2010_ByImmigrant = df_AvgHrsWages_2010.loc[
#     (df_AvgHrsWages_2010['Characteristics'] == 'Immigrant employees') |
#     (df_AvgHrsWages_2010['Characteristics'] == 'Non-immigrant employees')
# ]
# # print(df_AvgHrsWages_2010_ByImmigrant.head(20))
# grouped = df_AvgHrsWages_2010_ByImmigrant.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgHrsWages_2010_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgHrsWages_2010_ByIndigenous = df_AvgHrsWages_2010.loc[
#     (df_AvgHrsWages_2010['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgHrsWages_2010['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgHrsWages_2010_ByIndigenous.head(20))
# grouped = df_AvgHrsWages_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgHrsWages_2010_ByIndigenous.index))

# %%
# Dataset year of 2013 inside "Average hourly wage"

print("\nAge group in Alberta")
df_AvgHrsWages_2013_ByAge = df_AvgHrsWages_2013.loc[
    (df_AvgHrsWages_2013['Characteristics'] == '15 to 24 years') |
    (df_AvgHrsWages_2013['Characteristics'] == '25 to 34 years') |
    (df_AvgHrsWages_2013['Characteristics'] == '35 to 44 years') |
    (df_AvgHrsWages_2013['Characteristics'] == '45 to 54 years') |
    (df_AvgHrsWages_2013['Characteristics'] == '55 to 64 years') |
    (df_AvgHrsWages_2013['Characteristics'] == '65 years old and over')]
# print(df_AvgHrsWages_2013_ByAge.head(20))
grouped = df_AvgHrsWages_2013_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2013_ByAge.index))

print("\nGender group in Alberta")
df_AvgHrsWages_2013_ByGender = df_AvgHrsWages_2013.loc[
    (df_AvgHrsWages_2013['Characteristics'] == 'Female employees') |
    (df_AvgHrsWages_2013['Characteristics'] == 'Male employees')
]
# print(df_AvgHrsWages_2013_ByGender.head(20))
grouped = df_AvgHrsWages_2013_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2013_ByGender.index))

print("\nEducation group in Alberta")
df_AvgHrsWages_2013_ByEducation = df_AvgHrsWages_2013.loc[
    (df_AvgHrsWages_2013['Characteristics'] == 'High school diploma and less') |
    (df_AvgHrsWages_2013['Characteristics'] == 'Trade certificate') |
    (df_AvgHrsWages_2013['Characteristics'] == 'University degree and higher')
]
# print(df_AvgHrsWages_2013_ByEducation.head(20))
grouped = df_AvgHrsWages_2013_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2013_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgHrsWages_2013_ByImmigrant = df_AvgHrsWages_2013.loc[
    (df_AvgHrsWages_2013['Characteristics'] == 'Immigrant employees') |
    (df_AvgHrsWages_2013['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgHrsWages_2013_ByImmigrant.head(20))
grouped = df_AvgHrsWages_2013_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2013_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgHrsWages_2013_ByIndigenous = df_AvgHrsWages_2013.loc[
#     (df_AvgHrsWages_2013['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgHrsWages_2013['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgHrsWages_2013_ByIndigenous.head(20))
# grouped = df_AvgHrsWages_2013_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgHrsWages_2013_ByIndigenous.index))
# Out:
# Age group in Alberta
#                            sum  size
# Characteristics
# 15 to 24 years         3089.01   192
# 25 to 34 years         4937.02   210
# 35 to 44 years         6053.85   210
# 45 to 54 years         6297.06   210
# 55 to 64 years         6605.48   210
# 65 years old and over  5475.51   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                       sum  size
# Characteristics
# Female employees  5447.57   210
# Male employees    6321.74   210
# The total number of this one is  420
#
# Education group in Alberta
#                                   sum  size
# Characteristics
# High school diploma and less  4434.80   210
# Trade certificate             4774.81   198
# University degree and higher  6415.25   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                              sum  size
# Characteristics
# Immigrant employees      5306.29   198
# Non-immigrant employees  5402.47   198
# The total number of this one is  396

# %%
# Dataset year in 2017 inside "Average hourly wage"

print("\nAge group in Alberta")
df_AvgHrsWages_2016_ByAge = df_AvgHrsWages_2016.loc[
    (df_AvgHrsWages_2016['Characteristics'] == '15 to 24 years') |
    (df_AvgHrsWages_2016['Characteristics'] == '25 to 34 years') |
    (df_AvgHrsWages_2016['Characteristics'] == '35 to 44 years') |
    (df_AvgHrsWages_2016['Characteristics'] == '45 to 54 years') |
    (df_AvgHrsWages_2016['Characteristics'] == '55 to 64 years') |
    (df_AvgHrsWages_2016['Characteristics'] == '65 years old and over')]
# print(df_AvgHrsWages_2016_ByAge.head(20))
grouped = df_AvgHrsWages_2016_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2016_ByAge.index))

print("\nGender group in Alberta")
df_AvgHrsWages_2016_ByGender = df_AvgHrsWages_2016.loc[
    (df_AvgHrsWages_2016['Characteristics'] == 'Female employees') |
    (df_AvgHrsWages_2016['Characteristics'] == 'Male employees')
]
# print(df_AvgHrsWages_2016_ByGender.head(20))
grouped = df_AvgHrsWages_2016_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2016_ByGender.index))

print("\nEducation group in Alberta")
df_AvgHrsWages_2016_ByEducation = df_AvgHrsWages_2016.loc[
    (df_AvgHrsWages_2016['Characteristics'] == 'High school diploma and less') |
    (df_AvgHrsWages_2016['Characteristics'] == 'Trade certificate') |
    (df_AvgHrsWages_2016['Characteristics'] == 'University degree and higher')
]
# print(df_AvgHrsWages_2016_ByEducation.head(20))
grouped = df_AvgHrsWages_2016_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2016_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgHrsWages_2016_ByImmigrant = df_AvgHrsWages_2016.loc[
    (df_AvgHrsWages_2016['Characteristics'] == 'Immigrant employees') |
    (df_AvgHrsWages_2016['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgHrsWages_2016_ByImmigrant.head(20))
grouped = df_AvgHrsWages_2016_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2016_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgAnnHrk_ByIndigenous = df_AvgHrsWages_2016.loc[
#     (df_AvgHrsWages_2016['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgHrsWages_2016['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgAnnHrk_ByIndigenous.head(20))
# grouped = df_AvgAnnHrk_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgAnnHrk_ByIndigenous.index))
# Out:
# Age group in Alberta
#                            sum  size
# Characteristics
# 15 to 24 years         3305.36   192
# 25 to 34 years         5214.72   210
# 35 to 44 years         6375.48   210
# 45 to 54 years         6704.45   210
# 55 to 64 years         6934.64   210
# 65 years old and over  5778.32   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                       sum  size
# Characteristics
# Female employees  5805.97   210
# Male employees    6607.99   210
# The total number of this one is  420
#
# Education group in Alberta
#                                   sum  size
# Characteristics
# High school diploma and less  4707.09   210
# Trade certificate             5053.86   198
# University degree and higher  6739.74   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                              sum  size
# Characteristics
# Immigrant employees      5560.78   198
# Non-immigrant employees  5726.37   198
# The total number of this one is  396

# %%
# Dataset year in 2019 inside "Average hourly wage"

print("\nAge group in Alberta")
df_AvgHrsWages_2019_ByAge = df_AvgHrsWages_2019.loc[
    (df_AvgHrsWages_2019['Characteristics'] == '15 to 24 years') |
    (df_AvgHrsWages_2019['Characteristics'] == '25 to 34 years') |
    (df_AvgHrsWages_2019['Characteristics'] == '35 to 44 years') |
    (df_AvgHrsWages_2019['Characteristics'] == '45 to 54 years') |
    (df_AvgHrsWages_2019['Characteristics'] == '55 to 64 years') |
    (df_AvgHrsWages_2019['Characteristics'] == '65 years old and over')]
# print(df_AvgHrsWages_2019_ByAge.head(20))
grouped = df_AvgHrsWages_2019_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2019_ByAge.index))

print("\nGender group in Alberta")
df_AvgHrsWages_2019_ByGender = df_AvgHrsWages_2019.loc[
    (df_AvgHrsWages_2019['Characteristics'] == 'Female employees') |
    (df_AvgHrsWages_2019['Characteristics'] == 'Male employees')
]
# print(df_AvgHrsWages_2019_ByGender.head(20))
grouped = df_AvgHrsWages_2019_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2019_ByGender.index))

print("\nEducation group in Alberta")
df_AvgHrsWages_2019_ByEducation = df_AvgHrsWages_2019.loc[
    (df_AvgHrsWages_2019['Characteristics'] == 'High school diploma and less') |
    (df_AvgHrsWages_2019['Characteristics'] == 'Trade certificate') |
    (df_AvgHrsWages_2019['Characteristics'] == 'University degree and higher')
]
# print(df_AvgHrsWages_2019_ByEducation.head(20))
grouped = df_AvgHrsWages_2019_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2019_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgHrsWages_2019_ByImmigrant = df_AvgHrsWages_2019.loc[
    (df_AvgHrsWages_2019['Characteristics'] == 'Immigrant employees') |
    (df_AvgHrsWages_2019['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgHrsWages_2019_ByImmigrant.head(20))
grouped = df_AvgHrsWages_2019_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgHrsWages_2019_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgHrsWages_2019_ByIndigenous = df_AvgHrsWages_2019.loc[
#     (df_AvgHrsWages_2019['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgHrsWages_2019['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgHrsWages_2019_ByIndigenous.head(20))
# grouped = df_AvgHrsWages_2019_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgHrsWages_2019_ByIndigenous.index))
# Out:
# Age group in Alberta
#                            sum  size
# Characteristics
# 15 to 24 years         3689.12   192
# 25 to 34 years         5759.41   210
# 35 to 44 years         6991.24   210
# 45 to 54 years         7451.95   210
# 55 to 64 years         7475.92   210
# 65 years old and over  6329.58   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                       sum  size
# Characteristics
# Female employees  6439.32   210
# Male employees    7203.15   210
# The total number of this one is  420
#
# Education group in Alberta
#                                   sum  size
# Characteristics
# High school diploma and less  5242.44   210
# Trade certificate             5569.30   198
# University degree and higher  7296.08   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                              sum  size
# Characteristics
# Immigrant employees      6065.65   198
# Non-immigrant employees  6267.15   198
# The total number of this one is  396

# %% [markdown]
# Filtered for "Average weekly hours worked" by following: "Age group", "Gender level", "Education level", and "Immigration status".<br />
# "Aboriginal status" has been commented.

# %%
# # Dataset year in 2010 inside "Average weekly hours worked"

# print("\nAge group in Alberta")
# df_AvgWeekHrsWrked_2010_ByAge = df_AvgWeekHrsWrked_2010.loc[
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == '15 to 24 years') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == '25 to 34 years') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == '35 to 44 years') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == '45 to 54 years') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == '55 to 64 years') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == '65 years old and over')]
# # print(df_AvgWeekHrsWrked_2010_ByAge.head(20))
# grouped = df_AvgWeekHrsWrked_2010_ByAge.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2010_ByAge.index))

# print("\nGender group in Alberta")
# df_AvgWeekHrsWrked_2010_ByGender = df_AvgWeekHrsWrked_2010.loc[
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'Female employees') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'Male employees')
# ]
# # print(df_AvgWeekHrsWrked_2010_ByGender.head(20))
# grouped = df_AvgWeekHrsWrked_2010_ByGender.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2010_ByGender.index))

# print("\nEducation group in Alberta")
# df_AvgWeekHrsWrked_2010_ByEducation = df_AvgWeekHrsWrked_2010.loc[
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'High school diploma and less') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'Trade certificate') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'University degree and higher')
# ]
# # print(df_AvgWeekHrsWrked_2010_ByEducation.head(20))
# grouped = df_AvgWeekHrsWrked_2010_ByEducation.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2010_ByEducation.index))

# print("\nImmigrant group in Alberta")
# df_AvgWeekHrsWrked_2010_ByImmigrant = df_AvgWeekHrsWrked_2010.loc[
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'Immigrant employees') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'Non-immigrant employees')
# ]
# # print(df_AvgWeekHrsWrked_2010_ByImmigrant.head(20))
# grouped = df_AvgWeekHrsWrked_2010_ByImmigrant.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2010_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgWeekHrsWrked_2010_ByIndigenous = df_AvgWeekHrsWrked_2010.loc[
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgWeekHrsWrked_2010['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgWeekHrsWrked_2010_ByIndigenous.head(20))
# grouped = df_AvgWeekHrsWrked_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2010_ByIndigenous.index))

# %%
# Dataset year in 2013 inside "Average weekly hours worked"

print("\nAge group in Alberta")
df_AvgWeekHrsWrked_2013_ByAge = df_AvgWeekHrsWrked_2013.loc[
    (df_AvgWeekHrsWrked_2013['Characteristics'] == '15 to 24 years') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == '25 to 34 years') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == '35 to 44 years') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == '45 to 54 years') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == '55 to 64 years') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == '65 years old and over')]
# print(df_AvgWeekHrsWrked_2013_ByAge.head(20))
grouped = df_AvgWeekHrsWrked_2013_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2013_ByAge.index))

print("\nGender group in Alberta")
df_AvgWeekHrsWrked_2013_ByGender = df_AvgWeekHrsWrked_2013.loc[
    (df_AvgWeekHrsWrked_2013['Characteristics'] == 'Female employees') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == 'Male employees')
]
# print(df_AvgWeekHrsWrked_2013_ByGender.head(20))
grouped = df_AvgWeekHrsWrked_2013_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2013_ByGender.index))

print("\nEducation group in Alberta")
df_AvgWeekHrsWrked_2013_ByEducation = df_AvgWeekHrsWrked_2013.loc[
    (df_AvgWeekHrsWrked_2013['Characteristics'] == 'High school diploma and less') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == 'Trade certificate') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == 'University degree and higher')
]
# print(df_AvgWeekHrsWrked_2013_ByEducation.head(20))
grouped = df_AvgWeekHrsWrked_2013_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2013_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgWeekHrsWrked_2013_ByImmigrant = df_AvgWeekHrsWrked_2013.loc[
    (df_AvgWeekHrsWrked_2013['Characteristics'] == 'Immigrant employees') |
    (df_AvgWeekHrsWrked_2013['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgWeekHrsWrked_2013_ByImmigrant.head(20))
grouped = df_AvgWeekHrsWrked_2013_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2013_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgWeekHrsWrked_2013_ByIndigenous = df_AvgWeekHrsWrked_2013.loc[
#     (df_AvgWeekHrsWrked_2013['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgWeekHrsWrked_2013['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgWeekHrsWrked_2013_ByIndigenous.head(20))
# grouped = df_AvgWeekHrsWrked_2013_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2013_ByIndigenous.index))
# Out:
# Age group in Alberta
#                           sum  size
# Characteristics
# 15 to 24 years         3314.0   192
# 25 to 34 years         6556.0   210
# 35 to 44 years         7256.0   210
# 45 to 54 years         7454.0   210
# 55 to 64 years         6780.0   210
# 65 years old and over  3983.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                      sum  size
# Characteristics
# Female employees  6196.0   210
# Male employees    6768.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                  sum  size
# Characteristics
# High school diploma and less  5334.0   210
# Trade certificate             6034.0   198
# University degree and higher  6681.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                             sum  size
# Characteristics
# Immigrant employees      6278.0   198
# Non-immigrant employees  6001.0   198
# The total number of this one is  396

# %%
# Dataset year in 2016 inside "Average weekly hours worked"

print("\nAge group in Alberta")
df_AvgWeekHrsWrked_2016_ByAge = df_AvgWeekHrsWrked_2016.loc[
    (df_AvgWeekHrsWrked_2016['Characteristics'] == '15 to 24 years') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == '25 to 34 years') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == '35 to 44 years') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == '45 to 54 years') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == '55 to 64 years') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == '65 years old and over')]
# print(df_AvgWeekHrsWrked_2016_ByAge.head(20))
grouped = df_AvgWeekHrsWrked_2016_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2016_ByAge.index))

print("\nGender group in Alberta")
df_AvgWeekHrsWrked_2016_ByGender = df_AvgWeekHrsWrked_2016.loc[
    (df_AvgWeekHrsWrked_2016['Characteristics'] == 'Female employees') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == 'Male employees')
]
# print(df_AvgWeekHrsWrked_2016_ByGender.head(20))
grouped = df_AvgWeekHrsWrked_2016_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2016_ByGender.index))

print("\nEducation group in Alberta")
df_AvgWeekHrsWrked_2016_ByEducation = df_AvgWeekHrsWrked_2016.loc[
    (df_AvgWeekHrsWrked_2016['Characteristics'] == 'High school diploma and less') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == 'Trade certificate') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == 'University degree and higher')
]
# print(df_AvgWeekHrsWrked_2016_ByEducation.head(20))
grouped = df_AvgWeekHrsWrked_2016_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2016_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgWeekHrsWrked_2016_ByImmigrant = df_AvgWeekHrsWrked_2016.loc[
    (df_AvgWeekHrsWrked_2016['Characteristics'] == 'Immigrant employees') |
    (df_AvgWeekHrsWrked_2016['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgWeekHrsWrked_2016_ByImmigrant.head(20))
grouped = df_AvgWeekHrsWrked_2016_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2016_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgWeekHrsWrked_2016_ByIndigenous = df_AvgWeekHrsWrked_2016.loc[
#     (df_AvgWeekHrsWrked_2016['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgWeekHrsWrked_2016['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgAnnHrk_ByIndigenous.head(20))
# grouped = df_AvgWeekHrsWrked_2016_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2016_ByIndigenous.index))
# Out:
# Age group in Alberta
#                           sum  size
# Characteristics
# 15 to 24 years         3387.0   192
# 25 to 34 years         6489.0   210
# 35 to 44 years         7185.0   210
# 45 to 54 years         7415.0   210
# 55 to 64 years         6748.0   210
# 65 years old and over  3965.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                      sum  size
# Characteristics
# Female employees  6184.0   210
# Male employees    6668.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                  sum  size
# Characteristics
# High school diploma and less  5315.0   210
# Trade certificate             5922.0   198
# University degree and higher  6604.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                             sum  size
# Characteristics
# Immigrant employees      6185.0   198
# Non-immigrant employees  5968.0   198
# The total number of this one is  396

# %%
# Dataset year in 2019 inside "Average weekly hours worked"

print("\nAge group in Alberta")
df_AvgWeekHrsWrked_2019_ByAge = df_AvgWeekHrsWrked_2019.loc[
    (df_AvgWeekHrsWrked_2019['Characteristics'] == '15 to 24 years') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == '25 to 34 years') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == '35 to 44 years') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == '45 to 54 years') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == '55 to 64 years') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == '65 years old and over')]
# print(df_AvgWeekHrsWrked_2019_ByAge.head(20))
grouped = df_AvgWeekHrsWrked_2019_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2019_ByAge.index))

print("\nGender group in Alberta")
df_AvgWeekHrsWrked_2019_ByGender = df_AvgWeekHrsWrked_2019.loc[
    (df_AvgWeekHrsWrked_2019['Characteristics'] == 'Female employees') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == 'Male employees')
]
# print(df_AvgWeekHrsWrked_2019_ByGender.head(20))
grouped = df_AvgWeekHrsWrked_2019_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2019_ByGender.index))

print("\nEducation group in Alberta")
df_AvgWeekHrsWrked_2019_ByEducation = df_AvgWeekHrsWrked_2019.loc[
    (df_AvgWeekHrsWrked_2019['Characteristics'] == 'High school diploma and less') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == 'Trade certificate') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == 'University degree and higher')
]
# print(df_AvgWeekHrsWrked_2019_ByEducation.head(20))
grouped = df_AvgWeekHrsWrked_2019_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2019_ByEducation.index))

print("\nImmigrant group in Alberta")
df_AvgWeekHrsWrked_2019_ByImmigrant = df_AvgWeekHrsWrked_2019.loc[
    (df_AvgWeekHrsWrked_2019['Characteristics'] == 'Immigrant employees') |
    (df_AvgWeekHrsWrked_2019['Characteristics'] == 'Non-immigrant employees')
]
# print(df_AvgWeekHrsWrked_2019_ByImmigrant.head(20))
grouped = df_AvgWeekHrsWrked_2019_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_AvgWeekHrsWrked_2019_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_AvgWeekHrsWrked_2019_ByIndigenous = df_AvgWeekHrsWrked_2019.loc[
#     (df_AvgWeekHrsWrked_2019['Characteristics'] == 'Indigenous identity employees') |
#     (df_AvgWeekHrsWrked_2019['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgWeekHrsWrked_2019_ByIndigenous.head(20))
# grouped = df_AvgWeekHrsWrked_2019_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_AvgWeekHrsWrked_2019_ByIndigenous.index))
# Out:
# Age group in Alberta
#                           sum  size
# Characteristics
# 15 to 24 years         3465.0   192
# 25 to 34 years         6413.0   210
# 35 to 44 years         7139.0   210
# 45 to 54 years         7406.0   210
# 55 to 64 years         6765.0   210
# 65 years old and over  3969.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                      sum  size
# Characteristics
# Female employees  6219.0   210
# Male employees    6590.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                  sum  size
# Characteristics
# High school diploma and less  5303.0   210
# Trade certificate             5889.0   198
# University degree and higher  6568.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                             sum  size
# Characteristics
# Immigrant employees      6133.0   198
# Non-immigrant employees  5961.0   198
# The total number of this one is  396

# %% [markdown]
# Filtered for "Hours worked" by following: "Age group", "Gender level", "Education level", and "Immigration status".<br />
# "Aboriginal status" has been commented.

# %%
# # Dataset year in 2010 inside "Hours Worked"

# print("\nAge group in Alberta")
# df_Hrs_Wrked_2010_ByAge = df_Hrs_Wrked_2010.loc[
#     (df_Hrs_Wrked_2010['Characteristics'] == '15 to 24 years') |
#     (df_Hrs_Wrked_2010['Characteristics'] == '25 to 34 years') |
#     (df_Hrs_Wrked_2010['Characteristics'] == '35 to 44 years') |
#     (df_Hrs_Wrked_2010['Characteristics'] == '45 to 54 years') |
#     (df_Hrs_Wrked_2010['Characteristics'] == '55 to 64 years') |
#     (df_Hrs_Wrked_2010['Characteristics'] == '65 years old and over')]
# # print(df_Hrs_Wrked_2010_ByAge.head(20))
# grouped = df_Hrs_Wrked_2010_ByAge.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2010_ByAge.index))

# print("\nGender group in Alberta")
# df_Hrs_Wrked_2010_ByGender = df_Hrs_Wrked_2010.loc[
#     (df_Hrs_Wrked_2010['Characteristics'] == 'Female employees') |
#     (df_Hrs_Wrked_2010['Characteristics'] == 'Male employees')
# ]
# # print(df_Hrs_Wrked_2010_ByGender.head(20))
# grouped = df_Hrs_Wrked_2010_ByGender.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2010_ByGender.index))

# print("\nEducation group in Alberta")
# df_Hrs_Wrked_2010_ByEducation = df_Hrs_Wrked_2010.loc[
#     (df_Hrs_Wrked_2010['Characteristics'] == 'High school diploma and less') |
#     (df_Hrs_Wrked_2010['Characteristics'] == 'Trade certificate') |
#     (df_Hrs_Wrked_2010['Characteristics'] == 'University degree and higher')
# ]
# # print(df_Hrs_Wrked_2010_ByEducation.head(20))
# grouped = df_Hrs_Wrked_2010_ByEducation.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2010_ByEducation.index))

# print("\nImmigrant group in Alberta")
# df_Hrs_Wrked_2010_ByImmigrant = df_Hrs_Wrked_2010.loc[
#     (df_Hrs_Wrked_2010['Characteristics'] == 'Immigrant employees') |
#     (df_Hrs_Wrked_2010['Characteristics'] == 'Non-immigrant employees')
# ]
# # print(df_Hrs_Wrked_2010_ByImmigrant.head(20))
# grouped = df_Hrs_Wrked_2010_ByImmigrant.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2010_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_Hrs_Wrked_2010_ByIndigenous = df_Hrs_Wrked_2010.loc[
#     (df_Hrs_Wrked_2010['Characteristics'] == 'Indigenous identity employees') |
#     (df_Hrs_Wrked_2010['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_Hrs_Wrked_2010_ByIndigenous.head(20))
# grouped = df_Hrs_Wrked_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2010_ByIndigenous.index))

# %%
# Dataset year in 2013 inside "Hours Worked"

print("\nAge group in Alberta")
df_Hrs_Wrked_2013_ByAge = df_Hrs_Wrked_2013.loc[
    (df_Hrs_Wrked_2013['Characteristics'] == '15 to 24 years') |
    (df_Hrs_Wrked_2013['Characteristics'] == '25 to 34 years') |
    (df_Hrs_Wrked_2013['Characteristics'] == '35 to 44 years') |
    (df_Hrs_Wrked_2013['Characteristics'] == '45 to 54 years') |
    (df_Hrs_Wrked_2013['Characteristics'] == '55 to 64 years') |
    (df_Hrs_Wrked_2013['Characteristics'] == '65 years old and over')]
# print(df_Hrs_Wrked_2013_ByAge.head(20))
grouped = df_Hrs_Wrked_2013_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2013_ByAge.index))

print("\nGender group in Alberta")
df_Hrs_Wrked_2013_ByGender = df_Hrs_Wrked_2013.loc[
    (df_Hrs_Wrked_2013['Characteristics'] == 'Female employees') |
    (df_Hrs_Wrked_2013['Characteristics'] == 'Male employees')
]
# print(df_Hrs_Wrked_2013_ByGender.head(20))
grouped = df_Hrs_Wrked_2013_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2013_ByGender.index))

print("\nEducation group in Alberta")
df_Hrs_Wrked_2013_ByEducation = df_Hrs_Wrked_2013.loc[
    (df_Hrs_Wrked_2013['Characteristics'] == 'High school diploma and less') |
    (df_Hrs_Wrked_2013['Characteristics'] == 'Trade certificate') |
    (df_Hrs_Wrked_2013['Characteristics'] == 'University degree and higher')
]
# print(df_Hrs_Wrked_2013_ByEducation.head(20))
grouped = df_Hrs_Wrked_2013_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2013_ByEducation.index))

print("\nImmigrant group in Alberta")
df_Hrs_Wrked_2013_ByImmigrant = df_Hrs_Wrked_2013.loc[
    (df_Hrs_Wrked_2013['Characteristics'] == 'Immigrant employees') |
    (df_Hrs_Wrked_2013['Characteristics'] == 'Non-immigrant employees')
]
# print(df_Hrs_Wrked_2013_ByImmigrant.head(20))
grouped = df_Hrs_Wrked_2013_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2013_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_Hrs_Wrked_2013_ByIndigenous = df_Hrs_Wrked_2013.loc[
#     (df_Hrs_Wrked_2013['Characteristics'] == 'Indigenous identity employees') |
#     (df_Hrs_Wrked_2013['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_Hrs_Wrked_2013_ByIndigenous.head(20))
# grouped = df_Hrs_Wrked_2013_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2013_ByIndigenous.index))
# Out:
# Age group in Alberta
#                               sum  size
# Characteristics
# 15 to 24 years          3107754.0   192
# 25 to 34 years         10595996.0   210
# 35 to 44 years         11379938.0   210
# 45 to 54 years         13158896.0   210
# 55 to 64 years          9899434.0   210
# 65 years old and over   1974184.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees  34086022.0   210
# Male employees    16032036.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   9259138.0   210
# Trade certificate              3736455.0   198
# University degree and higher  23601210.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                 sum  size
# Characteristics
# Immigrant employees      12147236.0   198
# Non-immigrant employees  37962608.0   198
# The total number of this one is  396

# %%
# Dataset year in 2016 inside "Hours Worked"

print("\nAge group in Alberta")
df_Hrs_Wrked_2016_ByAge = df_Hrs_Wrked_2016.loc[
    (df_Hrs_Wrked_2016['Characteristics'] == '15 to 24 years') |
    (df_Hrs_Wrked_2016['Characteristics'] == '25 to 34 years') |
    (df_Hrs_Wrked_2016['Characteristics'] == '35 to 44 years') |
    (df_Hrs_Wrked_2016['Characteristics'] == '45 to 54 years') |
    (df_Hrs_Wrked_2016['Characteristics'] == '55 to 64 years') |
    (df_Hrs_Wrked_2016['Characteristics'] == '65 years old and over')]
# print(df_Hrs_Wrked_2016_ByAge.head(20))
grouped = df_Hrs_Wrked_2016_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2016_ByAge.index))

print("\nGender group in Alberta")
df_Hrs_Wrked_2016_ByGender = df_Hrs_Wrked_2016.loc[
    (df_Hrs_Wrked_2016['Characteristics'] == 'Female employees') |
    (df_Hrs_Wrked_2016['Characteristics'] == 'Male employees')
]
# print(df_Hrs_Wrked_2016_ByGender.head(20))
grouped = df_Hrs_Wrked_2016_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2016_ByGender.index))

print("\nEducation group in Alberta")
df_Hrs_Wrked_2016_ByEducation = df_Hrs_Wrked_2016.loc[
    (df_Hrs_Wrked_2016['Characteristics'] == 'High school diploma and less') |
    (df_Hrs_Wrked_2016['Characteristics'] == 'Trade certificate') |
    (df_Hrs_Wrked_2016['Characteristics'] == 'University degree and higher')
]
# print(df_Hrs_Wrked_2016_ByEducation.head(20))
grouped = df_Hrs_Wrked_2016_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2016_ByEducation.index))

print("\nImmigrant group in Alberta")
df_Hrs_Wrked_2016_ByImmigrant = df_Hrs_Wrked_2016.loc[
    (df_Hrs_Wrked_2016['Characteristics'] == 'Immigrant employees') |
    (df_Hrs_Wrked_2016['Characteristics'] == 'Non-immigrant employees')
]
# print(df_Hrs_Wrked_2016_ByImmigrant.head(20))
grouped = df_Hrs_Wrked_2016_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2016_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_Hrs_Wrked_2016_ByIndigenous = df_Hrs_Wrked_2016.loc[
#     (df_Hrs_Wrked_2016['Characteristics'] == 'Indigenous identity employees') |
#     (df_Hrs_Wrked_2016['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_AvgAnnHrk_ByIndigenous.head(20))
# grouped = df_Hrs_Wrked_2016_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2016_ByIndigenous.index))
# Out:
# Age group in Alberta
#                               sum  size
# Characteristics
# 15 to 24 years          3211600.0   192
# 25 to 34 years         11296322.0   210
# 35 to 44 years         12146992.0   210
# 45 to 54 years         13070232.0   210
# 55 to 64 years         10422244.0   210
# 65 years old and over   2324345.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees  35855312.0   210
# Male employees    16618598.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   9485452.0   210
# Trade certificate              3558304.0   198
# University degree and higher  25474813.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                 sum  size
# Characteristics
# Immigrant employees      13361296.0   198
# Non-immigrant employees  39103961.0   198
# The total number of this one is  396

# %%
# Dataset year in 2019 inside "Hour Worked"

print("\nAge group in Alberta")
df_Hrs_Wrked_2019_ByAge = df_Hrs_Wrked_2019.loc[
    (df_Hrs_Wrked_2019['Characteristics'] == '15 to 24 years') |
    (df_Hrs_Wrked_2019['Characteristics'] == '25 to 34 years') |
    (df_Hrs_Wrked_2019['Characteristics'] == '35 to 44 years') |
    (df_Hrs_Wrked_2019['Characteristics'] == '45 to 54 years') |
    (df_Hrs_Wrked_2019['Characteristics'] == '55 to 64 years') |
    (df_Hrs_Wrked_2019['Characteristics'] == '65 years old and over')]
# print(df_Hrs_Wrked_2019_ByAge.head(20))
grouped = df_Hrs_Wrked_2019_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2019_ByAge.index))

print("\nGender group in Alberta")
df_Hrs_Wrked_2019_ByGender = df_Hrs_Wrked_2019.loc[
    (df_Hrs_Wrked_2019['Characteristics'] == 'Female employees') |
    (df_Hrs_Wrked_2019['Characteristics'] == 'Male employees')
]
# print(df_Hrs_Wrked_2019_ByGender.head(20))
grouped = df_Hrs_Wrked_2019_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2019_ByGender.index))

print("\nEducation group in Alberta")
df_Hrs_Wrked_2019_ByEducation = df_Hrs_Wrked_2019.loc[
    (df_Hrs_Wrked_2019['Characteristics'] == 'High school diploma and less') |
    (df_Hrs_Wrked_2019['Characteristics'] == 'Trade certificate') |
    (df_Hrs_Wrked_2019['Characteristics'] == 'University degree and higher')
]
# print(df_Hrs_Wrked_2019_ByEducation.head(20))
grouped = df_Hrs_Wrked_2019_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2019_ByEducation.index))

print("\nImmigrant group in Alberta")
df_Hrs_Wrked_2019_ByImmigrant = df_Hrs_Wrked_2019.loc[
    (df_Hrs_Wrked_2019['Characteristics'] == 'Immigrant employees') |
    (df_Hrs_Wrked_2019['Characteristics'] == 'Non-immigrant employees')
]
# print(df_Hrs_Wrked_2019_ByImmigrant.head(20))
grouped = df_Hrs_Wrked_2019_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_Hrs_Wrked_2019_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_Hrs_Wrked_2019_ByIndigenous = df_Hrs_Wrked_2019.loc[
#     (df_Hrs_Wrked_2019['Characteristics'] == 'Indigenous identity employees') |
#     (df_Hrs_Wrked_2019['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_Hrs_Wrked_2019_ByIndigenous.head(20))
# grouped = df_Hrs_Wrked_2019_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_Hrs_Wrked_2019_ByIndigenous.index))
# Out:
# Age group in Alberta
#                               sum  size
# Characteristics
# 15 to 24 years          3132171.0   192
# 25 to 34 years         11857576.0   210
# 35 to 44 years         12919606.0   210
# 45 to 54 years         12974580.0   210
# 55 to 64 years         10690620.0   210
# 65 years old and over   2528517.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees  37193214.0   210
# Male employees    16912308.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   9285900.0   210
# Trade certificate              3449203.0   198
# University degree and higher  27393105.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                 sum  size
# Characteristics
# Immigrant employees      14355944.0   198
# Non-immigrant employees  39740524.0   198
# The total number of this one is  396

# %% [markdown]
# Filtered for "Number of jobs" by following: "Age group", "Gender level", "Education level", and "Immigration status".<br />
# "Aboriginal status" has been commented.

# %%
# # Dataset year in 2010 inside "Number of jobs"

# print("\nAge group in Alberta")
# df_NumOfJob_2010_ByAge = df_NumOfJob_2010.loc[
#     (df_NumOfJob_2010['Characteristics'] == '15 to 24 years') |
#     (df_NumOfJob_2010['Characteristics'] == '25 to 34 years') |
#     (df_NumOfJob_2010['Characteristics'] == '35 to 44 years') |
#     (df_NumOfJob_2010['Characteristics'] == '45 to 54 years') |
#     (df_NumOfJob_2010['Characteristics'] == '55 to 64 years') |
#     (df_NumOfJob_2010['Characteristics'] == '65 years old and over')]
# # print(df_NumOfJob_2010_ByAge.head(20))
# grouped = df_NumOfJob_2010_ByAge.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2010_ByAge.index))

# print("\nGender group in Alberta")
# df_NumOfJob_2010_ByGender = df_NumOfJob_2010.loc[
#     (df_NumOfJob_2010['Characteristics'] == 'Female employees') |
#     (df_NumOfJob_2010['Characteristics'] == 'Male employees')
# ]
# # print(df_NumOfJob_2010_ByGender.head(20))
# grouped = df_NumOfJob_2010_ByGender.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2010_ByGender.index))

# print("\nEducation group in Alberta")
# df_NumOfJob_2010_ByEducation = df_NumOfJob_2010.loc[
#     (df_NumOfJob_2010['Characteristics'] == 'High school diploma and less') |
#     (df_NumOfJob_2010['Characteristics'] == 'Trade certificate') |
#     (df_NumOfJob_2010['Characteristics'] == 'University degree and higher')
# ]
# # print(df_NumOfJob_2010_ByEducation.head(20))
# grouped = df_NumOfJob_2010_ByEducation.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2010_ByEducation.index))

# print("\nImmigrant group in Alberta")
# df_NumOfJob_2010_ByImmigrant = df_NumOfJob_2010.loc[
#     (df_NumOfJob_2010['Characteristics'] == 'Immigrant employees') |
#     (df_NumOfJob_2010['Characteristics'] == 'Non-immigrant employees')
# ]
# # print(df_NumOfJob_2010_ByImmigrant.head(20))
# grouped = df_NumOfJob_2010_ByImmigrant.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2010_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_NumOfJob_2010_ByIndigenous = df_NumOfJob_2010.loc[
#     (df_NumOfJob_2010['Characteristics'] == 'Indigenous identity employees') |
#     (df_NumOfJob_2010['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_NumOfJob_2010_ByIndigenous.head(20))
# grouped = df_NumOfJob_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2010_ByIndigenous.index))

# %%
# Dataset year in 2013 inside "Number of jobs"

print("\nAge group in Alberta")
df_NumOfJob_2013_ByAge = df_NumOfJob_2013.loc[
    (df_NumOfJob_2013['Characteristics'] == '15 to 24 years') |
    (df_NumOfJob_2013['Characteristics'] == '25 to 34 years') |
    (df_NumOfJob_2013['Characteristics'] == '35 to 44 years') |
    (df_NumOfJob_2013['Characteristics'] == '45 to 54 years') |
    (df_NumOfJob_2013['Characteristics'] == '55 to 64 years') |
    (df_NumOfJob_2013['Characteristics'] == '65 years old and over')]
# print(df_NumOfJob_2013_ByAge.head(20))
grouped = df_NumOfJob_2013_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2013_ByAge.index))

print("\nGender group in Alberta")
df_NumOfJob_2013_ByGender = df_NumOfJob_2013.loc[
    (df_NumOfJob_2013['Characteristics'] == 'Female employees') |
    (df_NumOfJob_2013['Characteristics'] == 'Male employees')
]
# print(df_NumOfJob_2013_ByGender.head(20))
grouped = df_NumOfJob_2013_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2013_ByGender.index))

print("\nEducation group in Alberta")
df_NumOfJob_2013_ByEducation = df_NumOfJob_2013.loc[
    (df_NumOfJob_2013['Characteristics'] == 'High school diploma and less') |
    (df_NumOfJob_2013['Characteristics'] == 'Trade certificate') |
    (df_NumOfJob_2013['Characteristics'] == 'University degree and higher')
]
# print(df_NumOfJob_2013_ByEducation.head(20))
grouped = df_NumOfJob_2013_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2013_ByEducation.index))

print("\nImmigrant group in Alberta")
df_NumOfJob_2013_ByImmigrant = df_NumOfJob_2013.loc[
    (df_NumOfJob_2013['Characteristics'] == 'Immigrant employees') |
    (df_NumOfJob_2013['Characteristics'] == 'Non-immigrant employees')
]
# print(df_NumOfJob_2013_ByImmigrant.head(20))
grouped = df_NumOfJob_2013_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2013_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_NumOfJob_2013_ByIndigenous = df_NumOfJob_2013.loc[
#     (df_NumOfJob_2013['Characteristics'] == 'Indigenous identity employees') |
#     (df_NumOfJob_2013['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_NumOfJob_2013_ByIndigenous.head(20))
# grouped = df_NumOfJob_2013_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2013_ByIndigenous.index))
# Out:
# Age group in Alberta
#                              sum  size
# Characteristics
# 15 to 24 years         3475038.0   192
# 25 to 34 years         6767092.0   210
# 35 to 44 years         6596518.0   210
# 45 to 54 years         7311054.0   210
# 55 to 64 years         6008488.0   210
# 65 years old and over  1910168.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees  22196810.0   210
# Male employees     9873690.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   7081390.0   210
# Trade certificate              2417879.0   198
# University degree and higher  14192344.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                 sum  size
# Characteristics
# Immigrant employees       7694218.0   198
# Non-immigrant employees  24370675.0   198
# The total number of this one is  396

# %%
# Dataset year in 2016 inside "Number of jobs"

print("\nAge group in Alberta")
df_NumOfJob_2016_ByAge = df_NumOfJob_2016.loc[
    (df_NumOfJob_2016['Characteristics'] == '15 to 24 years') |
    (df_NumOfJob_2016['Characteristics'] == '25 to 34 years') |
    (df_NumOfJob_2016['Characteristics'] == '35 to 44 years') |
    (df_NumOfJob_2016['Characteristics'] == '45 to 54 years') |
    (df_NumOfJob_2016['Characteristics'] == '55 to 64 years') |
    (df_NumOfJob_2016['Characteristics'] == '65 years old and over')]
# print(df_NumOfJob_2016_ByAge.head(20))
grouped = df_NumOfJob_2016_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2016_ByAge.index))

print("\nGender group in Alberta")
df_NumOfJob_2016_ByGender = df_NumOfJob_2016.loc[
    (df_NumOfJob_2016['Characteristics'] == 'Female employees') |
    (df_NumOfJob_2016['Characteristics'] == 'Male employees')
]
# print(df_NumOfJob_2016_ByGender.head(20))
grouped = df_NumOfJob_2016_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2016_ByGender.index))

print("\nEducation group in Alberta")
df_NumOfJob_2016_ByEducation = df_NumOfJob_2016.loc[
    (df_NumOfJob_2016['Characteristics'] == 'High school diploma and less') |
    (df_NumOfJob_2016['Characteristics'] == 'Trade certificate') |
    (df_NumOfJob_2016['Characteristics'] == 'University degree and higher')
]
# print(df_NumOfJob_2016_ByEducation.head(20))
grouped = df_NumOfJob_2016_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2016_ByEducation.index))

print("\nImmigrant group in Alberta")
df_NumOfJob_2016_ByImmigrant = df_NumOfJob_2016.loc[
    (df_NumOfJob_2016['Characteristics'] == 'Immigrant employees') |
    (df_NumOfJob_2016['Characteristics'] == 'Non-immigrant employees')
]
# print(df_NumOfJob_2016_ByImmigrant.head(20))
grouped = df_NumOfJob_2016_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2016_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_NumOfJob_2016_ByIndigenous = df_NumOfJob_2016.loc[
#     (df_NumOfJob_2016['Characteristics'] == 'Indigenous identity employees') |
#     (df_NumOfJob_2016['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_NumOfJob_2016_ByIndigenous.head(20))
# grouped = df_NumOfJob_2016_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2016_ByIndigenous.index))
# Out:
# Age group in Alberta
#                              sum  size
# Characteristics
# 15 to 24 years         3568591.0   192
# 25 to 34 years         7218822.0   210
# 35 to 44 years         7058062.0   210
# 45 to 54 years         7243040.0   210
# 55 to 64 years         6305020.0   210
# 65 years old and over  2240484.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees  23313522.0   210
# Male employees    10322788.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   7346224.0   210
# Trade certificate              2312220.0   198
# University degree and higher  15322286.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                 sum  size
# Characteristics
# Immigrant employees       8481252.0   198
# Non-immigrant employees  25149138.0   198
# The total number of this one is  396

# %%
# Dataset year in 2019 inside "Number of jobs"

print("\nAge group in Alberta")
df_NumOfJob_2019_ByAge = df_NumOfJob_2019.loc[
    (df_NumOfJob_2019['Characteristics'] == '15 to 24 years') |
    (df_NumOfJob_2019['Characteristics'] == '25 to 34 years') |
    (df_NumOfJob_2019['Characteristics'] == '35 to 44 years') |
    (df_NumOfJob_2019['Characteristics'] == '45 to 54 years') |
    (df_NumOfJob_2019['Characteristics'] == '55 to 64 years') |
    (df_NumOfJob_2019['Characteristics'] == '65 years old and over')]
# print(df_NumOfJob_2019_ByAge.head(20))
grouped = df_NumOfJob_2019_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2019_ByAge.index))

print("\nGender group in Alberta")
df_NumOfJob_2019_ByGender = df_NumOfJob_2019.loc[
    (df_NumOfJob_2019['Characteristics'] == 'Female employees') |
    (df_NumOfJob_2019['Characteristics'] == 'Male employees')
]
# print(df_NumOfJob_2019_ByGender.head(20))
grouped = df_NumOfJob_2019_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2019_ByGender.index))

print("\nEducation group in Alberta")
df_NumOfJob_2019_ByEducation = df_NumOfJob_2019.loc[
    (df_NumOfJob_2019['Characteristics'] == 'High school diploma and less') |
    (df_NumOfJob_2019['Characteristics'] == 'Trade certificate') |
    (df_NumOfJob_2019['Characteristics'] == 'University degree and higher')
]
# print(df_NumOfJob_2019_ByEducation.head(20))
grouped = df_NumOfJob_2019_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2019_ByEducation.index))

print("\nImmigrant group in Alberta")
df_NumOfJob_2019_ByImmigrant = df_NumOfJob_2019.loc[
    (df_NumOfJob_2019['Characteristics'] == 'Immigrant employees') |
    (df_NumOfJob_2019['Characteristics'] == 'Non-immigrant employees')
]
# print(df_NumOfJob_2019_ByImmigrant.head(20))
grouped = df_NumOfJob_2019_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_NumOfJob_2019_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_NumOfJob_2019_ByIndigenous = df_NumOfJob_2019.loc[
#     (df_NumOfJob_2019['Characteristics'] == 'Indigenous identity employees') |
#     (df_NumOfJob_2019['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_NumOfJob_2019_ByIndigenous.head(20))
# grouped = df_NumOfJob_2019_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_NumOfJob_2019_ByIndigenous.index))
# Out:
# Age group in Alberta
#                              sum  size
# Characteristics
# 15 to 24 years         3414206.0   192
# 25 to 34 years         7615612.0   210
# 35 to 44 years         7559436.0   210
# 45 to 54 years         7201656.0   210
# 55 to 64 years         6451160.0   210
# 65 years old and over  2416851.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                          sum  size
# Characteristics
# Female employees  24112770.0   210
# Male employees    10548592.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                      sum  size
# Characteristics
# High school diploma and less   7204888.0   210
# Trade certificate              2245738.0   198
# University degree and higher  16513042.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                 sum  size
# Characteristics
# Immigrant employees       9133147.0   198
# Non-immigrant employees  25522127.0   198
# The total number of this one is  396

# %% [markdown]
# Filtered for "Wages and Salaries" by following: "Age group", "Gender level", "Education level", and "Immigration status". <br />
# "Aboriginal status" has been commented.

# %%
# # Dataset year in 2010 inside "Wages and Salaries"

# print("\nAge group in Alberta")
# df_WagesAndSalaries_2010_ByAge = df_WagesAndSalaries_2010.loc[
#     (df_WagesAndSalaries_2010['Characteristics'] == '15 to 24 years') |
#     (df_WagesAndSalaries_2010['Characteristics'] == '25 to 34 years') |
#     (df_WagesAndSalaries_2010['Characteristics'] == '35 to 44 years') |
#     (df_WagesAndSalaries_2010['Characteristics'] == '45 to 54 years') |
#     (df_WagesAndSalaries_2010['Characteristics'] == '55 to 64 years') |
#     (df_WagesAndSalaries_2010['Characteristics'] == '65 years old and over')]
# # print(df_WagesAndSalaries_2010_ByAge.head(20))
# grouped = df_WagesAndSalaries_2010_ByAge.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2010_ByAge.index))

# print("\nGender group in Alberta")
# df_WagesAndSalaries_2010_ByGender = df_WagesAndSalaries_2010.loc[
#     (df_WagesAndSalaries_2010['Characteristics'] == 'Female employees') |
#     (df_WagesAndSalaries_2010['Characteristics'] == 'Male employees')
# ]
# # print(df_WagesAndSalaries_2010_ByGender.head(20))
# grouped = df_WagesAndSalaries_2010_ByGender.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2010_ByGender.index))

# print("\nEducation group in Alberta")
# df_WagesAndSalaries_2010_ByEducation = df_WagesAndSalaries_2010.loc[
#     (df_WagesAndSalaries_2010['Characteristics'] == 'High school diploma and less') |
#     (df_WagesAndSalaries_2010['Characteristics'] == 'Trade certificate') |
#     (df_WagesAndSalaries_2010['Characteristics'] == 'University degree and higher')
# ]
# # print(df_WagesAndSalaries_2010_ByEducation.head(20))
# grouped = df_WagesAndSalaries_2010_ByEducation.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2010_ByEducation.index))

# print("\nImmigrant group in Alberta")
# df_WagesAndSalaries_2010_ByImmigrant = df_WagesAndSalaries_2010.loc[
#     (df_WagesAndSalaries_2010['Characteristics'] == 'Immigrant employees') |
#     (df_WagesAndSalaries_2010['Characteristics'] == 'Non-immigrant employees')
# ]
# # print(df_WagesAndSalaries_2010_ByImmigrant.head(20))
# grouped = df_WagesAndSalaries_2010_ByImmigrant.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2010_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_WagesAndSalaries_2010_ByIndigenous = df_WagesAndSalaries_2010.loc[
#     (df_WagesAndSalaries_2010['Characteristics'] == 'Indigenous identity employees') |
#     (df_WagesAndSalaries_2010['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_WagesAndSalaries_2010_ByIndigenous.head(20))
# grouped = df_WagesAndSalaries_2010_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2010_ByIndigenous.index))

# %%
# Dataset year in 2013 inside "Wages and Salaries"

print("\nAge group in Alberta")
df_WagesAndSalaries_2013_ByAge = df_WagesAndSalaries_2013.loc[
    (df_WagesAndSalaries_2013['Characteristics'] == '15 to 24 years') |
    (df_WagesAndSalaries_2013['Characteristics'] == '25 to 34 years') |
    (df_WagesAndSalaries_2013['Characteristics'] == '35 to 44 years') |
    (df_WagesAndSalaries_2013['Characteristics'] == '45 to 54 years') |
    (df_WagesAndSalaries_2013['Characteristics'] == '55 to 64 years') |
    (df_WagesAndSalaries_2013['Characteristics'] == '65 years old and over')]
# print(df_WagesAndSalaries_2013_ByAge.head(20))
grouped = df_WagesAndSalaries_2013_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2013_ByAge.index))

print("\nGender group in Alberta")
df_WagesAndSalaries_2013_ByGender = df_WagesAndSalaries_2013.loc[
    (df_WagesAndSalaries_2013['Characteristics'] == 'Female employees') |
    (df_WagesAndSalaries_2013['Characteristics'] == 'Male employees')
]
# print(df_WagesAndSalaries_2013_ByGender.head(20))
grouped = df_WagesAndSalaries_2013_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2013_ByGender.index))

print("\nEducation group in Alberta")
df_WagesAndSalaries_2013_ByEducation = df_WagesAndSalaries_2013.loc[
    (df_WagesAndSalaries_2013['Characteristics'] == 'High school diploma and less') |
    (df_WagesAndSalaries_2013['Characteristics'] == 'Trade certificate') |
    (df_WagesAndSalaries_2013['Characteristics'] == 'University degree and higher')
]
# print(df_WagesAndSalaries_2013_ByEducation.head(20))
grouped = df_WagesAndSalaries_2013_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2013_ByEducation.index))

print("\nImmigrant group in Alberta")
df_WagesAndSalaries_2013_ByImmigrant = df_WagesAndSalaries_2013.loc[
    (df_WagesAndSalaries_2013['Characteristics'] == 'Immigrant employees') |
    (df_WagesAndSalaries_2013['Characteristics'] == 'Non-immigrant employees')
]
# print(df_WagesAndSalaries_2013_ByImmigrant.head(20))
grouped = df_WagesAndSalaries_2013_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2013_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_WagesAndSalaries_2013_ByIndigenous = df_WagesAndSalaries_2013.loc[
#     (df_WagesAndSalaries_2013['Characteristics'] == 'Indigenous identity employees') |
#     (df_WagesAndSalaries_2013['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_WagesAndSalaries_2013_ByIndigenous.head(20))
# grouped = df_WagesAndSalaries_2013_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2013_ByIndigenous.index))
# Out:
# Age group in Alberta
#                             sum  size
# Characteristics
# 15 to 24 years          51983.0   192
# 25 to 34 years         252992.0   210
# 35 to 44 years         334759.0   210
# 45 to 54 years         410954.0   210
# 55 to 64 years         313103.0   210
# 65 years old and over   62434.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                        sum  size
# Characteristics
# Female employees  926997.0   210
# Male employees    499293.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                    sum  size
# Characteristics
# High school diploma and less  191721.0   210
# Trade certificate              86569.0   198
# University degree and higher  793734.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                sum  size
# Characteristics
# Immigrant employees       348492.0   198
# Non-immigrant employees  1077526.0   198
# The total number of this one is  396

# %%
# Dataset year in 2016 inside "Wages and Salaries"

print("\nAge group in Alberta")
df_WagesAndSalaries_2016_ByAge = df_WagesAndSalaries_2016.loc[
    (df_WagesAndSalaries_2016['Characteristics'] == '15 to 24 years') |
    (df_WagesAndSalaries_2016['Characteristics'] == '25 to 34 years') |
    (df_WagesAndSalaries_2016['Characteristics'] == '35 to 44 years') |
    (df_WagesAndSalaries_2016['Characteristics'] == '45 to 54 years') |
    (df_WagesAndSalaries_2016['Characteristics'] == '55 to 64 years') |
    (df_WagesAndSalaries_2016['Characteristics'] == '65 years old and over')]
# print(df_WagesAndSalaries_2016_ByAge.head(20))
grouped = df_WagesAndSalaries_2016_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2016_ByAge.index))

print("\nGender group in Alberta")
df_WagesAndSalaries_2016_ByGender = df_WagesAndSalaries_2016.loc[
    (df_WagesAndSalaries_2016['Characteristics'] == 'Female employees') |
    (df_WagesAndSalaries_2016['Characteristics'] == 'Male employees')
]
# print(df_WagesAndSalaries_2016_ByGender.head(20))
grouped = df_WagesAndSalaries_2016_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2016_ByGender.index))

print("\nEducation group in Alberta")
df_WagesAndSalaries_2016_ByEducation = df_WagesAndSalaries_2016.loc[
    (df_WagesAndSalaries_2016['Characteristics'] == 'High school diploma and less') |
    (df_WagesAndSalaries_2016['Characteristics'] == 'Trade certificate') |
    (df_WagesAndSalaries_2016['Characteristics'] == 'University degree and higher')
]
# print(df_WagesAndSalaries_2016_ByEducation.head(20))
grouped = df_WagesAndSalaries_2016_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2016_ByEducation.index))

print("\nImmigrant group in Alberta")
df_WagesAndSalaries_2016_ByImmigrant = df_WagesAndSalaries_2016.loc[
    (df_WagesAndSalaries_2016['Characteristics'] == 'Immigrant employees') |
    (df_WagesAndSalaries_2016['Characteristics'] == 'Non-immigrant employees')
]
# print(df_WagesAndSalaries_2016_ByImmigrant.head(20))
grouped = df_WagesAndSalaries_2016_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2016_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_WagesAndSalaries_2016_ByIndigenous = df_WagesAndSalaries_2016.loc[
#     (df_WagesAndSalaries_2016['Characteristics'] == 'Indigenous identity employees') |
#     (df_WagesAndSalaries_2016['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_WagesAndSalaries_2016_ByIndigenous.head(20))
# grouped = df_WagesAndSalaries_2016_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2016_ByIndigenous.index))
# Out:
# Age group in Alberta
#                             sum  size
# Characteristics
# 15 to 24 years          56990.0   192
# 25 to 34 years         285555.0   210
# 35 to 44 years         376045.0   210
# 45 to 54 years         431853.0   210
# 55 to 64 years         344362.0   210
# 65 years old and over   76349.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                         sum  size
# Characteristics
# Female employees  1026881.0   210
# Male employees     544329.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                    sum  size
# Characteristics
# High school diploma and less  207705.0   210
# Trade certificate              86692.0   198
# University degree and higher  896636.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                sum  size
# Characteristics
# Immigrant employees       400833.0   198
# Non-immigrant employees  1170079.0   198
# The total number of this one is  396

# %%
# Dataset year in 2019 inside "Wages and Salaries"

print("\nAge group in Alberta")
df_WagesAndSalaries_2019_ByAge = df_WagesAndSalaries_2019.loc[
    (df_WagesAndSalaries_2019['Characteristics'] == '15 to 24 years') |
    (df_WagesAndSalaries_2019['Characteristics'] == '25 to 34 years') |
    (df_WagesAndSalaries_2019['Characteristics'] == '35 to 44 years') |
    (df_WagesAndSalaries_2019['Characteristics'] == '45 to 54 years') |
    (df_WagesAndSalaries_2019['Characteristics'] == '55 to 64 years') |
    (df_WagesAndSalaries_2019['Characteristics'] == '65 years old and over')]
# print(df_WagesAndSalaries_2019_ByAge.head(20))
grouped = df_WagesAndSalaries_2019_ByAge.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2019_ByAge.index))

print("\nGender group in Alberta")
df_WagesAndSalaries_2019_ByGender = df_WagesAndSalaries_2019.loc[
    (df_WagesAndSalaries_2019['Characteristics'] == 'Female employees') |
    (df_WagesAndSalaries_2019['Characteristics'] == 'Male employees')
]
# print(df_WagesAndSalaries_2019_ByGender.head(20))
grouped = df_WagesAndSalaries_2019_ByGender.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2019_ByGender.index))

print("\nEducation group in Alberta")
df_WagesAndSalaries_2019_ByEducation = df_WagesAndSalaries_2019.loc[
    (df_WagesAndSalaries_2019['Characteristics'] == 'High school diploma and less') |
    (df_WagesAndSalaries_2019['Characteristics'] == 'Trade certificate') |
    (df_WagesAndSalaries_2019['Characteristics'] == 'University degree and higher')
]
# print(df_WagesAndSalaries_2019_ByEducation.head(20))
grouped = df_WagesAndSalaries_2019_ByEducation.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2019_ByEducation.index))

print("\nImmigrant group in Alberta")
df_WagesAndSalaries_2019_ByImmigrant = df_WagesAndSalaries_2019.loc[
    (df_WagesAndSalaries_2019['Characteristics'] == 'Immigrant employees') |
    (df_WagesAndSalaries_2019['Characteristics'] == 'Non-immigrant employees')
]
# print(df_WagesAndSalaries_2019_ByImmigrant.head(20))
grouped = df_WagesAndSalaries_2019_ByImmigrant.groupby(['Characteristics'])
print(grouped['VALUE'].agg([np.sum, np.size]))
print("The total number of this one is ",len(df_WagesAndSalaries_2019_ByImmigrant.index))

# print("\nIndigenous group in Alberta")
# df_WagesAndSalaries_2019_ByIndigenous = df_WagesAndSalaries_2019.loc[
#     (df_WagesAndSalaries_2019['Characteristics'] == 'Indigenous identity employees') |
#     (df_WagesAndSalaries_2019['Characteristics'] == 'Non-indigenous identity employees')
# ]
# # print(df_WagesAndSalaries_2019_ByIndigenous.head(20))
# grouped = df_WagesAndSalaries_2019_ByIndigenous.groupby(['Characteristics'])
# print(grouped['VALUE'].agg([np.sum, np.size]))
# print("The total number of this one is ",len(df_WagesAndSalaries_2019_ByIndigenous.index))
# Out:
# Age group in Alberta
#                             sum  size
# Characteristics
# 15 to 24 years          63069.0   192
# 25 to 34 years         334200.0   210
# 35 to 44 years         441049.0   210
# 45 to 54 years         474202.0   210
# 55 to 64 years         386319.0   210
# 65 years old and over   90513.0   192
# The total number of this one is  1224
#
# Gender group in Alberta
#                         sum  size
# Characteristics
# Female employees  1179670.0   210
# Male employees     609748.0   210
# The total number of this one is  420
#
# Education group in Alberta
#                                     sum  size
# Characteristics
# High school diploma and less   226638.0   210
# Trade certificate               93374.0   198
# University degree and higher  1052815.0   198
# The total number of this one is  606
#
# Immigrant group in Alberta
#                                sum  size
# Characteristics
# Immigrant employees       473697.0   198
# Non-immigrant employees  1315368.0   198
# The total number of this one is  396

# %% [markdown]
# Final output for Average annual hours worked

# %%
# dfa_Target_To_Analysis = [df_AvgAnnHrsWrk_2010_ByAge, df_AvgAnnHrsWrk_2010_ByEducation, df_AvgAnnHrsWrk_2010_ByEducation, df_AvgAnnHrsWrk_2010_ByImmigrant]
# for df_Target_To_Analysis in dfa_Target_To_Analysis:
#       grouped = df_Target_To_Analysis.groupby(['Characteristics'])
#       print("Year of 2010")
#       print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
#       print("Overall,")
#       print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
#       print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
#       print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
#             np.median(df_Target_To_Analysis['VALUE']),"/",
#             np.max(df_Target_To_Analysis['VALUE']))
#       print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
#       print("Total size : ",len(df_Target_To_Analysis.index))

# print()
dfa_Target_To_Analysis = [df_AvgAnnHrsWrk_2013_ByAge, df_AvgAnnHrsWrk_2013_ByEducation, df_AvgAnnHrsWrk_2013_ByEducation, df_AvgAnnHrsWrk_2013_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2013")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgAnnHrsWrk_2016_ByAge, df_AvgAnnHrsWrk_2016_ByEducation, df_AvgAnnHrsWrk_2016_ByEducation, df_AvgAnnHrsWrk_2016_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2016")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgAnnHrsWrk_2019_ByAge, df_AvgAnnHrsWrk_2019_ByEducation, df_AvgAnnHrsWrk_2019_ByEducation, df_AvgAnnHrsWrk_2019_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2020")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))
# Out:
# Year of 2013
#                             sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         172087.0   896.286458   462.0   906.0  1108.0   192
# 25 to 34 years         340647.0  1622.128571  1236.0  1615.0  1946.0   210
# 35 to 44 years         377140.0  1795.904762  1477.0  1760.5  2183.0   210
# 45 to 54 years         387957.0  1847.414286  1523.0  1834.5  2294.0   210
# 55 to 64 years         352301.0  1677.623810  1390.0  1680.5  2000.0   210
# 65 years old and over  207070.0  1078.489583   724.0  1078.0  1500.0   192
# Overall,
# Sum :  1837202.0
# Mean :  1500.9820261437908
# Min/median/max : 462.0 / 1649.5 / 2294.0
# Skewnewss :  -0.5937132979460663
# Total size :  1224
# Year of 2013
#                                    sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  277682.0  1322.295238  1065.0  1323.5  1645.0
# Trade certificate             313663.0  1584.156566  1092.0  1581.0  1904.0
# University degree and higher  347222.0  1753.646465  1527.0  1735.0  2063.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  938567.0
# Mean :  1548.7904290429042
# Min/median/max : 1065.0 / 1566.0 / 2063.0
# Skewnewss :  -0.08200385461497713
# Total size :  606
# Year of 2013
#                                    sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  277682.0  1322.295238  1065.0  1323.5  1645.0
# Trade certificate             313663.0  1584.156566  1092.0  1581.0  1904.0
# University degree and higher  347222.0  1753.646465  1527.0  1735.0  2063.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  938567.0
# Mean :  1548.7904290429042
# Min/median/max : 1065.0 / 1566.0 / 2063.0
# Skewnewss :  -0.08200385461497713
# Total size :  606
# Year of 2013
#                               sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      326890.0  1650.959596  1333.0  1614.0  2500.0   198
# Non-immigrant employees  312119.0  1576.358586  1275.0  1579.5  1727.0   198
# Overall,
# Sum :  639009.0
# Mean :  1613.659090909091
# Min/median/max : 1275.0 / 1589.0 / 2500.0
# Skewnewss :  2.4308057363102553
# Total size :  396
#
# Year of 2016
#                             sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         176153.0   917.463542   691.0   924.5  1185.0   192
# 25 to 34 years         337302.0  1606.200000  1311.0  1602.5  1967.0   210
# 35 to 44 years         373702.0  1779.533333  1436.0  1761.0  2156.0   210
# 45 to 54 years         385915.0  1837.690476  1575.0  1821.5  2312.0   210
# 55 to 64 years         350828.0  1670.609524  1410.0  1677.0  2000.0   210
# 65 years old and over  206428.0  1075.145833   701.0  1068.5  1424.0   192
# Overall,
# Sum :  1830328.0
# Mean :  1495.3660130718954
# Min/median/max : 691.0 / 1642.5 / 2312.0
# Skewnewss :  -0.5756313431709856
# Total size :  1224
# Year of 2016
#                                    sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  276370.0  1316.047619  1066.0  1310.5  1615.0
# Trade certificate             307989.0  1555.500000   888.0  1547.0  1833.0
# University degree and higher  343664.0  1735.676768  1563.0  1711.5  2095.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  928023.0
# Mean :  1531.3910891089108
# Min/median/max : 888.0 / 1546.0 / 2095.0
# Skewnewss :  -0.12073761892929726
# Total size :  606
# Year of 2016
#                                    sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  276370.0  1316.047619  1066.0  1310.5  1615.0
# Trade certificate             307989.0  1555.500000   888.0  1547.0  1833.0
# University degree and higher  343664.0  1735.676768  1563.0  1711.5  2095.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  928023.0
# Mean :  1531.3910891089108
# Min/median/max : 888.0 / 1546.0 / 2095.0
# Skewnewss :  -0.12073761892929726
# Total size :  606
# Year of 2016
#                               sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      321592.0  1624.202020  1353.0  1594.5  2458.0   198
# Non-immigrant employees  310173.0  1566.530303  1321.0  1563.0  1764.0   198
# Overall,
# Sum :  631765.0
# Mean :  1595.3661616161617
# Min/median/max : 1321.0 / 1575.5 / 2458.0
# Skewnewss :  2.2802810869717547
# Total size :  396
#
# Year of 2020
#                             sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         179872.0   936.833333   713.0   927.5  1281.0   192
# 25 to 34 years         333662.0  1588.866667  1292.0  1576.0  1870.0   210
# 35 to 44 years         371386.0  1768.504762  1424.0  1757.0  2092.0   210
# 45 to 54 years         384987.0  1833.271429  1541.0  1826.5  2191.0   210
# 55 to 64 years         351843.0  1675.442857  1377.0  1675.0  2071.0   210
# 65 years old and over  206760.0  1076.875000   565.0  1076.5  1415.0   192
# Overall,
# Sum :  1828510.0
# Mean :  1493.8807189542483
# Min/median/max : 565.0 / 1633.0 / 2191.0
# Skewnewss :  -0.5829393561867995
# Total size :  1224
# Year of 2020
#                                    sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  275636.0  1312.552381  1054.0  1307.5  1667.0
# Trade certificate             306174.0  1546.333333   789.0  1547.5  1808.0
# University degree and higher  341795.0  1726.237374  1536.0  1706.5  2043.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  923605.0
# Mean :  1524.1006600660066
# Min/median/max : 789.0 / 1545.0 / 2043.0
# Skewnewss :  -0.1568377438071896
# Total size :  606
# Year of 2020
#                                    sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  275636.0  1312.552381  1054.0  1307.5  1667.0
# Trade certificate             306174.0  1546.333333   789.0  1547.5  1808.0
# University degree and higher  341795.0  1726.237374  1536.0  1706.5  2043.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  923605.0
# Mean :  1524.1006600660066
# Min/median/max : 789.0 / 1545.0 / 2043.0
# Skewnewss :  -0.1568377438071896
# Total size :  606
# Year of 2020
#                               sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      318818.0  1610.191919  1336.0  1589.0  2250.0   198
# Non-immigrant employees  310245.0  1566.893939  1315.0  1570.0  1767.0   198
# Overall,
# Sum :  629063.0
# Mean :  1588.5429292929293
# Min/median/max : 1315.0 / 1580.0 / 2250.0
# Skewnewss :  1.6694520665533967
# Total size :  396

# %% [markdown]
# Final output for "Average annual wages and salaries"

# %%
# dfa_Target_To_Analysis = [df_AvgAnnWages_2010_ByAge, df_AvgAnnWages_2010_ByEducation, df_AvgAnnWages_2010_ByEducation, df_AvgAnnWages_2010_ByImmigrant]
# for df_Target_To_Analysis in dfa_Target_To_Analysis:
#       grouped = df_Target_To_Analysis.groupby(['Characteristics'])
#       print("Year of 2010")
#       print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
#       print("Overall,")
#       print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
#       print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
#       print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
#             np.median(df_Target_To_Analysis['VALUE']),"/",
#             np.max(df_Target_To_Analysis['VALUE']))
#       print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
#       print("Total size : ",len(df_Target_To_Analysis.index))

# print()
dfa_Target_To_Analysis = [df_AvgAnnWages_2013_ByAge, df_AvgAnnWages_2013_ByEducation, df_AvgAnnWages_2013_ByEducation, df_AvgAnnWages_2013_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2013")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgAnnWages_2016_ByAge, df_AvgAnnWages_2016_ByEducation, df_AvgAnnWages_2016_ByEducation, df_AvgAnnWages_2016_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2016")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgAnnWages_2019_ByAge, df_AvgAnnWages_2019_ByEducation, df_AvgAnnWages_2019_ByEducation, df_AvgAnnWages_2019_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2020")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))
# Out:
# Year of 2013
#                               sum          mean     amin   median      amax  \
# Characteristics
# 15 to 24 years          2784616.0  14503.208333   8769.0  13954.0   24898.0
# 25 to 34 years          7953813.0  37875.300000  23433.0  36952.5   69687.0
# 35 to 44 years         10794086.0  51400.409524  33680.0  50296.0   92783.0
# 45 to 54 years         11596540.0  55221.619048  30761.0  53607.0   87000.0
# 55 to 64 years         11087673.0  52798.442857  28716.0  49704.0  105273.0
# 65 years old and over   5949938.0  30989.260417  14168.0  28631.0   81488.0
#
#                        size
# Characteristics
# 15 to 24 years          192
# 25 to 34 years          210
# 35 to 44 years          210
# 45 to 54 years          210
# 55 to 64 years          210
# 65 years old and over   192
# Overall,
# Sum :  50166666.0
# Mean :  40985.83823529412
# Min/median/max : 8769.0 / 40621.5 / 105273.0
# Skewnewss :  0.4232112184871187
# Total size :  1224
# Year of 2013
#                                      sum          mean     amin   median  \
# Characteristics
# High school diploma and less   5903675.0  28112.738095  13589.0  26733.0
# Trade certificate              7603798.0  38403.020202  19906.0  36236.5
# University degree and higher  11213834.0  56635.525253  34291.0  54820.5
#
#                                   amax  size
# Characteristics
# High school diploma and less   53361.0   210
# Trade certificate              81722.0   198
# University degree and higher  113502.0   198
# Overall,
# Sum :  24721307.0
# Mean :  40794.23597359736
# Min/median/max : 13589.0 / 37830.5 / 113502.0
# Skewnewss :  1.455121842324225
# Total size :  606
# Year of 2013
#                                      sum          mean     amin   median  \
# Characteristics
# High school diploma and less   5903675.0  28112.738095  13589.0  26733.0
# Trade certificate              7603798.0  38403.020202  19906.0  36236.5
# University degree and higher  11213834.0  56635.525253  34291.0  54820.5
#
#                                   amax  size
# Characteristics
# High school diploma and less   53361.0   210
# Trade certificate              81722.0   198
# University degree and higher  113502.0   198
# Overall,
# Sum :  24721307.0
# Mean :  40794.23597359736
# Min/median/max : 13589.0 / 37830.5 / 113502.0
# Skewnewss :  1.455121842324225
# Total size :  606
# Year of 2013
#                                sum          mean     amin   median      amax  \
# Characteristics
# Immigrant employees      8818758.0  44539.181818  19120.0  41988.0  105045.0
# Non-immigrant employees  8495409.0  42906.106061  25240.0  42114.0   77319.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  17314167.0
# Mean :  43722.643939393936
# Min/median/max : 19120.0 / 42075.5 / 105045.0
# Skewnewss :  1.2953139714251634
# Total size :  396
#
# Year of 2016
#                               sum          mean     amin   median      amax  \
# Characteristics
# 15 to 24 years          3060129.0  15938.171875   9794.0  14568.5   39963.0
# 25 to 34 years          8325679.0  39646.090476  24832.0  38644.5   68600.0
# 35 to 44 years         11269609.0  53664.804762  36704.0  52497.5   89097.0
# 45 to 54 years         12276948.0  58461.657143  36047.0  57665.0   94580.0
# 55 to 64 years         11610535.0  55288.261905  30816.0  52292.0  113680.0
# 65 years old and over   6249361.0  32548.755208  17359.0  30546.5   73364.0
#
#                        size
# Characteristics
# 15 to 24 years          192
# 25 to 34 years          210
# 35 to 44 years          210
# 45 to 54 years          210
# 55 to 64 years          210
# 65 years old and over   192
# Overall,
# Sum :  52792261.0
# Mean :  43130.93218954248
# Min/median/max : 9794.0 / 42923.0 / 113680.0
# Skewnewss :  0.4135401347803788
# Total size :  1224
# Year of 2016
#                                      sum          mean     amin   median  \
# Characteristics
# High school diploma and less   6237814.0  29703.876190  15835.0  28089.0
# Trade certificate              7881695.0  39806.540404  22892.0  38112.5
# University degree and higher  11672583.0  58952.439394  37846.0  57291.0
#
#                                   amax  size
# Characteristics
# High school diploma and less   55242.0   210
# Trade certificate              79053.0   198
# University degree and higher  112032.0   198
# Overall,
# Sum :  25792092.0
# Mean :  42561.207920792076
# Min/median/max : 15835.0 / 39694.5 / 112032.0
# Skewnewss :  1.365731094541449
# Total size :  606
# Year of 2016
#                                      sum          mean     amin   median  \
# Characteristics
# High school diploma and less   6237814.0  29703.876190  15835.0  28089.0
# Trade certificate              7881695.0  39806.540404  22892.0  38112.5
# University degree and higher  11672583.0  58952.439394  37846.0  57291.0
#
#                                   amax  size
# Characteristics
# High school diploma and less   55242.0   210
# Trade certificate              79053.0   198
# University degree and higher  112032.0   198
# Overall,
# Sum :  25792092.0
# Mean :  42561.207920792076
# Min/median/max : 15835.0 / 39694.5 / 112032.0
# Skewnewss :  1.365731094541449
# Total size :  606
# Year of 2016
#                                sum          mean     amin   median      amax  \
# Characteristics
# Immigrant employees      9093448.0  45926.505051  20646.0  44409.5  104174.0
# Non-immigrant employees  8954165.0  45223.055556  28408.0  44274.5   79641.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  18047613.0
# Mean :  45574.780303030304
# Min/median/max : 20646.0 / 44352.5 / 104174.0
# Skewnewss :  1.1947096122148104
# Total size :  396
#
# Year of 2020
#                               sum          mean     amin   median      amax  \
# Characteristics
# 15 to 24 years          3482308.0  18137.020833  11093.0  16653.5   45844.0
# 25 to 34 years          9108041.0  43371.623810  26534.0  42901.0   75429.0
# 35 to 44 years         12296655.0  58555.500000  37336.0  56960.5   95714.0
# 45 to 54 years         13595377.0  64739.890476  39455.0  64274.5  103580.0
# 55 to 64 years         12592232.0  59963.009524  33296.0  56266.0  133071.0
# 65 years old and over   6840988.0  35630.145833  18187.0  34170.0   76577.0
#
#                        size
# Characteristics
# 15 to 24 years          192
# 25 to 34 years          210
# 35 to 44 years          210
# 45 to 54 years          210
# 55 to 64 years          210
# 65 years old and over   192
# Overall,
# Sum :  57915601.0
# Mean :  47316.66748366013
# Min/median/max : 11093.0 / 47033.5 / 133071.0
# Skewnewss :  0.4846905588925664
# Total size :  1224
# Year of 2020
#                                      sum          mean     amin   median  \
# Characteristics
# High school diploma and less   6915927.0  32932.985714  17828.0  31071.0
# Trade certificate              8609637.0  43483.015152  25221.0  42431.0
# University degree and higher  12581443.0  63542.641414  38860.0  62574.0
#
#                                   amax  size
# Characteristics
# High school diploma and less   73020.0   210
# Trade certificate              72854.0   198
# University degree and higher  121264.0   198
# Overall,
# Sum :  28107007.0
# Mean :  46381.199669967
# Min/median/max : 17828.0 / 43075.0 / 121264.0
# Skewnewss :  1.273924834730388
# Total size :  606
# Year of 2020
#                                      sum          mean     amin   median  \
# Characteristics
# High school diploma and less   6915927.0  32932.985714  17828.0  31071.0
# Trade certificate              8609637.0  43483.015152  25221.0  42431.0
# University degree and higher  12581443.0  63542.641414  38860.0  62574.0
#
#                                   amax  size
# Characteristics
# High school diploma and less   73020.0   210
# Trade certificate              72854.0   198
# University degree and higher  121264.0   198
# Overall,
# Sum :  28107007.0
# Mean :  46381.199669967
# Min/median/max : 17828.0 / 43075.0 / 121264.0
# Skewnewss :  1.273924834730388
# Total size :  606
# Year of 2020
#                                sum          mean     amin   median     amax  \
# Characteristics
# Immigrant employees      9838690.0  49690.353535  23144.0  48933.5  98074.0
# Non-immigrant employees  9799014.0  49489.969697  29956.0  49313.5  85472.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  19637704.0
# Mean :  49590.16161616162
# Min/median/max : 23144.0 / 49016.0 / 98074.0
# Skewnewss :  0.9303937237175556
# Total size :  396

# %% [markdown]
# Final output for "Average hourly wage"

# %%
# dfa_Target_To_Analysis = [df_AvgHrsWages_2010_ByAge, df_AvgHrsWages_2010_ByEducation, df_AvgHrsWages_2010_ByEducation, df_AvgHrsWages_2010_ByImmigrant]
# for df_Target_To_Analysis in dfa_Target_To_Analysis:
#       grouped = df_Target_To_Analysis.groupby(['Characteristics'])
#       print("Year of 2010")
#       print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
#       print("Overall,")
#       print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
#       print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
#       print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
#             np.median(df_Target_To_Analysis['VALUE']),"/",
#             np.max(df_Target_To_Analysis['VALUE']))
#       print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
#       print("Total size : ",len(df_Target_To_Analysis.index))

# print()
dfa_Target_To_Analysis = [df_AvgHrsWages_2013_ByAge, df_AvgHrsWages_2013_ByEducation, df_AvgHrsWages_2013_ByEducation, df_AvgHrsWages_2013_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2013")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgHrsWages_2016_ByAge, df_AvgHrsWages_2016_ByEducation, df_AvgHrsWages_2016_ByEducation, df_AvgHrsWages_2016_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2016")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgHrsWages_2019_ByAge, df_AvgHrsWages_2019_ByEducation, df_AvgHrsWages_2019_ByEducation, df_AvgHrsWages_2019_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2019")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))
# Out:
# Year of 2013
#                            sum       mean   amin  median   amax  size
# Characteristics
# 15 to 24 years         3089.01  16.088594  11.70  15.375  26.00   192
# 25 to 34 years         4937.02  23.509619  15.07  22.835  47.75   210
# 35 to 44 years         6053.85  28.827857  17.22  28.400  54.92   210
# 45 to 54 years         6297.06  29.986000  16.89  29.935  50.43   210
# 55 to 64 years         6605.48  31.454667  16.73  29.800  63.50   210
# 65 years old and over  5475.51  28.518281  15.90  27.170  69.41   192
# Overall,
# Sum :  32457.93
# Mean :  26.517916666666668
# Min/median/max : 11.7 / 25.675 / 69.41
# Skewnewss :  1.0223945014335014
# Total size :  1224
# Year of 2013
#                                   sum       mean   amin  median   amax  size
# Characteristics
# High school diploma and less  4434.80  21.118095  12.76  20.295  35.57   210
# Trade certificate             4774.81  24.115202  14.10  23.015  43.26   198
# University degree and higher  6415.25  32.400253  18.40  31.705  68.02   198
# Overall,
# Sum :  15624.86
# Mean :  25.783597359735975
# Min/median/max : 12.76 / 23.46 / 68.02
# Skewnewss :  1.619049492933764
# Total size :  606
# Year of 2013
#                                   sum       mean   amin  median   amax  size
# Characteristics
# High school diploma and less  4434.80  21.118095  12.76  20.295  35.57   210
# Trade certificate             4774.81  24.115202  14.10  23.015  43.26   198
# University degree and higher  6415.25  32.400253  18.40  31.705  68.02   198
# Overall,
# Sum :  15624.86
# Mean :  25.783597359735975
# Min/median/max : 12.76 / 23.46 / 68.02
# Skewnewss :  1.619049492933764
# Total size :  606
# Year of 2013
#                              sum       mean   amin  median   amax  size
# Characteristics
# Immigrant employees      5306.29  26.799444  13.35  25.330  56.37   198
# Non-immigrant employees  5402.47  27.285202  16.38  26.565  52.22   198
# Overall,
# Sum :  10708.76
# Mean :  27.042323232323234
# Min/median/max : 13.35 / 26.134999999999998 / 56.37
# Skewnewss :  0.9100751567756702
# Total size :  396
#
# Year of 2016
#                            sum       mean   amin  median   amax  size
# Characteristics
# 15 to 24 years         3305.36  17.215417  12.66  16.300  33.72   192
# 25 to 34 years         5214.72  24.832000  16.17  24.090  46.15   210
# 35 to 44 years         6375.48  30.359429  18.07  29.740  53.12   210
# 45 to 54 years         6704.45  31.925952  19.16  31.625  56.39   210
# 55 to 64 years         6934.64  33.022095  17.98  31.125  63.53   210
# 65 years old and over  5778.32  30.095417  17.79  28.675  63.78   192
# Overall,
# Sum :  34312.97
# Mean :  28.033472222222223
# Min/median/max : 12.66 / 27.494999999999997 / 63.78
# Skewnewss :  0.9400525873183367
# Total size :  1224
# Year of 2016
#                                   sum       mean   amin  median   amax  size
# Characteristics
# High school diploma and less  4707.09  22.414714  14.10   21.38  38.43   210
# Trade certificate             5053.86  25.524545  16.93   24.69  44.18   198
# University degree and higher  6739.74  34.039091  20.12   32.94  66.29   198
# Overall,
# Sum :  16500.69
# Mean :  27.22886138613861
# Min/median/max : 14.1 / 25.125 / 66.29
# Skewnewss :  1.5725239182893158
# Total size :  606
# Year of 2016
#                                   sum       mean   amin  median   amax  size
# Characteristics
# High school diploma and less  4707.09  22.414714  14.10   21.38  38.43   210
# Trade certificate             5053.86  25.524545  16.93   24.69  44.18   198
# University degree and higher  6739.74  34.039091  20.12   32.94  66.29   198
# Overall,
# Sum :  16500.69
# Mean :  27.22886138613861
# Min/median/max : 14.1 / 25.125 / 66.29
# Skewnewss :  1.5725239182893158
# Total size :  606
# Year of 2016
#                              sum       mean   amin  median   amax  size
# Characteristics
# Immigrant employees      5560.78  28.084747  14.23   26.82  57.56   198
# Non-immigrant employees  5726.37  28.921061  17.85   28.02  52.15   198
# Overall,
# Sum :  11287.150000000001
# Mean :  28.502904040404044
# Min/median/max : 14.23 / 27.575 / 57.56
# Skewnewss :  1.0078903310307468
# Total size :  396
#
# Year of 2019
#                            sum       mean   amin  median   amax  size
# Characteristics
# 15 to 24 years         3689.12  19.214167  12.95  18.775  36.37   192
# 25 to 34 years         5759.41  27.425762  17.01  27.010  45.91   210
# 35 to 44 years         6991.24  33.291619  19.42  32.680  58.12   210
# 45 to 54 years         7451.95  35.485476  21.54  34.965  64.54   210
# 55 to 64 years         7475.92  35.599619  19.42  33.800  64.92   210
# 65 years old and over  6329.58  32.966563  18.32  32.140  66.63   192
# Overall,
# Sum :  37697.22
# Mean :  30.79838235294118
# Min/median/max : 12.95 / 30.425 / 66.63
# Skewnewss :  0.8175005207452904
# Total size :  1224
# Year of 2019
#                                   sum       mean   amin  median   amax  size
# Characteristics
# High school diploma and less  5242.44  24.964000  15.69  23.600  44.52   210
# Trade certificate             5569.30  28.127778  17.63  27.370  44.58   198
# University degree and higher  7296.08  36.848889  21.80  36.385  69.52   198
# Overall,
# Sum :  18107.82
# Mean :  29.88089108910891
# Min/median/max : 15.69 / 27.8 / 69.52
# Skewnewss :  1.32266748675931
# Total size :  606
# Year of 2019
#                                   sum       mean   amin  median   amax  size
# Characteristics
# High school diploma and less  5242.44  24.964000  15.69  23.600  44.52   210
# Trade certificate             5569.30  28.127778  17.63  27.370  44.58   198
# University degree and higher  7296.08  36.848889  21.80  36.385  69.52   198
# Overall,
# Sum :  18107.82
# Mean :  29.88089108910891
# Min/median/max : 15.69 / 27.8 / 69.52
# Skewnewss :  1.32266748675931
# Total size :  606
# Year of 2019
#                              sum       mean   amin  median   amax  size
# Characteristics
# Immigrant employees      6065.65  30.634596  16.93  29.925  60.18   198
# Non-immigrant employees  6267.15  31.652273  19.24  31.000  55.32   198
# Overall,
# Sum :  12332.8
# Mean :  31.143434343434343
# Min/median/max : 16.93 / 30.795 / 60.18
# Skewnewss :  0.8277016858447296
# Total size :  396

# %% [markdown]
# Final output for "Average weekly hours worked"

# %%
# dfa_Target_To_Analysis = [df_AvgWeekHrsWrked_2010_ByAge, df_AvgWeekHrsWrked_2010_ByEducation, df_AvgWeekHrsWrked_2010_ByEducation, df_AvgWeekHrsWrked_2010_ByImmigrant]
# for df_Target_To_Analysis in dfa_Target_To_Analysis:
#       grouped = df_Target_To_Analysis.groupby(['Characteristics'])
#       print("Year of 2010")
#       print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
#       print("Overall,")
#       print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
#       print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
#       print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
#             np.median(df_Target_To_Analysis['VALUE']),"/",
#             np.max(df_Target_To_Analysis['VALUE']))
#       print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
#       print("Total size : ",len(df_Target_To_Analysis.index))

# print()
dfa_Target_To_Analysis = [df_AvgWeekHrsWrked_2013_ByAge, df_AvgWeekHrsWrked_2013_ByEducation, df_AvgWeekHrsWrked_2013_ByEducation, df_AvgWeekHrsWrked_2013_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2013")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgWeekHrsWrked_2016_ByAge, df_AvgWeekHrsWrked_2016_ByEducation, df_AvgWeekHrsWrked_2016_ByEducation, df_AvgWeekHrsWrked_2016_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2016")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_AvgWeekHrsWrked_2019_ByAge, df_AvgWeekHrsWrked_2019_ByEducation, df_AvgWeekHrsWrked_2019_ByEducation, df_AvgWeekHrsWrked_2019_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2019")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))
# Out:
# Year of 2013
#                           sum       mean  amin  median  amax  size
# Characteristics
# 15 to 24 years         3314.0  17.260417   9.0    17.0  21.0   192
# 25 to 34 years         6556.0  31.219048  24.0    31.0  37.0   210
# 35 to 44 years         7256.0  34.552381  28.0    34.0  42.0   210
# 45 to 54 years         7454.0  35.495238  29.0    35.0  44.0   210
# 55 to 64 years         6780.0  32.285714  27.0    32.0  38.0   210
# 65 years old and over  3983.0  20.744792  14.0    21.0  29.0   192
# Overall,
# Sum :  35343.0
# Mean :  28.875
# Min/median/max : 9.0 / 32.0 / 44.0
# Skewnewss :  -0.5948697613902876
# Total size :  1224
# Year of 2013
#                                  sum       mean  amin  median  amax  size
# Characteristics
# High school diploma and less  5334.0  25.400000  20.0    25.0  32.0   210
# Trade certificate             6034.0  30.474747  21.0    30.0  37.0   198
# University degree and higher  6681.0  33.742424  29.0    33.0  40.0   198
# Overall,
# Sum :  18049.0
# Mean :  29.783828382838283
# Min/median/max : 20.0 / 30.0 / 40.0
# Skewnewss :  -0.07010943032755414
# Total size :  606
# Year of 2013
#                                  sum       mean  amin  median  amax  size
# Characteristics
# High school diploma and less  5334.0  25.400000  20.0    25.0  32.0   210
# Trade certificate             6034.0  30.474747  21.0    30.0  37.0   198
# University degree and higher  6681.0  33.742424  29.0    33.0  40.0   198
# Overall,
# Sum :  18049.0
# Mean :  29.783828382838283
# Min/median/max : 20.0 / 30.0 / 40.0
# Skewnewss :  -0.07010943032755414
# Total size :  606
# Year of 2013
#                             sum       mean  amin  median  amax  size
# Characteristics
# Immigrant employees      6278.0  31.707071  26.0    31.0  48.0   198
# Non-immigrant employees  6001.0  30.308081  25.0    30.0  33.0   198
# Overall,
# Sum :  12279.0
# Mean :  31.007575757575758
# Min/median/max : 25.0 / 31.0 / 48.0
# Skewnewss :  2.4359038835445643
# Total size :  396
#
# Year of 2016
#                           sum       mean  amin  median  amax  size
# Characteristics
# 15 to 24 years         3387.0  17.640625  13.0    18.0  23.0   192
# 25 to 34 years         6489.0  30.900000  25.0    31.0  38.0   210
# 35 to 44 years         7185.0  34.214286  28.0    34.0  41.0   210
# 45 to 54 years         7415.0  35.309524  30.0    35.0  44.0   210
# 55 to 64 years         6748.0  32.133333  27.0    32.0  38.0   210
# 65 years old and over  3965.0  20.651042  13.0    21.0  27.0   192
# Overall,
# Sum :  35189.0
# Mean :  28.749183006535947
# Min/median/max : 13.0 / 32.0 / 44.0
# Skewnewss :  -0.5799811137221278
# Total size :  1224
# Year of 2016
#                                  sum       mean  amin  median  amax  size
# Characteristics
# High school diploma and less  5315.0  25.309524  20.0    25.0  31.0   210
# Trade certificate             5922.0  29.909091  17.0    30.0  35.0   198
# University degree and higher  6604.0  33.353535  30.0    33.0  40.0   198
# Overall,
# Sum :  17841.0
# Mean :  29.440594059405942
# Min/median/max : 17.0 / 30.0 / 40.0
# Skewnewss :  -0.12138085477404481
# Total size :  606
# Year of 2016
#                                  sum       mean  amin  median  amax  size
# Characteristics
# High school diploma and less  5315.0  25.309524  20.0    25.0  31.0   210
# Trade certificate             5922.0  29.909091  17.0    30.0  35.0   198
# University degree and higher  6604.0  33.353535  30.0    33.0  40.0   198
# Overall,
# Sum :  17841.0
# Mean :  29.440594059405942
# Min/median/max : 17.0 / 30.0 / 40.0
# Skewnewss :  -0.12138085477404481
# Total size :  606
# Year of 2016
#                             sum       mean  amin  median  amax  size
# Characteristics
# Immigrant employees      6185.0  31.237374  26.0    31.0  47.0   198
# Non-immigrant employees  5968.0  30.141414  25.0    30.0  34.0   198
# Overall,
# Sum :  12153.0
# Mean :  30.689393939393938
# Min/median/max : 25.0 / 30.0 / 47.0
# Skewnewss :  2.188536649520565
# Total size :  396
#
# Year of 2019
#                           sum       mean  amin  median  amax  size
# Characteristics
# 15 to 24 years         3465.0  18.046875  14.0    18.0  25.0   192
# 25 to 34 years         6413.0  30.538095  25.0    30.0  36.0   210
# 35 to 44 years         7139.0  33.995238  27.0    34.0  40.0   210
# 45 to 54 years         7406.0  35.266667  30.0    35.0  42.0   210
# 55 to 64 years         6765.0  32.214286  26.0    32.0  40.0   210
# 65 years old and over  3969.0  20.671875  11.0    21.0  27.0   192
# Overall,
# Sum :  35157.0
# Mean :  28.723039215686274
# Min/median/max : 11.0 / 31.0 / 42.0
# Skewnewss :  -0.578814861266804
# Total size :  1224
# Year of 2019
#                                  sum       mean  amin  median  amax  size
# Characteristics
# High school diploma and less  5303.0  25.252381  20.0    25.0  32.0   210
# Trade certificate             5889.0  29.742424  15.0    30.0  35.0   198
# University degree and higher  6568.0  33.171717  30.0    33.0  39.0   198
# Overall,
# Sum :  17760.0
# Mean :  29.306930693069308
# Min/median/max : 15.0 / 30.0 / 39.0
# Skewnewss :  -0.18790375522922004
# Total size :  606
# Year of 2019
#                                  sum       mean  amin  median  amax  size
# Characteristics
# High school diploma and less  5303.0  25.252381  20.0    25.0  32.0   210
# Trade certificate             5889.0  29.742424  15.0    30.0  35.0   198
# University degree and higher  6568.0  33.171717  30.0    33.0  39.0   198
# Overall,
# Sum :  17760.0
# Mean :  29.306930693069308
# Min/median/max : 15.0 / 30.0 / 39.0
# Skewnewss :  -0.18790375522922004
# Total size :  606
# Year of 2019
#                             sum       mean  amin  median  amax  size
# Characteristics
# Immigrant employees      6133.0  30.974747  26.0    31.0  43.0   198
# Non-immigrant employees  5961.0  30.106061  25.0    30.0  34.0   198
# Overall,
# Sum :  12094.0
# Mean :  30.54040404040404
# Min/median/max : 25.0 / 30.0 / 43.0
# Skewnewss :  1.6446273199481087
# Total size :  396

# %% [markdown]
# Final output for "Hours Worked"

# %%
# dfa_Target_To_Analysis = [df_Hrs_Wrked_2010_ByAge, df_Hrs_Wrked_2010_ByEducation, df_Hrs_Wrked_2010_ByEducation, df_Hrs_Wrked_2010_ByImmigrant]
# for df_Target_To_Analysis in dfa_Target_To_Analysis:
#       grouped = df_Target_To_Analysis.groupby(['Characteristics'])
#       print("Year of 2010")
#       print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
#       print("Overall,")
#       print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
#       print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
#       print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
#             np.median(df_Target_To_Analysis['VALUE']),"/",
#             np.max(df_Target_To_Analysis['VALUE']))
#       print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
#       print("Total size : ",len(df_Target_To_Analysis.index))

# print()
dfa_Target_To_Analysis = [df_Hrs_Wrked_2013_ByAge, df_Hrs_Wrked_2013_ByEducation, df_Hrs_Wrked_2013_ByEducation, df_Hrs_Wrked_2013_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2013")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_Hrs_Wrked_2016_ByAge, df_Hrs_Wrked_2016_ByEducation, df_Hrs_Wrked_2016_ByEducation, df_Hrs_Wrked_2016_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2016")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_Hrs_Wrked_2019_ByAge, df_Hrs_Wrked_2019_ByEducation, df_Hrs_Wrked_2019_ByEducation, df_Hrs_Wrked_2019_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2019")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))
# Out:
# Year of 2013
#                               sum          mean  amin   median      amax  size
# Characteristics
# 15 to 24 years          3107754.0  16186.218750   6.0   3910.0  216618.0   192
# 25 to 34 years         10595996.0  50457.123810  32.0   9133.5  770449.0   210
# 35 to 44 years         11379938.0  54190.180952  32.0   9535.5  826253.0   210
# 45 to 54 years         13158896.0  62661.409524  29.0  10672.5  955066.0   210
# 55 to 64 years          9899434.0  47140.161905  20.0   8386.5  728243.0   210
# 65 years old and over   1974184.0  10282.208333  26.0   2329.0  146525.0   192
# Overall,
# Sum :  50116202.0
# Mean :  40944.609477124184
# Min/median/max : 6.0 / 6028.0 / 955066.0
# Skewnewss :  5.157256992066241
# Total size :  1224
# Year of 2013
#                                      sum           mean  amin   median  \
# Characteristics
# High school diploma and less   9259138.0   44091.133333  54.0  11595.5
# Trade certificate              3736455.0   18870.984848  26.0   3668.5
# University degree and higher  23601210.0  119198.030303  99.0  21519.0
#
#                                    amax  size
# Characteristics
# High school diploma and less   642541.0   210
# Trade certificate              276386.0   198
# University degree and higher  1729001.0   198
# Overall,
# Sum :  36596803.0
# Mean :  60390.76402640264
# Min/median/max : 26.0 / 8103.0 / 1729001.0
# Skewnewss :  6.272807085792226
# Total size :  606
# Year of 2013
#                                      sum           mean  amin   median  \
# Characteristics
# High school diploma and less   9259138.0   44091.133333  54.0  11595.5
# Trade certificate              3736455.0   18870.984848  26.0   3668.5
# University degree and higher  23601210.0  119198.030303  99.0  21519.0
#
#                                    amax  size
# Characteristics
# High school diploma and less   642541.0   210
# Trade certificate              276386.0   198
# University degree and higher  1729001.0   198
# Overall,
# Sum :  36596803.0
# Mean :  60390.76402640264
# Min/median/max : 26.0 / 8103.0 / 1729001.0
# Skewnewss :  6.272807085792226
# Total size :  606
# Year of 2013
#                                 sum           mean   amin   median       amax  \
# Characteristics
# Immigrant employees      12147236.0   61349.676768   41.0   6201.0   899418.0
# Non-immigrant employees  37962608.0  191730.343434  305.0  48064.5  2732791.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  50109844.0
# Mean :  126540.0101010101
# Min/median/max : 41.0 / 20475.5 / 2732791.0
# Skewnewss :  5.319178387971915
# Total size :  396
#
# Year of 2016
#                               sum          mean  amin   median      amax  size
# Characteristics
# 15 to 24 years          3211600.0  16727.083333  15.0   4100.0  225988.0   192
# 25 to 34 years         11296322.0  53792.009524  40.0   9922.5  824205.0   210
# 35 to 44 years         12146992.0  57842.819048  39.0  10902.5  892149.0   210
# 45 to 54 years         13070232.0  62239.200000  33.0  11328.5  946775.0   210
# 55 to 64 years         10422244.0  49629.733333  24.0   9417.5  754767.0   210
# 65 years old and over   2324345.0  12105.963542  27.0   2658.5  168451.0   192
# Overall,
# Sum :  52471735.0
# Mean :  42869.06454248366
# Min/median/max : 15.0 / 6214.5 / 946775.0
# Skewnewss :  5.082886547778594
# Total size :  1224
# Year of 2016
#                                      sum           mean  amin   median  \
# Characteristics
# High school diploma and less   9485452.0   45168.819048  68.0  11567.5
# Trade certificate              3558304.0   17971.232323  20.0   3397.0
# University degree and higher  25474813.0  128660.671717  88.0  22610.0
#
#                                    amax  size
# Characteristics
# High school diploma and less   650689.0   210
# Trade certificate              263036.0   198
# University degree and higher  1887922.0   198
# Overall,
# Sum :  38518569.0
# Mean :  63561.99504950495
# Min/median/max : 20.0 / 8101.0 / 1887922.0
# Skewnewss :  6.358954163111494
# Total size :  606
# Year of 2016
#                                      sum           mean  amin   median  \
# Characteristics
# High school diploma and less   9485452.0   45168.819048  68.0  11567.5
# Trade certificate              3558304.0   17971.232323  20.0   3397.0
# University degree and higher  25474813.0  128660.671717  88.0  22610.0
#
#                                    amax  size
# Characteristics
# High school diploma and less   650689.0   210
# Trade certificate              263036.0   198
# University degree and higher  1887922.0   198
# Overall,
# Sum :  38518569.0
# Mean :  63561.99504950495
# Min/median/max : 20.0 / 8101.0 / 1887922.0
# Skewnewss :  6.358954163111494
# Total size :  606
# Year of 2016
#                                 sum           mean   amin   median       amax  \
# Characteristics
# Immigrant employees      13361296.0   67481.292929   42.0   6713.0   992945.0
# Non-immigrant employees  39103961.0  197494.752525  258.0  48202.5  2811247.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  52465257.0
# Mean :  132488.02272727274
# Min/median/max : 42.0 / 21940.5 / 2811247.0
# Skewnewss :  5.234421190105478
# Total size :  396
#
# Year of 2019
#                               sum          mean  amin   median      amax  size
# Characteristics
# 15 to 24 years          3132171.0  16313.390625  29.0   3859.5  228566.0   192
# 25 to 34 years         11857576.0  56464.647619  32.0  10166.5  888764.0   210
# 35 to 44 years         12919606.0  61521.933333  33.0  10825.0  971688.0   210
# 45 to 54 years         12974580.0  61783.714286  31.0  10600.5  966480.0   210
# 55 to 64 years         10690620.0  50907.714286  25.0   8934.0  794712.0   210
# 65 years old and over   2528517.0  13169.359375  30.0   2913.5  183461.0   192
# Overall,
# Sum :  54103070.0
# Mean :  44201.8545751634
# Min/median/max : 25.0 / 6420.5 / 971688.0
# Skewnewss :  5.111311073923015
# Total size :  1224
# Year of 2019
#                                      sum           mean  amin   median  \
# Characteristics
# High school diploma and less   9285900.0   44218.571429  61.0  11984.5
# Trade certificate              3449203.0   17420.217172  20.0   3080.0
# University degree and higher  27393105.0  138349.015152  96.0  23963.5
#
#                                    amax  size
# Characteristics
# High school diploma and less   658441.0   210
# Trade certificate              260168.0   198
# University degree and higher  2065714.0   198
# Overall,
# Sum :  40128208.0
# Mean :  66218.16501650165
# Min/median/max : 20.0 / 7837.0 / 2065714.0
# Skewnewss :  6.531158889782265
# Total size :  606
# Year of 2019
#                                      sum           mean  amin   median  \
# Characteristics
# High school diploma and less   9285900.0   44218.571429  61.0  11984.5
# Trade certificate              3449203.0   17420.217172  20.0   3080.0
# University degree and higher  27393105.0  138349.015152  96.0  23963.5
#
#                                    amax  size
# Characteristics
# High school diploma and less   658441.0   210
# Trade certificate              260168.0   198
# University degree and higher  2065714.0   198
# Overall,
# Sum :  40128208.0
# Mean :  66218.16501650165
# Min/median/max : 20.0 / 7837.0 / 2065714.0
# Skewnewss :  6.531158889782265
# Total size :  606
# Year of 2019
#                                 sum           mean   amin   median       amax  \
# Characteristics
# Immigrant employees      14355944.0   72504.767677   44.0   7122.0  1084033.0
# Non-immigrant employees  39740524.0  200709.717172  264.0  48444.5  2949643.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  54096468.0
# Mean :  136607.24242424243
# Min/median/max : 44.0 / 22542.5 / 2949643.0
# Skewnewss :  5.210924241138901
# Total size :  396

# %% [markdown]
# Final output for "Number of jobs"

# %%
# dfa_Target_To_Analysis = [df_NumOfJob_2010_ByAge, df_NumOfJob_2010_ByEducation, df_NumOfJob_2010_ByEducation, df_NumOfJob_2010_ByImmigrant]
# for df_Target_To_Analysis in dfa_Target_To_Analysis:
#       grouped = df_Target_To_Analysis.groupby(['Characteristics'])
#       print("Year of 2010")
#       print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
#       print("Overall,")
#       print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
#       print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
#       print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
#             np.median(df_Target_To_Analysis['VALUE']),"/",
#             np.max(df_Target_To_Analysis['VALUE']))
#       print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
#       print("Total size : ",len(df_Target_To_Analysis.index))

# print()
dfa_Target_To_Analysis = [df_NumOfJob_2013_ByAge, df_NumOfJob_2013_ByEducation, df_NumOfJob_2013_ByEducation, df_NumOfJob_2013_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2013")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_NumOfJob_2016_ByAge, df_NumOfJob_2016_ByEducation, df_NumOfJob_2016_ByEducation, df_NumOfJob_2016_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2016")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_NumOfJob_2019_ByAge, df_NumOfJob_2019_ByEducation, df_NumOfJob_2019_ByEducation, df_NumOfJob_2019_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2019")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))
# Out:
# Year of 2013
#                              sum          mean  amin  median      amax  size
# Characteristics
# 15 to 24 years         3475038.0  18099.156250  13.0  4155.0  241122.0   192
# 25 to 34 years         6767092.0  32224.247619  17.0  5538.0  495502.0   210
# 35 to 44 years         6596518.0  31411.990476  18.0  5526.0  481136.0   210
# 45 to 54 years         7311054.0  34814.542857  14.0  5827.0  530812.0   210
# 55 to 64 years         6008488.0  28611.847619  11.0  4965.5  441682.0   210
# 65 years old and over  1910168.0   9948.791667  18.0  2144.5  138944.0   192
# Overall,
# Sum :  32068358.0
# Mean :  26199.63888888889
# Min/median/max : 11.0 / 4155.0 / 530812.0
# Skewnewss :  4.8267095355895036
# Total size :  1224
# Year of 2013
#                                      sum          mean  amin   median  \
# Characteristics
# High school diploma and less   7081390.0  33720.904762  36.0   7954.5
# Trade certificate              2417879.0  12211.510101  16.0   2158.0
# University degree and higher  14192344.0  71678.505051  50.0  12500.5
#
#                                    amax  size
# Characteristics
# High school diploma and less   490482.0   210
# Trade certificate              178883.0   198
# University degree and higher  1044725.0   198
# Overall,
# Sum :  23691613.0
# Mean :  39095.07095709571
# Min/median/max : 16.0 / 5470.0 / 1044725.0
# Skewnewss :  5.897742004006696
# Total size :  606
# Year of 2013
#                                      sum          mean  amin   median  \
# Characteristics
# High school diploma and less   7081390.0  33720.904762  36.0   7954.5
# Trade certificate              2417879.0  12211.510101  16.0   2158.0
# University degree and higher  14192344.0  71678.505051  50.0  12500.5
#
#                                    amax  size
# Characteristics
# High school diploma and less   490482.0   210
# Trade certificate              178883.0   198
# University degree and higher  1044725.0   198
# Overall,
# Sum :  23691613.0
# Mean :  39095.07095709571
# Min/median/max : 16.0 / 5470.0 / 1044725.0
# Skewnewss :  5.897742004006696
# Total size :  606
# Year of 2013
#                                 sum           mean   amin   median       amax  \
# Characteristics
# Immigrant employees       7694218.0   38859.686869   20.0   3598.0   569900.0
# Non-immigrant employees  24370675.0  123084.217172  192.0  29397.0  1754860.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  32064893.0
# Mean :  80971.95202020202
# Min/median/max : 20.0 / 12524.0 / 1754860.0
# Skewnewss :  5.310500968392142
# Total size :  396
#
# Year of 2016
#                              sum          mean  amin  median      amax  size
# Characteristics
# 15 to 24 years         3568591.0  18586.411458  17.0  4338.0  246749.0   192
# 25 to 34 years         7218822.0  34375.342857  22.0  6063.0  527094.0   210
# 35 to 44 years         7058062.0  33609.819048  22.0  6157.5  516879.0   210
# 45 to 54 years         7243040.0  34490.666667  16.0  6123.0  525300.0   210
# 55 to 64 years         6305020.0  30023.904762  12.0  5590.0  453209.0   210
# 65 years old and over  2240484.0  11669.187500  21.0  2432.5  162525.0   192
# Overall,
# Sum :  33634019.0
# Mean :  27478.773692810457
# Min/median/max : 12.0 / 4444.5 / 527094.0
# Skewnewss :  4.775599421631397
# Total size :  1224
# Year of 2016
#                                      sum          mean  amin   median  \
# Characteristics
# High school diploma and less   7346224.0  34982.019048  45.0   8309.5
# Trade certificate              2312220.0  11677.878788  13.0   2042.0
# University degree and higher  15322286.0  77385.282828  42.0  13038.0
#
#                                    amax  size
# Characteristics
# High school diploma and less   501836.0   210
# Trade certificate              170641.0   198
# University degree and higher  1133182.0   198
# Overall,
# Sum :  24980730.0
# Mean :  41222.32673267327
# Min/median/max : 13.0 / 5457.0 / 1133182.0
# Skewnewss :  5.973175820588759
# Total size :  606
# Year of 2016
#                                      sum          mean  amin   median  \
# Characteristics
# High school diploma and less   7346224.0  34982.019048  45.0   8309.5
# Trade certificate              2312220.0  11677.878788  13.0   2042.0
# University degree and higher  15322286.0  77385.282828  42.0  13038.0
#
#                                    amax  size
# Characteristics
# High school diploma and less   501836.0   210
# Trade certificate              170641.0   198
# University degree and higher  1133182.0   198
# Overall,
# Sum :  24980730.0
# Mean :  41222.32673267327
# Min/median/max : 13.0 / 5457.0 / 1133182.0
# Skewnewss :  5.973175820588759
# Total size :  606
# Year of 2016
#                                 sum           mean   amin   median       amax  \
# Characteristics
# Immigrant employees       8481252.0   42834.606061   19.0   4048.5   626191.0
# Non-immigrant employees  25149138.0  127015.848485  161.0  29819.5  1796966.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  33630390.0
# Mean :  84925.22727272728
# Min/median/max : 19.0 / 13979.5 / 1796966.0
# Skewnewss :  5.226871514642094
# Total size :  396
#
# Year of 2019
#                              sum          mean  amin  median      amax  size
# Characteristics
# 15 to 24 years         3414206.0  17782.322917  24.0  4022.0  247960.0   192
# 25 to 34 years         7615612.0  36264.819048  19.0  6267.5  564788.0   210
# 35 to 44 years         7559436.0  35997.314286  18.0  6322.0  561685.0   210
# 45 to 54 years         7201656.0  34293.600000  16.0  5847.0  529125.0   210
# 55 to 64 years         6451160.0  30719.809524  13.0  5371.5  472689.0   210
# 65 years old and over  2416851.0  12587.765625  25.0  2729.0  173157.0   192
# Overall,
# Sum :  34658921.0
# Mean :  28316.111928104576
# Min/median/max : 13.0 / 4637.5 / 564788.0
# Skewnewss :  4.838307897340021
# Total size :  1224
# Year of 2019
#                                      sum          mean  amin   median  \
# Characteristics
# High school diploma and less   7204888.0  34308.990476  40.0   8564.5
# Trade certificate              2245738.0  11342.111111  13.0   1865.5
# University degree and higher  16513042.0  83399.202020  47.0  13812.5
#
#                                    amax  size
# Characteristics
# High school diploma and less   506866.0   210
# Trade certificate              167537.0   198
# University degree and higher  1230063.0   198
# Overall,
# Sum :  25963668.0
# Mean :  42844.33663366337
# Min/median/max : 13.0 / 5005.0 / 1230063.0
# Skewnewss :  6.169027793480176
# Total size :  606
# Year of 2019
#                                      sum          mean  amin   median  \
# Characteristics
# High school diploma and less   7204888.0  34308.990476  40.0   8564.5
# Trade certificate              2245738.0  11342.111111  13.0   1865.5
# University degree and higher  16513042.0  83399.202020  47.0  13812.5
#
#                                    amax  size
# Characteristics
# High school diploma and less   506866.0   210
# Trade certificate              167537.0   198
# University degree and higher  1230063.0   198
# Overall,
# Sum :  25963668.0
# Mean :  42844.33663366337
# Min/median/max : 13.0 / 5005.0 / 1230063.0
# Skewnewss :  6.169027793480176
# Total size :  606
# Year of 2019
#                                 sum           mean   amin   median       amax  \
# Characteristics
# Immigrant employees       9133147.0   46127.005051   22.0   4384.0   677236.0
# Non-immigrant employees  25522127.0  128899.631313  163.0  30374.0  1866156.0
#
#                          size
# Characteristics
# Immigrant employees       198
# Non-immigrant employees   198
# Overall,
# Sum :  34655274.0
# Mean :  87513.31818181818
# Min/median/max : 22.0 / 14330.0 / 1866156.0
# Skewnewss :  5.199524609584711
# Total size :  396

# %% [markdown]
# Final output for "Wages and Salaries"

# %%
# dfa_Target_To_Analysis = [df_WagesAndSalaries_2010_ByAge, df_WagesAndSalaries_2010_ByEducation, df_WagesAndSalaries_2010_ByEducation, df_WagesAndSalaries_2010_ByImmigrant]
# for df_Target_To_Analysis in dfa_Target_To_Analysis:
#       grouped = df_Target_To_Analysis.groupby(['Characteristics'])
#       print("Year of 2010")
#       print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
#       print("Overall,")
#       print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
#       print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
#       print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
#             np.median(df_Target_To_Analysis['VALUE']),"/",
#             np.max(df_Target_To_Analysis['VALUE']))
#       print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
#       print("Total size : ",len(df_Target_To_Analysis.index))

# print()
dfa_Target_To_Analysis = [df_WagesAndSalaries_2013_ByAge, df_WagesAndSalaries_2013_ByEducation, df_WagesAndSalaries_2013_ByEducation, df_WagesAndSalaries_2013_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2013")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_WagesAndSalaries_2016_ByAge, df_WagesAndSalaries_2016_ByEducation, df_WagesAndSalaries_2016_ByEducation, df_WagesAndSalaries_2016_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2016")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))

print()
dfa_Target_To_Analysis = [df_WagesAndSalaries_2019_ByAge, df_WagesAndSalaries_2019_ByEducation, df_WagesAndSalaries_2019_ByEducation, df_WagesAndSalaries_2019_ByImmigrant]
for df_Target_To_Analysis in dfa_Target_To_Analysis:
      grouped = df_Target_To_Analysis.groupby(['Characteristics'])
      print("Year of 2019")
      print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
      print("Overall,")
      print("Sum : ",np.sum(df_Target_To_Analysis['VALUE']))
      print("Mean : ",np.mean(df_Target_To_Analysis['VALUE']))
      print("Min/median/max :",np.min(df_Target_To_Analysis['VALUE']),"/",
            np.median(df_Target_To_Analysis['VALUE']),"/",
            np.max(df_Target_To_Analysis['VALUE']))
      print("Skewnewss : ",df_Target_To_Analysis['VALUE'].skew())
      print("Total size : ",len(df_Target_To_Analysis.index))
# Out:
# Year of 2013
#                             sum         mean  amin  median     amax  size
# Characteristics
# 15 to 24 years          51983.0   270.744792   0.0    62.5   3770.0   192
# 25 to 34 years         252992.0  1204.723810   1.0   193.5  19337.0   210
# 35 to 44 years         334759.0  1594.090476   1.0   249.5  25471.0   210
# 45 to 54 years         410954.0  1956.923810   1.0   285.5  30946.0   210
# 55 to 64 years         313103.0  1490.966667   1.0   228.0  24134.0   210
# 65 years old and over   62434.0   325.177083   1.0    56.5   4980.0   192
# Overall,
# Sum :  1426225.0
# Mean :  1165.2165032679738
# Min/median/max : 0.0 / 131.5 / 30946.0
# Skewnewss :  5.458155190569106
# Total size :  1224
# Year of 2013
#                                    sum         mean  amin  median     amax  \
# Characteristics
# High school diploma and less  191721.0   912.957143   2.0   223.0  13803.0
# Trade certificate              86569.0   437.217172   1.0    97.5   6363.0
# University degree and higher  793734.0  4008.757576   3.0   676.0  61165.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  1072024.0
# Mean :  1769.016501650165
# Min/median/max : 1.0 / 194.0 / 61165.0
# Skewnewss :  7.058651252598137
# Total size :  606
# Year of 2013
#                                    sum         mean  amin  median     amax  \
# Characteristics
# High school diploma and less  191721.0   912.957143   2.0   223.0  13803.0
# Trade certificate              86569.0   437.217172   1.0    97.5   6363.0
# University degree and higher  793734.0  4008.757576   3.0   676.0  61165.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  1072024.0
# Mean :  1769.016501650165
# Min/median/max : 1.0 / 194.0 / 61165.0
# Skewnewss :  7.058651252598137
# Total size :  606
# Year of 2013
#                                sum         mean  amin  median     amax  size
# Characteristics
# Immigrant employees       348492.0  1760.060606   1.0   161.0  27151.0   198
# Non-immigrant employees  1077526.0  5442.050505   9.0  1200.5  81487.0   198
# Overall,
# Sum :  1426018.0
# Mean :  3601.0555555555557
# Min/median/max : 1.0 / 472.0 / 81487.0
# Skewnewss :  5.40064585441906
# Total size :  396
#
# Year of 2016
#                             sum         mean  amin  median     amax  size
# Characteristics
# 15 to 24 years          56990.0   296.822917   0.0    67.5   4250.0   192
# 25 to 34 years         285555.0  1359.785714   1.0   220.5  21911.0   210
# 35 to 44 years         376045.0  1790.690476   1.0   271.0  28840.0   210
# 45 to 54 years         431853.0  2056.442857   1.0   292.0  32326.0   210
# 55 to 64 years         344362.0  1639.819048   1.0   241.5  25923.0   210
# 65 years old and over   76349.0   397.651042   1.0    73.0   5823.0   192
# Overall,
# Sum :  1571154.0
# Mean :  1283.6225490196077
# Min/median/max : 0.0 / 147.5 / 32326.0
# Skewnewss :  5.350182768055304
# Total size :  1224
# Year of 2016
#                                    sum         mean  amin  median     amax  \
# Characteristics
# High school diploma and less  207705.0   989.071429   2.0   243.0  14711.0
# Trade certificate              86692.0   437.838384   1.0    87.5   6433.0
# University degree and higher  896636.0  4528.464646   3.0   798.0  69317.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  1191033.0
# Mean :  1965.40099009901
# Min/median/max : 1.0 / 205.0 / 69317.0
# Skewnewss :  7.079129163046304
# Total size :  606
# Year of 2016
#                                    sum         mean  amin  median     amax  \
# Characteristics
# High school diploma and less  207705.0   989.071429   2.0   243.0  14711.0
# Trade certificate              86692.0   437.838384   1.0    87.5   6433.0
# University degree and higher  896636.0  4528.464646   3.0   798.0  69317.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  1191033.0
# Mean :  1965.40099009901
# Min/median/max : 1.0 / 205.0 / 69317.0
# Skewnewss :  7.079129163046304
# Total size :  606
# Year of 2016
#                                sum         mean  amin  median     amax  size
# Characteristics
# Immigrant employees       400833.0  2024.409091   1.0   187.0  31105.0   198
# Non-immigrant employees  1170079.0  5909.489899   9.0  1324.0  87968.0   198
# Overall,
# Sum :  1570912.0
# Mean :  3966.949494949495
# Min/median/max : 1.0 / 519.0 / 87968.0
# Skewnewss :  5.320716824931746
# Total size :  396
#
# Year of 2019
#                             sum         mean  amin  median     amax  size
# Characteristics
# 15 to 24 years          63069.0   328.484375   1.0    69.0   4797.0   192
# 25 to 34 years         334200.0  1591.428571   1.0   236.5  25966.0   210
# 35 to 44 years         441049.0  2100.233333   2.0   314.5  34223.0   210
# 45 to 54 years         474202.0  2258.104762   1.0   317.0  36376.0   210
# 55 to 64 years         386319.0  1839.614286   1.0   260.5  29595.0   210
# 65 years old and over   90513.0   471.421875   1.0    88.0   6876.0   192
# Overall,
# Sum :  1789352.0
# Mean :  1461.888888888889
# Min/median/max : 1.0 / 160.5 / 36376.0
# Skewnewss :  5.308031050696339
# Total size :  1224
# Year of 2019
#                                     sum         mean  amin  median     amax  \
# Characteristics
# High school diploma and less   226638.0  1079.228571   2.0   260.5  16432.0
# Trade certificate               93374.0   471.585859   1.0    85.5   7213.0
# University degree and higher  1052815.0  5317.247475   4.0   931.5  81938.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  1372827.0
# Mean :  2265.391089108911
# Min/median/max : 1.0 / 215.5 / 81938.0
# Skewnewss :  7.125641720633304
# Total size :  606
# Year of 2019
#                                     sum         mean  amin  median     amax  \
# Characteristics
# High school diploma and less   226638.0  1079.228571   2.0   260.5  16432.0
# Trade certificate               93374.0   471.585859   1.0    85.5   7213.0
# University degree and higher  1052815.0  5317.247475   4.0   931.5  81938.0
#
#                               size
# Characteristics
# High school diploma and less   210
# Trade certificate              198
# University degree and higher   198
# Overall,
# Sum :  1372827.0
# Mean :  2265.391089108911
# Min/median/max : 1.0 / 215.5 / 81938.0
# Skewnewss :  7.125641720633304
# Total size :  606
# Year of 2019
#                                sum         mean  amin  median      amax  size
# Characteristics
# Immigrant employees       473697.0  2392.409091   1.0   216.5   36981.0   198
# Non-immigrant employees  1315368.0  6643.272727  10.0  1452.5  100851.0   198
# Overall,
# Sum :  1789065.0
# Mean :  4517.840909090909
# Min/median/max : 1.0 / 578.0 / 100851.0
# Skewnewss :  5.266660488336198
# Total size :  396

# %%
print("Final steps, by sorting out by provinces.")

# -- sum          mean           std  size
# -- GEO                                                                    
# -- Alberta                     2193966.0   2031.450000   2695.836034  1080
# -- British Columbia            2401296.0   2223.422222   2804.925187  1080
# -- Canada                     18252439.0  16900.406481  22232.852533  1080
# -- Manitoba                     767802.0    710.927778    915.637659  1080
# -- New Brunswick                359320.0    332.703704    530.962762  1080
# -- Newfoundland and Labrador    315895.0    306.099806    482.634908  1032
# -- Northwest Territories         42804.0     41.476744     51.817046  1032
# -- Nova Scotia                  531805.0    492.412037    757.119411  1080
# -- Nunavut                       14235.0     15.208333     14.752372   936
# -- Ontario                     6601634.0   6112.624074   7594.433779  1080
# -- Prince Edward Island          77931.0     75.514535    121.297367  1032
# -- Quebec                      4271657.0   3955.237963   5580.294544  1080
# -- Saskatchewan                 650781.0    602.575000    876.896377  1080
# -- Yukon                         16914.0     18.070513     20.188135   936
# -- The total number of this one is  14688
# Out:
# Final steps, by sorting out by provinces.

# %% [markdown]
# As final step, I am classifying the data by province. This is the final step, and this is where I will get the final result with.<br />
# For this step, I will use class methods to avoid duplicated and repeatitive steps to do programming.<br />
# For the complex of the analysis, only the dataset of 2013-2015, 2016-2018, 2019-2021 will be used. <br />
# However, 2010-2012 one will get commented.

# %%
print("With year of 2013 and above (three dataset), I will have to analyize, "+str(7*3*4*14)+" times.")
print("\nUse the year from 2010 to 2021 (four dataasets), I will have to analyize, "+str(7*4*4*14)+" times!")
# Out:
# With year of 2013 and above (three dataset), I will have to analyize, 1176 times.
#
# Use the year from 2010 to 2021 (four dataasets), I will have to analyize, 1568 times!

# %% [markdown]
# Main class for Province Analysis:

# %%
# https://www.w3schools.com/python/python_classes.asp
# https://www.w3schools.com/python/python_for_loops.asp
# https://www.educba.com/multidimensional-array-in-python/

class ProvinceAnalysis:

    # Province :
    # -- ['Alberta',  'British Columbia',    'Canada' , 'Manitoba' , 'New Brunswick' 
    # 'Newfoundland and Labrador', 'Northwest Territories' , 'Nova Scotia' , 'Nunavut'
    # 'Ontario' , 'Prince Edward Island', 'Quebec', 'Saskatchewan', 'Yukon']

    def __init__(self, df, pd, np, pp):
        self.df = df
        self.province = ['Alberta',  'British Columbia', 'Canada', 'Manitoba', 
                        'New Brunswick', 'Newfoundland and Labrador', 
                        'Northwest Territories' , 'Nova Scotia' , 'Nunavut',
                        'Ontario' , 'Prince Edward Island', 'Quebec', 
                        'Saskatchewan', 'Yukon'
                        ]
        self.indicator = ["Average annual hours worked",
                        "Average annual wages and salaries",
                        "Average hourly wage",
                        "Average weekly hours worked",
                        "Hours Worked",
                        "Number of jobs",
                        "Wages and Salaries"]
        self.characteristic = ["Age group", "Gender", "Education Level", "Immigrant status", "Aboriginal status"]
        self.year = ["2010",
                    "below 2015",
                    "above 2016",
                    "2013",
                    "2016",
                    "2019"]
        self.pd = pd
        self.np = np
        self.pp = pp
        self.df_ByProvince = []
        for x in self.province:
            df_sorted = df.loc[df['GEO'] == x]
            self.df_ByProvince.append(df_sorted)

    def outputProvince(self, province_id):
        print(self.province[province_id])

    def outputIndicator(self, indicator_id):
        print(self.province[indicator_id])

    def outputCharacteristic(self, cha_id):
        print(self.province[cha_id])

    def outputYear(self, year_id):
        print(self.province[year_id])

    def outputAnalysis(self, province_id):
        print("\nGrab the dataset only in " + str(self.province[province_id]))
        grouped = self.df_ByProvince[province_id].groupby(['Characteristics'])
        print(grouped['VALUE'].agg([np.sum, np.mean, np.min, np.median, np.max, np.size]))
        print("")
        print("Overall,")
        print("Sum : ",np.sum(self.df_ByProvince[province_id]['VALUE']))
        print("Mean : ",np.mean(self.df_ByProvince[province_id]['VALUE']))
        print("Min/median/max :",np.min(self.df_ByProvince[province_id]['VALUE']),"/",
            np.median(self.df_ByProvince[province_id]['VALUE']),"/",
            np.max(self.df_ByProvince[province_id]['VALUE']))
        print("Skewnewss : ",self.df_ByProvince[province_id]['VALUE'].skew())
        print("Total size : ",len(self.df_ByProvince[province_id].index))

    def outputAnalysisSimple(self, province_id):
        print("\nGrab the dataset only in " + str(self.province[province_id]))
        grouped = self.df_ByProvince[province_id].groupby(['Characteristics'])
        print(grouped['VALUE'].agg([self.np.sum, self.np.mean, self.np.size]))

    def outputList(self, province_id, num):
        print("\nGrab the dataset only in " + str(self.province[province_id]))
        print(self.df_ByProvince[province_id].head(num))
        print(self.df_ByProvince[province_id].info())

    def outputPandaProfiling(self, province_id, indicator_id, type_id):

        fileName = str(self.indicator[indicator_id]) + " " + str(self.year[type_id])+" in " + str(self.province[province_id]) + ".html"
        
        pp = ProfileReport(self.df_ByProvince[province_id])
        pp_df = pp.to_html()

        print("File name will be saved under "+str(fileName))
        f = open(fileName, "a")  # Expert into html file without modifying any columns in dataset.
        f.write(pp_df)
        f.close()

# %% [markdown]
# Filtered by provinces by "Average annual hours worked"

# %%
# By Average annual hours worked categories by provinces.

# df_AvgAnnHrsWrk_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_ByAge, pd, np, pp)
# df_AvgAnnHrsWrk_2010_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge, pd, np, pp)
df_AvgAnnHrsWrk_2013_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge, pd, np, pp)
df_AvgAnnHrsWrk_2016_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge, pd, np, pp)
df_AvgAnnHrsWrk_2019_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge, pd, np, pp)

# df_AvgAnnHrsWrk_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_ByGender, pd, np, pp)
# df_AvgAnnHrsWrk_2010_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGender, pd, np, pp)
df_AvgAnnHrsWrk_2013_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender, pd, np, pp)
df_AvgAnnHrsWrk_2016_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender, pd, np, pp)
df_AvgAnnHrsWrk_2019_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender, pd, np, pp)

# df_AvgAnnHrsWrk_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_ByEducation, pd, np, pp)
# df_AvgAnnHrsWrk_2010_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation, pd, np, pp)
df_AvgAnnHrsWrk_2013_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation, pd, np, pp)
df_AvgAnnHrsWrk_2016_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation, pd, np, pp)
df_AvgAnnHrsWrk_2019_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation, pd, np, pp)

# df_AvgAnnHrsWrk_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_ByImmigrant, pd, np, pp)
# df_AvgAnnHrsWrk_2010_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByImmigrant, pd, np, pp)
df_AvgAnnHrsWrk_2013_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByImmigrant, pd, np, pp)
df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant, pd, np, pp)
df_AvgAnnHrsWrk_2019_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByImmigrant, pd, np, pp)

# df_AvgAnnHrsWrk_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_ByIndigenous, pd, np, pp)
# df_AvgAnnHrsWrk_2010_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByIndigenous, pd, np, pp)
# df_AvgAnnHrsWrk_2013_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByIndigenous, pd, np, pp)
# df_AvgAnnHrsWrk_2016_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByIndigenous, pd, np, pp)
# df_AvgAnnHrsWrk_2019_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByIndigenous, pd, np, pp)

# %% [markdown]
# Filtered by provinces by "Average wages and salaries"

# %%
# By Average annual wages and salaries worked categories by provinces.

# df_AvgAnnWages_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnWages_ByAge, pd, np, pp)
# df_AvgAnnWages_2010_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnWages_2010_ByAge, pd, np, pp)
df_AvgAnnWages_2013_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnWages_2013_ByAge, pd, np, pp)
df_AvgAnnWages_2016_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnWages_2016_ByAge, pd, np, pp)
df_AvgAnnWages_2019_ByAge_Provinces = ProvinceAnalysis(df_AvgAnnWages_2019_ByAge, pd, np, pp)

# df_AvgAnnWages_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnWages_ByGender, pd, np, pp)
# df_AvgAnnWages_2010_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnWages_2010_ByGender, pd, np, pp)
df_AvgAnnWages_2013_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnWages_2013_ByGender, pd, np, pp)
df_AvgAnnWages_2016_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnWages_2016_ByGender, pd, np, pp)
df_AvgAnnWages_2019_ByGender_Provinces = ProvinceAnalysis(df_AvgAnnWages_2019_ByGender, pd, np, pp)

# df_AvgAnnWages_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnWages_ByEducation, pd, np, pp)
# df_AvgAnnWages_2010_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnWages_2010_ByEducation, pd, np, pp)
df_AvgAnnWages_2013_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnWages_2013_ByEducation, pd, np, pp)
df_AvgAnnWages_2016_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnWages_2016_ByEducation, pd, np, pp)
df_AvgAnnWages_2019_ByEducation_Provinces = ProvinceAnalysis(df_AvgAnnWages_2019_ByEducation, pd, np, pp)

# df_AvgAnnWages_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnWages_ByImmigrant, pd, np, pp)
# df_AvgAnnWages_2010_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnWages_2010_ByImmigrant, pd, np, pp)
df_AvgAnnWages_2013_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnWages_2013_ByImmigrant, pd, np, pp)
df_AvgAnnWages_2016_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnWages_2016_ByImmigrant, pd, np, pp)
df_AvgAnnWages_2019_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgAnnWages_2019_ByImmigrant, pd, np, pp)

# df_AvgAnnWages_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnWages_ByIndigenous, pd, np, pp)
# df_AvgAnnWages_2010_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnWages_2010_ByIndigenous, pd, np, pp)
# df_AvgAnnWages_2013_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnWages_2013_ByIndigenous, pd, np, pp)
# df_AvgAnnWages_2016_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnWages_2016_ByIndigenous, pd, np, pp)
# df_AvgAnnWages_2019_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgAnnWages_2019_ByIndigenous, pd, np, pp)

# %% [markdown]
# Filtered by provinces by "Average hourly wage"

# %%
# By Average hourly wages and salaries worked categories by provinces.

# df_AvgHrsWages_ByAge_Provinces = ProvinceAnalysis(df_AvgHrsWages_ByAge, pd, np, pp)
# df_AvgHrsWages_2010_ByAge_Provinces = ProvinceAnalysis(df_AvgHrsWages_2010_ByAge, pd, np, pp)
df_AvgHrsWages_2013_ByAge_Provinces = ProvinceAnalysis(df_AvgHrsWages_2013_ByAge, pd, np, pp)
df_AvgHrsWages_2016_ByAge_Provinces = ProvinceAnalysis(df_AvgHrsWages_2016_ByAge, pd, np, pp)
df_AvgHrsWages_2019_ByAge_Provinces = ProvinceAnalysis(df_AvgHrsWages_2019_ByAge, pd, np, pp)

# df_AvgHrsWages_ByGender_Provinces = ProvinceAnalysis(df_AvgHrsWages_ByGender, pd, np, pp)
# df_AvgHrsWages_2010_ByGender_Provinces = ProvinceAnalysis(df_AvgHrsWages_2010_ByGender, pd, np, pp)
df_AvgHrsWages_2013_ByGender_Provinces = ProvinceAnalysis(df_AvgHrsWages_2013_ByGender, pd, np, pp)
df_AvgHrsWages_2016_ByGender_Provinces = ProvinceAnalysis(df_AvgHrsWages_2016_ByGender, pd, np, pp)
df_AvgHrsWages_2019_ByGender_Provinces = ProvinceAnalysis(df_AvgHrsWages_2019_ByGender, pd, np, pp)

# df_AvgHrsWages_ByEducation_Provinces = ProvinceAnalysis(df_AvgHrsWages_ByEducation, pd, np, pp)
# df_AvgHrsWages_2010_ByEducation_Provinces = ProvinceAnalysis(df_AvgHrsWages_2010_ByEducation, pd, np, pp)
df_AvgHrsWages_2013_ByEducation_Provinces = ProvinceAnalysis(df_AvgHrsWages_2013_ByEducation, pd, np, pp)
df_AvgHrsWages_2016_ByEducation_Provinces = ProvinceAnalysis(df_AvgHrsWages_2016_ByEducation, pd, np, pp)
df_AvgHrsWages_2019_ByEducation_Provinces = ProvinceAnalysis(df_AvgHrsWages_2019_ByEducation, pd, np, pp)

# df_AvgHrsWages_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgHrsWages_ByImmigrant, pd, np, pp)
# df_AvgHrsWages_2010_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgHrsWages_2010_ByImmigrant, pd, np, pp)
df_AvgHrsWages_2013_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgHrsWages_2013_ByImmigrant, pd, np, pp)
df_AvgHrsWages_2016_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgHrsWages_2016_ByImmigrant, pd, np, pp)
df_AvgHrsWages_2019_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgHrsWages_2019_ByImmigrant, pd, np, pp)

# df_AvgHrsWages_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgHrsWages_ByIndigenous, pd, np, pp)
# df_AvgHrsWages_2010_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgHrsWages_2010_ByIndigenous, pd, np, pp)
# df_AvgHrsWages_2013_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgHrsWages_2013_ByIndigenous, pd, np, pp)
# df_AvgHrsWages_2016_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgHrsWages_2016_ByIndigenous, pd, np, pp)
# df_AvgHrsWages_2019_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgHrsWages_2019_ByIndigenous, pd, np, pp)

# %% [markdown]
# Filtered by provinces by "Average weekly hours worked"

# %%
# By Average annual wages and salaries worked categories by provinces.

# df_AvgWeekHrsWrked_ByAge_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_ByAge, pd, np, pp)
# df_AvgWeekHrsWrked_2010_ByAge_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2010_ByAge, pd, np, pp)
df_AvgWeekHrsWrked_2013_ByAge_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2013_ByAge, pd, np, pp)
df_AvgWeekHrsWrked_2016_ByAge_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2016_ByAge, pd, np, pp)
df_AvgWeekHrsWrked_2019_ByAge_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2019_ByAge, pd, np, pp)

# df_AvgWeekHrsWrked_ByGender_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_ByGender, pd, np, pp)
# df_AvgWeekHrsWrked_2010_ByGender_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2010_ByGender, pd, np, pp)
df_AvgWeekHrsWrked_2013_ByGender_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2013_ByGender, pd, np, pp)
df_AvgWeekHrsWrked_2016_ByGender_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2016_ByGender, pd, np, pp)
df_AvgWeekHrsWrked_2019_ByGender_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2019_ByGender, pd, np, pp)

# df_AvgWeekHrsWrked_ByEducation_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_ByEducation, pd, np, pp)
# df_AvgWeekHrsWrked_2010_ByEducation_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2010_ByEducation, pd, np, pp)
df_AvgWeekHrsWrked_2013_ByEducation_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2013_ByEducation, pd, np, pp)
df_AvgWeekHrsWrked_2016_ByEducation_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2016_ByEducation, pd, np, pp)
df_AvgWeekHrsWrked_2019_ByEducation_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2019_ByEducation, pd, np, pp)

# df_AvgWeekHrsWrked_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_ByImmigrant, pd, np, pp)
# df_AvgWeekHrsWrked_2010_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2010_ByImmigrant, pd, np, pp)
df_AvgWeekHrsWrked_2013_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2013_ByImmigrant, pd, np, pp)
df_AvgWeekHrsWrked_2016_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2016_ByImmigrant, pd, np, pp)
df_AvgWeekHrsWrked_2019_ByImmigrant_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2019_ByImmigrant, pd, np, pp)

# df_AvgWeekHrsWrked_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_ByIndigenous, pd, np, pp)
# df_AvgWeekHrsWrked_2010_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2010_ByIndigenous, pd, np, pp)
# df_AvgWeekHrsWrked_2013_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2013_ByIndigenous, pd, np, pp)
# df_AvgWeekHrsWrked_2016_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2016_ByIndigenous, pd, np, pp)
# df_AvgWeekHrsWrked_2019_ByIndigenous_Provinces = ProvinceAnalysis(df_AvgWeekHrsWrked_2019_ByIndigenous, pd, np, pp)

# %% [markdown]
# Filtered by provinces by "Hours Worked"

# %%
# By Hours workee and salaries worked categories by provinces.

# df_Hrs_Wrked_ByAge_Provinces = ProvinceAnalysis(df_Hrs_Wrked_ByAge, pd, np, pp)
# df_Hrs_Wrked_2010_ByAge_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2010_ByAge, pd, np, pp)
df_Hrs_Wrked_2013_ByAge_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2013_ByAge, pd, np, pp)
df_Hrs_Wrked_2016_ByAge_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2016_ByAge, pd, np, pp)
df_Hrs_Wrked_2019_ByAge_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2019_ByAge, pd, np, pp)

# df_Hrs_Wrked_ByGender_Provinces = ProvinceAnalysis(df_Hrs_Wrked_ByGender, pd, np, pp)
# df_Hrs_Wrked_2010_ByGender_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2010_ByGender, pd, np, pp)
df_Hrs_Wrked_2013_ByGender_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2013_ByGender, pd, np, pp)
df_Hrs_Wrked_2016_ByGender_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2016_ByGender, pd, np, pp)
df_Hrs_Wrked_2019_ByGender_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2019_ByGender, pd, np, pp)

# df_Hrs_Wrked_ByEducation_Provinces = ProvinceAnalysis(df_Hrs_Wrked_ByEducation, pd, np, pp)
# df_Hrs_Wrked_2010_ByEducation_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2010_ByEducation, pd, np, pp)
df_Hrs_Wrked_2013_ByEducation_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2013_ByEducation, pd, np, pp)
df_Hrs_Wrked_2016_ByEducation_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2016_ByEducation, pd, np, pp)
df_Hrs_Wrked_2019_ByEducation_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2019_ByEducation, pd, np, pp)

# df_Hrs_Wrked_ByImmigrant_Provinces = ProvinceAnalysis(df_Hrs_Wrked_ByImmigrant, pd, np, pp)
# df_Hrs_Wrked_2010_ByImmigrant_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2010_ByImmigrant, pd, np, pp)
df_Hrs_Wrked_2013_ByImmigrant_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2013_ByImmigrant, pd, np, pp)
df_Hrs_Wrked_2016_ByImmigrant_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2016_ByImmigrant, pd, np, pp)
df_Hrs_Wrked_2019_ByImmigrant_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2019_ByImmigrant, pd, np, pp)

# df_Hrs_Wrked_ByIndigenous_Provinces = ProvinceAnalysis(df_Hrs_Wrked_ByIndigenous, pd, np, pp)
# df_Hrs_Wrked_2010_ByIndigenous_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2010_ByIndigenous, pd, np, pp)
# df_Hrs_Wrked_2013_ByIndigenous_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2013_ByIndigenous, pd, np, pp)
# df_Hrs_Wrked_2016_ByIndigenous_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2016_ByIndigenous, pd, np, pp)
# df_Hrs_Wrked_2019_ByIndigenous_Provinces = ProvinceAnalysis(df_Hrs_Wrked_2019_ByIndigenous, pd, np, pp)

# %% [markdown]
# Filtered by provinces by "Number of jobs"

# %%
# By Number of jobs and salaries worked categories by provinces.

# df_NumOfJob_ByAge_Provinces = ProvinceAnalysis(df_NumOfJob_ByAge, pd, np, pp)
# df_NumOfJob_2010_ByAge_Provinces = ProvinceAnalysis(df_NumOfJob_2010_ByAge, pd, np, pp)
df_NumOfJob_2013_ByAge_Provinces = ProvinceAnalysis(df_NumOfJob_2013_ByAge, pd, np, pp)
df_NumOfJob_2016_ByAge_Provinces = ProvinceAnalysis(df_NumOfJob_2016_ByAge, pd, np, pp)
df_NumOfJob_2019_ByAge_Provinces = ProvinceAnalysis(df_NumOfJob_2019_ByAge, pd, np, pp)

# df_NumOfJob_ByGender_Provinces = ProvinceAnalysis(df_NumOfJob_ByGender, pd, np, pp)
# df_NumOfJob_2010_ByGender_Provinces = ProvinceAnalysis(df_NumOfJob_2010_ByGender, pd, np, pp)
df_NumOfJob_2013_ByGender_Provinces = ProvinceAnalysis(df_NumOfJob_2013_ByGender, pd, np, pp)
df_NumOfJob_2016_ByGender_Provinces = ProvinceAnalysis(df_NumOfJob_2016_ByGender, pd, np, pp)
df_NumOfJob_2019_ByGender_Provinces = ProvinceAnalysis(df_NumOfJob_2019_ByGender, pd, np, pp)

# df_NumOfJob_ByEducation_Provinces = ProvinceAnalysis(df_NumOfJob_ByEducation, pd, np, pp)
# df_NumOfJob_2010_ByEducation_Provinces = ProvinceAnalysis(df_NumOfJob_2010_ByEducation, pd, np, pp)
df_NumOfJob_2013_ByEducation_Provinces = ProvinceAnalysis(df_NumOfJob_2013_ByEducation, pd, np, pp)
df_NumOfJob_2016_ByEducation_Provinces = ProvinceAnalysis(df_NumOfJob_2016_ByEducation, pd, np, pp)
df_NumOfJob_2019_ByEducation_Provinces = ProvinceAnalysis(df_NumOfJob_2019_ByEducation, pd, np, pp)

# df_NumOfJob_ByImmigrant_Provinces = ProvinceAnalysis(df_NumOfJob_ByImmigrant, pd, np, pp)
# df_NumOfJob_2010_ByImmigrant_Provinces = ProvinceAnalysis(df_NumOfJob_2010_ByImmigrant, pd, np, pp)
df_NumOfJob_2013_ByImmigrant_Provinces = ProvinceAnalysis(df_NumOfJob_2013_ByImmigrant, pd, np, pp)
df_NumOfJob_2016_ByImmigrant_Provinces = ProvinceAnalysis(df_NumOfJob_2016_ByImmigrant, pd, np, pp)
df_NumOfJob_2019_ByImmigrant_Provinces = ProvinceAnalysis(df_NumOfJob_2019_ByImmigrant, pd, np, pp)

# df_NumOfJob_ByIndigenous_Provinces = ProvinceAnalysis(df_NumOfJob_ByIndigenous, pd, np, pp)
# df_NumOfJob_2010_ByIndigenous_Provinces = ProvinceAnalysis(df_NumOfJob_2010_ByIndigenous, pd, np, pp)
# df_NumOfJob_2013_ByIndigenous_Provinces = ProvinceAnalysis(df_NumOfJob_2013_ByIndigenous, pd, np, pp)
# df_NumOfJob_2016_ByIndigenous_Provinces = ProvinceAnalysis(df_NumOfJob_2016_ByIndigenous, pd, np, pp)
# df_NumOfJob_2019_ByIndigenous_Provinces = ProvinceAnalysis(df_NumOfJob_2019_ByIndigenous, pd, np, pp)

# %% [markdown]
# Filted by provinces by "Wages and Salaries"

# %%
# By Wages and Salaries worked categories by provinces.

# df_WagesAndSalaries_ByAge_Provinces = ProvinceAnalysis(df_WagesAndSalaries_ByAge, pd, np, pp)
# df_WagesAndSalaries_2010_ByAge_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2010_ByAge, pd, np, pp)
df_WagesAndSalaries_2013_ByAge_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2013_ByAge, pd, np, pp)
df_WagesAndSalaries_2016_ByAge_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2016_ByAge, pd, np, pp)
df_WagesAndSalaries_2019_ByAge_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2019_ByAge, pd, np, pp)

# df_WagesAndSalaries_ByGender_Provinces = ProvinceAnalysis(df_WagesAndSalaries_ByGender, pd, np, pp)
# df_WagesAndSalaries_2010_ByGender_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2010_ByGender, pd, np, pp)
df_WagesAndSalaries_2013_ByGender_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2013_ByGender, pd, np, pp)
df_WagesAndSalaries_2016_ByGender_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2016_ByGender, pd, np, pp)
df_WagesAndSalaries_2019_ByGender_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2019_ByGender, pd, np, pp)

# df_WagesAndSalaries_ByEducation_Provinces = ProvinceAnalysis(df_WagesAndSalaries_ByEducation, pd, np, pp)
# df_WagesAndSalaries_2010_ByEducation_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2010_ByEducation, pd, np, pp)
df_WagesAndSalaries_2013_ByEducation_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2013_ByEducation, pd, np, pp)
df_WagesAndSalaries_2016_ByEducation_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2016_ByEducation, pd, np, pp)
df_WagesAndSalaries_2019_ByEducation_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2019_ByEducation, pd, np, pp)

# df_WagesAndSalaries_ByImmigrant_Provinces = ProvinceAnalysis(df_WagesAndSalaries_ByImmigrant, pd, np, pp)
# df_WagesAndSalaries_2010_ByImmigrant_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2010_ByImmigrant, pd, np, pp)
df_WagesAndSalaries_2013_ByImmigrant_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2013_ByImmigrant, pd, np, pp)
df_WagesAndSalaries_2016_ByImmigrant_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2016_ByImmigrant, pd, np, pp)
df_WagesAndSalaries_2019_ByImmigrant_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2019_ByImmigrant, pd, np, pp)

# df_WagesAndSalaries_ByIndigenous_Provinces = ProvinceAnalysis(df_WagesAndSalaries_ByIndigenous, pd, np, pp)
# df_WagesAndSalaries_2010_ByIndigenous_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2010_ByIndigenous, pd, np, pp)
# df_WagesAndSalaries_2013_ByIndigenous_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2013_ByIndigenous, pd, np, pp)
# df_WagesAndSalaries_2016_ByIndigenous_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2016_ByIndigenous, pd, np, pp)
# df_WagesAndSalaries_2019_ByIndigenous_Provinces = ProvinceAnalysis(df_WagesAndSalaries_2019_ByIndigenous, pd, np, pp)

# %% [markdown]
# After data analysis of the data, the code below can output the result of the analysis.

# %% [markdown]
# Main class for outputting the analysis

# %%
# https://howtodoinjava.com/python-examples/python-print-to-file/


class OutputProvinceAnalysis:

    # Province :
    # -- ['Alberta',  'British Columbia',    'Canada' , 'Manitoba' , 'New Brunswick' 
    # 'Newfoundland and Labrador', 'Northwest Territories' , 'Nova Scotia' , 'Nunavut'
    # 'Ontario' , 'Prince Edward Island', 'Quebec', 'Saskatchewan', 'Yukon']

    def __init__(self, df, PC, yrs, pd, np, pp):

        self.df_output = df
        self.ProCode = PC
        self.YearOutput = yrs

    def OutputResult(self):
        print(str(self.YearOutput))
        self.df_output.outputList(self.ProCode, 20)
        self.df_output.outputAnalysis(self.ProCode)

    def OutputPandaProfiling(self):
        if self.YearOutput == '2010':
            print("Year 2010 is not valid at this moment")
            # self.df_output.outputPandaProfiling(self.ProCode,0,0)
        elif self.YearOutput == '2013':
            self.df_output.outputPandaProfiling(self.ProCode,0,3)
        elif self.YearOutput == '2016':
            self.df_output.outputPandaProfiling(self.ProCode,0,4)
        elif self.YearOutput == '2018':
            self.df_output.outputPandaProfiling(self.ProCode,0,5)
        else:
            print("Error!")

# %% [markdown]
# Filtering only Alberta.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# # -- Alberta                     2193966.0   2031.450000   2695.836034  1080
# (Before)
# print("2016 - Overall")
# df_AvgAnnHrsWrk_above_2016_ByAge_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_above_2016_ByAge_Provinces.outputAnalysis(0)
# print("2016")
# df_AvgAnnHrsWrk_2016_ByAge_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2016_ByAge_Provinces.outputAnalysis(0)
# print("2018")
# df_AvgAnnHrsWrk_2018_ByAge_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2018_ByAge_Provinces.outputAnalysis(0)
# print("2020")
# df_AvgAnnHrsWrk_2020_ByAge_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2020_ByAge_Provinces.outputAnalysis(0)

# print("2016 - Overall")
# df_AvgAnnHrsWrk_above_2016_ByGender_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_above_2016_ByGender_Provinces.outputAnalysis(0)
# print("2016")
# df_AvgAnnHrsWrk_2016_ByGender_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2016_ByGender_Provinces.outputAnalysis(0)
# print("2018")
# df_AvgAnnHrsWrk_2018_ByGender_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2018_ByGender_Provinces.outputAnalysis(0)
# print("2020")
# df_AvgAnnHrsWrk_2020_ByGender_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2020_ByGender_Provinces.outputAnalysis(0)

# print("2016 - Overall")
# df_AvgAnnHrsWrk_above_2016_ByEducation_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_above_2016_ByEducation_Provinces.outputAnalysis(0)
# print("2016")
# df_AvgAnnHrsWrk_2016_ByEducation_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2016_ByEducation_Provinces.outputAnalysis(0)
# print("2018")
# df_AvgAnnHrsWrk_2018_ByEducation_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2018_ByEducation_Provinces.outputAnalysis(0)
# print("2020")
# df_AvgAnnHrsWrk_2020_ByEducation_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2020_ByEducation_Provinces.outputAnalysis(0)

# print("2016 - Overall")
# df_AvgAnnHrsWrk_above_2016_ByImmigrant_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_above_2016_ByImmigrant_Provinces.outputAnalysis(0)
# print("2016")
# df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces.outputAnalysis(0)
# print("2018")
# df_AvgAnnHrsWrk_2018_ByImmigrant_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2018_ByImmigrant_Provinces.outputAnalysis(0)
# print("2020")
# df_AvgAnnHrsWrk_2020_ByImmigrant_Provinces.outputList(0, 20)
# df_AvgAnnHrsWrk_2020_ByImmigrant_Provinces.outputAnalysis(0)

# %%
# # -- Alberta                     2193966.0   2031.450000   2695.836034  1080
# (After using the class)

ProCode = 0

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Alberta
#        REF_DATE      GEO                                             Sector  \
# 32217      2013  Alberta                      Total non-profit institutions
# 32224      2013  Alberta                      Total non-profit institutions
# 32231      2013  Alberta                      Total non-profit institutions
# 32238      2013  Alberta                      Total non-profit institutions
# 32245      2013  Alberta                      Total non-profit institutions
# 32252      2013  Alberta                      Total non-profit institutions
# 32343      2013  Alberta  Total non-profit institutions excluding govern...
# 32350      2013  Alberta  Total non-profit institutions excluding govern...
# 32357      2013  Alberta  Total non-profit institutions excluding govern...
# 32364      2013  Alberta  Total non-profit institutions excluding govern...
# 32371      2013  Alberta  Total non-profit institutions excluding govern...
# 32378      2013  Alberta  Total non-profit institutions excluding govern...
# 32469      2013  Alberta  Non-profit institutions serving households (co...
# 32476      2013  Alberta  Non-profit institutions serving households (co...
# 32483      2013  Alberta  Non-profit institutions serving households (co...
# 32490      2013  Alberta  Non-profit institutions serving households (co...
# 32497      2013  Alberta  Non-profit institutions serving households (co...
# 32504      2013  Alberta  Non-profit institutions serving households (co...
# 32595      2013  Alberta                   Business non-profit institutions
# 32602      2013  Alberta                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 32217         15 to 24 years  Average annual hours worked  Hours
# 32224         25 to 34 years  Average annual hours worked  Hours
# 32231         35 to 44 years  Average annual hours worked  Hours
# 32238         45 to 54 years  Average annual hours worked  Hours
# 32245         55 to 64 years  Average annual hours worked  Hours
# 32252  65 years old and over  Average annual hours worked  Hours
# 32343         15 to 24 years  Average annual hours worked  Hours
# 32350         25 to 34 years  Average annual hours worked  Hours
# 32357         35 to 44 years  Average annual hours worked  Hours
# 32364         45 to 54 years  Average annual hours worked  Hours
# 32371         55 to 64 years  Average annual hours worked  Hours
# 32378  65 years old and over  Average annual hours worked  Hours
# 32469         15 to 24 years  Average annual hours worked  Hours
# 32476         25 to 34 years  Average annual hours worked  Hours
# 32483         35 to 44 years  Average annual hours worked  Hours
# 32490         45 to 54 years  Average annual hours worked  Hours
# 32497         55 to 64 years  Average annual hours worked  Hours
# 32504  65 years old and over  Average annual hours worked  Hours
# 32595         15 to 24 years  Average annual hours worked  Hours
# 32602         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 32217         units  1062.0
# 32224         units  1642.0
# 32231         units  1755.0
# 32238         units  1851.0
# 32245         units  1758.0
# 32252         units  1257.0
# 32343         units   991.0
# 32350         units  1723.0
# 32357         units  1803.0
# 32364         units  1876.0
# 32371         units  1795.0
# 32378         units  1234.0
# 32469         units   982.0
# 32476         units  1689.0
# 32483         units  1770.0
# 32490         units  1854.0
# 32497         units  1778.0
# 32504         units  1223.0
# 32595         units  1009.0
# 32602         units  1816.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries,
# 85361      2019  Alberta  Non-profit institutions serving households (co...
# 85368      2019  Alberta  Non-profit institutions serving households (co...
# 85382      2019  Alberta  Non-profit institutions serving households (co...
# 85487      2019  Alberta                   Business non-profit institutions
# 85494      2019  Alberta                   Business non-profit institutions
# 85508      2019  Alberta                   Business non-profit institutions
# 85613      2019  Alberta                 Government non-profit institutions
# 85620      2019  Alberta                 Government non-profit institutions
# 85634      2019  Alberta                 Government non-profit institutions
# 93929      2020  Alberta                      Total non-profit institutions
# 93936      2020  Alberta                      Total non-profit institutions
# 93950      2020  Alberta                      Total non-profit institutions
# 94055      2020  Alberta  Total non-profit institutions excluding govern...
# 94062      2020  Alberta  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 85109  High school diploma and less  Average annual hours worked  Hours
# 85116             Trade certificate  Average annual hours worked  Hours
# 85130  University degree and higher  Average annual hours worked  Hours
# 85235  High school diploma and less  Average annual hours worked  Hours
# 85242             Trade certificate  Average annual hours worked  Hours
# 85256  University degree and higher  Average annual hours worked  Hours
# 85361  High school diploma and less  Average annual hours worked  Hours
# 85368             Trade certificate  Average annual hours worked  Hours
# 85382  University degree and higher  Average annual hours worked  Hours
# 85487  High school diploma and less  Average annual hours worked  Hours
# 85494             Trade certificate  Average annual hours worked  Hours
# 85508  University degree and higher  Average annual hours worked  Hours
# 85613  High school diploma and less  Average annual hours worked  Hours
# 85620             Trade certificate  Average annual hours worked  Hours
# 85634  University degree and higher  Average annual hours worked  Hours
# 93929  High school diploma and less  Average annual hours worked  Hours
# 93936             Trade certificate  Average annual hours worked  Hours
# 93950  University degree and higher  Average annual hours worked  Hours
# 94055  High school diploma and less  Average annual hours worked  Hours
# 94062             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 85109         units  1334.0
# 85116         units  1595.0
# 85130         units  1648.0
# 85235         units  1312.0
# 85242         units  1633.0
# 85256         units  1714.0
# 85361         units  1254.0
# 85368         units  1556.0
# 85382         units  1692.0
# 85487         units  1460.0
# 85494         units  1808.0
# 85508         units  1795.0
# 85613         units  1350.0
# 85620         units  1573.0
# 85634         units  1625.0
# 93929         units  1315.0
# 93936         units  1542.0
# 93950         units  1626.0
# 94055         units  1287.0
# 94062         units  1548.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 85109 to 103274
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Alberta
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  20157.0  1343.800000  1246.0  1334.0  1460.0
# Trade certificate             24111.0  1607.400000  1489.0  1595.0  1808.0
# University degree and higher  25355.0  1690.333333  1615.0  1692.0  1795.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  69623.0
# Mean :  1547.1777777777777
# Min/median/max : 1246.0 / 1595.0 / 1808.0
# Skewnewss :  -0.3692931364152898
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Alberta

# %%
# ProCode = 0
# (Before)
# df_AvgAnnHrsWrk_above_2016_ByAge_Provinces.outputPandaProfiling(ProCode,0,2)
# df_AvgAnnHrsWrk_above_2016_ByGender_Provinces.outputPandaProfiling(ProCode,0,2)
# df_AvgAnnHrsWrk_above_2016_ByEducation_Provinces.outputPandaProfiling(ProCode,0,2)
# df_AvgAnnHrsWrk_above_2016_ByImmigrant_Provinces.outputPandaProfiling(ProCode,0,2)

# df_AvgAnnHrsWrk_2016_ByAge_Provinces.outputPandaProfiling(ProCode,0,3)
# df_AvgAnnHrsWrk_2016_ByGender_Provinces.outputPandaProfiling(ProCode,0,3)
# df_AvgAnnHrsWrk_2016_ByEducation_Provinces.outputPandaProfiling(ProCode,0,3)
# df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces.outputPandaProfiling(ProCode,0,3)

# df_AvgAnnHrsWrk_2018_ByAge_Provinces.outputPandaProfiling(ProCode,0,4)
# df_AvgAnnHrsWrk_2018_ByGender_Provinces.outputPandaProfiling(ProCode,0,4)
# df_AvgAnnHrsWrk_2018_ByEducation_Provinces.outputPandaProfiling(ProCode,0,4)
# df_AvgAnnHrsWrk_2018_ByImmigrant_Provinces.outputPandaProfiling(ProCode,0,4)

# df_AvgAnnHrsWrk_2020_ByAge_Provinces.outputPandaProfiling(ProCode,0,5)
# df_AvgAnnHrsWrk_2020_ByGender_Provinces.outputPandaProfiling(ProCode,0,5)
# df_AvgAnnHrsWrk_2020_ByEducation_Provinces.outputPandaProfiling(ProCode,0,5)
# df_AvgAnnHrsWrk_2020_ByImmigrant_Provinces.outputPandaProfiling(ProCode,0,5)

# %%
# After

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputPandaProfiling()
# Out:
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 15.17it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.32s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.57it/s]
# File name will be saved under Average annual hours worked 2013 in Alberta.html
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.12it/s, Completed]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.80it/s]
# File name will be saved under Average annual hours worked 2016 in Alberta.html
# Error!
# Summarize dataset: 100%|██████████| 18/18 [00:00<00:00, 19.07it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.69it/s]
# File name will be saved under Average annual hours worked 2013 in Alberta.html
# Summarize dataset: 100%|██████████| 18/18 [00:00<00:00, 20.56it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [11:45<00:00, 705.99s/it]
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# File name will be saved under Average annual hours worked 2016 in Alberta.html
# Error!
# Summarize dataset: 100%|██████████| 18/18 [00:02<00:00,  8.64it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.18s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.05it/s]
# File name will be saved under Average annual hours worked 2013 in Alberta.html
# Summarize dataset: 100%|██████████| 18/18 [00:01<00:00, 16.21it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.95it/s]
# File name will be saved under Average annual hours worked 2016 in Alberta.html
# Error!
# Summarize dataset: 100%|██████████| 18/18 [00:00<00:00, 20.70it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.76it/s]
# File name will be saved under Average annual hours worked 2013 in Alberta.html
# Summarize dataset: 100%|██████████| 18/18 [00:00<00:00, 22.11it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.32s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.76it/s]
# File name will be saved under Average annual hours worked 2016 in Alberta.html
# Error!

# %% [markdown]
# Filtering only British Columbia.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- British Columbia            2401296.0   2223.422222   2804.925187  1080

ProCode = 1

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult
0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 85739 to 103904
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in British Columbia
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19366.0  1291.066667  1233.0  1281.0  1414.0
# Trade certificate             22787.0  1519.133333  1412.0  1504.0  1714.0
# University degree and higher  24710.0  1647.333333  1591.0  1644.0  1720.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  66863.0
# Mean :  1485.8444444444444
# Min/median/max : 1233.0 / 1504.0 / 1720.0
# Skewnewss :  -0.1948411703938351
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for BC

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering if "GEO" levelled as "Canada" ONLY.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Canada                     18252439.0  16900.406481  22232.852533  1080

ProCode = 2 # Canada

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Canada
#        REF_DATE     GEO                                             Sector  \
# 26547      2013  Canada                      Total non-profit institutions
# 26554      2013  Canada                      Total non-profit institutions
# 26561      2013  Canada                      Total non-profit institutions
# 26568      2013  Canada                      Total non-profit institutions
# 26575      2013  Canada                      Total non-profit institutions
# 26582      2013  Canada                      Total non-profit institutions
# 26673      2013  Canada  Total non-profit institutions excluding govern...
# 26680      2013  Canada  Total non-profit institutions excluding govern...
# 26687      2013  Canada  Total non-profit institutions excluding govern...
# 26694      2013  Canada  Total non-profit institutions excluding govern...
# 26701      2013  Canada  Total non-profit institutions excluding govern...
# 26708      2013  Canada  Total non-profit institutions excluding govern...
# 26799      2013  Canada  Non-profit institutions serving households (co...
# 26806      2013  Canada  Non-profit institutions serving households (co...
# 26813      2013  Canada  Non-profit institutions serving households (co...
# 26820      2013  Canada  Non-profit institutions serving households (co...
# 26827      2013  Canada  Non-profit institutions serving households (co...
# 26834      2013  Canada  Non-profit institutions serving households (co...
# 26925      2013  Canada                   Business non-profit institutions
# 26932      2013  Canada                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 26547         15 to 24 years  Average annual hours worked  Hours
# 26554         25 to 34 years  Average annual hours worked  Hours
# 26561         35 to 44 years  Average annual hours worked  Hours
# 26568         45 to 54 years  Average annual hours worked  Hours
# 26575         55 to 64 years  Average annual hours worked  Hours
# 26582  65 years old and over  Average annual hours worked  Hours
# 26673         15 to 24 years  Average annual hours worked  Hours
# 26680         25 to 34 years  Average annual hours worked  Hours
# 26687         35 to 44 years  Average annual hours worked  Hours
# 26694         45 to 54 years  Average annual hours worked  Hours
# 26701         55 to 64 years  Average annual hours worked  Hours
# 26708  65 years old and over  Average annual hours worked  Hours
# 26799         15 to 24 years  Average annual hours worked  Hours
# 26806         25 to 34 years  Average annual hours worked  Hours
# 26813         35 to 44 years  Average annual hours worked  Hours
# 26820         45 to 54 years  Average annual hours worked  Hours
# 26827         55 to 64 years  Average annual hours worked  Hours
# 26834  65 years old and over  Average annual hours worked  Hours
# 26925         15 to 24 years  Average annual hours worked  Hours
# 26932         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 26547         units   906.0
# 26554         units  1559.0
# 26561         units  1725.0
# 26568         units  1799.0
# 26575         units  1645.0
# 26582         units  1008.0
# 26673         units   874.0
# 26680         units  1633.0
# 26687         units  1759.0
# 26694         units  1820.0
# 26701         units  1657.0
# 26708         units  1030.0
# 26799         units   872.0
# 26806         units  1594.0
# 26813         units  1718.0
# 26820         units  1787.0
# 26827         units  1630.0
# 26834         units  1013.0
# 26925         units   880.0
# 26932         units  1753.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 26547 to 44726
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Canada
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         13274.0   884.933333   858.0   874.0   929.0    15
# 25 to 34 years         24138.0  1609.200000  1517.0  1590.0  1755.0    15
# 35 to 44 years         26373.0  1758.200000  1697.0  1719.0  1902.0    15
# 45 to 54 years         27368.0  1824.533333  1781.0  1796.0  1942.0    15
# 55 to 64 years         25002.0  1666.800000  1629.0  1645.0  1773.0    15
# 65 years old and over  15745.0  1049.666667   994.0  1042.0  1150.0    15
#
# Overall,
# Sum :  131900.0
# Mean :  1465.5555555555557
# Min/median/max : 858.0 / 1634.0 / 1942.0
# Skewnewss :  -0.6044783460487682
# Total size :  90
# 2016
#
# Grab the dataset only in Canada
#        REF_DATE     GEO                                             Sector  \
# 53007      2016  Canada                      Total non-profit institutions
# 53014      2016  Canada                      Total non-profit institutions
# 53021      2016  Canada                      Total non-profit institutions
# 53028      2016  Canada                      Total non-profit institutions
# 53035      2016  Canada                      Total non-profit institutions
# 53042      2016  Canada                      Total non-profit institutions
# 53133      2016  Canada  Total non-profit institutions excluding govern...
# 53140      2016  Canada  Total non-profit institutions excluding govern...
# 53147      2016  Canada  Total non-profit institutions excluding govern...
# 53154      2016  Canada  Total non-profit institutions excluding govern...
# 53161      2016  Canada  Total non-profit institutions excluding govern...
# 53168      2016  Canada  Total non-profit institutions excluding govern...
# 53259      2016  Canada  Non-profit institutions serving households (co...
# 53266      2016  Canada  Non-profit institutions serving households (co...
# 53273      2016  Canada  Non-profit institutions serving households (co...
# 53280      2016  Canada  Non-profit institutions serving households (co...
# 53287      2016  Canada  Non-profit institutions serving households (co...
# 53294      2016  Canada  Non-profit institutions serving households (co...
# 53385      2016  Canada                   Business non-profit institutions
# 53392      2016  Canada                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 53007         15 to 24 years  Average annual hours worked  Hours
# 53014         25 to 34 years  Average annual hours worked  Hours
# 53021         35 to 44 years  Average annual hours worked  Hours
# 53028         45 to 54 years  Average annual hours worked  Hours
# 53035         55 to 64 years  Average annual hours worked  Hours
# 53042  65 years old and over  Average annual hours worked  Hours
# 53133         15 to 24 years  Average annual hours worked  Hours
# 53140         25 to 34 years  Average annual hours worked  Hours
# 53147         35 to 44 years  Average annual hours worked  Hours
# 53154         45 to 54 years  Average annual hours worked  Hours
# 53161         55 to 64 years  Average annual hours worked  Hours
# 53168  65 years old and over  Average annual hours worked  Hours
# 53259         15 to 24 years  Average annual hours worked  Hours
# 53266         25 to 34 years  Average annual hours worked  Hours
# 53273         35 to 44 years  Average annual hours worked  Hours
# 53280         45 to 54 years  Average annual hours worked  Hours
# 53287         55 to 64 years  Average annual hours worked  Hours
# 53294  65 years old and over  Average annual hours worked  Hours
# 53385         15 to 24 years  Average annual hours worked  Hours
# 53392         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
#
Female employees  Average annual hours worked  Hours         units
#
#         VALUE
# 26463  1622.0
# 26470  1543.0
# 26589  1662.0
# 26596  1511.0
# 26715  1642.0
# 26722  1495.0
# 26841  1702.0
# 26848  1577.0
# 26967  1597.0
# 26974  1557.0
# 35283  1611.0
# 35290  1537.0
# 35409  1655.0
# 35416  1509.0
# 35535  1637.0
# 35542  1495.0
# 35661  1694.0
# 35668  1564.0
# 35787  1583.0
# 35794  1550.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 26463 to 44614
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Canada
#                       sum    mean    amin  median    amax  size
# Characteristics
# Female employees  23010.0  1534.0  1492.0  1539.0  1579.0    15
# Male employees    24621.0  1641.4  1583.0  1637.0  1720.0    15
#
# Overall,
# Sum :  47631.0
# Mean :  1587.7
# Min/median/max : 1492.0 / 1581.0 / 1720.0
# Skewnewss :  0.2891902560473917
# Total size :  30
# 2016
#
# Grab the dataset only in Canada
#        REF_DATE     GEO                                             Sector  \
# 52923      2016  Canada                      Total non-profit institutions
# 52930      2016  Canada                      Total non-profit institutions
# 53049      2016  Canada  Total non-profit institutions excluding govern...
# 53056      2016  Canada  Total non-profit institutions excluding govern...
# 53175      2016  Canada  Non-profit institutions serving households (co...
# 53182      2016  Canada  Non-profit institutions serving households (co...
# 53301      2016  Canada                   Business non-profit institutions
# 53308      2016  Canada                   Business non-profit institutions
# 53427      2016  Canada                 Government non-profit institutions
# 53434      2016  Canada                 Government non-profit institutions
# 61743      2017  Canada                      Total non-profit institutions
# 61750      2017  Canada                      Total non-profit institutions
# 61869      2017  Canada  Total non-profit institutions excluding govern...
# 61876      2017  Canada  Total non-profit institutions excluding govern...
# 61995      2017  Canada  Non-profit institutions serving households (co...
# 62002      2017  Canada  Non-profit institutions serving households (co...
# 62121      2017  Canada                   Business non-profit institutions
# 62128      2017  Canada                   Business non-profit institutions
# 62247      2017  Canada                 Government non-profit institutions
# 62254      2017  Canada                 Government non-profit institutions
#
#         Characteristics                   Indicators    UOM SCALAR_FACTOR  \
# 52923    Male employees  Average annual hours worked  Hours         units
# 52930  Female employees  Average annual hours worked  Hours         units
# 53049    Male employees  Average annual hours worked  Hours         units
# 53056  Female employees  Average annual hours worked  Hours         units
# 53175    Male employees  Average annual hours worked  Hours         units
# 53182  Female employees  Average annual hours worked  Hours         units
# 53301    Male employees  Average annual hours worked  Hours         units
# 53308  Female employees  Average annual hours worked  Hours         units
# 53427    Male employees  Average annual hours worked  Hours         units
# 53434  Female employees  Average annual hours worked  Hours         units
# 61743    Male employees  Average annual hours worked  Hours         units
# 61750  Female employees  Average annual hours worked  Hours         units
# 61869    Male employees  Average annual hours worked  Hours         units
# 61876  Female employees  Average annual hours worked  Hours         units
# 61995    Male employees  Average annual hours worked  Hours         units
# 62002  Female employees  Average annual hours worked  Hours         units
# 62121    Male employees  Average annual hours worked  Hours         units
# 62128  Female employees  Average annual hours worked  Hours         units
# 62247    Male employees  Average annual hours worked  Hours         units
# 62254  Female employees  Average annual hours worked  Hours         units
#
#         VALUE
#
# 53448      2016  Canada                 Government non-profit institutions
# 61757      2017  Canada                      Total non-profit institutions
# 61764      2017  Canada                      Total non-profit institutions
# 61883      2017  Canada  Total non-profit institutions excluding govern...
# 61890      2017  Canada  Total non-profit institutions excluding govern...
# 62009      2017  Canada  Non-profit institutions serving households (co...
# 62016      2017  Canada  Non-profit institutions serving households (co...
# 62135      2017  Canada                   Business non-profit institutions
# 62142      2017  Canada                   Business non-profit institutions
# 62261      2017  Canada                 Government non-profit institutions
# 62268      2017  Canada                 Government non-profit institutions
#
#                Characteristics                   Indicators    UOM  \
# 52937      Immigrant employees  Average annual hours worked  Hours
# 52944  Non-immigrant employees  Average annual hours worked  Hours
# 53063      Immigrant employees  Average annual hours worked  Hours
# 53070  Non-immigrant employees  Average annual hours worked  Hours
# 53189      Immigrant employees  Average annual hours worked  Hours
# 53196  Non-immigrant employees  Average annual hours worked  Hours
# 53315      Immigrant employees  Average annual hours worked  Hours
# 53322  Non-immigrant employees  Average annual hours worked  Hours
# 53441      Immigrant employees  Average annual hours worked  Hours
# 53448  Non-immigrant employees  Average annual hours worked  Hours
# 61757      Immigrant employees  Average annual hours worked  Hours
# 61764  Non-immigrant employees  Average annual hours worked  Hours
# 61883      Immigrant employees  Average annual hours worked  Hours
# 61890  Non-immigrant employees  Average annual hours worked  Hours
# 62009      Immigrant employees  Average annual hours worked  Hours
# 62016  Non-immigrant employees  Average annual hours worked  Hours
# 62135      Immigrant employees  Average annual hours worked  Hours
# 62142  Non-immigrant employees  Average annual hours worked  Hours
# 62261      Immigrant employees  Average annual hours worked  Hours
# 62268  Non-immigrant employees  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 52937         units  1580.0
# 52944         units  1559.0
# 53063         units  1564.0
# 53070         units  1541.0
# 53189         units  1531.0
# 53196         units  1516.0
# 53315         units  1665.0
# 53322         units  1621.0
# 53441         units  1588.0
# 53448         units  1569.0
# 61757         units  1568.0
# 61764         units  1549.0
# 61883         units  1551.0
# 61890         units  1532.0
# 62009         units  1518.0
# 62016         units  1505.0
# 62135         units  1653.0
# 62142         units  1620.0
# 62261         units  1577.0
# 62268         units  1558.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 52937 to 71088
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Canada
#                              sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      23724.0  1581.600000  1518.0  1577.0  1665.0    15
# Non-immigrant employees  23402.0  1560.133333  1505.0  1558.0  1627.0    15
#
# Overall,
# Sum :  47126.0
# Mean :  1570.8666666666666
# Min/median/max : 1505.0 / 1564.0 / 1665.0
# Skewnewss :  0.6958752542272613
# Total size :  30
# 2019
#
# Grab the dataset only in Canada
#        REF_DATE     GEO                                             Sector  \
# 79439      2019  Canada                      Total non-profit institutions
# 79446      2019  Canada                      Total non-profit institutions
# 79460      2019  Canada                      Total non-profit institutions
# 79565      2019  Canada  Total non-profit institutions excluding govern...
# 79572      2019  Canada  Total non-profit institutions excluding govern...
# 79586      2019  Canada  Total non-profit institutions excluding govern...
# 79691      2019  Canada  Non-profit institutions serving households (co...
# 79698      2019  Canada  Non-profit institutions serving households (co...
# 79712      2019  Canada  Non-profit institutions serving households (co...
# 79817      2019  Canada                   Business non-profit institutions
# 79824      2019  Canada                   Business non-profit institutions
# 79838      2019  Canada                   Business non-profit institutions
# 79943      2019  Canada                 Government non-profit institutions
# 79950      2019  Canada                 Government non-profit institutions
# 79964      2019  Canada                 Government non-profit institutions
# 88259      2020  Canada                      Total non-profit institutions
# 88266      2020  Canada                      Total non-profit institutions
# 88280      2020  Canada                      Total non-profit institutions
# 88385      2020  Canada  Total non-profit institutions excluding govern...
# 88392      2020  Canada  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 79439  High school diploma and less  Average annual hours worked  Hours
# 79446             Trade certificate  Average annual hours worked  Hours
# 79460  University degree and higher  Average annual hours worked  Hours
# 79565  High school diploma and less  Average annual hours worked  Hours
# 79572             Trade certificate  Average annual hours worked  Hours
# 79586  University degree and higher  Average annual hours worked  Hours
# 79691  High school diploma and less  Average annual hours worked  Hours
# 79698             Trade certificate  Average annual hours worked  Hours
# 79712  University degree and higher  Average annual hours worked  Hours
# 79817  High school diploma and less  Average annual hours worked  Hours
# 79824             Trade certificate  Average annual hours worked  Hours
# 79838  University degree and higher  Average annual hours worked  Hours
# 79943  High school diploma and less  Average annual hours worked  Hours
# 79950             Trade certificate  Average annual hours worked  Hours
# 79964  University degree and higher  Average annual hours worked  Hours
# 88259  High school diploma and less  Average annual hours worked  Hours
# 88266             Trade certificate  Average annual hours worked  Hours
# 88280  University degree and higher  Average annual hours worked  Hours
# 88385  High school diploma and less  Average annual hours worked  Hours
# 88392             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 79439         units  1287.0
# 79446         units  1546.0
# 79460         units  1649.0
# 79565         units  1268.0
# 79572         units  1520.0
# 79586         units  1686.0
# 79691         units  1218.0
# 79698         units  1450.0
# 79712         units  1661.0
# 79817         units  1397.0
# 79824         units  1707.0
# 79838         units  1769.0
# 79943         units  1303.0
# 79950         units  1556.0
# 79964         units  1632.0
# 88259         units  1282.0
# 88266         units  1519.0
# 88280         units  1638.0
# 88385         units  1256.0
# 88392         units  1493.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 79439 to 97604
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Canada
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19456.0  1297.066667  1211.0  1287.0  1397.0
# Trade certificate             23189.0  1545.933333  1432.0  1528.0  1707.0
# University degree and higher  25185.0  1679.000000  1627.0  1671.0  1769.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  67830.0
# Mean :  1507.3333333333333
# Min/median/max : 1211.0 / 1528.0 / 1769.0
# Skewnewss :  -0.2637605275689323
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for GEO = Canada

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Manitoba.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Manitoba                     767802.0    710.927778    915.637659  1080

ProCode = 3

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# 30957      2013  Manitoba                      Total non-profit institutions
# 30964      2013  Manitoba                      Total non-profit institutions
# 30971      2013  Manitoba                      Total non-profit institutions
# 30978      2013  Manitoba                      Total non-profit institutions
# 30985      2013  Manitoba                      Total non-profit institutions
# 30992      2013  Manitoba                      Total non-profit institutions
# 31083      2013  Manitoba  Total non-profit institutions excluding govern...
# 31090      2013  Manitoba  Total non-profit institutions excluding govern...
# 31097      2013  Manitoba  Total non-profit institutions excluding govern...
# 31104      2013  Manitoba  Total non-profit institutions excluding govern...
# 31111      2013  Manitoba  Total non-profit institutions excluding govern...
# 31118      2013  Manitoba  Total non-profit institutions excluding govern...
# 31209      2013  Manitoba  Non-profit institutions serving households (co...
# 31216      2013  Manitoba  Non-profit institutions serving households (co...
# 31223      2013  Manitoba  Non-profit institutions serving households (co...
# 31230      2013  Manitoba  Non-profit institutions serving households (co...
# 31237      2013  Manitoba  Non-profit institutions serving households (co...
# 31244      2013  Manitoba  Non-profit institutions serving households (co...
# 31335      2013  Manitoba                   Business non-profit institutions
# 31342      2013  Manitoba                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 30957         15 to 24 years  Average annual hours worked  Hours
# 30964         25 to 34 years  Average annual hours worked  Hours
# 30971         35 to 44 years  Average annual hours worked  Hours
# 30978         45 to 54 years  Average annual hours worked  Hours
# 30985         55 to 64 years  Average annual hours worked  Hours
# 30992  65 years old and over  Average annual hours worked  Hours
# 31083         15 to 24 years  Average annual hours worked  Hours
# 31090         25 to 34 years  Average annual hours worked  Hours
# 31097         35 to 44 years  Average annual hours worked  Hours
# 31104         45 to 54 years  Average annual hours worked  Hours
# 31111         55 to 64 years  Average annual hours worked  Hours
# 31118  65 years old and over  Average annual hours worked  Hours
# 31209         15 to 24 years  Average annual hours worked  Hours
# 31216         25 to 34 years  Average annual hours worked  Hours
# 31223         35 to 44 years  Average annual hours worked  Hours
# 31230         45 to 54 years  Average annual hours worked  Hours
# 31237         55 to 64 years  Average annual hours worked  Hours
# 31244  65 years old and over  Average annual hours worked  Hours
# 31335         15 to 24 years  Average annual hours worked  Hours
# 31342         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 30957         units   965.0
# 30964         units  1545.0
# 30971         units  1698.0
# 30978         units  1781.0
# 30985         units  1634.0
# 30992         units  1034.0
# 31083         units   921.0
# 31090         units  1620.0
# 31097         units  1724.0
# 31104         units  1805.0
# 31111         units  1622.0
# 31118         units  1048.0
# 31209         units   921.0
# 31216         units  1593.0
# 31223         units  1699.0
# 31230         units  1784.0
# 31237         units  1610.0
# 31244         units  1039.0
# 31335         units   921.0
# 31342         units  1759.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 30957 to 49136
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Manitoba
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         14317.0   954.466667   897.0   958.0  1019.0    15
# 25 to 34 years         24492.0  1632.800000  1513.0  1614.0  1778.0    15
# 35 to 44 years         26560.0  1770.666667  1687.0  1754.0  1901.0    15
# 45 to 54 years         27584.0  1838.933333  1771.0  1827.0  1962.0    15
# 55 to 64 years         25102.0  1673.466667  1610.0  1691.0  1737.0    15
# 65 years old and over  16135.0  1075.666667  1026.0  1062.0  1149.0    15
#
# Overall,
# Sum :  134190.0
# Mean :  1491.0
# Min/median/max : 897.0 / 1643.5 / 1962.0
# Skewnewss :  -0.5815428634138992
# Total size :  90
# 2016
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# 57417      2016  Manitoba                      Total non-profit institutions
# 57424      2016  Manitoba                      Total non-profit institutions
# 57431      2016  Manitoba                      Total non-profit institutions
# 57438      2016  Manitoba                      Total non-profit institutions
# 57445      2016  Manitoba                      Total non-profit institutions
# 57452      2016  Manitoba                      Total non-profit institutions
# 57543      2016  Manitoba  Total non-profit institutions excluding govern...
# 57550      2016  Manitoba  Total non-profit institutions excluding govern...
# 57557      2016  Manitoba  Total non-profit institutions excluding govern...
# 57564      2016  Manitoba  Total non-profit institutions excluding govern...
# 57571      2016  Manitoba  Total non-profit institutions excluding govern...
# 57578      2016  Manitoba  Total non-profit institutions excluding govern...
# 57669      2016  Manitoba  Non-profit institutions serving households (co...
# 57676      2016  Manitoba  Non-profit institutions serving households (co...
# 57683      2016  Manitoba  Non-profit institutions serving households (co...
# 57690      2016  Manitoba  Non-profit institutions serving households (co...
# 57697      2016  Manitoba  Non-profit institutions serving households (co...
# 57704      2016  Manitoba  Non-profit institutions serving households (co...
# 57795      2016  Manitoba                   Business non-profit institutions
# 57802      2016  Manitoba                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 57417         15 to 24 years  Average annual hours worked  Hours
# 57424         25 to 34 years  Average annual hours worked  Hours
# 57431         35 to 44 years  Average annual hours worked  Hours
# 57438         45 to 54 years  Average annual hours worked  Hours
# 57445         55 to 64 years  Average annual hours worked  Hours
# 57452  65 years old and over  Average annual hours worked  Hours
# 57543         15 to 24 years  Average annual hours worked  Hours
# 57550         25 to 34 years  Average annual hours worked  Hours
# 57557         35 to 44 years  Average annual hours worked  Hours
# 57564         45 to 54 years  Average annual hours worked  Hours
# 57571         55 to 64 years  Average annual hours worked  Hours
# 57578  65 years old and over  Average annual hours worked  Hours
# 57669         15 to 24 years  Average annual hours worked  Hours
# 57676         25 to 34 years  Average annual hours worked  Hours
# 57683         35 to 44 years  Average annual hours worked  Hours
# 57690         45 to 54 years  Average annual hours worked  Hours
# 57697         55 to 64 years  Average annual hours worked  Hours
# 57704  65 years old and over  Average annual hours worked  Hours
# 57795         15 to 24 years  Average annual hours worked  Hours
# 57802         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 57417         units   962.0
# 57424         units  1565.0
# 57431         units  1728.0
# 57438         units  1803.0
# 57445         units  1659.0
# 57452         units  1052.0
# 57543         units   941.0
# 57550         units  1629.0
# 57557         units  1757.0
# 57564         units  1818.0
# 57571         units  1667.0
# 57578         units  1074.0
# 57669         units   944.0
# 57676         units  1603.0
# 57683         units  1732.0
# 57690         units  1794.0
# 57697         units  1657.0
# 57704         units  1065.0
# 57795         units   926.0
# 57802         units  1757.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 57417 to 75596
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Manitoba
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         14162.0   944.133333   906.0   944.0   979.0    15
# 25 to 34 years         23936.0  1595.733333  1512.0  1567.0  1757.0    15
# 35 to 44 years         26218.0  1747.866667  1685.0  1728.0  1908.0    15
# 45 to 54 years         27327.0  1821.800000  1766.0  1796.0  1964.0    15
# 55 to 64 years         24877.0  1658.466667  1612.0  1656.0  1740.0    15
# 65 years old and over  15640.0  1042.666667   951.0  1040.0  1127.0    15
#
# Overall,
# Sum :  132160.0
# Mean :  1468.4444444444443
# Min/median/max : 906.0 / 1634.0 / 1964.0
# Skewnewss :  -0.5544798756700609
# Total size :  90
# 2019
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# Min/median/max : 898.0 / 1641.5 / 1927.0
# Skewnewss :  -0.5575412160390797
# Total size :  90
# 2013
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# 30873      2013  Manitoba                      Total non-profit institutions
# 30880      2013  Manitoba                      Total non-profit institutions
# 30999      2013  Manitoba  Total non-profit institutions excluding govern...
# 31006      2013  Manitoba  Total non-profit institutions excluding govern...
# 31125      2013  Manitoba  Non-profit institutions serving households (co...
# 31132      2013  Manitoba  Non-profit institutions serving households (co...
# 31251      2013  Manitoba                   Business non-profit institutions
# 31258      2013  Manitoba                   Business non-profit institutions
# 31377      2013  Manitoba                 Government non-profit institutions
# 31384      2013  Manitoba                 Government non-profit institutions
# 39693      2014  Manitoba                      Total non-profit institutions
# 39700      2014  Manitoba                      Total non-profit institutions
# 39819      2014  Manitoba  Total non-profit institutions excluding govern...
# 39826      2014  Manitoba  Total non-profit institutions excluding govern...
# 39945      2014  Manitoba  Non-profit institutions serving households (co...
# 39952      2014  Manitoba  Non-profit institutions serving households (co...
# 40071      2014  Manitoba                   Business non-profit institutions
# 40078      2014  Manitoba                   Business non-profit institutions
# 40197      2014  Manitoba                 Government non-profit institutions
# 40204      2014  Manitoba                 Government non-profit institutions
#
#         Characteristics                   Indicators    UOM SCALAR_FACTOR  \
# 30873    Male employees  Average annual hours worked  Hours         units
# 30880  Female employees  Average annual hours worked  Hours         units
# 30999    Male employees  Average annual hours worked  Hours         units
# 31006  Female employees  Average annual hours worked  Hours         units
# 31125    Male employees  Average annual hours worked  Hours         units
# 31132  Female employees  Average annual hours worked  Hours         units
# 31251    Male employees  Average annual hours worked  Hours         units
# 31258  Female employees  Average annual hours worked  Hours         units
# 31377    Male employees  Average annual hours worked  Hours         units
# 31384  Female employees  Average annual hours worked  Hours         units
# 39693    Male employees  Average annual hours worked  Hours         units
# 39700  Female employees  Average annual hours worked  Hours         units
# 39819    Male employees  Average annual hours worked  Hours         units
# 39826  Female employees  Average annual hours worked  Hours         units
# 39945    Male employees  Average annual hours worked  Hours         units
# 39952  Female employees  Average annual hours worked  Hours         units
# 40071    Male employees  Average annual hours worked  Hours         units
# 40078  Female employees  Average annual hours worked  Hours         units
# 40197    Male employees  Average annual hours worked  Hours         units
# 40204  Female employees  Average annual hours worked  Hours         units
#
#         VALUE
# 30873  1610.0
# 30880  1534.0
# 30999  1647.0
# 31006  1463.0
# 31125  1635.0
# 31132  1456.0
# 31251  1690.0
# 31258  1515.0
# 31377  1589.0
# 31384  1563.0
# 39693  1635.0
# 39700  1580.0
# 39819  1659.0
# 39826  1485.0
# 39945  1646.0
# 39952  1477.0
# 40071  1704.0
# 40078  1536.0
# 40197  1622.0
# 40204  1618.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 30873 to 49024
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Manitoba
#                       sum         mean    amin  median    amax  size
# Characteristics
# Female employees  23034.0  1535.600000  1456.0  1534.0  1618.0    15
# Male employees    24835.0  1655.666667  1589.0  1647.0  1710.0    15
#
# Overall,
# Sum :  47869.0
# Mean :  1595.6333333333334
# Min/median/max : 1456.0 / 1614.0 / 1710.0
# Skewnewss :  -0.2160921306545881
# Total size :  30
# 2016
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# 57333      2016  Manitoba                      Total non-profit institutions
# 31314      2013  Manitoba                   Business non-profit institutions
# 31328      2013  Manitoba                   Business non-profit institutions
# 31433      2013  Manitoba                 Government non-profit institutions
# 31440      2013  Manitoba                 Government non-profit institutions
# 31454      2013  Manitoba                 Government non-profit institutions
# 39749      2014  Manitoba                      Total non-profit institutions
# 39756      2014  Manitoba                      Total non-profit institutions
# 39770      2014  Manitoba                      Total non-profit institutions
# 39875      2014  Manitoba  Total non-profit institutions excluding govern...
# 39882      2014  Manitoba  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 30929  High school diploma and less  Average annual hours worked  Hours
# 30936             Trade certificate  Average annual hours worked  Hours
# 30950  University degree and higher  Average annual hours worked  Hours
# 31055  High school diploma and less  Average annual hours worked  Hours
# 31062             Trade certificate  Average annual hours worked  Hours
# 31076  University degree and higher  Average annual hours worked  Hours
# 31181  High school diploma and less  Average annual hours worked  Hours
# 31188             Trade certificate  Average annual hours worked  Hours
# 31202  University degree and higher  Average annual hours worked  Hours
# 31307  High school diploma and less  Average annual hours worked  Hours
# 31314             Trade certificate  Average annual hours worked  Hours
# 31328  University degree and higher  Average annual hours worked  Hours
# 31433  High school diploma and less  Average annual hours worked  Hours
# 31440             Trade certificate  Average annual hours worked  Hours
# 31454  University degree and higher  Average annual hours worked  Hours
# 39749  High school diploma and less  Average annual hours worked  Hours
# 39756             Trade certificate  Average annual hours worked  Hours
# 39770  University degree and higher  Average annual hours worked  Hours
# 39875  High school diploma and less  Average annual hours worked  Hours
# 39882             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 30929         units  1340.0
# 30936         units  1563.0
# 30950         units  1669.0
# 31055         units  1286.0
# 31062         units  1570.0
# 31076         units  1708.0
# 31181         units  1260.0
# 31188         units  1526.0
# 31202         units  1698.0
# 31307         units  1398.0
# 31314         units  1759.0
# 31328         units  1769.0
# 31433         units  1379.0
# 31440         units  1560.0
# 31454         units  1654.0
# 39749         units  1370.0
# 39756         units  1606.0
# 39770         units  1707.0
# 39875         units  1299.0
# 39882         units  1610.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 30929 to 49094
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Manitoba
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  20309.0  1353.933333  1260.0  1370.0  1419.0
# Trade certificate             24419.0  1627.933333  1526.0  1605.0  1812.0
# University degree and higher  25903.0  1726.866667  1654.0  1711.0  1814.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  70631.0
# Mean :  1569.5777777777778
# Min/median/max : 1260.0 / 1605.0 / 1814.0
# Skewnewss :  -0.33993741952217466
# Total size :  45
# 2016
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# 57389      2016  Manitoba                      Total non-profit institutions
# 57396      2016  Manitoba                      Total non-profit institutions
# 57410      2016  Manitoba                      Total non-profit institutions
# 57515      2016  Manitoba  Total non-profit institutions excluding govern...
# 57522      2016  Manitoba  Total non-profit institutions excluding govern...
# 57536      2016  Manitoba  Total non-profit institutions excluding govern...
# 57641      2016  Manitoba  Non-profit institutions serving households (co...
# 57648      2016  Manitoba  Non-profit institutions serving households (co...
# 57662      2016  Manitoba  Non-profit institutions serving households (co...
# 57767      2016  Manitoba                   Business non-profit institutions
# 57774      2016  Manitoba                   Business non-profit institutions
# 57788      2016  Manitoba                   Business non-profit institutions
# 57893      2016  Manitoba                 Government non-profit institutions
# 57900      2016  Manitoba                 Government non-profit institutions
# 57914      2016  Manitoba                 Government non-profit institutions
# 66209      2017  Manitoba                      Total non-profit institutions
# 66216      2017  Manitoba                      Total non-profit institutions
# 66230      2017  Manitoba                      Total non-profit institutions
# 66335      2017  Manitoba  Total non-profit institutions excluding govern...
# 66342      2017  Manitoba  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
#
Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 30929  High school diploma and less  Average annual hours worked  Hours
# 30936             Trade certificate  Average annual hours worked  Hours
# 30950  University degree and higher  Average annual hours worked  Hours
# 31055  High school diploma and less  Average annual hours worked  Hours
# 31062             Trade certificate  Average annual hours worked  Hours
# 31076  University degree and higher  Average annual hours worked  Hours
# 31181  High school diploma and less  Average annual hours worked  Hours
# 31188             Trade certificate  Average annual hours worked  Hours
# 31202  University degree and higher  Average annual hours worked  Hours
# 31307  High school diploma and less  Average annual hours worked  Hours
# 31314             Trade certificate  Average annual hours worked  Hours
# 31328  University degree and higher  Average annual hours worked  Hours
# 31433  High school diploma and less  Average annual hours worked  Hours
# 31440             Trade certificate  Average annual hours worked  Hours
# 31454  University degree and higher  Average annual hours worked  Hours
# 39749  High school diploma and less  Average annual hours worked  Hours
# 39756             Trade certificate  Average annual hours worked  Hours
# 39770  University degree and higher  Average annual hours worked  Hours
# 39875  High school diploma and less  Average annual hours worked  Hours
# 39882             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 30929         units  1340.0
# 30936         units  1563.0
# 30950         units  1669.0
# 31055         units  1286.0
# 31062         units  1570.0
# 31076         units  1708.0
# 31181         units  1260.0
# 31188         units  1526.0
# 31202         units  1698.0
# 31307         units  1398.0
# 31314         units  1759.0
# 31328         units  1769.0
# 31433         units  1379.0
# 31440         units  1560.0
# 31454         units  1654.0
# 39749         units  1370.0
# 39756         units  1606.0
# 39770         units  1707.0
# 39875         units  1299.0
# 39882         units  1610.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 30929 to 49094
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Manitoba
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  20309.0  1353.933333  1260.0  1370.0  1419.0
# Trade certificate             24419.0  1627.933333  1526.0  1605.0  1812.0
# University degree and higher  25903.0  1726.866667  1654.0  1711.0  1814.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  70631.0
# Mean :  1569.5777777777778
# Min/median/max : 1260.0 / 1605.0 / 1814.0
# Skewnewss :  -0.33993741952217466
# Total size :  45
# 2016
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# 57347      2016  Manitoba                      Total non-profit institutions
# 57354      2016  Manitoba                      Total non-profit institutions
# 57473      2016  Manitoba  Total non-profit institutions excluding govern...
# 57480      2016  Manitoba  Total non-profit institutions excluding govern...
# 57599      2016  Manitoba  Non-profit institutions serving households (co...
# 57606      2016  Manitoba  Non-profit institutions serving households (co...
# 57725      2016  Manitoba                   Business non-profit institutions
# 57732      2016  Manitoba                   Business non-profit institutions
# 57851      2016  Manitoba                 Government non-profit institutions
# 57858      2016  Manitoba                 Government non-profit institutions
# 66167      2017  Manitoba                      Total non-profit institutions
# 66174      2017  Manitoba                      Total non-profit institutions
# 66293      2017  Manitoba  Total non-profit institutions excluding govern...
# 66300      2017  Manitoba  Total non-profit institutions excluding govern...
# 66419      2017  Manitoba  Non-profit institutions serving households (co...
# 66426      2017  Manitoba  Non-profit institutions serving households (co...
# 66545      2017  Manitoba                   Business non-profit institutions
# 66552      2017  Manitoba                   Business non-profit institutions
# 66671      2017  Manitoba                 Government non-profit institutions
# 66678      2017  Manitoba                 Government non-profit institutions
#
#                Characteristics                   Indicators    UOM  \
# 57347      Immigrant employees  Average annual hours worked  Hours
# 57354  Non-immigrant employees  Average annual hours worked  Hours
# 57473      Immigrant employees  Average annual hours worked  Hours
# 57480  Non-immigrant employees  Average annual hours worked  Hours
# 57599      Immigrant employees  Average annual hours worked  Hours
# 57606  Non-immigrant employees  Average annual hours worked  Hours
# 57725      Immigrant employees  Average annual hours worked  Hours
# 57732  Non-immigrant employees  Average annual hours worked  Hours
# 57851      Immigrant employees  Average annual hours worked  Hours
# 57858  Non-immigrant employees  Average annual hours worked  Hours
# 66167      Immigrant employees  Average annual hours worked  Hours
# 66174  Non-immigrant employees  Average annual hours worked  Hours
# 66293      Immigrant employees  Average annual hours worked  Hours
# 66300  Non-immigrant employees  Average annual hours worked  Hours
# 66419      Immigrant employees  Average annual hours worked  Hours
# 66426  Non-immigrant employees  Average annual hours worked  Hours
# 66545      Immigrant employees  Average annual hours worked  Hours
# 66552  Non-immigrant employees  Average annual hours worked  Hours
# 66671      Immigrant employees  Average annual hours worked  Hours
# 66678  Non-immigrant employees  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 57347         units  1593.0
# 57354         units  1564.0
# 57473         units  1574.0
# 57480         units  1547.0
# 57599         units  1569.0
# 57606         units  1531.0
# 57725         units  1607.0
# 57732         units  1624.0
# 57851         units  1599.0
# 57858         units  1573.0
# 66167         units  1580.0
# 66174         units  1551.0
# 66293         units  1573.0
# 66300         units  1554.0
# 66419         units  1566.0
# 66426         units  1537.0
# 66545         units  1610.0
# 66552         units  1640.0
# 66671         units  1582.0
# 66678         units  1550.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 57347 to 75498
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Manitoba
#                              sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      23592.0  1572.800000  1517.0  1574.0  1610.0    15
# Non-immigrant employees  23269.0  1551.266667  1480.0  1550.0  1640.0    15
#
# Overall,
# Sum :  46861.0
# Mean :  1562.0333333333333
# Min/median/max : 1480.0 / 1565.0 / 1640.0
# Skewnewss :  -0.11829330573067925
# Total size :  30
# 2019
#
# Grab the dataset only in Manitoba
#        REF_DATE       GEO                                             Sector  \
# 83849      2019  Manitoba                      Total non-profit institutions
# 83856      2019  Manitoba                      Total non-profit institutions
# 83870      2019  Manitoba                      Total non-profit institutions
# 83975      2019  Manitoba  Total non-profit institutions excluding govern...
# 83982      2019  Manitoba  Total non-profit institutions excluding govern...
# 83996      2019  Manitoba  Total non-profit institutions excluding govern...
# 84101      2019  Manitoba  Non-profit institutions serving households (co...
# 84108      2019  Manitoba  Non-profit institutions serving households (co...
# 84122      2019  Manitoba  Non-profit institutions serving households (co...
# 84227      2019  Manitoba                   Business non-profit institutions
# 84234      2019  Manitoba                   Business non-profit institutions
# 84248      2019  Manitoba                   Business non-profit institutions
# 84353      2019  Manitoba                 Government non-profit institutions
# 84360      2019  Manitoba                 Government non-profit institutions
# 84374      2019  Manitoba                 Government non-profit institutions
# 92669      2020  Manitoba                      Total non-profit institutions
# 92676      2020  Manitoba                      Total non-profit institutions
# 92690      2020  Manitoba                      Total non-profit institutions
# 92795      2020  Manitoba  Total non-profit institutions excluding govern...
# 92802      2020  Manitoba  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 83849  High school diploma and less  Average annual hours worked  Hours
# 83856             Trade certificate  Average annual hours worked  Hours
# 83870  University degree and higher  Average annual hours worked  Hours
# 83975  High school diploma and less  Average annual hours worked  Hours
# 83982             Trade certificate  Average annual hours worked  Hours
# 83996  University degree and higher  Average annual hours worked  Hours
# 84101  High school diploma and less  Average annual hours worked  Hours
# 84108             Trade certificate  Average annual hours worked  Hours
# 84122  University degree and higher  Average annual hours worked  Hours
# 84227  High school diploma and less  Average annual hours worked  Hours
# 84234             Trade certificate  Average annual hours worked  Hours
# 84248  University degree and higher  Average annual hours worked  Hours
# 84353  High school diploma and less  Average annual hours worked  Hours
# 84360             Trade certificate  Average annual hours worked  Hours
# 84374  University degree and higher  Average annual hours worked  Hours
# 92669  High school diploma and less  Average annual hours worked  Hours
# 92676             Trade certificate  Average annual hours worked  Hours
# 92690  University degree and higher  Average annual hours worked  Hours
# 92795  High school diploma and less  Average annual hours worked  Hours
# 92802             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 83849         units  1334.0
# 83856         units  1565.0
# 83870         units  1660.0
# 83975         units  1272.0
# 83982         units  1511.0
# 83996         units  1660.0
# 84101         units  1251.0
# 84108         units  1462.0
# 84122         units  1650.0
# 84227         units  1367.0
# 84234         units  1726.0
# 84248         units  1715.0
# 84353         units  1382.0
# 84360         units  1587.0
# 84374         units  1660.0
# 92669         units  1326.0
# 92676         units  1540.0
# 92690         units  1657.0
# 92795         units  1292.0
# 92802         units  1510.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 83849 to 102014
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Manitoba
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19953.0  1330.200000  1251.0  1332.0  1382.0
# Trade certificate             23525.0  1568.333333  1462.0  1552.0  1730.0
# University degree and higher  25254.0  1683.600000  1644.0  1677.0  1755.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  68732.0
# Mean :  1527.3777777777777
# Min/median/max : 1251.0 / 1552.0 / 1755.0
# Skewnewss :  -0.26063733924010696
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Manitoba

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only New Brunswick.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- New Brunswick                359320.0    332.703704    530.962762  1080

ProCode = 4

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in New Brunswick
#        REF_DATE            GEO  \
# 29067      2013  New Brunswick
# 29074      2013  New Brunswick
# 29081      2013  New Brunswick
# 29088      2013  New Brunswick
# 29095      2013  New Brunswick
# 29102      2013  New Brunswick
# 29193      2013  New Brunswick
# 29200      2013  New Brunswick
# 29207      2013  New Brunswick
# 29214      2013  New Brunswick
# 29221      2013  New Brunswick
# 29228      2013  New Brunswick
# 29319      2013  New Brunswick
# 29326      2013  New Brunswick
# 29333      2013  New Brunswick
# 29340      2013  New Brunswick
# 29347      2013  New Brunswick
# 29354      2013  New Brunswick
# 29445      2013  New Brunswick
# 29452      2013  New Brunswick
#
#                                                   Sector  \
# 29067                      Total non-profit institutions
# 29074                      Total non-profit institutions
# 29081                      Total non-profit institutions
# 29088                      Total non-profit institutions
# 29095                      Total non-profit institutions
# 29102                      Total non-profit institutions
# 29193  Total non-profit institutions excluding govern...
# 29200  Total non-profit institutions excluding govern...
# 29207  Total non-profit institutions excluding govern...
# 29214  Total non-profit institutions excluding govern...
# 29221  Total non-profit institutions excluding govern...
# 29228  Total non-profit institutions excluding govern...
# 29319  Non-profit institutions serving households (co...
# 29326  Non-profit institutions serving households (co...
# 29333  Non-profit institutions serving households (co...
# 29340  Non-profit institutions serving households (co...
# 29347  Non-profit institutions serving households (co...
# 29354  Non-profit institutions serving households (co...
# 29445                   Business non-profit institutions
# 29452                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 29067         15 to 24 years  Average annual hours worked  Hours
# 29074         25 to 34 years  Average annual hours worked  Hours
# 29081         35 to 44 years  Average annual hours worked  Hours
# 29088         45 to 54 years  Average annual hours worked  Hours
# 29095         55 to 64 years  Average annual hours worked  Hours
# 29102  65 years old and over  Average annual hours worked  Hours
# 29193         15 to 24 years  Average annual hours worked  Hours
# 29200         25 to 34 years  Average annual hours worked  Hours
# 29207         35 to 44 years  Average annual hours worked  Hours
# 29214         45 to 54 years  Average annual hours worked  Hours
# 29221         55 to 64 years  Average annual hours worked  Hours
# 29228  65 years old and over  Average annual hours worked  Hours
# 29319         15 to 24 years  Average annual hours worked  Hours
# 29326         25 to 34 years  Average annual hours worked  Hours
# 29333         35 to 44 years  Average annual hours worked  Hours
# 29340         45 to 54 years  Average annual hours worked  Hours
# 29347         55 to 64 years  Average annual hours worked  Hours
# 29354  65 years old and over  Average annual hours worked  Hours
# 29445         15 to 24 years  Average annual hours worked  Hours
# 29452         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 29067         units   958.0
# 29074         units  1711.0
# 29081         units  1908.0
# 29088         units  1922.0
# 29095         units  1716.0
# 29102         units  1020.0
# 29193         units   903.0
# 29200         units  1761.0
# 29207         units  1971.0
# 29214         units  1947.0
# 29221         units  1716.0
# 29228         units  1097.0
# 29319         units   899.0
# 29326         units  1732.0
# 29333         units  1945.0
# 29340         units  1908.0
# 29347         units  1716.0
# 29354         units  1086.0
# 29445         units   914.0
# 29452         units  1850.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 29067 to 47246
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in New Brunswick
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         13941.0   929.400000   861.0   912.0  1006.0    15
# 25 to 34 years         26060.0  1737.333333  1653.0  1732.0  1850.0    15
# 35 to 44 years         29148.0  1943.200000  1824.0  1945.0  2078.0    15
# 45 to 54 years         29173.0  1944.866667  1860.0  1922.0  2091.0    15
# 55 to 64 years         25741.0  1716.066667  1656.0  1716.0  1790.0    15
# 65 years old and over  16373.0  1091.533333   920.0  1097.0  1232.0    15
#
# Overall,
# Sum :  140436.0
# Mean :  1560.4
# Min/median/max : 861.0 / 1717.5 / 2091.0
# Skewnewss :  -0.585718507481045
# Total size :  90
# 2016
#
# Grab the dataset only in New Brunswick
#        REF_DATE            GEO  \
# 55527      2016  New Brunswick
# 55534      2016  New Brunswick
# 55541      2016  New Brunswick
# 55548      2016  New Brunswick
# 55555      2016  New Brunswick
# 55562      2016  New Brunswick
# 55653      2016  New Brunswick
# 55660      2016  New Brunswick
# 55667      2016  New Brunswick
# 55674      2016  New Brunswick
# 55681      2016  New Brunswick
# 55688      2016  New Brunswick
# 55779      2016  New Brunswick
0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 28983 to 47134
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in New Brunswick
#                       sum         mean    amin  median    amax  size
# Characteristics
# Female employees  24116.0  1607.733333  1544.0  1610.0  1683.0    15
# Male employees    26399.0  1759.933333  1709.0  1758.0  1824.0    15
#
# Overall,
# Sum :  50515.0
# Mean :  1683.8333333333333
# Min/median/max : 1544.0 / 1696.0 / 1824.0
# Skewnewss :  -0.13526057290725768
# Total size :  30
# 2016
#
# Grab the dataset only in New Brunswick
#        REF_DATE            GEO  \
# 55443      2016  New Brunswick
# 55450      2016  New Brunswick
# 55569      2016  New Brunswick
# 55576      2016  New Brunswick
# 55695      2016  New Brunswick
# 55702      2016  New Brunswick
# 55821      2016  New Brunswick
# 55828      2016  New Brunswick
# 55947      2016  New Brunswick
# 55954      2016  New Brunswick
# 64263      2017  New Brunswick
# 64270      2017  New Brunswick
# 64389      2017  New Brunswick
# 64396      2017  New Brunswick
# 64515      2017  New Brunswick
# 64522      2017  New Brunswick
# 64641      2017  New Brunswick
# 64648      2017  New Brunswick
# 64767      2017  New Brunswick
# 64774      2017  New Brunswick
#
#                                                   Sector   Characteristics  \
# 55443                      Total non-profit institutions    Male employees
# 55450                      Total non-profit institutions  Female employees
# 55569  Total non-profit institutions excluding govern...    Male employees
# 55576  Total non-profit institutions excluding govern...  Female employees
# 55695  Non-profit institutions serving households (co...    Male employees
# 55702  Non-profit institutions serving households (co...  Female employees
# 55821                   Business non-profit institutions    Male employees
# 55828                   Business non-profit institutions  Female employees
# 55947                 Government non-profit institutions    Male employees
# 55954                 Government non-profit institutions  Female employees
# 64263                      Total non-profit institutions    Male employees
# 64270                      Total non-profit institutions  Female employees
# 64389  Total non-profit institutions excluding govern...    Male employees
# 64396  Total non-profit institutions excluding govern...  Female employees
# 64515  Non-profit institutions serving households (co...    Male employees
# 64522  Non-profit institutions serving households (co...  Female employees
# 64641                   Business non-profit institutions    Male employees
# 64648                   Business non-profit institutions  Female employees
# 64767                 Government non-profit institutions    Male employees
# 64774                 Government non-profit institutions  Female employees
#
#                         Indicators    UOM SCALAR_FACTOR   VALUE
# 55443  Average annual hours worked  Hours         units  1734.0
# 55450  Average annual hours worked  Hours         units  1631.0
# 55569  Average annual hours worked  Hours         units  1787.0
# 55576  Average annual hours worked  Hours         units  1588.0
# 55695  Average annual hours worked  Hours         units  1775.0
# 55702  Average annual hours worked  Hours         units  1556.0
# 55821  Average annual hours worked  Hours         units  1816.0
# 55828  Average annual hours worked  Hours         units  1717.0
# 55947  Average annual hours worked  Hours         units  1705.0
# 55954  Average annual hours worked  Hours         units  1645.0
# 64263  Average annual hours worked  Hours         units  1719.0
# 64270  Average annual hours worked  Hours         units  1631.0
# 64389  Average annual hours worked  Hours         units  1747.0
# 64396  Average annual hours worked  Hours         units  1570.0
# 64515  Average annual hours worked  Hours         units  1739.0
# 64522  Average annual hours worked  Hours         units  1546.0
# 64641  Average annual hours worked  Hours         units  1768.0
# 64648  Average annual hours worked  Hours         units  1668.0
# 64767  Average annual hours worked  Hours         units  1703.0
# 64774  Average annual hours worked  Hours         units  1651.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries,
Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 81959         units  1436.0
# 81966         units  1646.0
# 81980         units  1783.0
# 82085         units  1387.0
# 82092         units  1600.0
# 82106         units  1857.0
# 82211         units  1343.0
# 82218         units  1548.0
# 82232         units  1838.0
# 82337         units  1530.0
# 82344         units  1761.0
# 82358         units  1938.0
# 82463         units  1467.0
# 82470         units  1665.0
# 82484         units  1758.0
# 90779         units  1411.0
# 90786         units  1602.0
# 90800         units  1728.0
# 90905         units  1312.0
# 90912         units  1501.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 81959 to 100124
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in New Brunswick
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  21026.0  1401.733333  1270.0  1414.0  1530.0
# Trade certificate             24003.0  1600.200000  1452.0  1602.0  1761.0
# University degree and higher  27045.0  1803.000000  1715.0  1783.0  1938.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  72074.0
# Mean :  1601.6444444444444
# Min/median/max : 1270.0 / 1602.0 / 1938.0
# Skewnewss :  -0.028905993570962334
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for New Brunswick

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Newfoundland and Labrador.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Newfoundland and Labrador    315895.0    306.099806    482.634908  1032

ProCode = 5

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Newfoundland and Labrador
#        REF_DATE                        GEO  \
# 27177      2013  Newfoundland and Labrador
# 27184      2013  Newfoundland and Labrador
# 27191      2013  Newfoundland and Labrador
# 27198      2013  Newfoundland and Labrador
# 27205      2013  Newfoundland and Labrador
# 27212      2013  Newfoundland and Labrador
# 27303      2013  Newfoundland and Labrador
# 27310      2013  Newfoundland and Labrador
# 27317      2013  Newfoundland and Labrador
# 27324      2013  Newfoundland and Labrador
# 27331      2013  Newfoundland and Labrador
# 27338      2013  Newfoundland and Labrador
# 27429      2013  Newfoundland and Labrador
# 27436      2013  Newfoundland and Labrador
# 27443      2013  Newfoundland and Labrador
# 27450      2013  Newfoundland and Labrador
# 27457      2013  Newfoundland and Labrador
# 27464      2013  Newfoundland and Labrador
# 27555      2013  Newfoundland and Labrador
# 27562      2013  Newfoundland and Labrador
#
#                                                   Sector  \
# 27177                      Total non-profit institutions
# 27184                      Total non-profit institutions
# 27191                      Total non-profit institutions
# 27198                      Total non-profit institutions
# 27205                      Total non-profit institutions
# 27212                      Total non-profit institutions
# 27303  Total non-profit institutions excluding govern...
# 27310  Total non-profit institutions excluding govern...
# 27317  Total non-profit institutions excluding govern...
# 27324  Total non-profit institutions excluding govern...
# 27331  Total non-profit institutions excluding govern...
# 27338  Total non-profit institutions excluding govern...
# 27429  Non-profit institutions serving households (co...
# 27436  Non-profit institutions serving households (co...
# 27443  Non-profit institutions serving households (co...
# 27450  Non-profit institutions serving households (co...
# 27457  Non-profit institutions serving households (co...
# 27464  Non-profit institutions serving households (co...
# 27555                   Business non-profit institutions
# 27562                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
#
# 53763  Total non-profit institutions excluding govern...
# 53770  Total non-profit institutions excluding govern...
# 53777  Total non-profit institutions excluding govern...
# 53784  Total non-profit institutions excluding govern...
# 53791  Total non-profit institutions excluding govern...
# 53798  Total non-profit institutions excluding govern...
# 53889  Non-profit institutions serving households (co...
# 53896  Non-profit institutions serving households (co...
# 53903  Non-profit institutions serving households (co...
# 53910  Non-profit institutions serving households (co...
# 53917  Non-profit institutions serving households (co...
# 53924  Non-profit institutions serving households (co...
# 54015                   Business non-profit institutions
# 54022                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 53637         15 to 24 years  Average annual hours worked  Hours
# 53644         25 to 34 years  Average annual hours worked  Hours
# 53651         35 to 44 years  Average annual hours worked  Hours
# 53658         45 to 54 years  Average annual hours worked  Hours
# 53665         55 to 64 years  Average annual hours worked  Hours
# 53672  65 years old and over  Average annual hours worked  Hours
# 53763         15 to 24 years  Average annual hours worked  Hours
# 53770         25 to 34 years  Average annual hours worked  Hours
# 53777         35 to 44 years  Average annual hours worked  Hours
# 53784         45 to 54 years  Average annual hours worked  Hours
# 53791         55 to 64 years  Average annual hours worked  Hours
# 53798  65 years old and over  Average annual hours worked  Hours
# 53889         15 to 24 years  Average annual hours worked  Hours
# 53896         25 to 34 years  Average annual hours worked  Hours
# 53903         35 to 44 years  Average annual hours worked  Hours
# 53910         45 to 54 years  Average annual hours worked  Hours
# 53917         55 to 64 years  Average annual hours worked  Hours
# 53924  65 years old and over  Average annual hours worked  Hours
# 54015         15 to 24 years  Average annual hours worked  Hours
# 54022         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 53637         units   905.0
# 53644         units  1686.0
# 53651         units  1889.0
# 53658         units  1935.0
# 53665         units  1699.0
# 53672         units  1150.0
# 53763         units   734.0
# 53770         units  1830.0
# 53777         units  2004.0
# 53784         units  2093.0
# 53791         units  1732.0
# 53798         units  1236.0
# 53889         units   695.0
# 53896         units  1812.0
# 53903         units  1978.0
# 53910         units  2086.0
# 53917         units  1733.0
# 53924         units  1240.0
# 54015         units   832.0
# 54022         units  1879.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 53637 to 71816
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Newfoundland and Labrador
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         12541.0   836.066667   691.0   824.0  1028.0    15
# 25 to 34 years         26330.0  1755.333333  1657.0  1756.0  1879.0    15
# 35 to 44 years         29219.0  1947.933333  1857.0  1944.0  2078.0    15
# 45 to 54 years         30358.0  2023.866667  1903.0  2050.0  2127.0    15
# 55 to 64 years         25543.0  1702.866667  1664.0  1701.0  1733.0    15
# 65 years old and over  17873.0  1191.533333  1047.0  1213.0  1268.0    15
#
# Overall,
# Sum :  141864.0
# Mean :  1576.2666666666667
# Min/median/max : 691.0 / 1709.0 / 2127.0
# Skewnewss :  -0.6967235909325254
# Total size :  90
# 2019
#
# Grab the dataset only in Newfoundland and Labrador
#        REF_DATE                        GEO  \
# 80097      2019  Newfoundland and Labrador
# 80104      2019  Newfoundland and Labrador
# 80111      2019  Newfoundland and Labrador
# 80118      2019  Newfoundland and Labrador
# 80125      2019  Newfoundland and Labrador
# 80132      2019  Newfoundland and Labrador
# 80223      2019  Newfoundland and Labrador
# 80230      2019  Newfoundland and Labrador
Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 80069         units  1408.0
# 80076         units  1619.0
# 80090         units  1772.0
# 80195         units  1260.0
# 80202         units  1576.0
# 80216         units  1993.0
# 80321         units  1230.0
# 80328         units  1514.0
# 80342         units  1987.0
# 80447         units  1353.0
# 80454         units  1734.0
# 80468         units  2018.0
# 80573         units  1475.0
# 80580         units  1632.0
# 80594         units  1726.0
# 88889         units  1411.0
# 88896         units  1608.0
# 88910         units  1754.0
# 89015         units  1200.0
# 89022         units  1490.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 80069 to 98234
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Newfoundland and Labrador
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  20037.0  1335.800000  1178.0  1305.0  1507.0
# Trade certificate             23932.0  1595.466667  1445.0  1615.0  1734.0
# University degree and higher  28061.0  1870.733333  1726.0  1876.0  2018.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  72030.0
# Mean :  1600.6666666666667
# Min/median/max : 1178.0 / 1615.0 / 2018.0
# Skewnewss :  -0.018789938513471514
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Newfoundland

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Northwest Territories.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Northwest Territories         42804.0     41.476744     51.817046  1032

ProCode = 6

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Northwest Territories
#        REF_DATE                    GEO  \
# 34107      2013  Northwest Territories
# 34114      2013  Northwest Territories
# 34121      2013  Northwest Territories
# 34128      2013  Northwest Territories
# 34135      2013  Northwest Territories
# 34142      2013  Northwest Territories
# 34233      2013  Northwest Territories
# 34240      2013  Northwest Territories
# 34247      2013  Northwest Territories
# 34254      2013  Northwest Territories
# 34261      2013  Northwest Territories
# 34268      2013  Northwest Territories
# 34366      2013  Northwest Territories
# 34373      2013  Northwest Territories
# 34380      2013  Northwest Territories
# 34387      2013  Northwest Territories
# 34492      2013  Northwest Territories
# 34499      2013  Northwest Territories
# 34506      2013  Northwest Territories
# 34513      2013  Northwest Territories
#
#                                                   Sector  \
# 34107                      Total non-profit institutions
# 34114                      Total non-profit institutions
# 34121                      Total non-profit institutions
# 34128                      Total non-profit institutions
# 34135                      Total non-profit institutions
# 34142                      Total non-profit institutions
# 34233  Total non-profit institutions excluding govern...
# 34240  Total non-profit institutions excluding govern...
# 34247  Total non-profit institutions excluding govern...
# 34254  Total non-profit institutions excluding govern...
# 34261  Total non-profit institutions excluding govern...
# 34268  Total non-profit institutions excluding govern...
# 34366  Non-profit institutions serving households (co...
# 34373  Non-profit institutions serving households (co...
# 34380  Non-profit institutions serving households (co...
# 34387  Non-profit institutions serving households (co...
# 34492                   Business non-profit institutions
# 34499                   Business non-profit institutions
# 34506                   Business non-profit institutions
# 34513                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 34107         15 to 24 years  Average annual hours worked  Hours
# 34114         25 to 34 years  Average annual hours worked  Hours
# 34121         35 to 44 years  Average annual hours worked  Hours
# 34128         45 to 54 years  Average annual hours worked  Hours
# 34135         55 to 64 years  Average annual hours worked  Hours
# 34142  65 years old and over  Average annual hours worked  Hours
# 34233         15 to 24 years  Average annual hours worked  Hours
# 34240         25 to 34 years  Average annual hours worked  Hours
# 34247         35 to 44 years  Average annual hours worked  Hours
# 34254         45 to 54 years  Average annual hours worked  Hours
# 34261         55 to 64 years  Average annual hours worked  Hours
# 34268  65 years old and over  Average annual hours worked  Hours
# 34366         25 to 34 years  Average annual hours worked  Hours
# 34373         35 to 44 years  Average annual hours worked  Hours
# 34380         45 to 54 years  Average annual hours worked  Hours
# 34387         55 to 64 years  Average annual hours worked  Hours
# 34492         25 to 34 years  Average annual hours worked  Hours
# 34499         35 to 44 years  Average annual hours worked  Hours
# 34506         45 to 54 years  Average annual hours worked  Hours
# 34513         55 to 64 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 34107         units   897.0
# 34114         units  1509.0
# 34121         units  1769.0
# 34128         units  1759.0
# 34135         units  1641.0
# 34142         units  1233.0
# 34233         units   782.0
# 34240         units  1378.0
# 34247         units  1779.0
# 34254         units  1682.0
# 34261         units  1688.0
# 34268         units  1250.0
# 34366         units  1330.0
# 34373         units  1728.0
# 34380         units  1653.0
# 34387         units  1673.0
# 34492         units  1647.0
# 34499         units  2023.0
# 34506         units  1814.0
# 34513         units  1765.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 34107 to 52286
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         78 non-null     int64
#  1   GEO              78 non-null     object
#  2   Sector           78 non-null     object
#  3   Characteristics  78 non-null     object
#  4   Indicators       78 non-null     object
#  5   UOM              78 non-null     object
#  6   SCALAR_FACTOR    78 non-null     object
#  7   VALUE            78 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Northwest Territories
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          8121.0   902.333333   782.0   897.0  1016.0     9
# 25 to 34 years         21615.0  1441.000000  1236.0  1416.0  1667.0    15
# 35 to 44 years         26887.0  1792.466667  1675.0  1750.0  2024.0    15
# 45 to 54 years         25291.0  1686.066667  1523.0  1682.0  1833.0    15
# 55 to 64 years         24843.0  1656.200000  1528.0  1656.0  1765.0    15
# 65 years old and over  10594.0  1177.111111  1090.0  1185.0  1250.0     9
#
# Overall,
# Sum :  117351.0
# Mean :  1504.5
# Min/median/max : 782.0 / 1632.0 / 2024.0
# Skewnewss :  -0.7876364712236495
# Total size :  78
# 2016
#
# Grab the dataset only in Northwest Territories
#        REF_DATE                    GEO  \
# 60567      2016  Northwest Territories
# 60574      2016  Northwest Territories
# 60581      2016  Northwest Territories
# 60588      2016  Northwest Territories
# 60595      2016  Northwest Territories
# 60602      2016  Northwest Territories
# 60693      2016  Northwest Territories
# 60700      2016  Northwest Territories
# 60707      2016  Northwest Territories
# 60714      2016  Northwest Territories
# 60721      2016  Northwest Territories
# 60728      2016  Northwest Territories
# 60826      2016  Northwest Territories
# 60833      2016  Northwest Territories
# 60840      2016  Northwest Territories
# 60847      2016  Northwest Territories
# 60952      2016  Northwest Territories
# 60959      2016  Northwest Territories
# 60966      2016  Northwest Territories
# 60973      2016  Northwest Territories
#
#                                                   Sector  \
# 60567                      Total non-profit institutions
# 60574                      Total non-profit institutions
# 60581                      Total non-profit institutions
# 60588                      Total non-profit institutions
# 60595                      Total non-profit institutions
# 60602                      Total non-profit institutions
# 60693  Total non-profit institutions excluding govern...
# 60700  Total non-profit institutions excluding govern...
# 60707  Total non-profit institutions excluding govern...
# 60714  Total non-profit institutions excluding govern...
# 60721  Total non-profit institutions excluding govern...
# 60728  Total non-profit institutions excluding govern...
# 60826  Non-profit institutions serving households (co...
# 60833  Non-profit institutions serving households (co...
# 60840  Non-profit institutions serving households (co...
# 60847  Non-profit institutions serving households (co...
# 60952                   Business non-profit institutions
# 60959                   Business non-profit institutions
# 60966                   Business non-profit institutions
# 60973                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 60567         15 to 24 years  Average annual hours worked  Hours
# 60574         25 to 34 years  Average annual hours worked  Hours
# 60581         35 to 44 years  Average annual hours worked  Hours
# 60588         45 to 54 years  Average annual hours worked  Hours
# 60595         55 to 64 years  Average annual hours worked  Hours
# 60602  65 years old and over  Average annual hours worked  Hours
# 60693         15 to 24 years  Average annual hours worked  Hours
# 60700         25 to 34 years  Average annual hours worked  Hours
# 60707         35 to 44 years  Average annual hours worked  Hours
# 60714         45 to 54 years  Average annual hours worked  Hours
# 60721         55 to 64 years  Average annual hours worked  Hours
# 60728  65 years old and over  Average annual hours worked  Hours
# 60826         25 to 34 years  Average annual hours worked  Hours
# 60833         35 to 44 years  Average annual hours worked  Hours
# 60840         45 to 54 years  Average annual hours worked  Hours
# 60847         55 to 64 years  Average annual hours worked  Hours
# 60952         25 to 34 years  Average annual hours worked  Hours
# 60959         35 to 44 years  Average annual hours worked  Hours
# 60966         45 to 54 years  Average annual hours worked  Hours
# 60973         55 to 64 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 60567         units   942.0
# 60574         units  1443.0
# 60581         units  1747.0
# 60588         units  1680.0
# 60595         units  1626.0
# 60602         units  1149.0
# 60693         units   856.0
# 60700         units  1360.0
# 60707         units  1747.0
# 60714         units  1605.0
# 60721         units  1695.0
# 60728         units  1210.0
# 60826         units  1311.0
# 60833         units  1691.0
# 60840         units  1575.0
# 60847         units  1677.0
# 60952         units  1610.0
# 60959         units  1957.0
# 60966         units  1717.0
# 60973         units  1789.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 60567 to 78746
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         78 non-null     int64
#  1   GEO              78 non-null     object
#  2   Sector           78 non-null     object
#  3   Characteristics  78 non-null     object
#  4   Indicators       78 non-null     object
#  5   UOM              78 non-null     object
#  6   SCALAR_FACTOR    78 non-null     object
#  7   VALUE            78 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Northwest Territories
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          8580.0   953.333333   856.0   955.0  1027.0     9
# 25 to 34 years         21907.0  1460.466667  1311.0  1443.0  1721.0    15
# 35 to 44 years         26472.0  1764.800000  1638.0  1747.0  2000.0    15
# 45 to 54 years         25273.0  1684.866667  1575.0  1699.0  1844.0    15
# 55 to 64 years         25076.0  1671.733333  1578.0  1653.0  1828.0    15
# 65 years old and over  10296.0  1144.000000  1106.0  1137.0  1210.0     9
#
# Overall,
# Sum :  117604.0
# Mean :  1507.7435897435898
# Min/median/max : 856.0 / 1620.5 / 2000.0
# Skewnewss :  -0.7411756712707891
# Total size :  78
# 2019
#
# Grab the dataset only in Northwest Territories
#        REF_DATE                    GEO  \
# 87027      2019  Northwest Territories
# 87034      2019  Northwest Territories
# 87041      2019  Northwest Territories
non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Northwest Territories
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          8928.0   992.000000   933.0   988.0  1053.0     9
# 25 to 34 years         22546.0  1503.066667  1385.0  1470.0  1674.0    15
# 35 to 44 years         25852.0  1723.466667  1577.0  1663.0  1923.0    15
# 45 to 54 years         26041.0  1736.066667  1541.0  1746.0  1921.0    15
# 55 to 64 years         24700.0  1646.666667  1532.0  1629.0  1800.0    15
# 65 years old and over  10051.0  1116.777778  1029.0  1132.0  1172.0     9
#
# Overall,
# Sum :  118118.0
# Mean :  1514.3333333333333
# Min/median/max : 933.0 / 1611.0 / 1923.0
# Skewnewss :  -0.7095023931536831
# Total size :  78
# 2013
#
# Grab the dataset only in Northwest Territories
#        REF_DATE                    GEO  \
# 34023      2013  Northwest Territories
# 34030      2013  Northwest Territories
# 34149      2013  Northwest Territories
# 34156      2013  Northwest Territories
# 34275      2013  Northwest Territories
# 34282      2013  Northwest Territories
# 34401      2013  Northwest Territories
# 34408      2013  Northwest Territories
# 34527      2013  Northwest Territories
# 34534      2013  Northwest Territories
# 42843      2014  Northwest Territories
# 42850      2014  Northwest Territories
# 42969      2014  Northwest Territories
# 42976      2014  Northwest Territories
# 43095      2014  Northwest Territories
# 43102      2014  Northwest Territories
# 43221      2014  Northwest Territories
# 43228      2014  Northwest Territories
# 43347      2014  Northwest Territories
# 43354      2014  Northwest Territories
#
#                                                   Sector   Characteristics  \
# 34023                      Total non-profit institutions    Male employees
# 34030                      Total non-profit institutions  Female employees
# 34149  Total non-profit institutions excluding govern...    Male employees
# 34156  Total non-profit institutions excluding govern...  Female employees
# 34275  Non-profit institutions serving households (co...    Male employees
# 34282  Non-profit institutions serving households (co...  Female employees
# 34401                   Business non-profit institutions    Male employees
# 34408                   Business non-profit institutions  Female employees
# 34527                 Government non-profit institutions    Male employees
# 34534                 Government non-profit institutions  Female employees
# 42843                      Total non-profit institutions    Male employees
# 42850                      Total non-profit institutions  Female employees
# 42969  Total non-profit institutions excluding govern...    Male employees
# 42976  Total non-profit institutions excluding govern...  Female employees
# 43095  Non-profit institutions serving households (co...    Male employees
# 43102  Non-profit institutions serving households (co...  Female employees
# 43221                   Business non-profit institutions    Male employees
# 43228                   Business non-profit institutions  Female employees
# 43347                 Government non-profit institutions    Male employees
# 43354                 Government non-profit institutions  Female employees
#
#                         Indicators    UOM SCALAR_FACTOR   VALUE
# 34023  Average annual hours worked  Hours         units  1575.0
# 34030  Average annual hours worked  Hours         units  1544.0
# 34149  Average annual hours worked  Hours         units  1521.0
# 34156  Average annual hours worked  Hours         units  1411.0
# 34275  Average annual hours worked  Hours         units  1453.0
# 34282  Average annual hours worked  Hours         units  1380.0
# 34401  Average annual hours worked  Hours         units  1774.0
# 34408  Average annual hours worked  Hours         units  1607.0
# 34527  Average annual hours worked  Hours         units  1624.0
# 34534  Average annual hours worked  Hours         units  1601.0
# 42843  Average annual hours worked  Hours         units  1514.0
# 42850  Average annual hours worked  Hours         units  1462.0
# 42969  Average annual hours worked  Hours         units  1498.0
# 42976  Average annual hours worked  Hours         units  1349.0
# 43095  Average annual hours worked  Hours         units  1431.0
# 43102  Average annual hours worked  Hours         units  1317.0
# 43221  Average annual hours worked  Hours         units  1779.0
# 43228  Average annual hours worked  Hours         units  1574.0
# 43347  Average annual hours worked  Hours         units  1530.0
# 43354  Average annual hours worked  Hours         units  1513.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries,
Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 86999         units  1231.0
# 87006         units  1412.0
# 87020         units  1782.0
# 87125         units  1186.0
# 87132         units  1300.0
# 87146         units  1830.0
# 87251         units  1146.0
# 87258         units  1247.0
# 87272         units  1805.0
# 87377         units  1516.0
# 87384         units  1692.0
# 87398         units  2043.0
# 87503         units  1271.0
# 87510         units  1520.0
# ...
# 34086                      Total non-profit institutions
# 34100                      Total non-profit institutions
# 34205  Total non-profit institutions excluding govern...
# 34212  Total non-profit institutions excluding govern...
# 34226  Total non-profit institutions excluding govern...
# 34331  Non-profit institutions serving households (co...
# 34338  Non-profit institutions serving households (co...
# 34352  Non-profit institutions serving households (co...
# 34457                   Business non-profit institutions
# 34464                   Business non-profit institutions
# 34478                   Business non-profit institutions
# 34583                 Government non-profit institutions
# 34590                 Government non-profit institutions
# 34604                 Government non-profit institutions
# 42899                      Total non-profit institutions
# 42906                      Total non-profit institutions
# 42920                      Total non-profit institutions
# 43025  Total non-profit institutions excluding govern...
# 43032  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 34079  High school diploma and less  Average annual hours worked  Hours
# 34086             Trade certificate  Average annual hours worked  Hours
# 34100  University degree and higher  Average annual hours worked  Hours
# 34205  High school diploma and less  Average annual hours worked  Hours
# 34212             Trade certificate  Average annual hours worked  Hours
# 34226  University degree and higher  Average annual hours worked  Hours
# 34331  High school diploma and less  Average annual hours worked  Hours
# 34338             Trade certificate  Average annual hours worked  Hours
# 34352  University degree and higher  Average annual hours worked  Hours
# 34457  High school diploma and less  Average annual hours worked  Hours
# 34464             Trade certificate  Average annual hours worked  Hours
# 34478  University degree and higher  Average annual hours worked  Hours
# 34583  High school diploma and less  Average annual hours worked  Hours
# 34590             Trade certificate  Average annual hours worked  Hours
# 34604  University degree and higher  Average annual hours worked  Hours
# 42899  High school diploma and less  Average annual hours worked  Hours
# 42906             Trade certificate  Average annual hours worked  Hours
# 42920  University degree and higher  Average annual hours worked  Hours
# 43025  High school diploma and less  Average annual hours worked  Hours
# 43032             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 34079         units  1247.0
# 34086         units  1426.0
# 34100         units  1814.0
# 34205         units  1180.0
# 34212         units  1268.0
# 34226         units  1858.0
# 34331         units  1109.0
# 34338         units  1175.0
# 34352         units  1837.0
# 34457         units  1538.0
# 34464         units  1611.0
# 34478         units  1980.0
# 34583         units  1306.0
# 34590         units  1622.0
# 34604         units  1799.0
# 42899         units  1201.0
# 42906         units  1320.0
# 42920         units  1712.0
# 43025         units  1134.0
# 43032         units  1194.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 34079 to 52244
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Northwest Territories
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  18685.0  1245.666667  1068.0  1201.0  1538.0
# Trade certificate             20574.0  1371.600000  1092.0  1346.0  1625.0
# University degree and higher  27410.0  1827.333333  1669.0  1814.0  2057.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :
Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 86999         units  1231.0
# 87006         units  1412.0
# 87020         units  1782.0
# 87125         units  1186.0
# 87132         units  1300.0
# 87146         units  1830.0
# 87251         units  1146.0
# 87258         units  1247.0
# 87272         units  1805.0
# 87377         units  1516.0
# 87384         units  1692.0
# 87398         units  2043.0
# 87503         units  1271.0
# 87510         units  1520.0
# 87524         units  1764.0
# 95819         units  1270.0
# 95826         units  1476.0
# 95840         units  1874.0
# 95945         units  1193.0
# 95952         units  1330.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 86999 to 105164
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Northwest Territories
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  18845.0  1256.333333  1109.0  1193.0  1516.0
# Trade certificate             21224.0  1414.933333  1231.0  1412.0  1692.0
# University degree and higher  27541.0  1836.066667  1676.0  1810.0  2043.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  67610.0
# Mean :  1502.4444444444443
# Min/median/max : 1109.0 / 1476.0 / 2043.0
# Skewnewss :  0.3255787303695556
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Northwest Territories

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Nova Scotia.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Nova Scotia                  531805.0    492.412037    757.119411  1080

ProCode = 7

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Nova Scotia
#        REF_DATE          GEO  \
# 28437      2013  Nova Scotia
# 28444      2013  Nova Scotia
# 28451      2013  Nova Scotia
# 28458      2013  Nova Scotia
# 28465      2013  Nova Scotia
# 28472      2013  Nova Scotia
# 28563      2013  Nova Scotia
# 28570      2013  Nova Scotia
# 28577      2013  Nova Scotia
# 28584      2013  Nova Scotia
# 28591      2013  Nova Scotia
# 28598      2013  Nova Scotia
# 28689      2013  Nova Scotia
# 28696      2013  Nova Scotia
# 28703      2013  Nova Scotia
# 28710      2013  Nova Scotia
# 28717      2013  Nova Scotia
# 28724      2013  Nova Scotia
# 28815      2013  Nova Scotia
# 28822      2013  Nova Scotia
#
#                                                   Sector  \
# 28437                      Total non-profit institutions
# 28444                      Total non-profit institutions
# 28451                      Total non-profit institutions
# 28458                      Total non-profit institutions
# 28465                      Total non-profit institutions
# 28472                      Total non-profit institutions
# 28563  Total non-profit institutions excluding govern...
# 28570  Total non-profit institutions excluding govern...
# 28577  Total non-profit institutions excluding govern...
# 28584  Total non-profit institutions excluding govern...
# 28591  Total non-profit institutions excluding govern...
# 28598  Total non-profit institutions excluding govern...
# 28689  Non-profit institutions serving households (co...
# 28696  Non-profit institutions serving households (co...
# 28703  Non-profit institutions serving households (co...
# 28710  Non-profit institutions serving households (co...
# 28717  Non-profit institutions serving households (co...
# 28724  Non-profit institutions serving households (co...
# 28815                   Business non-profit institutions
# 28822                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 28437         15 to 24 years  Average annual hours worked  Hours
# 28444         25 to 34 years  Average annual hours worked  Hours
# 28451         35 to 44 years  Average annual hours worked  Hours
# 28458         45 to 54 years  Average annual hours worked  Hours
# 28465         55 to 64 years  Average annual hours worked  Hours
# 28472  65 years old and over  Average annual hours worked  Hours
# 28563         15 to 24 years  Average annual hours worked  Hours
# 28570         25 to 34 years  Average annual hours worked  Hours
# 28577         35 to 44 years  Average annual hours worked  Hours
# 28584         45 to 54 years  Average annual hours worked  Hours
# 28591         55 to 64 years  Average annual hours worked  Hours
# 28598  65 years old and over  Average annual hours worked  Hours
# 28689         15 to 24 years  Average annual hours worked  Hours
# 28696         25 to 34 years  Average annual hours worked  Hours
# 28703         35 to 44 years  Average annual hours worked  Hours
# 28710         45 to 54 years  Average annual hours worked  Hours
# 28717         55 to 64 years  Average annual hours worked  Hours
# 28724  65 years old and over  Average annual hours worked  Hours
# 28815         15 to 24 years  Average annual hours worked  Hours
# 28822         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
#
0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  69505.0
# Mean :  1544.5555555555557
# Min/median/max : 1178.0 / 1607.0 / 1837.0
# Skewnewss :  -0.32747583947326697
# Total size :  45
# 2013
#
# Grab the dataset only in Nova Scotia
#        REF_DATE          GEO  \
# 28409      2013  Nova Scotia
# 28416      2013  Nova Scotia
# 28430      2013  Nova Scotia
# 28535      2013  Nova Scotia
# 28542      2013  Nova Scotia
# 28556      2013  Nova Scotia
# 28661      2013  Nova Scotia
# 28668      2013  Nova Scotia
# 28682      2013  Nova Scotia
# 28787      2013  Nova Scotia
# 28794      2013  Nova Scotia
# 28808      2013  Nova Scotia
# 28913      2013  Nova Scotia
# 28920      2013  Nova Scotia
# 28934      2013  Nova Scotia
# 37229      2014  Nova Scotia
# 37236      2014  Nova Scotia
# 37250      2014  Nova Scotia
# 37355      2014  Nova Scotia
# 37362      2014  Nova Scotia
#
#                                                   Sector  \
# 28409                      Total non-profit institutions
# 28416                      Total non-profit institutions
# 28430                      Total non-profit institutions
# 28535  Total non-profit institutions excluding govern...
# 28542  Total non-profit institutions excluding govern...
# 28556  Total non-profit institutions excluding govern...
# 28661  Non-profit institutions serving households (co...
# 28668  Non-profit institutions serving households (co...
# 28682  Non-profit institutions serving households (co...
# 28787                   Business non-profit institutions
# 28794                   Business non-profit institutions
# 28808                   Business non-profit institutions
# 28913                 Government non-profit institutions
# 28920                 Government non-profit institutions
# 28934                 Government non-profit institutions
# 37229                      Total non-profit institutions
# 37236                      Total non-profit institutions
# 37250                      Total non-profit institutions
# 37355  Total non-profit institutions excluding govern...
# 37362  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 28409  High school diploma and less  Average annual hours worked  Hours
# 28416             Trade certificate  Average annual hours worked  Hours
# 28430  University degree and higher  Average annual hours worked  Hours
# 28535  High school diploma and less  Average annual hours worked  Hours
# 28542             Trade certificate  Average annual hours worked  Hours
# 28556  University degree and higher  Average annual hours worked  Hours
# 28661  High school diploma and less  Average annual hours worked  Hours
# 28668             Trade certificate  Average annual hours worked  Hours
# 28682  University degree and higher  Average annual hours worked  Hours
# 28787  High school diploma and less  Average annual hours worked  Hours
# 28794             Trade certificate  Average annual hours worked  Hours
# 28808  University degree and higher  Average annual hours worked  Hours
# 28913  High school diploma and less  Average annual hours worked  Hours
# 28920             Trade certificate  Average annual hours worked  Hours
# 28934  University degree and higher  Average annual hours worked  Hours
# 37229  High school diploma and less  Average annual hours worked  Hours
# 37236             Trade certificate  Average annual hours worked  Hours
# 37250  University degree and higher  Average annual hours worked  Hours
# 37355  High school diploma and less  Average annual hours worked  Hours
# 37362             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 28409         units  1296.0
# 28416         units  1618.0
# 28430         units  1706.0
# 28535         units  1249.0
# 28542         units  1605.0
# 28556         units  1805.0
# 28661         units  1192.0
# 28668         units  1547.0
# 28682         units  1787.0
# 28787         units  1421.0
# 28794         units  1805.0
# 28808         units  1894.0
# 28913         units  1322.0
# 28920         units  1622.0
# 28934         units  1673.0
# 37229         units  1318.0
# 37236         units  1625.0
# 37250         units  1745.0
# 37355         units  1242.0
# 37362         units  1564.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 28409 to 46574
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Nova Scotia
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19633.0  1308.866667  1192.0  1318.0  1429.0
# Trade certificate             24443.0  1629.533333  1512.0  1622.0  1805.0
# University degree and higher  26653.0  1776.866667  1673.0  1770.0  1894.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  70729.0
# Mean :  1571.7555555555555
# Min/median/max : 1192.0 / 1622.0 / 1894.0
# Skewnewss :  -0.358085565941755
# Total size :  45
# 2016
#
# Grab the dataset only in Nova Scotia
#        REF_DATE          GEO  \
# 54827      2016  Nova Scotia
# 54834      2016  Nova Scotia
# 54953      2016  Nova Scotia
# 54960      2016  Nova Scotia
# 55079      2016  Nova Scotia
# 55086      2016  Nova Scotia
# 55205      2016  Nova Scotia
# 55212      2016  Nova Scotia
# 55331      2016  Nova Scotia
# 55338      2016  Nova Scotia
# 63647      2017  Nova Scotia
# 63654      2017  Nova Scotia
# 63773      2017  Nova Scotia
# 63780      2017  Nova Scotia
# 63899      2017  Nova Scotia
# 63906      2017  Nova Scotia
# 64025      2017  Nova Scotia
# 64032      2017  Nova Scotia
# 64151      2017  Nova Scotia
# 64158      2017  Nova Scotia
#
#                                                   Sector  \
# 54827                      Total non-profit institutions
# 54834                      Total non-profit institutions
# 54953  Total non-profit institutions excluding govern...
# 54960  Total non-profit institutions excluding govern...
# 55079  Non-profit institutions serving households (co...
# 55086  Non-profit institutions serving households (co...
# 55205                   Business non-profit institutions
# 55212                   Business non-profit institutions
# 55331                 Government non-profit institutions
# 55338                 Government non-profit institutions
# 63647                      Total non-profit institutions
# 63654                      Total non-profit institutions
# 63773  Total non-profit institutions excluding govern...
# 63780  Total non-profit institutions excluding govern...
# 63899  Non-profit institutions serving households (co...
# 63906  Non-profit institutions serving households (co...
# 64025                   Business non-profit institutions
# 64032                   Business non-profit institutions
# 64151                 Government non-profit institutions
# 64158                 Government non-profit institutions
#
#                Characteristics                   Indicators    UOM  \
# 54827      Immigrant employees  Average annual hours worked  Hours
# 54834  Non-immigrant employees  Average annual hours worked  Hours
# 54953      Immigrant employees  Average annual hours worked  Hours
# 54960  Non-immigrant employees  Average annual hours worked  Hours
# 55079      Immigrant employees  Average annual hours worked  Hours
# 55086  Non-immigrant employees  Average annual hours worked  Hours
# 55205      Immigrant employees  Average annual hours worked  Hours
# 55212  Non-immigrant employees  Average annual hours worked  Hours
# 55331      Immigrant employees  Average annual hours worked  Hours
# 55338  Non-immigrant employees  Average annual hours worked  Hours
# 63647      Immigrant employees  Average annual hours worked  Hours
# 63654  Non-immigrant employees  Average annual hours worked  Hours
# 63773      Immigrant employees  Average annual hours worked  Hours
# 63780  Non-immigrant employees  Average annual hours worked  Hours
# 63899      Immigrant employees  Average annual hours worked  Hours
# 63906  Non-immigrant employees  Average annual hours worked  Hours
# 64025      Immigrant employees  Average annual hours worked  Hours
# 64032  Non-immigrant employees  Average annual hours worked  Hours
# 64151      Immigrant employees  Average annual hours worked  Hours
# 64158  Non-immigrant employees  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 54827         units  1727.0
# 54834         units  1663.0
# 54953         units  1576.0
# 54960         units  1574.0
# 55079         units  1561.0
# 55086         units  1557.0
# 55205         units  1634.0
# 55212         units  1637.0
# 55331         units  1765.0
# 55338         units  1699.0
# 63647         units  1640.0
# 63654         units  1599.0
# 63773         units  1552.0
# 63780         units  1560.0
# 63899         units  1531.0
# 63906         units  1538.0
# 64025         units  1631.0
# 64032         units  1647.0
# 64151         units  1662.0
# 64158         units  1614.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 54827 to 72978
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in
0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 81329 to 99494
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Nova Scotia
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19503.0  1300.200000  1178.0  1324.0  1388.0
# Trade certificate             23734.0  1582.266667  1462.0  1607.0  1688.0
# University degree and higher  26268.0  1751.200000  1689.0  1733.0  1837.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  69505.0
# Mean :  1544.5555555555557
# Min/median/max : 1178.0 / 1607.0 / 1837.0
# Skewnewss :  -0.32747583947326697
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Nova Scotia

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Nunavut.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Nunavut                       14235.0     15.208333     14.752372   936

ProCode = 8

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 34737      2013  Nunavut                      Total non-profit institutions
# 34744      2013  Nunavut                      Total non-profit institutions
# 34751      2013  Nunavut                      Total non-profit institutions
# 34758      2013  Nunavut                      Total non-profit institutions
# 34765      2013  Nunavut                      Total non-profit institutions
# 34772      2013  Nunavut                      Total non-profit institutions
# 34863      2013  Nunavut  Total non-profit institutions excluding govern...
# 34870      2013  Nunavut  Total non-profit institutions excluding govern...
# 34877      2013  Nunavut  Total non-profit institutions excluding govern...
# 34884      2013  Nunavut  Total non-profit institutions excluding govern...
# 34891      2013  Nunavut  Total non-profit institutions excluding govern...
# 34898      2013  Nunavut  Total non-profit institutions excluding govern...
# 34996      2013  Nunavut  Non-profit institutions serving households (co...
# 35003      2013  Nunavut  Non-profit institutions serving households (co...
# 35010      2013  Nunavut  Non-profit institutions serving households (co...
# 35017      2013  Nunavut  Non-profit institutions serving households (co...
# 35122      2013  Nunavut                   Business non-profit institutions
# 35129      2013  Nunavut                   Business non-profit institutions
# 35136      2013  Nunavut                   Business non-profit institutions
# 35143      2013  Nunavut                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 34737         15 to 24 years  Average annual hours worked  Hours
# 34744         25 to 34 years  Average annual hours worked  Hours
# 34751         35 to 44 years  Average annual hours worked  Hours
# 34758         45 to 54 years  Average annual hours worked  Hours
# 34765         55 to 64 years  Average annual hours worked  Hours
# 34772  65 years old and over  Average annual hours worked  Hours
# 34863         15 to 24 years  Average annual hours worked  Hours
# 34870         25 to 34 years  Average annual hours worked  Hours
# 34877         35 to 44 years  Average annual hours worked  Hours
# 34884         45 to 54 years  Average annual hours worked  Hours
# 34891         55 to 64 years  Average annual hours worked  Hours
# 34898  65 years old and over  Average annual hours worked  Hours
# 34996         25 to 34 years  Average annual hours worked  Hours
# 35003         35 to 44 years  Average annual hours worked  Hours
# 35010         45 to 54 years  Average annual hours worked  Hours
# 35017         55 to 64 years  Average annual hours worked  Hours
# 35122         25 to 34 years  Average annual hours worked  Hours
# 35129         35 to 44 years  Average annual hours worked  Hours
# 35136         45 to 54 years  Average annual hours worked  Hours
# 35143         55 to 64 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 34737         units   959.0
# 34744         units  1549.0
# 34751         units  1743.0
# 34758         units  1912.0
# 34765         units  1745.0
# 34772         units  1353.0
# 34863         units   956.0
# 34870         units  1512.0
# 34877         units  1720.0
# 34884         units  1919.0
# 34891         units  1786.0
# 34898         units  1273.0
# 34996         units  1478.0
# 35003         units  1709.0
# 35010         units  1880.0
# 35017         units  1778.0
# 35122         units  1710.0
# 35129         units  1781.0
# 35136         units  2050.0
# 35143         units  1833.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 34737 to 52916
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         78 non-null     int64
#  1   GEO              78 non-null     object
#  2   Sector           78 non-null     object
#  3   Characteristics  78 non-null     object
#  4   Indicators       78 non-null     object
#  5   UOM              78 non-null     object
#  6   SCALAR_FACTOR    78 non-null     object
#  7   VALUE            78 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Nunavut
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          8577.0   953.000000   905.0   962.0   971.0     9
# 25 to 34 years         23268.0  1551.200000  1451.0  1532.0  1710.0    15
# 35 to 44 years         25722.0  1714.800000  1620.0  1709.0  1798.0    15
# 45 to 54 years         28570.0  1904.666667  1725.0  1904.0  2071.0    15
# 55 to 64 years         26564.0  1770.933333  1595.0  1770.0  2000.0    15
# 65 years old and over  12105.0  1345.000000  1273.0  1315.0  1500.0     9
#
# Overall,
# Sum :  124806.0
# Mean :  1600.076923076923
# Min/median/max : 905.0 / 1694.0 / 2071.0
# Skewnewss :  -0.9423562698067877
# Total size :  78
# 2016
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 61197      2016  Nunavut                      Total non-profit institutions
# 61204      2016  Nunavut                      Total non-profit institutions
# 61211      2016  Nunavut                      Total non-profit institutions
# 61218      2016  Nunavut                      Total non-profit institutions
# 61225      2016  Nunavut                      Total non-profit institutions
# 61232      2016  Nunavut                      Total non-profit institutions
# 61323      2016  Nunavut  Total non-profit institutions excluding govern...
# 61330      2016  Nunavut  Total non-profit institutions excluding govern...
# 61337      2016  Nunavut  Total non-profit institutions excluding govern...
# 61344      2016  Nunavut  Total non-profit institutions excluding govern...
# 61351      2016  Nunavut  Total non-profit institutions excluding govern...
# 61358      2016  Nunavut  Total non-profit institutions excluding govern...
# 61456      2016  Nunavut  Non-profit institutions serving households (co...
# 61463      2016  Nunavut  Non-profit institutions serving households (co...
# 61470      2016  Nunavut  Non-profit institutions serving households (co...
# 61477      2016  Nunavut  Non-profit institutions serving households (co...
# 61582      2016  Nunavut                   Business non-profit institutions
# 61589      2016  Nunavut                   Business non-profit institutions
# 61596      2016  Nunavut                   Business non-profit institutions
# 61603      2016  Nunavut                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 61197         15 to 24 years  Average annual hours worked  Hours
# 61204         25 to 34 years  Average annual hours worked  Hours
# 61211         35 to 44 years  Average annual hours worked  Hours
# 61218         45 to 54 years  Average annual hours worked  Hours
# 61225         55 to 64 years  Average annual hours worked  Hours
# 61232  65 years old and over  Average annual hours worked  Hours
# 61323         15 to 24 years  Average annual hours worked  Hours
# 61330         25 to 34 years  Average annual hours worked  Hours
# 61337         35 to 44 years  Average annual hours worked  Hours
# 61344         45 to 54 years  Average annual hours worked  Hours
# 61351         55 to 64 years  Average annual hours worked  Hours
# 61358  65 years old and over  Average annual hours worked  Hours
# 61456         25 to 34 years  Average annual hours worked  Hours
# 61463         35 to 44 years  Average annual hours worked  Hours
# 61470         45 to 54 years  Average annual hours worked  Hours
# 61477         55 to 64 years  Average annual hours worked  Hours
# 61582         25 to 34 years  Average annual hours worked  Hours
# 61589         35 to 44 years  Average annual hours worked  Hours
# 61596         45 to 54 years  Average annual hours worked  Hours
# 61603         55 to 64 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 61197         units   980.0
# 61204         units  1520.0
# 61211         units  1691.0
# 61218         units  1839.0
# 61225         units  1747.0
# 61232         units  1370.0
# 61323         units   974.0
# 61330         units  1510.0
# 61337         units  1735.0
# 61344         units  1917.0
# 61351         units  1851.0
# 61358         units  1424.0
# 61456         units  1483.0
# 61463         units  1730.0
# 61470         units  1897.0
# 61477         units  1811.0
# 61582         units  1654.0
# 61589         units  1773.0
# 61596         units  1941.0
# 61603         units  2000.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 61197 to 79376
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         78 non-null     int64
#  1   GEO              78 non-null     object
#  2   Sector           78 non-null     object
#  3   Characteristics  78 non-null     object
#  4   Indicators       78 non-null     object
#  5   UOM              78 non-null     object
#  6   SCALAR_FACTOR    78 non-null     object
#  7   VALUE            78 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Nunavut
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          9042.0  1004.666667   946.0   984.0  1143.0     9
# 25 to 34 years         23230.0  1548.666667  1437.0  1511.0  1759.0    15
# 35 to 44 years         25614.0  1707.600000  1594.0  1714.0  1783.0    15
# 45 to 54 years         27396.0  1826.400000  1667.0  1828.0  1941.0    15
# 55 to 64 years         26989.0  1799.266667  1608.0  1807.0  2000.0    15
# 65 years old and over  12015.0  1335.000000  1208.0  1339.0  1424.0     9
#
# Overall,
# Sum :  124286.0
# Mean :  1593.4102564102564
# Min/median/max : 946.0 / 1684.5 / 2000.0
# Skewnewss :  -0.94949798343025
# Total size :  78
# 2019
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 87657      2019  Nunavut                      Total non-profit institutions
# 87664      2019  Nunavut                      Total non-profit institutions
# 87671      2019  Nunavut                      Total non-profit institutions
# 87678      2019  Nunavut                      Total non-profit institutions
# 87685      2019  Nunavut                      Total non-profit institutions
# 87692      2019  Nunavut                      Total non-profit institutions
# 87783      2019  Nunavut  Total non-profit institutions excluding govern...
# 87790      2019  Nunavut  Total non-profit institutions excluding govern...
# 87797      2019  Nunavut  Total non-profit institutions excluding govern...
# 87804      2019  Nunavut  Total non-profit institutions excluding govern...
# 87811      2019  Nunavut  Total non-profit institutions excluding govern...
# 87818      2019  Nunavut  Total non-profit institutions excluding govern...
# 87916      2019  Nunavut  Non-profit institutions serving households (co...
# 87923      2019  Nunavut  Non-profit institutions serving households (co...
# 87930      2019  Nunavut  Non-profit institutions serving households (co...
# 87937      2019  Nunavut  Non-profit institutions serving households (co...
# 88042      2019  Nunavut                   Business non-profit institutions
# 88049      2019  Nunavut                   Business non-profit institutions
# 88056      2019  Nunavut                   Business non-profit institutions
# 88063      2019  Nunavut                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 87657         15 to 24 years  Average annual hours worked  Hours
# 87664         25 to 34 years  Average annual hours worked  Hours
# 87671         35 to 44 years  Average annual hours worked  Hours
# 87678         45 to 54 years  Average annual hours worked  Hours
# 87685         55 to 64 years  Average annual hours worked  Hours
# 87692  65 years old and over  Average annual hours worked  Hours
# 87783         15 to 24 years  Average annual hours worked  Hours
# 87790         25 to 34 years  Average annual hours worked  Hours
# 87797         35 to 44 years  Average annual hours worked  Hours
# 87804         45 to 54 years  Average annual hours worked  Hours
# 87811         55 to 64 years  Average annual hours worked  Hours
# 87818  65 years old and over  Average annual hours worked  Hours
# 87916         25 to 34 years  Average annual hours worked  Hours
# 87923         35 to 44 years  Average annual hours worked  Hours
# 87930         45 to 54 years  Average annual hours worked  Hours
# 87937         55 to 64 years  Average annual hours worked  Hours
# 88042         25 to 34 years  Average annual hours worked  Hours
# 88049         35 to 44 years  Average annual hours worked  Hours
# 88056         45 to 54 years  Average annual hours worked  Hours
# 88063         55 to 64 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 87657         units  1045.0
# 87664         units  1504.0
# 87671         units  1720.0
# 87678         units  1749.0
# 87685         units  1823.0
# 87692         units  1333.0
# 87783         units  1016.0
# 87790         units  1470.0
# 87797         units  1784.0
# 87804         units  1803.0
# 87811         units  1899.0
# 87818         units  1415.0
# 87916         units  1432.0
# 87923         units  1786.0
# 87930         units  1781.0
# 87937         units  1895.0
# 88042         units  1652.0
# 88049         units  1762.0
# 88056         units  1947.0
# 88063         units  1929.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 87657 to 105836
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         78 non-null     int64
#  1   GEO              78 non-null     object
#  2   Sector           78 non-null     object
#  3   Characteristics  78 non-null     object
#  4   Indicators       78 non-null     object
#  5   UOM              78 non-null     object
#  6   SCALAR_FACTOR    78 non-null     object
#  7   VALUE            78 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Nunavut
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          9774.0  1086.000000   961.0  1045.0  1250.0     9
# 25 to 34 years         22902.0  1526.800000  1348.0  1502.0  1714.0    15
# 35 to 44 years         26076.0  1738.400000  1584.0  1752.0  1857.0    15
# 45 to 54 years         26522.0  1768.133333  1605.0  1749.0  1947.0    15
# 55 to 64 years         28160.0  1877.333333  1690.0  1899.0  2071.0    15
# 65 years old and over  11610.0  1290.000000  1111.0  1308.0  1415.0     9
#
# Overall,
# Sum :  125044.0
# Mean :  1603.128205128205
# Min/median/max : 961.0 / 1691.5 / 2071.0
# Skewnewss :  -0.6933271516211263
# Total size :  78
# 2013
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 34653      2013  Nunavut                      Total non-profit institutions
# 34660      2013  Nunavut                      Total non-profit institutions
# 34779      2013  Nunavut  Total non-profit institutions excluding govern...
# 34786      2013  Nunavut  Total non-profit institutions excluding govern...
# 34905      2013  Nunavut  Non-profit institutions serving households (co...
# 34912      2013  Nunavut  Non-profit institutions serving households (co...
# 35031      2013  Nunavut                   Business non-profit institutions
# 35038      2013  Nunavut                   Business non-profit institutions
# 35157      2013  Nunavut                 Government non-profit institutions
# 35164      2013  Nunavut                 Government non-profit institutions
# 43473      2014  Nunavut                      Total non-profit institutions
# 34842             Trade certificate  Average annual hours worked  Hours
# 34856  University degree and higher  Average annual hours worked  Hours
# 34961  High school diploma and less  Average annual hours worked  Hours
# 35087  High school diploma and less  Average annual hours worked  Hours
# 35213  High school diploma and less  Average annual hours worked  Hours
# 35220             Trade certificate  Average annual hours worked  Hours
# 35234  University degree and higher  Average annual hours worked  Hours
# 43529  High school diploma and less  Average annual hours worked  Hours
# 43536             Trade certificate  Average annual hours worked  Hours
# 43550  University degree and higher  Average annual hours worked  Hours
# 43655  High school diploma and less  Average annual hours worked  Hours
# 43662             Trade certificate  Average annual hours worked  Hours
# 43676  University degree and higher  Average annual hours worked  Hours
# 43781  High school diploma and less  Average annual hours worked  Hours
# 43907  High school diploma and less  Average annual hours worked  Hours
# 44033  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 34709         units  1434.0
# 34716         units  1651.0
# 34730         units  1931.0
# 34835         units  1410.0
# 34842         units  1581.0
# 34856         units  2008.0
# 34961         units  1377.0
# 35087         units  1645.0
# 35213         units  1503.0
# 35220         units  1800.0
# 35234         units  1856.0
# 43529         units  1412.0
# 43536         units  1610.0
# 43550         units  1893.0
# 43655         units  1409.0
# 43662         units  1538.0
# 43676         units  2009.0
# 43781         units  1374.0
# 43907         units  1603.0
# 44033         units  1420.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 34709 to 52874
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Nunavut
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  21619.0  1441.266667  1353.0  1410.0  1645.0
# Trade certificate             15056.0  1672.888889  1513.0  1632.0  1889.0
# University degree and higher  17122.0  1902.444444  1750.0  1893.0  2009.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  53797.0
# Mean :  1630.2121212121212
# Min/median/max : 1353.0 / 1603.0 / 2009.0
# Skewnewss :  0.33343067558816875
# Total size :  33
# 2016
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 61169      2016  Nunavut                      Total non-profit institutions
# 61176      2016  Nunavut                      Total non-profit institutions
# 61190      2016  Nunavut                      Total non-profit institutions
# 61295      2016  Nunavut  Total non-profit institutions excluding govern...
# 61302      2016  Nunavut  Total non-profit institutions excluding govern...
# 61316      2016  Nunavut  Total non-profit institutions excluding govern...
# 61421      2016  Nunavut  Non-profit institutions serving households (co...
# 61547      2016  Nunavut                   Business non-profit institutions
# 61673      2016  Nunavut                 Government non-profit institutions
# 61680      2016  Nunavut                 Government non-profit institutions
# 61694      2016  Nunavut                 Government non-profit institutions
# 69989      2017  Nunavut                      Total non-profit institutions
# 69996      2017  Nunavut                      Total non-profit institutions
# 70010      2017  Nunavut                      Total non-profit institutions
# 70115      2017  Nunavut  Total non-profit institutions excluding govern...
# 70122      2017  Nunavut  Total non-profit institutions excluding govern...
# 70136      2017  Nunavut  Total non-profit institutions excluding govern...
# 70241      2017  Nunavut  Non-profit institutions serving households (co...
# 70367      2017  Nunavut                   Business non-profit institutions
# 70493      2017  Nunavut                 Government non-profit institutions
#
#                     Characteristics                   Indicators    UOM  \
# 61169  High school diploma and less  Average annual hours worked  Hours
# 61176             Trade certificate  Average annual hours worked  Hours
# 61190  University degree and higher  Average annual hours worked  Hours
# 61295  High school diploma and less  Average annual hours worked  Hours
# 61302             Trade certificate  Average annual hours worked  Hours
# 61316  University degree and higher  Average annual hours worked  Hours
# 61421  High school diploma and less  Average annual hours worked  Hours
# 61547  High school diploma and less  Average annual hours worked  Hours
# 61673  High school diploma and less  Average annual hours worked  Hours
# 61680             Trade certificate  Average annual hours worked  Hours
# 61694  University degree and higher  Average annual hours worked  Hours
# 69989  High school diploma and less  Average annual hours worked  Hours
# 69996             Trade certificate  Average annual hours worked  Hours
# 70010  University degree and higher  Average annual hours worked  Hours
# 70115  High school diploma and less  Average annual hours worked  Hours
# 70122             Trade certificate  Average annual hours worked  Hours
# 70136  University degree and higher  Average annual hours worked  Hours
# 70241  High school diploma and less  Average annual hours worked  Hours
# 70367  High school diploma and less  Average annual hours worked  Hours
# 70493  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 61169         units  1420.0
# 61176         units  1644.0
# 61190         units  1870.0
# 61295         units  1436.0
# 61302         units  1575.0
# 61316         units  2000.0
# 61421         units  1417.0
# 61547         units  1596.0
# 61673         units  1367.0
# 61680         units  1789.0
# 61694         units  1722.0
# 69989         units  1395.0
# 69996         units  1621.0
# 70010         units  1832.0
# 70115         units  1404.0
# 70122         units  1526.0
# 70136         units  1955.0
# 70241         units  1368.0
# 70367         units  1615.0
# 70493         units  1367.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 61169 to 79334
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Nunavut
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  21630.0  1442.000000  1367.0  1417.0  1615.0
# Trade certificate             14937.0  1659.666667  1526.0  1644.0  1789.0
# University degree and higher  16603.0  1844.777778  1690.0  1846.0  2000.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  53170.0
# Mean :  1611.2121212121212
# Min/median/max : 1367.0 / 1615.0 / 2000.0
# Skewnewss :  0.3916017712400948
# Total size :  33
# 2019
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 87629      2019  Nunavut                      Total non-profit institutions
# 87636      2019  Nunavut                      Total non-profit institutions
# 87650      2019  Nunavut                      Total non-profit institutions
# 87755      2019  Nunavut  Total non-profit institutions excluding govern...
# 87762      2019  Nunavut  Total non-profit institutions excluding govern...
# 87776      2019  Nunavut  Total non-profit institutions excluding govern...
# 87881      2019  Nunavut  Non-profit institutions serving households (co...
# 88007      2019  Nunavut                   Business non-profit institutions
# 88133      2019  Nunavut                 Government non-profit institutions
# 88140      2019  Nunavut                 Government non-profit institutions
# 88154      2019  Nunavut                 Government non-profit institutions
# 96449      2020  Nunavut                      Total non-profit institutions
# 96456      2020  Nunavut                      Total non-profit institutions
# 96470      2020  Nunavut                      Total non-profit institutions
# 96575      2020  Nunavut  Total non-profit institutions excluding govern...
# 96582      2020  Nunavut  Total non-profit institutions excluding govern...
# 96596      2020  Nunavut  Total non-profit institutions excluding govern...
# 96701      2020  Nunavut  Non-profit institutions serving households (co...
# 96827      2020  Nunavut                   Business non-profit institutions
# 96953      2020  Nunavut                 Government non-profit institutions
#
#                     Characteristics                   Indicators    UOM  \
# 87629  High school diploma and less  Average annual hours worked  Hours
# 87636             Trade certificate  Average annual hours worked  Hours
# 87650  University degree and higher  Average annual hours worked  Hours
# 87755  High school diploma and less  Average annual hours worked  Hours
# 87762             Trade certificate  Average annual hours worked  Hours
# 87776  University degree and higher  Average annual hours worked  Hours
# 87881  High school diploma and less  Average annual hours worked  Hours
# 88007  High school diploma and less  Average annual hours worked  Hours
# 88133  High school diploma and less  Average annual hours worked  Hours
# 88140             Trade certificate  Average annual hours worked  Hours
# 88154  University degree and higher  Average annual hours worked  Hours
# 96449  High school diploma and less  Average annual hours worked  Hours
# 96456             Trade certificate  Average annual hours worked  Hours
# 96470  University degree and higher  Average annual hours worked  Hours
# 96575  High school diploma and less  Average annual hours worked  Hours
# 96582             Trade certificate  Average annual hours worked  Hours
# 96596  University degree and higher  Average annual hours worked  Hours
# 96701  High school diploma and less  Average annual hours worked  Hours
# 96827  High school diploma and less  Average annual hours worked  Hours
# 96953  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 87629         units  1430.0
# 87636         units  1708.0
# 87650         units  1837.0
# 87755         units  1437.0
# 87762         units  1714.0
# 87776         units  1985.0
# 87881         units  1415.0
# 88007         units  1593.0
# 88133         units  1415.0
# 88140         units  1652.0
# 88154         units  1687.0
# 96449         units  1392.0
# 96456         units  1646.0
# 96470         units  1827.0
# 96575         units  1373.0
# 96582         units  1634.0
# 96596         units  1951.0
# 96701         units  1345.0
# 96827         units  1644.0
# 96953         units  1452.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 87629 to 105794
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Nunavut
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  21934.0  1462.266667  1345.0  1437.0  1667.0
# Trade certificate             15055.0  1672.777778  1634.0  1667.0  1714.0
# University degree and higher  16486.0  1831.777778  1652.0  1837.0  2000.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  53475.0
# Mean :  1620.4545454545455
# Min/median/max : 1345.0 / 1646.0 / 2000.0
# Skewnewss :  0.35755238545180545
# Total size :  33
# 2013
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 34709      2013  Nunavut                      Total non-profit institutions
# 34716      2013  Nunavut                      Total non-profit institutions
# 34730      2013  Nunavut                      Total non-profit institutions
# 34835      2013  Nunavut  Total non-profit institutions excluding govern...
# 34842      2013  Nunavut  Total non-profit institutions excluding govern...
non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.3+ KB
# None
#
# Grab the dataset only in Nunavut
#                              sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      16116.0  1790.666667  1743.0  1800.0  1826.0     9
# Non-immigrant employees  13989.0  1554.333333  1527.0  1562.0  1577.0     9
#
# Overall,
# Sum :  30105.0
# Mean :  1672.5
# Min/median/max : 1527.0 / 1660.0 / 1826.0
# Skewnewss :  0.04488893716483184
# Total size :  18
# 2019
#
# Grab the dataset only in Nunavut
#        REF_DATE      GEO                                             Sector  \
# 87629      2019  Nunavut                      Total non-profit institutions
# 87636      2019  Nunavut                      Total non-profit institutions
# 87650      2019  Nunavut                      Total non-profit institutions
# 87755      2019  Nunavut  Total non-profit institutions excluding govern...
# 87762      2019  Nunavut  Total non-profit institutions excluding govern...
# 87776      2019  Nunavut  Total non-profit institutions excluding govern...
# 87881      2019  Nunavut  Non-profit institutions serving households (co...
# 88007      2019  Nunavut                   Business non-profit institutions
# 88133      2019  Nunavut                 Government non-profit institutions
# 88140      2019  Nunavut                 Government non-profit institutions
# 88154      2019  Nunavut                 Government non-profit institutions
# 96449      2020  Nunavut                      Total non-profit institutions
# 96456      2020  Nunavut                      Total non-profit institutions
# 96470      2020  Nunavut                      Total non-profit institutions
# 96575      2020  Nunavut  Total non-profit institutions excluding govern...
# 96582      2020  Nunavut  Total non-profit institutions excluding govern...
# 96596      2020  Nunavut  Total non-profit institutions excluding govern...
# 96701      2020  Nunavut  Non-profit institutions serving households (co...
# 96827      2020  Nunavut                   Business non-profit institutions
# 96953      2020  Nunavut                 Government non-profit institutions
#
#                     Characteristics                   Indicators    UOM  \
# 87629  High school diploma and less  Average annual hours worked  Hours
# 87636             Trade certificate  Average annual hours worked  Hours
# 87650  University degree and higher  Average annual hours worked  Hours
# 87755  High school diploma and less  Average annual hours worked  Hours
# 87762             Trade certificate  Average annual hours worked  Hours
# 87776  University degree and higher  Average annual hours worked  Hours
# 87881  High school diploma and less  Average annual hours worked  Hours
# 88007  High school diploma and less  Average annual hours worked  Hours
# 88133  High school diploma and less  Average annual hours worked  Hours
# 88140             Trade certificate  Average annual hours worked  Hours
# 88154  University degree and higher  Average annual hours worked  Hours
# 96449  High school diploma and less  Average annual hours worked  Hours
# 96456             Trade certificate  Average annual hours worked  Hours
# 96470  University degree and higher  Average annual hours worked  Hours
# 96575  High school diploma and less  Average annual hours worked  Hours
# 96582             Trade certificate  Average annual hours worked  Hours
# 96596  University degree and higher  Average annual hours worked  Hours
# 96701  High school diploma and less  Average annual hours worked  Hours
# 96827  High school diploma and less  Average annual hours worked  Hours
# 96953  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 87629         units  1430.0
# 87636         units  1708.0
# 87650         units  1837.0
# 87755         units  1437.0
# 87762         units  1714.0
# 87776         units  1985.0
# 87881         units  1415.0
# 88007         units  1593.0
# 88133         units  1415.0
# 88140         units  1652.0
# 88154         units  1687.0
# 96449         units  1392.0
# 96456         units  1646.0
# 96470         units  1827.0
# 96575         units  1373.0
# 96582         units  1634.0
# 96596         units  1951.0
# 96701         units  1345.0
# 96827         units  1644.0
# 96953         units  1452.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 87629 to 105794
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Nunavut
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  21934.0  1462.266667  1345.0  1437.0  1667.0
# Trade certificate             15055.0  1672.777778  1634.0  1667.0  1714.0
# University degree and higher  16486.0  1831.777778  1652.0  1837.0  2000.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  53475.0
# Mean :  1620.4545454545455
# Min/median/max : 1345.0 / 1646.0 / 2000.0
# Skewnewss :  0.35755238545180545
# Total size :  33

# %% [markdown]
# Panda Profiling for Final Result for Nunavut

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtered by Ontario

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Ontario                     6601634.0   6112.624074   7594.433779  1080

ProCode = 9

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Ontario
#        REF_DATE      GEO                                             Sector  \
# 30327      2013  Ontario                      Total non-profit institutions
# 30334      2013  Ontario                      Total non-profit institutions
# 30341      2013  Ontario                      Total non-profit institutions
# 30348      2013  Ontario                      Total non-profit institutions
# 30355      2013  Ontario                      Total non-profit institutions
# 30362      2013  Ontario                      Total non-profit institutions
# 30453      2013  Ontario  Total non-profit institutions excluding govern...
# 30460      2013  Ontario  Total non-profit institutions excluding govern...
# 30467      2013  Ontario  Total non-profit institutions excluding govern...
# 30474      2013  Ontario  Total non-profit institutions excluding govern...
# 30481      2013  Ontario  Total non-profit institutions excluding govern...
# 30488      2013  Ontario  Total non-profit institutions excluding govern...
# 30579      2013  Ontario  Non-profit institutions serving households (co...
# 30586      2013  Ontario  Non-profit institutions serving households (co...
# 30593      2013  Ontario  Non-profit institutions serving households (co...
# 30600      2013  Ontario  Non-profit institutions serving households (co...
# 30607      2013  Ontario  Non-profit institutions serving households (co...
# 30614      2013  Ontario  Non-profit institutions serving households (co...
# 30705      2013  Ontario                   Business non-profit institutions
# 30712      2013  Ontario                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 30327         15 to 24 years  Average annual hours worked  Hours
# 30334         25 to 34 years  Average annual hours worked  Hours
# 30341         35 to 44 years  Average annual hours worked  Hours
# 30348         45 to 54 years  Average annual hours worked  Hours
# 30355         55 to 64 years  Average annual hours worked  Hours
# 30362  65 years old and over  Average annual hours worked  Hours
# 30453         15 to 24 years  Average annual hours worked  Hours
# 30460         25 to 34 years  Average annual hours worked  Hours
# 30467         35 to 44 years  Average annual hours worked  Hours
# 30474         45 to 54 years  Average annual hours worked  Hours
# 30481         55 to 64 years  Average annual hours worked  Hours
# 30488  65 years old and over  Average annual hours worked  Hours
# 30579         15 to 24 years  Average annual hours worked  Hours
# 30586         25 to 34 years  Average annual hours worked  Hours
# 30593         35 to 44 years  Average annual hours worked  Hours
# 30600         45 to 54 years  Average annual hours worked  Hours
# 30607         55 to 64 years  Average annual hours worked  Hours
# 30614  65 years old and over  Average annual hours worked  Hours
# 30705         15 to 24 years  Average annual hours worked  Hours
# 30712         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 30327         units   835.0
# 30334         units  1580.0
# 30341         units  1774.0
# 30348         units  1837.0
# 30355         units  1702.0
# 30362         units  1041.0
# 30453         units   845.0
# 30460         units  1669.0
# 30467         units  1806.0
# 30474         units  1863.0
# 30481         units  1717.0
# 30488         units  1060.0
# 30579         units   839.0
# 30586         units  1628.0
# 30593         units  1763.0
# 30600         units  1830.0
# 30607         units  1691.0
# 30614         units  1044.0
# 30705         units   857.0
# 30712         units  1788.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries,
Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 83219  High school diploma and less  Average annual hours worked  Hours
# 83226             Trade certificate  Average annual hours worked  Hours
# 83240  University degree and higher  Average annual hours worked  Hours
# 83345  High school diploma and less  Average annual hours worked  Hours
# 83352             Trade certificate  Average annual hours worked  Hours
# 83366  University degree and higher  Average annual hours worked  Hours
# 83471  High school diploma and less  Average annual hours worked  Hours
# 83478             Trade certificate  Average annual hours worked  Hours
# 83492  University degree and higher  Average annual hours worked  Hours
# 83597  High school diploma and less  Average annual hours worked  Hours
# 83604             Trade certificate  Average annual hours worked  Hours
# 83618  University degree and higher  Average annual hours worked  Hours
# 83723  High school diploma and less  Average annual hours worked  Hours
# 83730             Trade certificate  Average annual hours worked  Hours
# 83744  University degree and higher  Average annual hours worked  Hours
# 92039  High school diploma and less  Average annual hours worked  Hours
# 92046             Trade certificate  Average annual hours worked  Hours
# 92060  University degree and higher  Average annual hours worked  Hours
# 92165  High school diploma and less  Average annual hours worked  Hours
# 92172             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 83219         units  1245.0
# 83226         units  1499.0
# 83240         units  1670.0
# 83345         units  1251.0
# 83352         units  1513.0
# 83366         units  1706.0
# 83471         units  1197.0
# 83478         units  1454.0
# 83492         units  1680.0
# 83597         units  1386.0
# 83604         units  1669.0
# 83618         units  1792.0
# 83723         units  1238.0
# 83730         units  1486.0
# 83744         units  1649.0
# 92039         units  1248.0
# 92046         units  1482.0
# 92060         units  1673.0
# 92165         units  1234.0
# 92172         units  1459.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 83219 to 101384
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Ontario
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19132.0  1275.466667  1171.0  1251.0  1423.0
# Trade certificate             22756.0  1517.066667  1396.0  1499.0  1669.0
# University degree and higher  25550.0  1703.333333  1615.0  1688.0  1808.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  67438.0
# Mean :  1498.6222222222223
# Min/median/max : 1171.0 / 1499.0 / 1808.0
# Skewnewss :  -0.16058488152240866
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Ontario

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Prince Edward Island.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Prince Edward Island          77931.0     75.514535    121.297367  1032

ProCode = 10

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Prince Edward Island
#        REF_DATE                   GEO  \
# 27807      2013  Prince Edward Island
# 27814      2013  Prince Edward Island
# 27821      2013  Prince Edward Island
# 27828      2013  Prince Edward Island
# 27835      2013  Prince Edward Island
# 27842      2013  Prince Edward Island
# 27933      2013  Prince Edward Island
# 27940      2013  Prince Edward Island
# 27947      2013  Prince Edward Island
# 27954      2013  Prince Edward Island
# 27961      2013  Prince Edward Island
# 27968      2013  Prince Edward Island
# 28059      2013  Prince Edward Island
# 28066      2013  Prince Edward Island
# 28073      2013  Prince Edward Island
# 28080      2013  Prince Edward Island
# 28087      2013  Prince Edward Island
# 28094      2013  Prince Edward Island
# 28185      2013  Prince Edward Island
# 28192      2013  Prince Edward Island
#
#                                                   Sector  \
# 27807                      Total non-profit institutions
# 27814                      Total non-profit institutions
# 27821                      Total non-profit institutions
# 27828                      Total non-profit institutions
# 27835                      Total non-profit institutions
# 27842                      Total non-profit institutions
# 27933  Total non-profit institutions excluding govern...
# 27940  Total non-profit institutions excluding govern...
# 27947  Total non-profit institutions excluding govern...
# 27954  Total non-profit institutions excluding govern...
# 27961  Total non-profit institutions excluding govern...
# 27968  Total non-profit institutions excluding govern...
# 28059  Non-profit institutions serving households (co...
# 28066  Non-profit institutions serving households (co...
# 28073  Non-profit institutions serving households (co...
# 28080  Non-profit institutions serving households (co...
# 28087  Non-profit institutions serving households (co...
# 28094  Non-profit institutions serving households (co...
# 28185                   Business non-profit institutions
# 28192                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 27807         15 to 24 years  Average annual hours worked  Hours
# 27814         25 to 34 years  Average annual hours worked  Hours
# 27821         35 to 44 years  Average annual hours worked  Hours
# 27828         45 to 54 years  Average annual hours worked  Hours
# 27835         55 to 64 years  Average annual hours worked  Hours
# 27842  65 years old and over  Average annual hours worked  Hours
# 27933         15 to 24 years  Average annual hours worked  Hours
# 27940         25 to 34 years  Average annual hours worked  Hours
# 27947         35 to 44 years  Average annual hours worked  Hours
# 27954         45 to 54 years  Average annual hours worked  Hours
# 27961         55 to 64 years  Average annual hours worked  Hours
# 27968  65 years old and over  Average annual hours worked  Hours
# 28059         15 to 24 years  Average annual hours worked  Hours
# 28066         25 to 34 years  Average annual hours worked  Hours
# 28073         35 to 44 years  Average annual hours worked  Hours
# 28080         45 to 54 years  Average annual hours worked  Hours
# 28087         55 to 64 years  Average annual hours worked  Hours
# 28094  65 years old and over  Average annual hours worked  Hours
# 28185         15 to 24 years  Average annual hours worked  Hours
# 28192         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 27807         units   886.0
# 27814         units  1548.0
# 27821         units  1766.0
# 27828         units  1790.0
# 27835         units  1639.0
# 27842         units   985.0
# 27933         units   768.0
# 27940         units  1692.0
# 27947         units  1964.0
# 27954         units  1890.0
# 27961         units  1693.0
# 27968         units   894.0
# 28059         units   741.0
# 28066         units  1645.0
# 28073         units  1940.0
# 28080         units  1822.0
# 28087         units  1716.0
# 28094         units   882.0
# 28185         units   830.0
# 28192         units  1852.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 27807 to 45986
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Prince Edward Island
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         12434.0   828.933333   741.0   815.0   964.0    15
# 25 to 34 years         25215.0  1681.000000  1504.0  1692.0  1946.0    15
# 35 to 44 years         29087.0  1939.133333  1711.0  1964.0  2183.0    15
# 45 to 54 years         28795.0  1919.666667  1760.0  1890.0  2234.0    15
# 55 to 64 years         25001.0  1666.733333  1621.0  1663.0  1716.0    15
# 65 years old and over  14541.0   969.400000   863.0   943.0  1130.0    15
#
# Overall,
# Sum :  135073.0
# Mean :  1500.8111111111111
# Min/median/max : 741.0 / 1663.5 / 2234.0
# Skewnewss :  -0.4057395793071024
# Total size :  90
# 2016
#
# Grab the dataset only in Prince Edward Island
#        REF_DATE                   GEO  \
# 54267      2016  Prince Edward Island
# 54274      2016  Prince Edward Island
# 54281      2016  Prince Edward Island
# 54288      2016  Prince Edward Island
# 54295      2016  Prince Edward Island
# 54302      2016  Prince Edward Island
# 54393      2016  Prince Edward Island
# 54400      2016  Prince Edward Island
# 54407      2016  Prince Edward Island
# 54414      2016  Prince Edward Island
# 54421      2016  Prince Edward Island
# 54428      2016  Prince Edward Island
# 54519      2016  Prince Edward Island
# 54526      2016  Prince Edward Island
# 54533      2016  Prince Edward Island
# 54540      2016  Prince Edward Island
# 54547      2016  Prince Edward Island
# 54554      2016  Prince Edward Island
# 54645      2016  Prince Edward Island
# 54652      2016  Prince Edward Island
#
#                                                   Sector  \
# 54267                      Total non-profit institutions
# 54274                      Total non-profit institutions
# 54281                      Total non-profit institutions
# 54288                      Total non-profit institutions
# 54295                      Total non-profit institutions
# 54302                      Total non-profit institutions
# 54393  Total non-profit institutions excluding govern...
# 54400  Total non-profit institutions excluding govern...
# 54407  Total non-profit institutions excluding govern...
# 54414  Total non-profit institutions excluding govern...
# 54421  Total non-profit institutions excluding govern...
# 54428  Total non-profit institutions excluding govern...
# 54519  Non-profit institutions serving households (co...
# 54526  Non-profit institutions serving households (co...
# 54533  Non-profit institutions serving households (co...
# 54540  Non-profit institutions serving households (co...
# 54547  Non-profit institutions serving households (co...
# 54554  Non-profit institutions serving households (co...
# 54645                   Business non-profit institutions
# 54652                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 54267         15 to 24 years  Average annual hours worked  Hours
# 54274         25 to 34 years  Average annual hours worked  Hours
# 54281         35 to 44 years  Average annual hours worked  Hours
# 54288         45 to 54 years  Average annual hours worked  Hours
# 54295         55 to 64 years  Average annual hours worked  Hours
# 54302  65 years old and over  Average annual hours worked  Hours
# 54393         15 to 24 years  Average annual hours worked  Hours
# 54400         25 to 34 years  Average annual hours worked  Hours
# 54407         35 to 44 years  Average annual hours worked  Hours
# 54414         45 to 54 years  Average annual hours worked  Hours
# 54421         55 to 64 years  Average annual hours worked  Hours
# 54428  65 years old and over  Average annual hours worked  Hours
# 54519         15 to 24 years  Average annual hours worked  Hours
# 54526         25 to 34 years  Average annual hours worked  Hours
# 54533         35 to 44 years  Average annual hours worked  Hours
# 54540         45 to 54 years  Average annual hours worked  Hours
# 54547         55 to 64 years  Average annual hours worked  Hours
# 54554  65 years old and over  Average annual hours worked  Hours
# 54645         15 to 24 years  Average annual hours worked  Hours
# 54652         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 54267         units   906.0
# 54274         units  1597.0
# 54281         units  1836.0
# 54288         units  1833.0
# 54295         units  1698.0
# 54302         units  1088.0
# 54393         units   823.0
# 54400         units  1760.0
# 54407         units  2071.0
# 54414         units  1950.0
# 54421         units  1713.0
# 54428         units   965.0
# 54519         units   793.0
# 54526         units  1693.0
# 54533         units  2048.0
# 54540         units  1881.0
# 54547         units  1714.0
# 54554         units   941.0
# 54645         units   885.0
# 54652         units  1967.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 54267 to 72446
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Prince Edward Island
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         13332.0   888.800000   793.0   899.0   956.0    15
# 25 to 34 years         25066.0  1671.066667  1531.0  1628.0  1967.0    15
# 35 to 44 years         28999.0  1933.266667  1745.0  1947.0  2156.0    15
# 45 to 54 years         28337.0  1889.133333  1779.0  1851.0  2152.0    15
# 55 to 64 years         25394.0  1692.933333  1613.0  1698.0  1761.0    15
# 65 years old and over  15507.0  1033.800000   927.0  1059.0  1153.0    15
#
# Overall,
# Sum :  136635.0
# Mean :  1518.1666666666667
# Min/median/max : 793.0 / 1688.0 / 2156.0
# Skewnewss :  -0.4531169132913988
# Total size :  90
# 2019
#
# Grab the dataset only in Prince Edward Island
#        REF_DATE                   GEO  \
# 81098  University degree and higher  Average annual hours worked  Hours
# 81203  High school diploma and less  Average annual hours worked  Hours
# 81210             Trade certificate  Average annual hours worked  Hours
# 81224  University degree and higher  Average annual hours worked  Hours
# 89519  High school diploma and less  Average annual hours worked  Hours
# 89526             Trade certificate  Average annual hours worked  Hours
# 89540  University degree and higher  Average annual hours worked  Hours
# 89645  High school diploma and less  Average annual hours worked  Hours
# 89652             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 80699         units  1299.0
# 80706         units  1652.0
# 80720         units  1709.0
# 80825         units  1165.0
# 80832         units  1508.0
# 80846         units  1800.0
# 80951         units  1136.0
# 80958         units  1430.0
# 80972         units  1783.0
# 81077         units  1240.0
# 81084         units  1684.0
# 81098         units  1856.0
# 81203         units  1373.0
# 81210         units  1692.0
# 81224         units  1678.0
# 89519         units  1315.0
# 89526         units  1636.0
# 89540         units  1697.0
# 89645         units  1201.0
# 89652         units  1543.0
# ...
# 27779                      Total non-profit institutions
# 27786                      Total non-profit institutions
# 27800                      Total non-profit institutions
# 27905  Total non-profit institutions excluding govern...
# 27912  Total non-profit institutions excluding govern...
# 27926  Total non-profit institutions excluding govern...
# 28031  Non-profit institutions serving households (co...
# 28038  Non-profit institutions serving households (co...
# 28052  Non-profit institutions serving households (co...
# 28157                   Business non-profit institutions
# 28164                   Business non-profit institutions
# 28178                   Business non-profit institutions
# 28283                 Government non-profit institutions
# 28290                 Government non-profit institutions
# 28304                 Government non-profit institutions
# 36599                      Total non-profit institutions
# 36606                      Total non-profit institutions
# 36620                      Total non-profit institutions
# 36725  Total non-profit institutions excluding govern...
# 36732  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 27779  High school diploma and less  Average annual hours worked  Hours
# 27786             Trade certificate  Average annual hours worked  Hours
# 27800  University degree and higher  Average annual hours worked  Hours
# 27905  High school diploma and less  Average annual hours worked  Hours
# 27912             Trade certificate  Average annual hours worked  Hours
# 27926  University degree and higher  Average annual hours worked  Hours
# 28031  High school diploma and less  Average annual hours worked  Hours
# 28038             Trade certificate  Average annual hours worked  Hours
# 28052  University degree and higher  Average annual hours worked  Hours
# 28157  High school diploma and less  Average annual hours worked  Hours
# 28164             Trade certificate  Average annual hours worked  Hours
# 28178  University degree and higher  Average annual hours worked  Hours
# 28283  High school diploma and less  Average annual hours worked  Hours
# 28290             Trade certificate  Average annual hours worked  Hours
# 28304  University degree and higher  Average annual hours worked  Hours
# 36599  High school diploma and less  Average annual hours worked  Hours
# 36606             Trade certificate  Average annual hours worked  Hours
# 36620  University degree and higher  Average annual hours worked  Hours
# 36725  High school diploma and less  Average annual hours worked  Hours
# 36732             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 27779         units  1244.0
# 27786         units  1645.0
# 27800         units  1690.0
# 27905         units  1103.0
# 27912         units  1513.0
# 27926         units  1869.0
# 28031         units  1065.0
# 28038         units  1412.0
# 28052         units  1863.0
# 28157         units  1202.0
# 28164         units  1714.0
# 28178         units  1885.0
# 28283         units  1324.0
# 28290         units  1676.0
# 28304         units  1630.0
# 36599         units  1256.0
# 36606         units  1631.0
# 36620         units  1736.0
# 36725         units  1104.0
# 36732         units  1487.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 27779 to 45944
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in
Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 80699         units  1299.0
# 80706         units  1652.0
# 80720         units  1709.0
# 80825         units  1165.0
# 80832         units  1508.0
# 80846         units  1800.0
# 80951         units  1136.0
# 80958         units  1430.0
# 80972         units  1783.0
# 81077         units  1240.0
# 81084         units  1684.0
# 81098         units  1856.0
# 81203         units  1373.0
# 81210         units  1692.0
# 81224         units  1678.0
# 89519         units  1315.0
# 89526         units  1636.0
# 89540         units  1697.0
# 89645         units  1201.0
# 89652         units  1543.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 80699 to 98864
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Prince Edward Island
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19036.0  1269.066667  1136.0  1257.0  1447.0
# Trade certificate             24223.0  1614.866667  1430.0  1652.0  1767.0
# University degree and higher  26526.0  1768.400000  1672.0  1781.0  1884.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  69785.0
# Mean :  1550.7777777777778
# Min/median/max : 1136.0 / 1652.0 / 1884.0
# Skewnewss :  -0.42705829993901157
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Prince Edward Island

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Quebec.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Quebec                      4271657.0   3955.237963   5580.294544  1080

ProCode = 11

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Quebec
#        REF_DATE     GEO                                             Sector  \
# 29697      2013  Quebec                      Total non-profit institutions
# 29704      2013  Quebec                      Total non-profit institutions
# 29711      2013  Quebec                      Total non-profit institutions
# 29718      2013  Quebec                      Total non-profit institutions
# 29725      2013  Quebec                      Total non-profit institutions
# 29732      2013  Quebec                      Total non-profit institutions
# 29823      2013  Quebec  Total non-profit institutions excluding govern...
# 29830      2013  Quebec  Total non-profit institutions excluding govern...
# 29837      2013  Quebec  Total non-profit institutions excluding govern...
# 29844      2013  Quebec  Total non-profit institutions excluding govern...
# 29851      2013  Quebec  Total non-profit institutions excluding govern...
# 29858      2013  Quebec  Total non-profit institutions excluding govern...
# 29949      2013  Quebec  Non-profit institutions serving households (co...
# 29956      2013  Quebec  Non-profit institutions serving households (co...
# 29963      2013  Quebec  Non-profit institutions serving households (co...
# 29970      2013  Quebec  Non-profit institutions serving households (co...
# 29977      2013  Quebec  Non-profit institutions serving households (co...
# 29984      2013  Quebec  Non-profit institutions serving households (co...
# 30075      2013  Quebec                   Business non-profit institutions
# 30082      2013  Quebec                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 29697         15 to 24 years  Average annual hours worked  Hours
# 29704         25 to 34 years  Average annual hours worked  Hours
# 29711         35 to 44 years  Average annual hours worked  Hours
# 29718         45 to 54 years  Average annual hours worked  Hours
# 29725         55 to 64 years  Average annual hours worked  Hours
# 29732  65 years old and over  Average annual hours worked  Hours
# 29823         15 to 24 years  Average annual hours worked  Hours
# 29830         25 to 34 years  Average annual hours worked  Hours
# 29837         35 to 44 years  Average annual hours worked  Hours
# 29844         45 to 54 years  Average annual hours worked  Hours
# 29851         55 to 64 years  Average annual hours worked  Hours
# 29858  65 years old and over  Average annual hours worked  Hours
# 29949         15 to 24 years  Average annual hours worked  Hours
# 29956         25 to 34 years  Average annual hours worked  Hours
# 29963         35 to 44 years  Average annual hours worked  Hours
# 29970         45 to 54 years  Average annual hours worked  Hours
# 29977         55 to 64 years  Average annual hours worked  Hours
# 29984  65 years old and over  Average annual hours worked  Hours
# 30075         15 to 24 years  Average annual hours worked  Hours
# 30082         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 29697         units   905.0
# 29704         units  1477.0
# 29711         units  1646.0
# 29718         units  1724.0
# 29725         units  1523.0
# 29732         units   843.0
# 29823         units   841.0
# 29830         units  1543.0
# 29837         units  1679.0
# 29844         units  1740.0
# 29851         units  1530.0
# 29858         units   917.0
# 29949         units   854.0
# 29956         units  1500.0
# 29963         units  1636.0
# 29970         units  1698.0
# 29977         units  1486.0
# 29984         units   893.0
# 30075         units   813.0
# 30082         units  1678.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 29697 to 47876
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Quebec
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         12815.0   854.333333   791.0   841.0   948.0    15
# 25 to 34 years         22941.0  1529.400000  1425.0  1503.0  1700.0    15
# 35 to 44 years         25333.0  1688.866667  1616.0  1646.0  1855.0    15
# 45 to 54 years         26338.0  1755.866667  1697.0  1720.0  1912.0    15
# 55 to 64 years         23210.0  1547.333333  1473.0  1519.0  1715.0    15
# 65 years old and over  13362.0   890.800000   788.0   893.0  1023.0    15
#
# Overall,
# Sum :  123999.0
# Mean :  1377.7666666666667
# Min/median/max : 788.0 / 1514.5 / 1912.0
# Skewnewss :  -0.5118003083466407
# Total size :  90
# 2016
#
# Grab the dataset only in Quebec
#        REF_DATE     GEO                                             Sector  \
# 56157      2016  Quebec                      Total non-profit institutions
# 56164      2016  Quebec                      Total non-profit institutions
# 56171      2016  Quebec                      Total non-profit institutions
# 56178      2016  Quebec                      Total non-profit institutions
# 56185      2016  Quebec                      Total non-profit institutions
# 56192      2016  Quebec                      Total non-profit institutions
# 56283      2016  Quebec  Total non-profit institutions excluding govern...
# 56290      2016  Quebec  Total non-profit institutions excluding govern...
# 56297      2016  Quebec  Total non-profit institutions excluding govern...
# 56304      2016  Quebec  Total non-profit institutions excluding govern...
# 56311      2016  Quebec  Total non-profit institutions excluding govern...
# 56318      2016  Quebec  Total non-profit institutions excluding govern...
# 56409      2016  Quebec  Non-profit institutions serving households (co...
# 56416      2016  Quebec  Non-profit institutions serving households (co...
# 56423      2016  Quebec  Non-profit institutions serving households (co...
# 56430      2016  Quebec  Non-profit institutions serving households (co...
# 56437      2016  Quebec  Non-profit institutions serving households (co...
# 56444      2016  Quebec  Non-profit institutions serving households (co...
# 56535      2016  Quebec                   Business non-profit institutions
# 56542      2016  Quebec                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 56157         15 to 24 years  Average annual hours worked  Hours
# 56164         25 to 34 years  Average annual hours worked  Hours
# 56171         35 to 44 years  Average annual hours worked  Hours
# 56178         45 to 54 years  Average annual hours worked  Hours
# 56185         55 to 64 years  Average annual hours worked  Hours
# 56192  65 years old and over  Average annual hours worked  Hours
# 56283         15 to 24 years  Average annual hours worked  Hours
# 56290         25 to 34 years  Average annual hours worked  Hours
# 56297         35 to 44 years  Average annual hours worked  Hours
# 56304         45 to 54 years  Average annual hours worked  Hours
# 56311         55 to 64 years  Average annual hours worked  Hours
# 56318  65 years old and over  Average annual hours worked  Hours
# 56409         15 to 24 years  Average annual hours worked  Hours
# 56416         25 to 34 years  Average annual hours worked  Hours
# 56423         35 to 44 years  Average annual hours worked  Hours
# 56430         45 to 54 years  Average annual hours worked  Hours
# 56437         55 to 64 years  Average annual hours worked  Hours
# 56444  65 years old and over  Average annual hours worked  Hours
# 56535         15 to 24 years  Average annual hours worked  Hours
# 56542         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 56157         units   900.0
# 56164         units  1478.0
# 56171         units  1656.0
# 56178         units  1731.0
# 56185         units  1540.0
# 56192         units   872.0
# 56283         units   818.0
# 56290         units  1535.0
# 56297         units  1678.0
# 56304         units  1743.0
# 56311         units  1537.0
# 56318         units   922.0
# 56409         units   826.0
# 56416         units  1487.0
# 56423         units  1631.0
# 56430         units  1696.0
# 56437         units  1490.0
# 56444         units   903.0
# 56535         units   802.0
# 56542         units  1678.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 56157 to 74336
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Quebec
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         13139.0   875.933333   802.0   850.0   977.0    15
# 25 to 34 years         22807.0  1520.466667  1453.0  1486.0  1678.0    15
# 35 to 44 years         25266.0  1684.400000  1629.0  1656.0  1830.0    15
# 45 to 54 years         26376.0  1758.400000  1694.0  1735.0  1896.0    15
# 55 to 64 years         23388.0  1559.200000  1476.0  1541.0  1696.0    15
# 65 years old and over  13385.0   892.333333   840.0   873.0  1001.0    15
#
# Overall,
# Sum :  124361.0
# Mean :  1381.7888888888888
# Min/median/max : 802.0 / 1531.0 / 1896.0
# Skewnewss :  -0.5184482009556456
# Total size :  90
# 2019
#
# Grab the dataset only in Quebec
#        REF_DATE     GEO                                             Sector  \
# 82617      2019  Quebec                      Total non-profit institutions
# 82624      2019  Quebec                      Total non-profit institutions
# 82631      2019  Quebec                      Total non-profit institutions
# 82638      2019  Quebec                      Total non-profit institutions
# 82645      2019  Quebec                      Total non-profit institutions
# 82652      2019  Quebec                      Total non-profit institutions
# 82743      2019  Quebec  Total non-profit institutions excluding govern...
# 82750      2019  Quebec  Total non-profit institutions excluding govern...
# 82757      2019  Quebec  Total non-profit institutions excluding govern...
# 82764      2019  Quebec  Total non-profit institutions excluding govern...
# 82771      2019  Quebec  Total non-profit institutions excluding govern...
# 82778      2019  Quebec  Total non-profit institutions excluding govern...
# 82869      2019  Quebec  Non-profit institutions serving households (co...
# 82876      2019  Quebec  Non-profit institutions serving households (co...
# 82883      2019  Quebec  Non-profit institutions serving households (co...
# 82890      2019  Quebec  Non-profit institutions serving households (co...
# 82897      2019  Quebec  Non-profit institutions serving households (co...
# 82904      2019  Quebec  Non-profit institutions serving households (co...
# 82995      2019  Quebec                   Business non-profit institutions
# 83002      2019  Quebec                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 82617         15 to 24 years  Average annual hours worked  Hours
# 82624         25 to 34 years  Average annual hours worked  Hours
# 82631         35 to 44 years  Average annual hours worked  Hours
# 82638         45 to 54 years  Average annual hours worked  Hours
# 82645         55 to 64 years  Average annual hours worked  Hours
# 82652  65 years old and over  Average annual hours worked  Hours
# 82743         15 to 24 years  Average annual hours worked  Hours
# 82750         25 to 34 years  Average annual hours worked  Hours
# 82757         35 to 44 years  Average annual hours worked  Hours
# 82764         45 to 54 years  Average annual hours worked  Hours
# 82771         55 to 64 years  Average annual hours worked  Hours
# 82778  65 years old and over  Average annual hours worked  Hours
# 82869         15 to 24 years  Average annual hours worked  Hours
# 82876         25 to 34 years  Average annual hours worked  Hours
# 82883         35 to 44 years  Average annual hours worked  Hours
# 82890         45 to 54 years  Average annual hours worked  Hours
# 82897         55 to 64 years  Average annual hours worked  Hours
# 82904  65 years old and over  Average annual hours worked  Hours
# 82995         15 to 24 years  Average annual hours worked  Hours
# 83002         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 82617         units   941.0
# 82624         units  1491.0
# 82631         units  1670.0
# 82638         units  1756.0
# 82645         units  1570.0
# 82652         units   886.0
# 82743         units   867.0
# 82750         units  1533.0
# 82757         units  1678.0
# 82764         units  1760.0
# 82771         units  1566.0
# 82778         units   891.0
# 82869         units   874.0
# 82876         units  1481.0
# 82883         units  1626.0
# 82890         units  1707.0
# 82897         units  1515.0
# 82904         units   867.0
# 82995         units   851.0
# 83002         units  1681.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 82617 to 100796
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Quebec
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         13667.0   911.133333   835.0   897.0   996.0    15
# 25 to 34 years         22878.0  1525.200000  1438.0  1491.0  1681.0    15
# 35 to 44 years         25276.0  1685.066667  1615.0  1670.0  1841.0    15
# 45 to 54 years         26585.0  1772.333333  1697.0  1756.0  1931.0    15
# 55 to 64 years         23864.0  1590.933333  1515.0  1572.0  1729.0    15
# 65 years old and over  13713.0   914.200000   867.0   893.0  1032.0    15
#
# Overall,
# Sum :  125983.0
# Mean :  1399.8111111111111
# Min/median/max : 835.0 / 1538.0 / 1931.0
# Skewnewss :  -0.5048806522886445
# Total size :  90
# 2013
#
# Grab the dataset only in Quebec
#        REF_DATE     GEO                                             Sector  \
# 29613      2013  Quebec                      Total non-profit institutions
# 29620      2013  Quebec                      Total non-profit institutions
# 29739      2013  Quebec  Total non-profit institutions excluding govern...
# 29746      2013  Quebec  Total non-profit institutions excluding govern...
# 29865      2013  Quebec  Non-profit institutions serving households (co...
# 29872      2013  Quebec  Non-profit institutions serving households (co...
# 29991      2013  Quebec                   Business non-profit institutions
# 29998      2013  Quebec                   Business non-profit institutions
# 30117      2013  Quebec                 Government non-profit institutions
# 30124      2013  Quebec                 Government non-profit institutions
# 38433      2014  Quebec                      Total non-profit institutions
# 38440      2014  Quebec                      Total non-profit institutions
# 38559      2014  Quebec  Total non-profit institutions excluding govern...
# 38566      2014  Quebec  Total non-profit institutions excluding govern...
# 38685      2014  Quebec  Non-profit institutions serving households (co...
# 38692      2014  Quebec  Non-profit institutions serving households (co...
# 38811      2014  Quebec                   Business non-profit institutions
# 38818      2014  Quebec                   Business non-profit institutions
# 38937      2014  Quebec                 Government non-profit institutions
# 38944      2014  Quebec                 Government non-profit institutions
#
#         Characteristics                   Indicators    UOM SCALAR_FACTOR  \
#
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Saskatchewan.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Saskatchewan                 650781.0    602.575000    876.896377  1080

ProCode = 12

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 31587      2013  Saskatchewan
# 31594      2013  Saskatchewan
# 31601      2013  Saskatchewan
# 31608      2013  Saskatchewan
# 31615      2013  Saskatchewan
# 31622      2013  Saskatchewan
# 31713      2013  Saskatchewan
# 31720      2013  Saskatchewan
# 31727      2013  Saskatchewan
# 31734      2013  Saskatchewan
# 31741      2013  Saskatchewan
# 31748      2013  Saskatchewan
# 31839      2013  Saskatchewan
# 31846      2013  Saskatchewan
# 31853      2013  Saskatchewan
# 31860      2013  Saskatchewan
# 31867      2013  Saskatchewan
# 31874      2013  Saskatchewan
# 31965      2013  Saskatchewan
# 31972      2013  Saskatchewan
#
#                                                   Sector  \
# 31587                      Total non-profit institutions
# 31594                      Total non-profit institutions
# 31601                      Total non-profit institutions
# 31608                      Total non-profit institutions
# 31615                      Total non-profit institutions
# 31622                      Total non-profit institutions
# 31713  Total non-profit institutions excluding govern...
# 31720  Total non-profit institutions excluding govern...
# 31727  Total non-profit institutions excluding govern...
# 31734  Total non-profit institutions excluding govern...
# 31741  Total non-profit institutions excluding govern...
# 31748  Total non-profit institutions excluding govern...
# 31839  Non-profit institutions serving households (co...
# 31846  Non-profit institutions serving households (co...
# 31853  Non-profit institutions serving households (co...
# 31860  Non-profit institutions serving households (co...
# 31867  Non-profit institutions serving households (co...
# 31874  Non-profit institutions serving households (co...
# 31965                   Business non-profit institutions
# 31972                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 31587         15 to 24 years  Average annual hours worked  Hours
# 31594         25 to 34 years  Average annual hours worked  Hours
# 31601         35 to 44 years  Average annual hours worked  Hours
# 31608         45 to 54 years  Average annual hours worked  Hours
# 31615         55 to 64 years  Average annual hours worked  Hours
# 31622  65 years old and over  Average annual hours worked  Hours
# 31713         15 to 24 years  Average annual hours worked  Hours
# 31720         25 to 34 years  Average annual hours worked  Hours
# 31727         35 to 44 years  Average annual hours worked  Hours
# 31734         45 to 54 years  Average annual hours worked  Hours
# 31741         55 to 64 years  Average annual hours worked  Hours
# 31748  65 years old and over  Average annual hours worked  Hours
# 31839         15 to 24 years  Average annual hours worked  Hours
# 31846         25 to 34 years  Average annual hours worked  Hours
# 31853         35 to 44 years  Average annual hours worked  Hours
# 31860         45 to 54 years  Average annual hours worked  Hours
# 31867         55 to 64 years  Average annual hours worked  Hours
# 31874  65 years old and over  Average annual hours worked  Hours
# 31965         15 to 24 years  Average annual hours worked  Hours
# 31972         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 31587         units   976.0
# 31594         units  1548.0
# 31601         units  1719.0
# 31608         units  1804.0
# 31615         units  1648.0
# 31622         units  1050.0
# 31713         units   926.0
# 31720         units  1636.0
# 31727         units  1725.0
# 31734         units  1813.0
# 31741         units  1614.0
# 31748         units  1008.0
# 31839         units   906.0
# 31846         units  1590.0
# 31853         units  1678.0
# 31860         units  1783.0
# 31867         units  1593.0
# 31874         units   998.0
# 31965         units   988.0
# 31972         units  1817.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries,
25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 58047         units   952.0
# 58054         units  1504.0
# 58061         units  1676.0
# 58068         units  1775.0
# 58075         units  1625.0
# 58082         units  1054.0
# 58173         units   925.0
# 58180         units  1605.0
# 58187         units  1714.0
# 58194         units  1838.0
# 58201         units  1624.0
# 58208         units  1055.0
# 58299         units   915.0
# 58306         units  1562.0
# 58313         units  1680.0
# 58320         units  1809.0
# 58327         units  1607.0
# 58334         units  1054.0
# 58425         units   961.0
# 58432         units  1787.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 58047 to 76226
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         14158.0   943.866667   890.0   947.0  1010.0    15
# 25 to 34 years         23612.0  1574.133333  1473.0  1549.0  1787.0    15
# 35 to 44 years         25733.0  1715.533333  1644.0  1685.0  1872.0    15
# 45 to 54 years         27299.0  1819.933333  1749.0  1797.0  1971.0    15
# 55 to 64 years         24369.0  1624.600000  1554.0  1624.0  1699.0    15
# 65 years old and over  15679.0  1045.266667  1008.0  1054.0  1078.0    15
#
# Overall,
# Sum :  130850.0
# Mean :  1453.888888888889
# Min/median/max : 890.0 / 1605.5 / 1971.0
# Skewnewss :  -0.4965142208647792
# Total size :  90
# 2019
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 84507      2019  Saskatchewan
# 84514      2019  Saskatchewan
# 84521      2019  Saskatchewan
# 84528      2019  Saskatchewan
# 84535      2019  Saskatchewan
# 84542      2019  Saskatchewan
# 84633      2019  Saskatchewan
# 84640      2019  Saskatchewan
# 84647      2019  Saskatchewan
# 84654      2019  Saskatchewan
# 84661      2019  Saskatchewan
# 84668      2019  Saskatchewan
# 84759      2019  Saskatchewan
# 84766      2019  Saskatchewan
# 84773      2019  Saskatchewan
# 84780      2019  Saskatchewan
# 84787      2019  Saskatchewan
# 84794      2019  Saskatchewan
# 84885      2019  Saskatchewan
# 84892      2019  Saskatchewan
#
#                                                   Sector  \
# 84507                      Total non-profit institutions
# 84514                      Total non-profit institutions
# 84521                      Total non-profit institutions
# 84528                      Total non-profit institutions
# 84535                      Total non-profit institutions
# 84542                      Total non-profit institutions
# 84633  Total non-profit institutions excluding govern...
# 84640  Total non-profit institutions excluding govern...
# 84647  Total non-profit institutions excluding govern...
# 84654  Total non-profit institutions excluding govern...
# 84661  Total non-profit institutions excluding govern...
# 84668  Total non-profit institutions excluding govern...
# 84759  Non-profit institutions serving households (co...
# 84766  Non-profit institutions serving households (co...
# 84773  Non-profit institutions serving households (co...
# 84780  Non-profit institutions serving households (co...
# 84787  Non-profit institutions serving households (co...
# 84794  Non-profit institutions serving households (co...
# 84885                   Business non-profit institutions
# 84892                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 84507         15 to 24 years  Average annual hours worked  Hours
# 84514         25 to 34 years  Average annual hours worked  Hours
# 84521         35 to 44 years  Average annual hours worked  Hours
# 84528         45 to 54 years  Average annual hours worked  Hours
# 84535         55 to 64 years  Average annual hours worked  Hours
# 84542  65 years old and over  Average annual hours worked  Hours
# 84633         15 to 24 years  Average annual hours worked  Hours
# 84640         25 to 34 years  Average annual hours worked  Hours
# 84647         35 to 44 years  Average annual hours worked  Hours
# 84654         45 to 54 years  Average annual hours worked  Hours
# 84661         55 to 64 years  Average annual hours worked  Hours
# 84668  65 years old and over  Average annual hours worked  Hours
# 84759         15 to 24 years  Average annual hours worked  Hours
# 84766         25 to 34 years  Average annual hours worked  Hours
# 84773         35 to 44 years  Average annual hours worked  Hours
# 84780         45 to 54 years  Average annual hours worked  Hours
# 84787         55 to 64 years  Average annual hours worked  Hours
# 84794  65 years old and over  Average annual hours worked  Hours
# 84885         15 to 24 years  Average annual hours worked  Hours
# 84892         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 84507         units   981.0
# 84514         units  1533.0
# 84521         units  1702.0
# 84528         units  1804.0
# 84535         units  1650.0
# 84542         units  1052.0
# 84633         units   925.0
# 84640         units  1589.0
# 84647         units  1747.0
# 84654         units  1856.0
# 84661         units  1632.0
# 84668         units  1059.0
# 84759         units   927.0
# 84766         units  1562.0
# 84773         units  1726.0
# 84780         units  1845.0
# 84787         units  1625.0
# 84794         units  1065.0
# 84885         units   920.0
# 84892         units  1701.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 84507 to 102686
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         14285.0   952.333333   904.0   925.0  1053.0    15
# 25 to 34 years         23609.0  1573.933333  1500.0  1554.0  1701.0    15
# 35 to 44 years         26024.0  1734.933333  1659.0  1723.0  1845.0    15
# 45 to 54 years         27466.0  1831.066667  1758.0  1822.0  1912.0    15
# 55 to 64 years         24602.0  1640.133333  1566.0  1641.0  1690.0    15
# 65 years old and over  15732.0  1048.800000   992.0  1058.0  1071.0    15
#
# Overall,
# Sum :  131718.0
# Mean :  1463.5333333333333
# Min/median/max : 904.0 / 1622.0 / 1912.0
# Skewnewss :  -0.5344500399370813
# Total size :  90
# 2013
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 31503      2013  Saskatchewan
# 31510      2013  Saskatchewan
# 31629      2013  Saskatchewan
# 31636      2013  Saskatchewan
# 31755      2013  Saskatchewan
# 31762      2013  Saskatchewan
# 31881      2013  Saskatchewan
# 31888      2013  Saskatchewan
# 32007      2013  Saskatchewan
# 32014      2013  Saskatchewan
# 40323      2014  Saskatchewan
# 40330      2014  Saskatchewan
# 40449      2014  Saskatchewan
# 40456      2014  Saskatchewan
# 40575      2014  Saskatchewan
# 40582      2014  Saskatchewan
# 40701      2014  Saskatchewan
# 40708      2014  Saskatchewan
# 40827      2014  Saskatchewan
# 40834      2014  Saskatchewan
#
#                                                   Sector   Characteristics  \
# 31503                      Total non-profit institutions    Male employees
# 31510                      Total non-profit institutions  Female employees
# 31629  Total non-profit institutions excluding govern...    Male employees
# 31636  Total non-profit institutions excluding govern...  Female employees
# 31755  Non-profit institutions serving households (co...    Male employees
# 31762  Non-profit institutions serving households (co...  Female employees
# 31881                   Business non-profit institutions    Male employees
# 31888                   Business non-profit institutions  Female employees
# 32007                 Government non-profit institutions    Male employees
# 32014                 Government non-profit institutions  Female employees
# 40323                      Total non-profit institutions    Male employees
# 40330                      Total non-profit institutions  Female employees
# 40449  Total non-profit institutions excluding govern...    Male employees
# 40456  Total non-profit institutions excluding govern...  Female employees
# 40575  Non-profit institutions serving households (co...    Male employees
# 40582  Non-profit institutions serving households (co...  Female employees
# 40701                   Business non-profit institutions    Male employees
# 40708                   Business non-profit institutions  Female employees
# 40827                 Government non-profit institutions    Male employees
# 40834                 Government non-profit institutions  Female employees
#
#                         Indicators    UOM SCALAR_FACTOR   VALUE
# 31503  Average annual hours worked  Hours         units  1685.0
# 31510  Average annual hours worked  Hours         units  1528.0
# 31629  Average annual hours worked  Hours         units  1707.0
# 31636  Average annual hours worked  Hours         units  1415.0
# 31755  Average annual hours worked  Hours         units  1687.0
# 31762  Average annual hours worked  Hours         units  1401.0
# 31881  Average annual hours worked  Hours         units  1759.0
# 31888  Average annual hours worked  Hours         units  1493.0
# 32007  Average annual hours worked  Hours         units  1674.0
# 32014  Average annual hours worked  Hours         units  1560.0
# 40323  Average annual hours worked  Hours         units  1664.0
# 40330  Average annual hours worked  Hours         units  1532.0
# 40449  Average annual hours worked  Hours         units  1729.0
# 40456  Average annual hours worked  Hours         units  1452.0
# 40575  Average annual hours worked  Hours         units  1724.0
# 40582  Average annual hours worked  Hours         units  1445.0
# 40701  Average annual hours worked  Hours         units  1744.0
# 40708  Average annual hours worked  Hours         units  1492.0
# 40827  Average annual hours worked  Hours         units  1630.0
# 40834  Average annual hours worked  Hours         units  1555.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 31503 to 49654
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                       sum         mean    amin  median    amax  size
# Characteristics
# Female employees  22296.0  1486.400000  1401.0  1493.0  1560.0    15
# Male employees    25442.0  1696.133333  1602.0  1707.0  1759.0    15
#
# Overall,
# Sum :  47738.0
# Mean :  1591.2666666666667
# Min/median/max : 1401.0 / 1581.0 / 1759.0
# Skewnewss :  -0.07059890741928074
# Total size :  30
# 2016
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 57963      2016  Saskatchewan
# 57970      2016  Saskatchewan
# 58089      2016  Saskatchewan
# 58096      2016  Saskatchewan
# 58215      2016  Saskatchewan
# 58222      2016  Saskatchewan
# 58341      2016  Saskatchewan
# 58348      2016  Saskatchewan
# 58467      2016  Saskatchewan
# 58474      2016  Saskatchewan
# 66783      2017  Saskatchewan
# 66790      2017  Saskatchewan
# 66909      2017  Saskatchewan
# 66916      2017  Saskatchewan
# 67035      2017  Saskatchewan
# 67042      2017  Saskatchewan
# 67161      2017  Saskatchewan
# 67168      2017  Saskatchewan
# 67287      2017  Saskatchewan
# 67294      2017  Saskatchewan
#
#                                                   Sector   Characteristics  \
# 57963                      Total non-profit institutions    Male employees
# 57970                      Total non-profit institutions  Female employees
# 58089  Total non-profit institutions excluding govern...    Male employees
# 58096  Total non-profit institutions excluding govern...  Female employees
# 58215  Non-profit institutions serving households (co...    Male employees
# 58222  Non-profit institutions serving households (co...  Female employees
# 58341                   Business non-profit institutions    Male employees
# 58348                   Business non-profit institutions  Female employees
# 58467                 Government non-profit institutions    Male employees
# 58474                 Government non-profit institutions  Female employees
# 66783                      Total non-profit institutions    Male employees
# 66790                      Total non-profit institutions  Female employees
# 66909  Total non-profit institutions excluding govern...    Male employees
# 66916  Total non-profit institutions excluding govern...  Female employees
# 67035  Non-profit institutions serving households (co...    Male employees
# 67042  Non-profit institutions serving households (co...  Female employees
# 67161                   Business non-profit institutions    Male employees
# 67168                   Business non-profit institutions  Female employees
# 67287                 Government non-profit institutions    Male employees
# 67294                 Government non-profit institutions  Female employees
#
#                         Indicators    UOM SCALAR_FACTOR   VALUE
# 57963  Average annual hours worked  Hours         units  1623.0
# 57970  Average annual hours worked  Hours         units  1497.0
# 58089  Average annual hours worked  Hours         units  1695.0
# 58096  Average annual hours worked  Hours         units  1426.0
# 58215  Average annual hours worked  Hours         units  1682.0
# 58222  Average annual hours worked  Hours         units  1411.0
# 58341  Average annual hours worked  Hours         units  1737.0
# 58348  Average annual hours worked  Hours         units  1507.0
# 58467  Average annual hours worked  Hours         units  1586.0
# 58474  Average annual hours worked  Hours         units  1518.0
# 66783  Average annual hours worked  Hours         units  1615.0
# 66790  Average annual hours worked  Hours         units  1482.0
# 66909  Average annual hours worked  Hours         units  1628.0
# 66916  Average annual hours worked  Hours         units  1390.0
# 67035  Average annual hours worked  Hours         units  1618.0
# 67042  Average annual hours worked  Hours         units  1378.0
# 67161  Average annual hours worked  Hours         units  1663.0
# 67168  Average annual hours worked  Hours         units  1456.0
# 67287  Average annual hours worked  Hours         units  1608.0
# 67294  Average annual hours worked  Hours         units  1509.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 57963 to 76114
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                       sum         mean    amin  median    amax  size
# Characteristics
# Female employees  22061.0  1470.733333  1378.0  1482.0  1544.0    15
# Male employees    24772.0  1651.466667  1586.0  1642.0  1737.0    15
#
# Overall,
# Sum :  46833.0
# Mean :  1561.1
# Min/median/max : 1378.0 / 1565.0 / 1737.0
# Skewnewss :  -0.12546913496381007
# Total size :  30
# 2019
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 84423      2019  Saskatchewan
# 84430      2019  Saskatchewan
# 84549      2019  Saskatchewan
# 84556      2019  Saskatchewan
# 84675      2019  Saskatchewan
# 84682      2019  Saskatchewan
# 84801      2019  Saskatchewan
# 84808      2019  Saskatchewan
# 84927      2019  Saskatchewan
# 84934      2019  Saskatchewan
# 93243      2020  Saskatchewan
# 93250      2020  Saskatchewan
# 93369      2020  Saskatchewan
# 93376      2020  Saskatchewan
# 93495      2020  Saskatchewan
# 93502      2020  Saskatchewan
# 93621      2020  Saskatchewan
# 93628      2020  Saskatchewan
# 93747      2020  Saskatchewan
# 93754      2020  Saskatchewan
#
#                                                   Sector   Characteristics  \
# 84423                      Total non-profit institutions    Male employees
# 84430                      Total non-profit institutions  Female employees
# 84549  Total non-profit institutions excluding govern...    Male employees
# 84556  Total non-profit institutions excluding govern...  Female employees
# 84675  Non-profit institutions serving households (co...    Male employees
# 84682  Non-profit institutions serving households (co...  Female employees
# 84801                   Business non-profit institutions    Male employees
# 84808                   Business non-profit institutions  Female employees
# 84927                 Government non-profit institutions    Male employees
# 84934                 Government non-profit institutions  Female employees
# 93243                      Total non-profit institutions    Male employees
# 93250                      Total non-profit institutions  Female employees
# 93369  Total non-profit institutions excluding govern...    Male employees
# 93376  Total non-profit institutions excluding govern...  Female employees
# 93495  Non-profit institutions serving households (co...    Male employees
# 93502  Non-profit institutions serving households (co...  Female employees
# 93621                   Business non-profit institutions    Male employees
# 93628                   Business non-profit institutions  Female employees
# 93747                 Government non-profit institutions    Male employees
# 93754                 Government non-profit institutions  Female employees
#
#                         Indicators    UOM SCALAR_FACTOR   VALUE
# 84423  Average annual hours worked  Hours         units  1644.0
# 84430  Average annual hours worked  Hours         units  1522.0
# 84549  Average annual hours worked  Hours         units  1676.0
# 84556  Average annual hours worked  Hours         units  1454.0
# 84675  Average annual hours worked  Hours         units  1675.0
# 84682  Average annual hours worked  Hours         units  1449.0
# 84801  Average annual hours worked  Hours         units  1682.0
# 84808  Average annual hours worked  Hours         units  1480.0
# 84927  Average annual hours worked  Hours         units  1627.0
# 84934  Average annual hours worked  Hours         units  1544.0
# 93243  Average annual hours worked  Hours         units  1633.0
# 93250  Average annual hours worked  Hours         units  1505.0
# 93369  Average annual hours worked  Hours         units  1633.0
# 93376  Average annual hours worked  Hours         units  1441.0
# 93495  Average annual hours worked  Hours         units  1615.0
# 93502  Average annual hours worked  Hours         units  1427.0
# 93621  Average annual hours worked  Hours         units  1688.0
# 93628  Average annual hours worked  Hours         units  1509.0
# 93747  Average annual hours worked  Hours         units  1633.0
# 93754  Average annual hours worked  Hours         units  1524.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 84423 to 102574
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                       sum         mean    amin  median    amax  size
# Characteristics
# Female employees  22375.0  1491.666667  1427.0  1493.0  1563.0    15
# Male employees    24826.0  1655.066667  1615.0  1657.0  1688.0    15
#
# Overall,
# Sum :  47201.0
# Mean :  1573.3666666666666
# Min/median/max : 1427.0 / 1589.0 / 1688.0
# Skewnewss :  -0.2114383571298647
# Total size :  30
# 2013
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 31559      2013  Saskatchewan
# 31566      2013  Saskatchewan
# 31580      2013  Saskatchewan
# 31685      2013  Saskatchewan
# 31692      2013  Saskatchewan
# 31706      2013  Saskatchewan
# 31811      2013  Saskatchewan
# 31818      2013  Saskatchewan
# 31832      2013  Saskatchewan
# 31937      2013  Saskatchewan
# 31944      2013  Saskatchewan
# 31958      2013  Saskatchewan
# 32063      2013  Saskatchewan
# 32070      2013  Saskatchewan
# 32084      2013  Saskatchewan
# 40379      2014  Saskatchewan
# 40386      2014  Saskatchewan
# 40400      2014  Saskatchewan
# 40505      2014  Saskatchewan
# 40512      2014  Saskatchewan
#
#                                                   Sector  \
# 31559                      Total non-profit institutions
# 31566                      Total non-profit institutions
# 31580                      Total non-profit institutions
# 31685  Total non-profit institutions excluding govern...
# 31692  Total non-profit institutions excluding govern...
# 31706  Total non-profit institutions excluding govern...
# 31811  Non-profit institutions serving households (co...
# 31818  Non-profit institutions serving households (co...
# 31832  Non-profit institutions serving households (co...
# 31937                   Business non-profit institutions
# 31944                   Business non-profit institutions
# 31958                   Business non-profit institutions
# 32063                 Government non-profit institutions
# 32070                 Government non-profit institutions
# 32084                 Government non-profit institutions
# 40379                      Total non-profit institutions
# 40386                      Total non-profit institutions
# 40400                      Total non-profit institutions
# 40505  Total non-profit institutions excluding govern...
# 40512  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 31559  High school diploma and less  Average annual hours worked  Hours
# 31566             Trade certificate  Average annual hours worked  Hours
# 31580  University degree and higher  Average annual hours worked  Hours
# 31685  High school diploma and less  Average annual hours worked  Hours
# 31692             Trade certificate  Average annual hours worked  Hours
# 31706  University degree and higher  Average annual hours worked  Hours
# 31811  High school diploma and less  Average annual hours worked  Hours
# 31818             Trade certificate  Average annual hours worked  Hours
# 31832  University degree and higher  Average annual hours worked  Hours
# 31937  High school diploma and less  Average annual hours worked  Hours
# 31944             Trade certificate  Average annual hours worked  Hours
# 31958  University degree and higher  Average annual hours worked  Hours
# 32063  High school diploma and less  Average annual hours worked  Hours
# 32070             Trade certificate  Average annual hours worked  Hours
# 32084  University degree and higher  Average annual hours worked  Hours
# 40379  High school diploma and less  Average annual hours worked  Hours
# 40386             Trade certificate  Average annual hours worked  Hours
# 40400  University degree and higher  Average annual hours worked  Hours
# 40505  High school diploma and less  Average annual hours worked  Hours
# 40512             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 31559         units  1337.0
# 31566         units  1581.0
# 31580         units  1675.0
# 31685         units  1283.0
# 31692         units  1537.0
# 31706         units  1713.0
# 31811         units  1224.0
# 31818         units  1458.0
# 31832         units  1707.0
# 31937         units  1461.0
# 31944         units  1809.0
# 31958         units  1743.0
# 32063         units  1368.0
# 32070         units  1594.0
# 32084         units  1665.0
# 40379         units  1350.0
# 40386         units  1574.0
# 40400         units  1657.0
# 40505         units  1317.0
# 40512         units  1542.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 31559 to 49724
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  20151.0  1343.400000  1224.0  1330.0  1470.0
# Trade certificate             23728.0  1581.866667  1456.0  1545.0  1809.0
# University degree and higher  25420.0  1694.666667  1607.0  1713.0  1747.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  69299.0
# Mean :  1539.9777777777779
# Min/median/max : 1224.0 / 1545.0 / 1809.0
# Skewnewss :  -0.23945957113697736
# Total size :  45
# 2016
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 58019      2016  Saskatchewan
# 58026      2016  Saskatchewan
# 58040      2016  Saskatchewan
# 58145      2016  Saskatchewan
# 58152      2016  Saskatchewan
# 58166      2016  Saskatchewan
# 58271      2016  Saskatchewan
# 58278      2016  Saskatchewan
# 58292      2016  Saskatchewan
# 58397      2016  Saskatchewan
# 58404      2016  Saskatchewan
# 58418      2016  Saskatchewan
# 58523      2016  Saskatchewan
# 58530      2016  Saskatchewan
# 58544      2016  Saskatchewan
# 66839      2017  Saskatchewan
# 66846      2017  Saskatchewan
# 66860      2017  Saskatchewan
# 66965      2017  Saskatchewan
# 66972      2017  Saskatchewan
#
#                                                   Sector  \
# 58019                      Total non-profit institutions
# 58026                      Total non-profit institutions
# 58040                      Total non-profit institutions
# 58145  Total non-profit institutions excluding govern...
# 58152  Total non-profit institutions excluding govern...
# 58166  Total non-profit institutions excluding govern...
# 58271  Non-profit institutions serving households (co...
# 58278  Non-profit institutions serving households (co...
# 58292  Non-profit institutions serving households (co...
# 58397                   Business non-profit institutions
# 58404                   Business non-profit institutions
# 58418                   Business non-profit institutions
# 58523                 Government non-profit institutions
# 58530                 Government non-profit institutions
# 58544                 Government non-profit institutions
# 66839                      Total non-profit institutions
# 66846                      Total non-profit institutions
# 66860                      Total non-profit institutions
# 66965  Total non-profit institutions excluding govern...
# 66972  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
#
# 84626  Total non-profit institutions excluding govern...
# 84731  Non-profit institutions serving households (co...
# 84738  Non-profit institutions serving households (co...
# 84752  Non-profit institutions serving households (co...
# 84857                   Business non-profit institutions
# 84864                   Business non-profit institutions
# 84878                   Business non-profit institutions
# 84983                 Government non-profit institutions
# 84990                 Government non-profit institutions
# 85004                 Government non-profit institutions
# 93299                      Total non-profit institutions
# 93306                      Total non-profit institutions
# 93320                      Total non-profit institutions
# 93425  Total non-profit institutions excluding govern...
# 93432  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 84479  High school diploma and less  Average annual hours worked  Hours
# 84486             Trade certificate  Average annual hours worked  Hours
# 84500  University degree and higher  Average annual hours worked  Hours
# 84605  High school diploma and less  Average annual hours worked  Hours
# 84612             Trade certificate  Average annual hours worked  Hours
# 84626  University degree and higher  Average annual hours worked  Hours
# 84731  High school diploma and less  Average annual hours worked  Hours
# 84738             Trade certificate  Average annual hours worked  Hours
# 84752  University degree and higher  Average annual hours worked  Hours
# 84857  High school diploma and less  Average annual hours worked  Hours
# 84864             Trade certificate  Average annual hours worked  Hours
# 84878  University degree and higher  Average annual hours worked  Hours
# 84983  High school diploma and less  Average annual hours worked  Hours
# 84990             Trade certificate  Average annual hours worked  Hours
# 85004  University degree and higher  Average annual hours worked  Hours
# 93299  High school diploma and less  Average annual hours worked  Hours
# 93306             Trade certificate  Average annual hours worked  Hours
# 93320  University degree and higher  Average annual hours worked  Hours
# 93425  High school diploma and less  Average annual hours worked  Hours
# 93432             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 84479         units  1333.0
# 84486         units  1546.0
# 84500         units  1655.0
# 84605         units  1300.0
# 84612         units  1546.0
# 84626         units  1693.0
# 84731         units  1270.0
# 84738         units  1507.0
# 84752         units  1695.0
# 84857         units  1400.0
# 84864         units  1682.0
# 84878         units  1685.0
# 84983         units  1353.0
# 84990         units  1546.0
# 85004         units  1643.0
# 93299         units  1331.0
# 93306         units  1528.0
# 93320         units  1637.0
# 93425         units  1288.0
# 93432         units  1537.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 84479 to 102644
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19994.0  1332.933333  1251.0  1333.0  1410.0
# Trade certificate             23481.0  1565.400000  1493.0  1546.0  1685.0
# University degree and higher  25030.0  1668.666667  1634.0  1671.0  1707.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  68505.0
# Mean :  1522.3333333333333
# Min/median/max : 1251.0 / 1546.0 / 1707.0
# Skewnewss :  -0.41071412438731125
# Total size :  45
# 2013
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 31559      2013  Saskatchewan
# 31566      2013  Saskatchewan
# 31580      2013  Saskatchewan
# 31685      2013  Saskatchewan
# 31692      2013  Saskatchewan
# ...
# 31944      2013  Saskatchewan
# 31958      2013  Saskatchewan
# 32063      2013  Saskatchewan
# 32070      2013  Saskatchewan
# 32084      2013  Saskatchewan
# 40379      2014  Saskatchewan
# 40386      2014  Saskatchewan
# 40400      2014  Saskatchewan
# 40505      2014  Saskatchewan
# 40512      2014  Saskatchewan
#
#                                                   Sector  \
# 31559                      Total non-profit institutions
# 31566                      Total non-profit institutions
# 31580                      Total non-profit institutions
# 31685  Total non-profit institutions excluding govern...
# 31692  Total non-profit institutions excluding govern...
# 31706  Total non-profit institutions excluding govern...
# 31811  Non-profit institutions serving households (co...
# 31818  Non-profit institutions serving households (co...
# 31832  Non-profit institutions serving households (co...
# 31937                   Business non-profit institutions
# 31944                   Business non-profit institutions
# 31958                   Business non-profit institutions
# 32063                 Government non-profit institutions
# 32070                 Government non-profit institutions
# 32084                 Government non-profit institutions
# 40379                      Total non-profit institutions
# 40386                      Total non-profit institutions
# 40400                      Total non-profit institutions
# 40505  Total non-profit institutions excluding govern...
# 40512  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 31559  High school diploma and less  Average annual hours worked  Hours
# 31566             Trade certificate  Average annual hours worked  Hours
# 31580  University degree and higher  Average annual hours worked  Hours
# 31685  High school diploma and less  Average annual hours worked  Hours
# 31692             Trade certificate  Average annual hours worked  Hours
# 31706  University degree and higher  Average annual hours worked  Hours
# 31811  High school diploma and less  Average annual hours worked  Hours
# 31818             Trade certificate  Average annual hours worked  Hours
# 31832  University degree and higher  Average annual hours worked  Hours
# 31937  High school diploma and less  Average annual hours worked  Hours
# 31944             Trade certificate  Average annual hours worked  Hours
# 31958  University degree and higher  Average annual hours worked  Hours
# 32063  High school diploma and less  Average annual hours worked  Hours
# 32070             Trade certificate  Average annual hours worked  Hours
# 32084  University degree and higher  Average annual hours worked  Hours
# 40379  High school diploma and less  Average annual hours worked  Hours
# 40386             Trade certificate  Average annual hours worked  Hours
# 40400  University degree and higher  Average annual hours worked  Hours
# 40505  High school diploma and less  Average annual hours worked  Hours
# 40512             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 31559         units  1337.0
# 31566         units  1581.0
# 31580         units  1675.0
# 31685         units  1283.0
# 31692         units  1537.0
# 31706         units  1713.0
# 31811         units  1224.0
# 31818         units  1458.0
# 31832         units  1707.0
# 31937         units  1461.0
# 31944         units  1809.0
# 31958         units  1743.0
# 32063         units  1368.0
# 32070         units  1594.0
# 32084         units  1665.0
# 40379         units  1350.0
# 40386         units  1574.0
# 40400         units  1657.0
# 40505         units  1317.0
# 40512         units  1542.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 31559 to 49724
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  20151.0  1343.400000  1224.0  1330.0  1470.0
# Trade certificate             23728.0  1581.866667  1456.0  1545.0  1809.0
# University degree and higher  25420.0  1694.666667  1607.0  1713.0  1747.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  69299.0
# Mean :  1539.9777777777779
# Min/median/max : 1224.0 / 1545.0 / 1809.0
# Skewnewss :  -0.23945957113697736
# Total size :  45
# 2016
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 57977      2016  Saskatchewan
# 57984      2016  Saskatchewan
# 58103      2016  Saskatchewan
# 58110      2016  Saskatchewan
# 58229      2016  Saskatchewan
# 58236      2016  Saskatchewan
# 58355      2016  Saskatchewan
# 58362      2016  Saskatchewan
# 58481      2016  Saskatchewan
# 58488      2016  Saskatchewan
# 66797      2017  Saskatchewan
# 66804      2017  Saskatchewan
# 66923      2017  Saskatchewan
# 66930      2017  Saskatchewan
# 67049      2017  Saskatchewan
# 67056      2017  Saskatchewan
# 67175      2017  Saskatchewan
# 67182      2017  Saskatchewan
# 67301      2017  Saskatchewan
# 67308      2017  Saskatchewan
#
#                                                   Sector  \
# 57977                      Total non-profit institutions
# 57984                      Total non-profit institutions
# 58103  Total non-profit institutions excluding govern...
# 58110  Total non-profit institutions excluding govern...
# 58229  Non-profit institutions serving households (co...
# 58236  Non-profit institutions serving households (co...
# 58355                   Business non-profit institutions
# 58362                   Business non-profit institutions
# 58481                 Government non-profit institutions
# 58488                 Government non-profit institutions
# 66797                      Total non-profit institutions
# 66804                      Total non-profit institutions
# 66923  Total non-profit institutions excluding govern...
# 66930  Total non-profit institutions excluding govern...
# 67049  Non-profit institutions serving households (co...
# 67056  Non-profit institutions serving households (co...
# 67175                   Business non-profit institutions
# 67182                   Business non-profit institutions
# 67301                 Government non-profit institutions
# 67308                 Government non-profit institutions
#
#                Characteristics                   Indicators    UOM  \
# 57977      Immigrant employees  Average annual hours worked  Hours
# 57984  Non-immigrant employees  Average annual hours worked  Hours
# 58103      Immigrant employees  Average annual hours worked  Hours
# 58110  Non-immigrant employees  Average annual hours worked  Hours
# 58229      Immigrant employees  Average annual hours worked  Hours
# 58236  Non-immigrant employees  Average annual hours worked  Hours
# 58355      Immigrant employees  Average annual hours worked  Hours
# 58362  Non-immigrant employees  Average annual hours worked  Hours
# 58481      Immigrant employees  Average annual hours worked  Hours
# 58488  Non-immigrant employees  Average annual hours worked  Hours
# 66797      Immigrant employees  Average annual hours worked  Hours
# 66804  Non-immigrant employees  Average annual hours worked  Hours
# 66923      Immigrant employees  Average annual hours worked  Hours
# 66930  Non-immigrant employees  Average annual hours worked  Hours
# 67049      Immigrant employees  Average annual hours worked  Hours
# 67056  Non-immigrant employees  Average annual hours worked  Hours
# 67175      Immigrant employees  Average annual hours worked  Hours
# 67182  Non-immigrant employees  Average annual hours worked  Hours
# 67301      Immigrant employees  Average annual hours worked  Hours
# 67308  Non-immigrant employees  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 57977         units  1529.0
# 57984         units  1531.0
# 58103         units  1533.0
# 58110         units  1518.0
# 58229         units  1516.0
# 58236         units  1496.0
# 58355         units  1629.0
# 58362         units  1610.0
# 58481         units  1528.0
# 58488         units  1535.0
# 66797         units  1523.0
# 66804         units  1516.0
# 66923         units  1485.0
# 66930         units  1470.0
# 67049         units  1471.0
# 67056         units  1452.0
# 67175         units  1557.0
# 67182         units  1547.0
# 67301         units  1532.0
# 67308         units  1533.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 57977 to 76128
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                              sum    mean    amin  median    amax  size
# Characteristics
# Immigrant employees      23109.0  1540.6  1471.0  1532.0  1629.0    15
# Non-immigrant employees  22968.0  1531.2  1452.0  1531.0  1610.0    15
#
# Overall,
# Sum :  46077.0
# Mean :  1535.9
# Min/median/max : 1452.0 / 1531.5 / 1629.0
# Skewnewss :  0.35030046818430766
# Total size :  30
# 2019
#
# Grab the dataset only in Saskatchewan
#        REF_DATE           GEO  \
# 84479      2019  Saskatchewan
# 84486      2019  Saskatchewan
# 84500      2019  Saskatchewan
# 84605      2019  Saskatchewan
# 84612      2019  Saskatchewan
# 84626      2019  Saskatchewan
# 84731      2019  Saskatchewan
# 84738      2019  Saskatchewan
# 84752      2019  Saskatchewan
# 84857      2019  Saskatchewan
# 84864      2019  Saskatchewan
# 84878      2019  Saskatchewan
# 84983      2019  Saskatchewan
# 84990      2019  Saskatchewan
# 85004      2019  Saskatchewan
# 93299      2020  Saskatchewan
# 93306      2020  Saskatchewan
# 93320      2020  Saskatchewan
# 93425      2020  Saskatchewan
# 93432      2020  Saskatchewan
#
#                                                   Sector  \
# 84479                      Total non-profit institutions
# 84486                      Total non-profit institutions
# 84500                      Total non-profit institutions
# 84605  Total non-profit institutions excluding govern...
# 84612  Total non-profit institutions excluding govern...
# 84626  Total non-profit institutions excluding govern...
# 84731  Non-profit institutions serving households (co...
# 84738  Non-profit institutions serving households (co...
# 84752  Non-profit institutions serving households (co...
# 84857                   Business non-profit institutions
# 84864                   Business non-profit institutions
# 84878                   Business non-profit institutions
# 84983                 Government non-profit institutions
# 84990                 Government non-profit institutions
# 85004                 Government non-profit institutions
# 93299                      Total non-profit institutions
# 93306                      Total non-profit institutions
# 93320                      Total non-profit institutions
# 93425  Total non-profit institutions excluding govern...
# 93432  Total non-profit institutions excluding govern...
#
#                     Characteristics                   Indicators    UOM  \
# 84479  High school diploma and less  Average annual hours worked  Hours
# 84486             Trade certificate  Average annual hours worked  Hours
# 84500  University degree and higher  Average annual hours worked  Hours
# 84605  High school diploma and less  Average annual hours worked  Hours
# 84612             Trade certificate  Average annual hours worked  Hours
# 84626  University degree and higher  Average annual hours worked  Hours
# 84731  High school diploma and less  Average annual hours worked  Hours
# 84738             Trade certificate  Average annual hours worked  Hours
# 84752  University degree and higher  Average annual hours worked  Hours
# 84857  High school diploma and less  Average annual hours worked  Hours
# 84864             Trade certificate  Average annual hours worked  Hours
# 84878  University degree and higher  Average annual hours worked  Hours
# 84983  High school diploma and less  Average annual hours worked  Hours
# 84990             Trade certificate  Average annual hours worked  Hours
# 85004  University degree and higher  Average annual hours worked  Hours
# 93299  High school diploma and less  Average annual hours worked  Hours
# 93306             Trade certificate  Average annual hours worked  Hours
# 93320  University degree and higher  Average annual hours worked  Hours
# 93425  High school diploma and less  Average annual hours worked  Hours
# 93432             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 84479         units  1333.0
# 84486         units  1546.0
# 84500         units  1655.0
# 84605         units  1300.0
# 84612         units  1546.0
# 84626         units  1693.0
# 84731         units  1270.0
# 84738         units  1507.0
# 84752         units  1695.0
# 84857         units  1400.0
# 84864         units  1682.0
# 84878         units  1685.0
# 84983         units  1353.0
# 84990         units  1546.0
# 85004         units  1643.0
# 93299         units  1331.0
# 93306         units  1528.0
# 93320         units  1637.0
# 93425         units  1288.0
# 93432         units  1537.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 84479 to 102644
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Saskatchewan
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19994.0  1332.933333  1251.0  1333.0  1410.0
# Trade certificate             23481.0  1565.400000  1493.0  1546.0  1685.0
# University degree and higher  25030.0  1668.666667  1634.0  1671.0  1707.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  68505.0
# Mean :  1522.3333333333333
# Min/median/max : 1251.0 / 1546.0 / 1707.0
# Skewnewss :  -0.41071412438731125
# Total size :  45

# %% [markdown]
# Panda Profiling for Final Result for Saskatchewan

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Filtering only Yukon.

# %% [markdown]
# Only finished "Average annual hours worked".

# %%
# -- Yukon                         16914.0     18.070513     20.188135   936

ProCode = 13

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          7276.0   808.444444   462.0   876.0   953.0     9
# 25 to 34 years         23527.0  1568.466667  1408.0  1514.0  1882.0    15
# 35 to 44 years         25314.0  1687.600000  1477.0  1721.0  1864.0    15
# 45 to 54 years         26117.0  1741.133333  1577.0  1679.0  2294.0    15
# 55 to 64 years         23196.0  1546.400000  1390.0  1539.0  1673.0    15
# 65 years old and over   7438.0   826.444444   724.0   812.0   962.0     9
#
# Overall,
# Sum :  112868.0
# Mean :  1447.025641025641
# Min/median/max : 462.0 / 1567.5 / 2294.0
# Skewnewss :  -0.8219440206627865
# Total size :  78
# 2016
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 59937      2016  Yukon                      Total non-profit institutions
# 59944      2016  Yukon                      Total non-profit institutions
# 59951      2016  Yukon                      Total non-profit institutions
# 59958      2016  Yukon                      Total non-profit institutions
# 59965      2016  Yukon                      Total non-profit institutions
# 59972      2016  Yukon                      Total non-profit institutions
# 60063      2016  Yukon  Total non-profit institutions excluding govern...
# 60070      2016  Yukon  Total non-profit institutions excluding govern...
# 60077      2016  Yukon  Total non-profit institutions excluding govern...
# 60084      2016  Yukon  Total non-profit institutions excluding govern...
# 60091      2016  Yukon  Total non-profit institutions excluding govern...
# 60098      2016  Yukon  Total non-profit institutions excluding govern...
# 60196      2016  Yukon  Non-profit institutions serving households (co...
# 60203      2016  Yukon  Non-profit institutions serving households (co...
# 60210      2016  Yukon  Non-profit institutions serving households (co...
# 60217      2016  Yukon  Non-profit institutions serving households (co...
# 60322      2016  Yukon                   Business non-profit institutions
# 60329      2016  Yukon                   Business non-profit institutions
# 60336      2016  Yukon                   Business non-profit institutions
# 60343      2016  Yukon                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 59937         15 to 24 years  Average annual hours worked  Hours
# 59944         25 to 34 years  Average annual hours worked  Hours
# 59951         35 to 44 years  Average annual hours worked  Hours
# 59958         45 to 54 years  Average annual hours worked  Hours
# 59965         55 to 64 years  Average annual hours worked  Hours
# 59972  65 years old and over  Average annual hours worked  Hours
# 60063         15 to 24 years  Average annual hours worked  Hours
# 60070         25 to 34 years  Average annual hours worked  Hours
# 60077         35 to 44 years  Average annual hours worked  Hours
# 60084         45 to 54 years  Average annual hours worked  Hours
# 60091         55 to 64 years  Average annual hours worked  Hours
# 60098  65 years old and over  Average annual hours worked  Hours
# 60196         25 to 34 years  Average annual hours worked  Hours
# 60203         35 to 44 years  Average annual hours worked  Hours
# 60210         45 to 54 years  Average annual hours worked  Hours
# 60217         55 to 64 years  Average annual hours worked  Hours
# 60322         25 to 34 years  Average annual hours worked  Hours
# 60329         35 to 44 years  Average annual hours worked  Hours
# 60336         45 to 54 years  Average annual hours worked  Hours
# 60343         55 to 64 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 59937         units   908.0
# 59944         units  1482.0
# 59951         units  1601.0
# 59958         units  1693.0
# 59965         units  1515.0
# 59972         units   757.0
# 60063         units   924.0
# 60070         units  1449.0
# 60077         units  1774.0
# 60084         units  1665.0
# 60091         units  1417.0
# 60098         units   719.0
# 60196         units  1411.0
# 60203         units  1759.0
# 60210         units  1606.0
# 60217         units  1410.0
# 60322         units  1864.0
# 60329         units  1864.0
# 60336         units  2312.0
# 60343         units  1500.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 59937 to 78116
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         78 non-null     int64
#  1   GEO              78 non-null     object
#  2   Sector           78 non-null     object
#  3   Characteristics  78 non-null     object
#  4   Indicators       78 non-null     object
#  5   UOM              78 non-null     object
#  6   SCALAR_FACTOR    78 non-null     object
#  7   VALUE            78 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Yukon
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          8722.0   969.111111   882.0   925.0  1185.0     9
# 25 to 34 years         22959.0  1530.600000  1343.0  1482.0  1864.0    15
# 35 to 44 years         25369.0  1691.266667  1436.0  1773.0  1864.0    15
# 45 to 54 years         26570.0  1771.333333  1595.0  1716.0  2312.0    15
# 55 to 64 years         22400.0  1493.333333  1410.0  1500.0  1608.0    15
# 65 years old and over   6811.0   756.777778   701.0   754.0   828.0     9
#
# Overall,
# Sum :  112831.0
# Mean :  1446.551282051282
# Min/median/max : 701.0 / 1503.5 / 2312.0
# Skewnewss :  -0.6012574770654578
# Total size :  78
# 2019
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 86397      2019  Yukon                      Total non-profit institutions
# 86404      2019  Yukon                      Total non-profit institutions
# 86411      2019  Yukon                      Total non-profit institutions
# 86418      2019  Yukon                      Total non-profit institutions
# 86425      2019  Yukon                      Total non-profit institutions
# 86432      2019  Yukon                      Total non-profit institutions
# 86523      2019  Yukon  Total non-profit institutions excluding govern...
# 86530      2019  Yukon  Total non-profit institutions excluding govern...
# 86537      2019  Yukon  Total non-profit institutions excluding govern...
# 86544      2019  Yukon  Total non-profit institutions excluding govern...
# 86551      2019  Yukon  Total non-profit institutions excluding govern...
# 86558      2019  Yukon  Total non-profit institutions excluding govern...
# 86656      2019  Yukon  Non-profit institutions serving households (co...
# 86663      2019  Yukon  Non-profit institutions serving households (co...
# 86670      2019  Yukon  Non-profit institutions serving households (co...
# 86677      2019  Yukon  Non-profit institutions serving households (co...
# 86782      2019  Yukon                   Business non-profit institutions
# 86789      2019  Yukon                   Business non-profit institutions
# 86796      2019  Yukon                   Business non-profit institutions
# 86803      2019  Yukon                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 86397         15 to 24 years  Average annual hours worked  Hours
# 86404         25 to 34 years  Average annual hours worked  Hours
# 86411         35 to 44 years  Average annual hours worked  Hours
# 86418         45 to 54 years  Average annual hours worked  Hours
# 86425         55 to 64 years  Average annual hours worked  Hours
# 86432  65 years old and over  Average annual hours worked  Hours
# 86523         15 to 24 years  Average annual hours worked  Hours
# 86530         25 to 34 years  Average annual hours worked  Hours
# 86537         35 to 44 years  Average annual hours worked  Hours
# 86544         45 to 54 years  Average annual hours worked  Hours
# 86551         55 to 64 years  Average annual hours worked  Hours
# 86558  65 years old and over  Average annual hours worked  Hours
# 86656         25 to 34 years  Average annual hours worked  Hours
# 86663         35 to 44 years  Average annual hours worked  Hours
# 86670         45 to 54 years  Average annual hours worked  Hours
# 86677         55 to 64 years  Average annual hours worked  Hours
# 86782         25 to 34 years  Average annual hours worked  Hours
# 86789         35 to 44 years  Average annual hours worked  Hours
# 86796         45 to 54 years  Average annual hours worked  Hours
# 86803         55 to 64 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 86397         units   987.0
# 86404         units  1416.0
# 86411         units  1602.0
# 86418         units  1749.0
# 86425         units  1453.0
# 86432         units   719.0
# 86523         units   913.0
# 86530         units  1363.0
# 86537         units  1794.0
# 86544         units  1640.0
# 86551         units  1419.0
# 86558         units   798.0
# 86656         units  1307.0
# 86663         units  1779.0
# 86670         units  1600.0
# 86677         units  1405.0
# 86782         units  1870.0
# 86789         units  1875.0
# 86796         units  2000.0
# 86803         units  1500.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 86397 to 104576
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         78 non-null     int64
#  1   GEO              78 non-null     object
#  2   Sector           78 non-null     object
#  3   Characteristics  78 non-null     object
#  4   Indicators       78 non-null     object
#  5   UOM              78 non-null     object
#  6   SCALAR_FACTOR    78 non-null     object
#  7   VALUE            78 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.5+ KB
# None
#
# Grab the dataset only in Yukon
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years          8712.0   968.000000   885.0   924.0  1281.0     9
# 25 to 34 years         22260.0  1484.000000  1292.0  1416.0  1870.0    15
# 35 to 44 years         25897.0  1726.466667  1424.0  1794.0  1957.0    15
# 45 to 54 years         26108.0  1740.533333  1600.0  1683.0  2000.0    15
# 55 to 64 years         22232.0  1482.133333  1377.0  1474.0  1728.0    15
# 65 years old and over   6443.0   715.888889   565.0   719.0   850.0     9
#
# Overall,
# Sum :  111652.0
# Mean :  1431.4358974358975
# Min/median/max : 565.0 / 1491.0 / 2000.0
# Skewnewss :  -0.7102658286319622
# Total size :  78
# 2013
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 33393      2013  Yukon                      Total non-profit institutions
# 33400      2013  Yukon                      Total non-profit institutions
# 33519      2013  Yukon  Total non-profit institutions excluding govern...
# 33526      2013  Yukon  Total non-profit institutions excluding govern...
# 33645      2013  Yukon  Non-profit institutions serving households (co...
# 33652      2013  Yukon  Non-profit institutions serving households (co...
# 33771      2013  Yukon                   Business non-profit institutions
# 33778      2013  Yukon                   Business non-profit institutions
# 33897      2013  Yukon                 Government non-profit institutions
# 33904      2013  Yukon                 Government non-profit institutions
# 42213      2014  Yukon                      Total non-profit institutions
# 42220      2014  Yukon                      Total non-profit institutions
# 42339      2014  Yukon  Total non-profit institutions excluding govern...
# 42346      2014  Yukon  Total non-profit institutions excluding govern...
# 42465      2014  Yukon  Non-profit institutions serving households (co...
# 42472      2014  Yukon  Non-profit institutions serving households (co...
# 42591      2014  Yukon                   Business non-profit institutions
# 42598      2014  Yukon                   Business non-profit institutions
# 42717      2014  Yukon                 Government non-profit institutions
# 42724      2014  Yukon                 Government non-profit institutions
#
#         Characteristics                   Indicators    UOM SCALAR_FACTOR  \
# 33393    Male employees  Average annual hours worked  Hours         units
# 33400  Female employees  Average annual hours worked  Hours         units
# 33519    Male employees  Average annual hours worked  Hours         units
# 33526  Female employees  Average annual hours worked  Hours         units
# 33645    Male employees  Average annual hours worked  Hours         units
# 33652  Female employees  Average annual hours worked  Hours         units
# 33771    Male employees  Average annual hours worked  Hours         units
# 33778  Female employees  Average annual hours worked  Hours         units
# 33897    Male employees  Average annual hours worked  Hours         units
# 33904  Female employees  Average annual hours worked  Hours         units
Female employees  Average annual hours worked  Hours         units
#
#         VALUE
# 59853  1749.0
# 59860  1333.0
# 59979  1670.0
# 59986  1279.0
# 60105  1659.0
# 60112  1260.0
# 60231  1783.0
# 60238  1536.0
# 60357  1861.0
# 60364  1397.0
# 68673  1698.0
# 68680  1367.0
# 68799  1611.0
# 68806  1316.0
# 68925  1596.0
# 68932  1301.0
# 69051  1673.0
# 69058  1468.0
# 69177  1832.0
# 69184  1428.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 59853 to 78004
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Yukon
#                       sum         mean    amin  median    amax  size
# Characteristics
# Female employees  20564.0  1370.933333  1260.0  1354.0  1536.0    15
# Male employees    25442.0  1696.133333  1558.0  1673.0  1861.0    15
#
# Overall,
# Sum :  46006.0
# Mean :  1533.5333333333333
# Min/median/max : 1260.0 / 1547.0 / 1861.0
# Skewnewss :  0.09064089970596877
# Total size :  30
# 2019
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 86313      2019  Yukon                      Total non-profit institutions
# 86320      2019  Yukon                      Total non-profit institutions
# 86439      2019  Yukon  Total non-profit institutions excluding govern...
# 86446      2019  Yukon  Total non-profit institutions excluding govern...
# 86565      2019  Yukon  Non-profit institutions serving households (co...
# 86572      2019  Yukon  Non-profit institutions serving households (co...
# 86691      2019  Yukon                   Business non-profit institutions
# 86698      2019  Yukon                   Business non-profit institutions
# 86817      2019  Yukon                 Government non-profit institutions
# 86824      2019  Yukon                 Government non-profit institutions
# 95133      2020  Yukon                      Total non-profit institutions
# 95140      2020  Yukon                      Total non-profit institutions
# 95259      2020  Yukon  Total non-profit institutions excluding govern...
# 95266      2020  Yukon  Total non-profit institutions excluding govern...
# 95385      2020  Yukon  Non-profit institutions serving households (co...
# 95392      2020  Yukon  Non-profit institutions serving households (co...
# 95511      2020  Yukon                   Business non-profit institutions
# 95518      2020  Yukon                   Business non-profit institutions
# 95637      2020  Yukon                 Government non-profit institutions
# 95644      2020  Yukon                 Government non-profit institutions
#
#         Characteristics                   Indicators    UOM SCALAR_FACTOR  \
# 86313    Male employees  Average annual hours worked  Hours         units
# 86320  Female employees  Average annual hours worked  Hours         units
# 86439    Male employees  Average annual hours worked  Hours         units
# 86446  Female employees  Average annual hours worked  Hours         units
# 86565    Male employees  Average annual hours worked  Hours         units
# 86572  Female employees  Average annual hours worked  Hours         units
# 86691    Male employees  Average annual hours worked  Hours         units
# 86698  Female employees  Average annual hours worked  Hours         units
# 86817    Male employees  Average annual hours worked  Hours         units
# 86824  Female employees  Average annual hours worked  Hours         units
# 95133    Male employees  Average annual hours worked  Hours         units
# 95140  Female employees  Average annual hours worked  Hours         units
# 95259    Male employees  Average annual hours worked  Hours         units
# 95266  Female employees  Average annual hours worked  Hours         units
# 95385    Male employees  Average annual hours worked  Hours         units
# 95392  Female employees  Average annual hours worked  Hours         units
# 95511    Male employees  Average annual hours worked  Hours         units
# 95518  Female employees  Average annual hours worked  Hours         units
# 95637    Male employees  Average annual hours worked  Hours         units
# 95644  Female employees  Average annual hours worked  Hours         units
#
#         VALUE
#
0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 33449 to 51614
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Yukon
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19194.0  1279.600000  1085.0  1216.0  1574.0
# Trade certificate             12251.0  1361.222222  1125.0  1388.0  1550.0
# University degree and higher  14780.0  1642.222222  1585.0  1648.0  1708.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  46225.0
# Mean :  1400.7575757575758
# Min/median/max : 1085.0 / 1425.0 / 1708.0
# Skewnewss :  -0.11614327495631972
# Total size :  33
# 2016
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 59909      2016  Yukon                      Total non-profit institutions
# 59916      2016  Yukon                      Total non-profit institutions
# 59930      2016  Yukon                      Total non-profit institutions
# 60035      2016  Yukon  Total non-profit institutions excluding govern...
# 60042      2016  Yukon  Total non-profit institutions excluding govern...
# 60056      2016  Yukon  Total non-profit institutions excluding govern...
# 60161      2016  Yukon  Non-profit institutions serving households (co...
# 60287      2016  Yukon                   Business non-profit institutions
# 60413      2016  Yukon                 Government non-profit institutions
# 60420      2016  Yukon                 Government non-profit institutions
# 60434      2016  Yukon                 Government non-profit institutions
# 68729      2017  Yukon                      Total non-profit institutions
# 68736      2017  Yukon                      Total non-profit institutions
# 68750      2017  Yukon                      Total non-profit institutions
# 68855      2017  Yukon  Total non-profit institutions excluding govern...
# 68862      2017  Yukon  Total non-profit institutions excluding govern...
# 68876      2017  Yukon  Total non-profit institutions excluding govern...
# 68981      2017  Yukon  Non-profit institutions serving households (co...
# 69107      2017  Yukon                   Business non-profit institutions
# 69233      2017  Yukon                 Government non-profit institutions
#
#                     Characteristics                   Indicators    UOM  \
# 59909  High school diploma and less  Average annual hours worked  Hours
# 59916             Trade certificate  Average annual hours worked  Hours
# 59930  University degree and higher  Average annual hours worked  Hours
# 60035  High school diploma and less  Average annual hours worked  Hours
# 60042             Trade certificate  Average annual hours worked  Hours
# 60056  University degree and higher  Average annual hours worked  Hours
# 60161  High school diploma and less  Average annual hours worked  Hours
# 60287  High school diploma and less  Average annual hours worked  Hours
# 60413  High school diploma and less  Average annual hours worked  Hours
# 60420             Trade certificate  Average annual hours worked  Hours
# 60434  University degree and higher  Average annual hours worked  Hours
# 68729  High school diploma and less  Average annual hours worked  Hours
# 68736             Trade certificate  Average annual hours worked  Hours
# 68750  University degree and higher  Average annual hours worked  Hours
# 68855  High school diploma and less  Average annual hours worked  Hours
# 68862             Trade certificate  Average annual hours worked  Hours
# 68876  University degree and higher  Average annual hours worked  Hours
# 68981  High school diploma and less  Average annual hours worked  Hours
# 69107  High school diploma and less  Average annual hours worked  Hours
# 69233  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 59909         units  1215.0
# 59916         units  1259.0
# 59930         units  1616.0
# 60035         units  1154.0
# 60042         units  1515.0
# 60056         units  1588.0
# 60161         units  1106.0
# 60287         units  1543.0
# 60413         units  1436.0
# 60420         units  1027.0
# 60434         units  1647.0
# 68729         units  1212.0
# 68736         units  1204.0
# 68750         units  1654.0
# 68855         units  1141.0
# 68862         units  1471.0
# 68876         units  1623.0
# 68981         units  1098.0
# 69107         units  1458.0
# 69233         units  1459.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 59909 to 78074
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Yukon
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19173.0  1278.200000  1075.0  1212.0  1543.0
# Trade certificate             10938.0  1215.333333   888.0  1204.0  1515.0
# University degree and higher  14715.0  1635.000000  1588.0  1632.0  1688.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  44826.0
# Mean :  1358.3636363636363
# Min/median/max : 888.0 / 1444.0 / 1688.0
# Skewnewss :  -0.2289882553806574
# Total size :  33
# 2019
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 86369      2019  Yukon                      Total non-profit institutions
# 86376      2019  Yukon                      Total non-profit institutions
# 86390      2019  Yukon                      Total non-profit institutions
# 86495      2019  Yukon  Total non-profit institutions excluding govern...
# 86502      2019  Yukon  Total non-profit institutions excluding govern...
# 86516      2019  Yukon  Total non-profit institutions excluding govern...
# 86621      2019  Yukon  Non-profit institutions serving households (co...
# 86747      2019  Yukon                   Business non-profit institutions
# 86873      2019  Yukon                 Government non-profit institutions
# 86880      2019  Yukon                 Government non-profit institutions
# 86894      2019  Yukon                 Government non-profit institutions
# 95189      2020  Yukon                      Total non-profit institutions
# 95196      2020  Yukon                      Total non-profit institutions
# 95210      2020  Yukon                      Total non-profit institutions
# 95315      2020  Yukon  Total non-profit institutions excluding govern...
# 95322      2020  Yukon  Total non-profit institutions excluding govern...
# 95336      2020  Yukon  Total non-profit institutions excluding govern...
# 95441      2020  Yukon  Non-profit institutions serving households (co...
# 95567      2020  Yukon                   Business non-profit institutions
# 95693      2020  Yukon                 Government non-profit institutions
#
#                     Characteristics                   Indicators    UOM  \
# 86369  High school diploma and less  Average annual hours worked  Hours
# 86376             Trade certificate  Average annual hours worked  Hours
# 86390  University degree and higher  Average annual hours worked  Hours
# 86495  High school diploma and less  Average annual hours worked  Hours
# 86502             Trade certificate  Average annual hours worked  Hours
# 86516  University degree and higher  Average annual hours worked  Hours
# 86621  High school diploma and less  Average annual hours worked  Hours
# 86747  High school diploma and less  Average annual hours worked  Hours
# 86873  High school diploma and less  Average annual hours worked  Hours
# 86880             Trade certificate  Average annual hours worked  Hours
# 86894  University degree and higher  Average annual hours worked  Hours
# 95189  High school diploma and less  Average annual hours worked  Hours
# 95196             Trade certificate  Average annual hours worked  Hours
# 95210  University degree and higher  Average annual hours worked  Hours
# 95315  High school diploma and less  Average annual hours worked  Hours
# 95322             Trade certificate  Average annual hours worked  Hours
# 95336  University degree and higher  Average annual hours worked  Hours
# 95441  High school diploma and less  Average annual hours worked  Hours
# 95567  High school diploma and less  Average annual hours worked  Hours
# 95693  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 86369         units  1198.0
# 86376         units  1058.0
# 86390         units  1629.0
# 86495         units  1122.0
# 86502         units  1438.0
# 86516         units  1587.0
# 86621         units  1068.0
# 86747         units  1543.0
# 86873         units  1445.0
# 86880         units   789.0
# 86894         units  1671.0
# 95189         units  1094.0
# 95196         units  1288.0
# 95210         units  1557.0
# 95315         units  1115.0
# 95322         units  1393.0
# 95336         units  1581.0
# 95441         units  1068.0
# 95567         units  1525.0
# 95693         units  1054.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 86369 to 104534
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Yukon
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  18132.0  1208.800000  1054.0  1121.0  1543.0
# Trade certificate             11036.0  1226.222222   789.0  1288.0  1438.0
# University degree and higher  14362.0  1595.777778  1536.0  1590.0  1671.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  43530.0
# Mean :  1319.090909090909
# Min/median/max : 789.0 / 1314.0 / 1671.0
# Skewnewss :  -0.15611420775236792
# Total size :  33
# 2013
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 33449      2013  Yukon                      Total non-profit institutions
# 33456      2013  Yukon                      Total non-profit institutions
# 33470      2013  Yukon                      Total non-profit institutions
# 33575      2013  Yukon  Total non-profit institutions excluding govern...
# 33582      2013  Yukon  Total non-profit institutions excluding govern...
# 33596      2013  Yukon  Total non-profit institutions excluding govern...
# 33701      2013  Yukon  Non-profit institutions serving households (co...
# 33827      2013  Yukon                   Business non-profit institutions
# 33953      2013  Yukon                 Government non-profit institutions
# 33960      2013  Yukon                 Government non-profit institutions
# 33974      2013  Yukon                 Government non-profit institutions
# 42269      2014  Yukon                      Total non-profit institutions
# 42276      2014  Yukon                      Total non-profit institutions
# 42290      2014  Yukon                      Total non-profit institutions
# 42395      2014  Yukon  Total non-profit institutions excluding govern...
# 42402      2014  Yukon  Total non-profit institutions excluding govern...
# 42416      2014  Yukon  Total non-profit institutions excluding govern...
# 42521      2014  Yukon  Non-profit institutions serving households (co...
# 42647      2014  Yukon                   Business non-profit institutions
# 42773      2014  Yukon                 Government non-profit institutions
#
#                     Characteristics                   Indicators    UOM  \
# 33449  High school diploma and less  Average annual hours worked  Hours
# 33456             Trade certificate  Average annual hours worked  Hours
# 33470  University degree and higher  Average annual hours worked  Hours
# 33575  High school diploma and less  Average annual hours worked  Hours
# 33582             Trade certificate  Average annual hours worked  Hours
# 33596  University degree and higher  Average annual hours worked  Hours
# 33701  High school diploma and less  Average annual hours worked  Hours
# 33827  High school diploma and less  Average annual hours worked  Hours
# 33953  High school diploma and less  Average annual hours worked  Hours
# 33960             Trade certificate  Average annual hours worked  Hours
# 33974  University degree and higher  Average annual hours worked  Hours
# 42269  High school diploma and less  Average annual hours worked  Hours
# 42276             Trade certificate  Average annual hours worked  Hours
# 42290  University degree and higher  Average annual hours worked  Hours
# 42395  High school diploma and less  Average annual hours worked  Hours
# 42402             Trade certificate  Average annual hours worked  Hours
# 42416  University degree and higher  Average annual hours worked  Hours
# 42521  High school diploma and less  Average annual hours worked  Hours
# 42647  High school diploma and less  Average annual hours worked  Hours
# 42773  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 33449         units  1219.0
# 33456         units  1397.0
# 33470         units  1651.0
# 33575         units  1159.0
# 33582         units  1550.0
# 33596         units  1600.0
# 33701         units  1116.0
# 33827         units  1500.0
# 33953         units  1410.0
# 33960         units  1267.0
# 33974         units  1702.0
# 42269         units  1206.0
# 42276         units  1388.0
# 42290         units  1648.0
# 42395         units  1134.0
# 42402         units  1523.0
# 42416         units  1588.0
# 42521         units  1100.0
# 42647         units  1459.0
# 42773         units  1425.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 33449 to 51614
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Yukon
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19194.0  1279.600000  1085.0  1216.0  1574.0
# Trade certificate             12251.0  1361.222222  1125.0  1388.0  1550.0
# University degree and higher  14780.0  1642.222222  1585.0  1648.0  1708.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  46225.0
# Mean :  1400.7575757575758
# Min/median/max : 1085.0 / 1425.0 / 1708.0
# Skewnewss :  -0.11614327495631972
# Total size :  33
# 2016
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 59867      2016  Yukon                      Total non-profit institutions
# 59874      2016  Yukon                      Total non-profit institutions
# 59993      2016  Yukon  Total non-profit institutions excluding govern...
# 60000      2016  Yukon  Total non-profit institutions excluding govern...
# 60371      2016  Yukon                 Government non-profit institutions
# 60378      2016  Yukon                 Government non-profit institutions
# 68687      2017  Yukon                      Total non-profit institutions
# 68694      2017  Yukon                      Total non-profit institutions
# 68813      2017  Yukon  Total non-profit institutions excluding govern...
# 68820      2017  Yukon  Total non-profit institutions excluding govern...
# 69191      2017  Yukon                 Government non-profit institutions
# 69198      2017  Yukon                 Government non-profit institutions
# 77507      2018  Yukon                      Total non-profit institutions
# 77514      2018  Yukon                      Total non-profit institutions
# 77633      2018  Yukon  Total non-profit institutions excluding govern...
# 77640      2018  Yukon  Total non-profit institutions excluding govern...
# 78011      2018  Yukon                 Government non-profit institutions
# 78018      2018  Yukon                 Government non-profit institutions
#
#                Characteristics                   Indicators    UOM  \
# 59867      Immigrant employees  Average annual hours worked  Hours
# 59874  Non-immigrant employees  Average annual hours worked  Hours
# 59993      Immigrant employees  Average annual hours worked  Hours
# 60000  Non-immigrant employees  Average annual hours worked  Hours
# 60371      Immigrant employees  Average annual hours worked  Hours
# 60378  Non-immigrant employees  Average annual hours worked  Hours
# 68687      Immigrant employees  Average annual hours worked  Hours
# 68694  Non-immigrant employees  Average annual hours worked  Hours
# 68813      Immigrant employees  Average annual hours worked  Hours
# 68820  Non-immigrant employees  Average annual hours worked  Hours
# 69191      Immigrant employees  Average annual hours worked  Hours
# 69198  Non-immigrant employees  Average annual hours worked  Hours
# 77507      Immigrant employees  Average annual hours worked  Hours
# 77514  Non-immigrant employees  Average annual hours worked  Hours
# 77633      Immigrant employees  Average annual hours worked  Hours
# 77640  Non-immigrant employees  Average annual hours worked  Hours
# 78011      Immigrant employees  Average annual hours worked  Hours
# 78018  Non-immigrant employees  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 59867         units  1464.0
# 59874         units  1447.0
# 59993         units  1529.0
# 60000         units  1381.0
# 60371         units  1394.0
# 60378         units  1535.0
# 68687         units  1493.0
# 68694         units  1457.0
# 68813         units  1561.0
# 68820         units  1384.0
# 69191         units  1417.0
# 69198         units  1551.0
# 77507         units  1478.0
# 77514         units  1438.0
# 77633         units  1564.0
# 77640         units  1372.0
# 78011         units  1366.0
# 78018         units  1518.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 59867 to 78018
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         18 non-null     int64
#  1   GEO              18 non-null     object
#  2   Sector           18 non-null     object
#  3   Characteristics  18 non-null     object
#  4   Indicators       18 non-null     object
#  5   UOM              18 non-null     object
#  6   SCALAR_FACTOR    18 non-null     object
#  7   VALUE            18 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.3+ KB
# None
#
# Grab the dataset only in Yukon
#                              sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      13266.0  1474.000000  1366.0  1478.0  1564.0     9
# Non-immigrant employees  13083.0  1453.666667  1372.0  1447.0  1551.0     9
#
# Overall,
# Sum :  26349.0
# Mean :  1463.8333333333333
# Min/median/max : 1366.0 / 1460.5 / 1564.0
# Skewnewss :  0.03193181719841883
# Total size :  18
# 2019
#
# Grab the dataset only in Yukon
#        REF_DATE    GEO                                             Sector  \
# 86369      2019  Yukon                      Total non-profit institutions
# 86376      2019  Yukon                      Total non-profit institutions
# 86390      2019  Yukon                      Total non-profit institutions
# 86495      2019  Yukon  Total non-profit institutions excluding govern...
# 86502      2019  Yukon  Total non-profit institutions excluding govern...
# 86516      2019  Yukon  Total non-profit institutions excluding govern...
# 86621      2019  Yukon  Non-profit institutions serving households (co...
# 86747      2019  Yukon                   Business non-profit institutions
# 86873      2019  Yukon                 Government non-profit institutions
# 86880      2019  Yukon                 Government non-profit institutions
# 86894      2019  Yukon                 Government non-profit institutions
# 95189      2020  Yukon                      Total non-profit institutions
# 95196      2020  Yukon                      Total non-profit institutions
# 95210      2020  Yukon                      Total non-profit institutions
# 95315      2020  Yukon  Total non-profit institutions excluding govern...
# 95322      2020  Yukon  Total non-profit institutions excluding govern...
# 95336      2020  Yukon  Total non-profit institutions excluding govern...
# 95441      2020  Yukon  Non-profit institutions serving households (co...
# 95567      2020  Yukon                   Business non-profit institutions
# 95693      2020  Yukon                 Government non-profit institutions
#
#                     Characteristics                   Indicators    UOM  \
# 86369  High school diploma and less  Average annual hours worked  Hours
# 86376             Trade certificate  Average annual hours worked  Hours
# 86390  University degree and higher  Average annual hours worked  Hours
# 86495  High school diploma and less  Average annual hours worked  Hours
# 86502             Trade certificate  Average annual hours worked  Hours
# 86516  University degree and higher  Average annual hours worked  Hours
# 86621  High school diploma and less  Average annual hours worked  Hours
# 86747  High school diploma and less  Average annual hours worked  Hours
# 86873  High school diploma and less  Average annual hours worked  Hours
# 86880             Trade certificate  Average annual hours worked  Hours
# 86894  University degree and higher  Average annual hours worked  Hours
# 95189  High school diploma and less  Average annual hours worked  Hours
# 95196             Trade certificate  Average annual hours worked  Hours
# 95210  University degree and higher  Average annual hours worked  Hours
# 95315  High school diploma and less  Average annual hours worked  Hours
# 95322             Trade certificate  Average annual hours worked  Hours
# 95336  University degree and higher  Average annual hours worked  Hours
# 95441  High school diploma and less  Average annual hours worked  Hours
# 95567  High school diploma and less  Average annual hours worked  Hours
# 95693  High school diploma and less  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 86369         units  1198.0
# 86376         units  1058.0
# 86390         units  1629.0
# 86495         units  1122.0
# 86502         units  1438.0
# 86516         units  1587.0
# 86621         units  1068.0
# 86747         units  1543.0
# 86873         units  1445.0
# 86880         units   789.0
# 86894         units  1671.0
# 95189         units  1094.0
# 95196         units  1288.0
# 95210         units  1557.0
# 95315         units  1115.0
# 95322         units  1393.0
# 95336         units  1581.0
# 95441         units  1068.0
# 95567         units  1525.0
# 95693         units  1054.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 86369 to 104534
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         33 non-null     int64
#  1   GEO              33 non-null     object
#  2   Sector           33 non-null     object
#  3   Characteristics  33 non-null     object
#  4   Indicators       33 non-null     object
#  5   UOM              33 non-null     object
#  6   SCALAR_FACTOR    33 non-null     object
#  7   VALUE            33 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ KB
# None
#
# Grab the dataset only in Yukon
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  18132.0  1208.800000  1054.0  1121.0  1543.0
# Trade certificate             11036.0  1226.222222   789.0  1288.0  1438.0
# University degree and higher  14362.0  1595.777778  1536.0  1590.0  1671.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate                9
# University degree and higher     9
#
# Overall,
# Sum :  43530.0
# Mean :  1319.090909090909
# Min/median/max : 789.0 / 1314.0 / 1671.0
# Skewnewss :  -0.15611420775236792
# Total size :  33

# %% [markdown]
# Panda Profiling for Final Result for Yukon

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByAge_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByAge_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByAge_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByAge_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByGende_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByGender_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByGender_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByGender_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByEducation_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2010_ByEducation_Provinces, ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2013_ByEducation_Provinces, ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces, ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(df_AvgAnnHrsWrk_2019_ByEducation_Provinces, ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# %% [markdown]
# Display all of the indicators, characteristics, and provinces will display too much to analysis.<br />
# Therefore, I made custom code below to display output for speciic province and the indicators<br />
# Characteristics (Age, gender, education, immigrant) still display all of them.<br />
# To use, enter province name (string) and the indicator (in numeric 0-6).<br />

# %%
# https://realpython.com/python-raise-exception/
# https://www.geeksforgeeks.org/check-multiple-conditions-in-if-statement-python/

list_of_province = ['Alberta',  'British Columbia', 'Canada', 'Manitoba', 'New Brunswick', 'Newfoundland and Labrador', 
                    'Northwest Territories' , 'Nova Scotia' , 'Nunavut', 'Ontario' , 
                    'Prince Edward Island', 'Quebec', 'Saskatchewan', 'Yukon']
categorized_province = input('Enter your province name:')
categorized_province = categorized_province.lower()
categorized_province_analysis = "Invalid"
for x in list_of_province:
    if (x.lower() == categorized_province) :
        categorized_province_analysis = x
        break

list_indicator = ["Average annual hours worked",
             "Average annual wages and salaries",
             "Average hourly wage",
             "Average weekly hours worked",
             "Hours Worked", 
             "Number of jobs", 
             "Wages and Salaries"]
categorized_indicator = ""
categorized_indcator_analysis = "Invalid"

if categorized_province_analysis == "Invalid":
    print("Run this code again, this province doesn't exist.")
    print("End of Program")

else:
    print("Enter your indicator attributes, ")
    print("0. Average annual hours worked")
    print("1. Average annual wages and salaries")
    print("2. Average hourly wage")
    print("3. Average weekly hours worked")
    print("4. Hours Worked")
    print("5. Number of jobs")
    print("6. Wages and Salaries")
    categorized_indicator = input('Enter your indicator number:')
    try:
        categorized_indicator = int(categorized_indicator)
    except ValueError:
        if not type(categorized_indicator) is int:
            print("Run this code again, invalid integer")
            print("End of Program")
    try:
        categorized_indicator_analysis = list_indicator[categorized_indicator]
    except IndexError:
        print("Run this code again, invalid range (0-6)")
        print("End of Program")

    if categorized_province_analysis == "Invalid":
        print("End of Program")
    else:
        num = 0
        for x in list_of_province:
            if (categorized_province_analysis == x) :
                ProCode = num
                break
            else:
                num = num + 1
        if categorized_indicator == 0:
            categorized_indicator_analysis = []
            categorized_indicator_analysis.append("") # df_AvgAnnHrsWrk_2010_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2013_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2016_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2019_ByAge_Provinces)
            categorized_indicator_analysis.append("") # df_AvgAnnHrsWrk_2010_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2013_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2016_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2019_ByGender_Provinces)
            categorized_indicator_analysis.append("") # df_AvgAnnHrsWrk_2010_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2013_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2016_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2019_ByEducation_Provinces)
            categorized_indicator_analysis.append("") # df_AvgAnnHrsWrk_2010_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2013_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2016_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnHrsWrk_2019_ByImmigrant_Provinces)
        elif categorized_indicator == 1:
            categorized_indicator_analysis = []
            categorized_indicator_analysis.append("") # df_AvgAnnWages_2010_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2013_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2016_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2019_ByAge_Provinces)
            categorized_indicator_analysis.append("") # df_AvgAnnWages_2010_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2013_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2016_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2019_ByGender_Provinces)
            categorized_indicator_analysis.append("") # df_AvgAnnWages_2010_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2013_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2016_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2019_ByEducation_Provinces)
            categorized_indicator_analysis.append("") # df_AvgAnnWages_2010_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2013_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2016_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgAnnWages_2019_ByImmigrant_Provinces)
        elif categorized_indicator == 2:
            categorized_indicator_analysis = []
            categorized_indicator_analysis.append("") # df_AvgHrsWages_2010_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2013_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2016_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2019_ByAge_Provinces)
            categorized_indicator_analysis.append("") # df_AvgHrsWages_2010_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2013_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2016_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2019_ByGender_Provinces)
            categorized_indicator_analysis.append("") # df_AvgHrsWages_2010_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2013_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2016_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2019_ByEducation_Provinces)
            categorized_indicator_analysis.append("") # df_AvgHrsWages_2010_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2013_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2016_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgHrsWages_2019_ByImmigrant_Provinces)
        elif categorized_indicator == 3:
            categorized_indicator_analysis = []
            categorized_indicator_analysis.append("") # df_AvgWeekHrsWrked_2010_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2013_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2016_ByAge_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2019_ByAge_Provinces)
            categorized_indicator_analysis.append("") # df_AvgWeekHrsWrked_2010_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2013_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2016_ByGender_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2019_ByGender_Provinces)
            categorized_indicator_analysis.append("") # df_AvgWeekHrsWrked_2010_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2013_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2016_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2019_ByEducation_Provinces)
            categorized_indicator_analysis.append("") # df_AvgWeekHrsWrked_2010_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2013_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2016_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_AvgWeekHrsWrked_2019_ByImmigrant_Provinces)
        elif categorized_indicator == 4:
            categorized_indicator_analysis = []
            categorized_indicator_analysis.append("") # df_Hrs_Wrked_2010_ByAge_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2013_ByAge_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2016_ByAge_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2019_ByAge_Provinces)
            categorized_indicator_analysis.append("") # df_Hrs_Wrked_2010_ByGender_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2013_ByGender_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2016_ByGender_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2019_ByGender_Provinces)
            categorized_indicator_analysis.append("") # df_Hrs_Wrked_2010_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2013_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2016_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2019_ByEducation_Provinces)
            categorized_indicator_analysis.append("") # df_Hrs_Wrked_2010_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2013_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2016_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_Hrs_Wrked_2019_ByImmigrant_Provinces)
        elif categorized_indicator == 5:
            categorized_indicator_analysis = []
            categorized_indicator_analysis.append("") # df_NumOfJob_2010_ByAge_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2013_ByAge_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2016_ByAge_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2019_ByAge_Provinces)
            categorized_indicator_analysis.append("") # df_NumOfJob_2010_ByGender_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2013_ByGender_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2016_ByGender_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2019_ByGender_Provinces)
            categorized_indicator_analysis.append("") # df_NumOfJob_2010_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2013_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2016_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2019_ByEducation_Provinces)
            categorized_indicator_analysis.append("") # df_NumOfJob_2010_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2013_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2016_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_NumOfJob_2019_ByImmigrant_Provinces)
        elif categorized_indicator == 6:
            categorized_indicator_analysis = []
            categorized_indicator_analysis.append("") # df_WagesAndSalaries_2010_ByAge_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2013_ByAge_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2016_ByAge_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2019_ByAge_Provinces)
            categorized_indicator_analysis.append("") # df_WagesAndSalaries_2010_ByGender_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2013_ByGender_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2016_ByGender_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2019_ByGender_Provinces)
            categorized_indicator_analysis.append("") # df_WagesAndSalaries_2010_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2013_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2016_ByEducation_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2019_ByEducation_Provinces)
            categorized_indicator_analysis.append("") # df_WagesAndSalaries_2010_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2013_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2016_ByImmigrant_Provinces)
            categorized_indicator_analysis.append(df_WagesAndSalaries_2019_ByImmigrant_Provinces)
        else:
            pass
        print("The province name is "+categorized_province_analysis)
        print("The indicator name is "+list_indicator[categorized_indicator])
        print("From here, the ProCode will be "+str(ProCode))
        print("The array from categorized_indicator_analysis is")
        print(categorized_indicator_analysis)
# Out:
# Enter your indicator attributes,
# 0. Average annual hours worked
# 1. Average annual wages and salaries
# 2. Average hourly wage
# 3. Average weekly hours worked
# 4. Hours Worked
# 5. Number of jobs
# 6. Wages and Salaries
# The province name is Ontario
# The indicator name is Average annual hours worked
# From here, the ProCode will be 9
# The array from categorized_indicator_analysis is
# ['', <__main__.ProvinceAnalysis object at 0x00000282670046D0>, <__main__.ProvinceAnalysis object at 0x0000028267004370>, <__main__.ProvinceAnalysis object at 0x0000028267004E80>, '', <__main__.ProvinceAnalysis object at 0x0000028267004A30>, <__main__.ProvinceAnalysis object at 0x0000028266B1A520>, <__main__.ProvinceAnalysis object at 0x00000282653A1F40>, '', <__main__.ProvinceAnalysis object at 0x0000028266E56400>, <__main__.ProvinceAnalysis object at 0x00000282660DBAF0>, <__main__.ProvinceAnalysis object at 0x0000028266B1E7C0>, '', <__main__.ProvinceAnalysis object at 0x000002826649F370>, <__main__.ProvinceAnalysis object at 0x000002826617DFA0>, <__main__.ProvinceAnalysis object at 0x00000282665E80D0>]

# %% [markdown]
# Filtering based on ProCode and indicator given above. <br />
# Must run the code above to run this code. <br />

# %%
# This code need code above.

# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[0], ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[1], ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[2], ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[3], ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[4], ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[5], ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[6], ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[7], ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[8], ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[9], ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[10], ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[11], ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()

# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[12], ProCode, "2010", pd, np, pp)
# df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[13], ProCode, "2013", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[14], ProCode, "2016", pd, np, pp)
df_Display_Output_Result.OutputResult()
df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[15], ProCode, "2019", pd, np, pp)
df_Display_Output_Result.OutputResult()
# Out:
# 2013
#
# Grab the dataset only in Ontario
#        REF_DATE      GEO                                             Sector  \
# 30327      2013  Ontario                      Total non-profit institutions
# 30334      2013  Ontario                      Total non-profit institutions
# 30341      2013  Ontario                      Total non-profit institutions
# 30348      2013  Ontario                      Total non-profit institutions
# 30355      2013  Ontario                      Total non-profit institutions
# 30362      2013  Ontario                      Total non-profit institutions
# 30453      2013  Ontario  Total non-profit institutions excluding govern...
# 30460      2013  Ontario  Total non-profit institutions excluding govern...
# 30467      2013  Ontario  Total non-profit institutions excluding govern...
# 30474      2013  Ontario  Total non-profit institutions excluding govern...
# 30481      2013  Ontario  Total non-profit institutions excluding govern...
# 30488      2013  Ontario  Total non-profit institutions excluding govern...
# 30579      2013  Ontario  Non-profit institutions serving households (co...
# 30586      2013  Ontario  Non-profit institutions serving households (co...
# 30593      2013  Ontario  Non-profit institutions serving households (co...
# 30600      2013  Ontario  Non-profit institutions serving households (co...
# 30607      2013  Ontario  Non-profit institutions serving households (co...
# 30614      2013  Ontario  Non-profit institutions serving households (co...
# 30705      2013  Ontario                   Business non-profit institutions
# 30712      2013  Ontario                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 30327         15 to 24 years  Average annual hours worked  Hours
# 30334         25 to 34 years  Average annual hours worked  Hours
# 30341         35 to 44 years  Average annual hours worked  Hours
# 30348         45 to 54 years  Average annual hours worked  Hours
# 30355         55 to 64 years  Average annual hours worked  Hours
# 30362  65 years old and over  Average annual hours worked  Hours
# 30453         15 to 24 years  Average annual hours worked  Hours
# 30460         25 to 34 years  Average annual hours worked  Hours
# 30467         35 to 44 years  Average annual hours worked  Hours
# 30474         45 to 54 years  Average annual hours worked  Hours
# 30481         55 to 64 years  Average annual hours worked  Hours
# 30488  65 years old and over  Average annual hours worked  Hours
# 30579         15 to 24 years  Average annual hours worked  Hours
# 30586         25 to 34 years  Average annual hours worked  Hours
# 30593         35 to 44 years  Average annual hours worked  Hours
# 30600         45 to 54 years  Average annual hours worked  Hours
# 30607         55 to 64 years  Average annual hours worked  Hours
# 30614  65 years old and over  Average annual hours worked  Hours
# 30705         15 to 24 years  Average annual hours worked  Hours
# 30712         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 30327         units   835.0
# 30334         units  1580.0
# 30341         units  1774.0
# 30348         units  1837.0
# 30355         units  1702.0
# 30362         units  1041.0
# 30453         units   845.0
# 30460         units  1669.0
# 30467         units  1806.0
# 30474         units  1863.0
# 30481         units  1717.0
# 30488         units  1060.0
# 30579         units   839.0
# 30586         units  1628.0
# 30593         units  1763.0
# 30600         units  1830.0
# 30607         units  1691.0
# 30614         units  1044.0
# 30705         units   857.0
# 30712         units  1788.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 30327 to 48506
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Ontario
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         12561.0   837.400000   824.0   836.0   857.0    15
# 25 to 34 years         24473.0  1631.533333  1527.0  1611.0  1788.0    15
# 35 to 44 years         26974.0  1798.266667  1731.0  1769.0  1941.0    15
# 45 to 54 years         27822.0  1854.800000  1795.0  1831.0  1967.0    15
# 55 to 64 years         25858.0  1723.866667  1679.0  1713.0  1822.0    15
# 65 years old and over  16363.0  1090.866667  1027.0  1092.0  1192.0    15
#
# Overall,
# Sum :  134051.0
# Mean :  1489.4555555555555
# Min/median/max : 824.0 / 1693.0 / 1967.0
# Skewnewss :  -0.6827679863947949
# Total size :  90
# 2016
#
# Grab the dataset only in Ontario
#        REF_DATE      GEO                                             Sector  \
# 56787      2016  Ontario                      Total non-profit institutions
# 56794      2016  Ontario                      Total non-profit institutions
# 56801      2016  Ontario                      Total non-profit institutions
# 56808      2016  Ontario                      Total non-profit institutions
# 56815      2016  Ontario                      Total non-profit institutions
# 56822      2016  Ontario                      Total non-profit institutions
# 56913      2016  Ontario  Total non-profit institutions excluding govern...
# 56920      2016  Ontario  Total non-profit institutions excluding govern...
# 56927      2016  Ontario  Total non-profit institutions excluding govern...
#
# Grab the dataset only in Ontario
#        REF_DATE      GEO                                             Sector  \
# 83247      2019  Ontario                      Total non-profit institutions
# 83254      2019  Ontario                      Total non-profit institutions
# 83261      2019  Ontario                      Total non-profit institutions
# 83268      2019  Ontario                      Total non-profit institutions
# 83275      2019  Ontario                      Total non-profit institutions
# 83282      2019  Ontario                      Total non-profit institutions
# 83373      2019  Ontario  Total non-profit institutions excluding govern...
# 83380      2019  Ontario  Total non-profit institutions excluding govern...
# 83387      2019  Ontario  Total non-profit institutions excluding govern...
# 83394      2019  Ontario  Total non-profit institutions excluding govern...
# 83401      2019  Ontario  Total non-profit institutions excluding govern...
# 83408      2019  Ontario  Total non-profit institutions excluding govern...
# 83499      2019  Ontario  Non-profit institutions serving households (co...
# 83506      2019  Ontario  Non-profit institutions serving households (co...
# 83513      2019  Ontario  Non-profit institutions serving households (co...
# 83520      2019  Ontario  Non-profit institutions serving households (co...
# 83527      2019  Ontario  Non-profit institutions serving households (co...
# 83534      2019  Ontario  Non-profit institutions serving households (co...
# 83625      2019  Ontario                   Business non-profit institutions
# 83632      2019  Ontario                   Business non-profit institutions
#
#              Characteristics                   Indicators    UOM  \
# 83247         15 to 24 years  Average annual hours worked  Hours
# 83254         25 to 34 years  Average annual hours worked  Hours
# 83261         35 to 44 years  Average annual hours worked  Hours
# 83268         45 to 54 years  Average annual hours worked  Hours
# 83275         55 to 64 years  Average annual hours worked  Hours
# 83282  65 years old and over  Average annual hours worked  Hours
# 83373         15 to 24 years  Average annual hours worked  Hours
# 83380         25 to 34 years  Average annual hours worked  Hours
# 83387         35 to 44 years  Average annual hours worked  Hours
# 83394         45 to 54 years  Average annual hours worked  Hours
# 83401         55 to 64 years  Average annual hours worked  Hours
# 83408  65 years old and over  Average annual hours worked  Hours
# 83499         15 to 24 years  Average annual hours worked  Hours
# 83506         25 to 34 years  Average annual hours worked  Hours
# 83513         35 to 44 years  Average annual hours worked  Hours
# 83520         45 to 54 years  Average annual hours worked  Hours
# 83527         55 to 64 years  Average annual hours worked  Hours
# 83534  65 years old and over  Average annual hours worked  Hours
# 83625         15 to 24 years  Average annual hours worked  Hours
# 83632         25 to 34 years  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 83247         units   865.0
# 83254         units  1579.0
# 83261         units  1745.0
# 83268         units  1831.0
# 83275         units  1708.0
# 83282         units  1056.0
# 83373         units   847.0
# 83380         units  1631.0
# 83387         units  1757.0
# 83394         units  1830.0
# 83401         units  1690.0
# 83408         units  1060.0
# 83499         units   843.0
# 83506         units  1589.0
# 83513         units  1716.0
# 83520         units  1794.0
# 83527         units  1657.0
# 83534         units  1038.0
# 83625         units   856.0
# 83632         units  1755.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 83247 to 101426
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         90 non-null     int64
#  1   GEO              90 non-null     object
#  2   Sector           90 non-null     object
#  3   Characteristics  90 non-null     object
#  4   Indicators       90 non-null     object
#  5   UOM              90 non-null     object
#  6   SCALAR_FACTOR    90 non-null     object
#  7   VALUE            90 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.3+ KB
# None
#
# Grab the dataset only in Ontario
#                            sum         mean    amin  median    amax  size
# Characteristics
# 15 to 24 years         13099.0   873.266667   823.0   872.0   932.0    15
# 25 to 34 years         24347.0  1623.133333  1529.0  1600.0  1765.0    15
# 35 to 44 years         26457.0  1763.800000  1647.0  1755.0  1884.0    15
# 45 to 54 years         27665.0  1844.333333  1722.0  1832.0  1945.0    15
# 55 to 64 years         25732.0  1715.466667  1592.0  1708.0  1806.0    15
# 65 years old and over  16252.0  1083.466667  1005.0  1071.0  1192.0    15
#
# Overall,
# Sum :  133552.0
# Mean :  1483.911111111111
# Min/median/max : 823.0 / 1652.0 / 1945.0
# Skewnewss :  -0.6561285966673744
# Total size :  90
# 2013
#
# Grab the dataset only in Ontario
#        REF_DATE      GEO                                             Sector  \
#
# 83226             Trade certificate  Average annual hours worked  Hours
# 83240  University degree and higher  Average annual hours worked  Hours
# 83345  High school diploma and less  Average annual hours worked  Hours
# 83352             Trade certificate  Average annual hours worked  Hours
# 83366  University degree and higher  Average annual hours worked  Hours
# 83471  High school diploma and less  Average annual hours worked  Hours
# 83478             Trade certificate  Average annual hours worked  Hours
# 83492  University degree and higher  Average annual hours worked  Hours
# 83597  High school diploma and less  Average annual hours worked  Hours
# 83604             Trade certificate  Average annual hours worked  Hours
# 83618  University degree and higher  Average annual hours worked  Hours
# 83723  High school diploma and less  Average annual hours worked  Hours
# 83730             Trade certificate  Average annual hours worked  Hours
# 83744  University degree and higher  Average annual hours worked  Hours
# 92039  High school diploma and less  Average annual hours worked  Hours
# 92046             Trade certificate  Average annual hours worked  Hours
# 92060  University degree and higher  Average annual hours worked  Hours
# 92165  High school diploma and less  Average annual hours worked  Hours
# 92172             Trade certificate  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 83219         units  1245.0
# 83226         units  1499.0
# 83240         units  1670.0
# 83345         units  1251.0
# 83352         units  1513.0
# 83366         units  1706.0
# 83471         units  1197.0
# 83478         units  1454.0
# 83492         units  1680.0
# 83597         units  1386.0
# 83604         units  1669.0
# 83618         units  1792.0
# 83723         units  1238.0
# 83730         units  1486.0
# 83744         units  1649.0
# 92039         units  1248.0
# 92046         units  1482.0
# 92060         units  1673.0
# 92165         units  1234.0
# 92172         units  1459.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 45 entries, 83219 to 101384
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         45 non-null     int64
#  1   GEO              45 non-null     object
#  2   Sector           45 non-null     object
#  3   Characteristics  45 non-null     object
#  4   Indicators       45 non-null     object
#  5   UOM              45 non-null     object
#  6   SCALAR_FACTOR    45 non-null     object
#  7   VALUE            45 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB
# None
#
# Grab the dataset only in Ontario
#                                   sum         mean    amin  median    amax  \
# Characteristics
# High school diploma and less  19132.0  1275.466667  1171.0  1251.0  1423.0
# Trade certificate             22756.0  1517.066667  1396.0  1499.0  1669.0
# University degree and higher  25550.0  1703.333333  1615.0  1688.0  1808.0
#
#                               size
# Characteristics
# High school diploma and less    15
# Trade certificate               15
# University degree and higher    15
#
# Overall,
# Sum :  67438.0
# Mean :  1498.6222222222223
# Min/median/max : 1171.0 / 1499.0 / 1808.0
# Skewnewss :  -0.16058488152240866
# Total size :  45
# 2013
#
# Grab the dataset only in Ontario
#        REF_DATE      GEO                                             Sector  \
# 30257      2013  Ontario                      Total non-profit institutions
# 30264      2013  Ontario                      Total non-profit institutions
# 30383      2013  Ontario  Total non-profit institutions excluding govern...
# 30390      2013  Ontario  Total non-profit institutions excluding govern...
# 30509      2013  Ontario  Non-profit institutions serving households (co...
# 30516      2013  Ontario  Non-profit institutions serving households (co...
# 30635      2013  Ontario                   Business non-profit institutions
# 30642      2013  Ontario                   Business non-profit institutions
# 30761      2013  Ontario                 Government non-profit institutions
# 30768      2013  Ontario                 Government non-profit institutions
# 39077      2014  Ontario                      Total non-profit institutions
# 39084      2014  Ontario                      Total non-profit institutions
# 39203      2014  Ontario  Total non-profit institutions excluding govern...
# 39210      2014  Ontario  Total non-profit institutions excluding govern...
# 39329      2014  Ontario  Non-profit institutions serving households (co...
# 39336      2014  Ontario  Non-profit institutions serving households (co...
# 65922      2017  Ontario                   Business non-profit institutions
# 66041      2017  Ontario                 Government non-profit institutions
# 66048      2017  Ontario                 Government non-profit institutions
#
#                Characteristics                   Indicators    UOM  \
# 56717      Immigrant employees  Average annual hours worked  Hours
# 56724  Non-immigrant employees  Average annual hours worked  Hours
# 56843      Immigrant employees  Average annual hours worked  Hours
# 56850  Non-immigrant employees  Average annual hours worked  Hours
# 56969      Immigrant employees  Average annual hours worked  Hours
# 56976  Non-immigrant employees  Average annual hours worked  Hours
# 57095      Immigrant employees  Average annual hours worked  Hours
# 57102  Non-immigrant employees  Average annual hours worked  Hours
# 57221      Immigrant employees  Average annual hours worked  Hours
# 57228  Non-immigrant employees  Average annual hours worked  Hours
# 65537      Immigrant employees  Average annual hours worked  Hours
# 65544  Non-immigrant employees  Average annual hours worked  Hours
# 65663      Immigrant employees  Average annual hours worked  Hours
# 65670  Non-immigrant employees  Average annual hours worked  Hours
# 65789      Immigrant employees  Average annual hours worked  Hours
# 65796  Non-immigrant employees  Average annual hours worked  Hours
# 65915      Immigrant employees  Average annual hours worked  Hours
# 65922  Non-immigrant employees  Average annual hours worked  Hours
# 66041      Immigrant employees  Average annual hours worked  Hours
# 66048  Non-immigrant employees  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 56717         units  1599.0
# 56724         units  1586.0
# 56843         units  1596.0
# 56850         units  1573.0
# 56969         units  1558.0
# 56976         units  1547.0
# 57095         units  1706.0
# 57102         units  1651.0
# 57221         units  1601.0
# 57228         units  1595.0
# 65537         units  1599.0
# 65544         units  1585.0
# 65663         units  1593.0
# 65670         units  1577.0
# 65789         units  1557.0
# 65796         units  1550.0
# 65915         units  1697.0
# 65922         units  1660.0
# 66041         units  1602.0
# 66048         units  1590.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 56717 to 74868
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Ontario
#                              sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      24132.0  1608.800000  1540.0  1599.0  1706.0    15
# Non-immigrant employees  23879.0  1591.933333  1542.0  1586.0  1660.0    15
#
# Overall,
# Sum :  48011.0
# Mean :  1600.3666666666666
# Min/median/max : 1540.0 / 1594.0 / 1706.0
# Skewnewss :  0.9632697618544546
# Total size :  30
# 2019
#
# Grab the dataset only in Ontario
#        REF_DATE      GEO                                             Sector  \
# 83177      2019  Ontario                      Total non-profit institutions
# 83184      2019  Ontario                      Total non-profit institutions
# 83303      2019  Ontario  Total non-profit institutions excluding govern...
# 83310      2019  Ontario  Total non-profit institutions excluding govern...
# 83429      2019  Ontario  Non-profit institutions serving households (co...
# 83436      2019  Ontario  Non-profit institutions serving households (co...
# 83555      2019  Ontario                   Business non-profit institutions
# 83562      2019  Ontario                   Business non-profit institutions
# 83681      2019  Ontario                 Government non-profit institutions
# 83688      2019  Ontario                 Government non-profit institutions
# 91997      2020  Ontario                      Total non-profit institutions
# 92004      2020  Ontario                      Total non-profit institutions
# 92123      2020  Ontario  Total non-profit institutions excluding govern...
# 92130      2020  Ontario  Total non-profit institutions excluding govern...
# 92249      2020  Ontario  Non-profit institutions serving households (co...
# 92256      2020  Ontario  Non-profit institutions serving households (co...
# 92375      2020  Ontario                   Business non-profit institutions
# 92382      2020  Ontario                   Business non-profit institutions
# 92501      2020  Ontario                 Government non-profit institutions
# 92508      2020  Ontario                 Government non-profit institutions
#
#                Characteristics                   Indicators    UOM  \
# 83177      Immigrant employees  Average annual hours worked  Hours
# 83184  Non-immigrant employees  Average annual hours worked  Hours
# 83303      Immigrant employees  Average annual hours worked  Hours
# 83310  Non-immigrant employees  Average annual hours worked  Hours
# 83429      Immigrant employees  Average annual hours worked  Hours
# 83436  Non-immigrant employees  Average annual hours worked  Hours
# 83555      Immigrant employees  Average annual hours worked  Hours
# 83562  Non-immigrant employees  Average annual hours worked  Hours
# 83681      Immigrant employees  Average annual hours worked  Hours
# 83688  Non-immigrant employees  Average annual hours worked  Hours
# 91997      Immigrant employees  Average annual hours worked  Hours
# 92004  Non-immigrant employees  Average annual hours worked  Hours
# 92123      Immigrant employees  Average annual hours worked  Hours
# 92130  Non-immigrant employees  Average annual hours worked  Hours
# 92249      Immigrant employees  Average annual hours worked  Hours
# 92256  Non-immigrant employees  Average annual hours worked  Hours
# 92375      Immigrant employees  Average annual hours worked  Hours
# 92382  Non-immigrant employees  Average annual hours worked  Hours
# 92501      Immigrant employees  Average annual hours worked  Hours
# 92508  Non-immigrant employees  Average annual hours worked  Hours
#
#       SCALAR_FACTOR   VALUE
# 83177         units  1583.0
# 83184         units  1570.0
# 83303         units  1573.0
# 83310         units  1566.0
# 83429         units  1535.0
# 83436         units  1540.0
# 83555         units  1684.0
# 83562         units  1651.0
# 83681         units  1590.0
# 83688         units  1573.0
# 91997         units  1588.0
# 92004         units  1576.0
# 92123         units  1528.0
# 92130         units  1533.0
# 92249         units  1477.0
# 92256         units  1494.0
# 92375         units  1677.0
# 92382         units  1659.0
# 92501         units  1621.0
# 92508         units  1602.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 83177 to 101328
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         30 non-null     int64
#  1   GEO              30 non-null     object
#  2   Sector           30 non-null     object
#  3   Characteristics  30 non-null     object
#  4   Indicators       30 non-null     object
#  5   UOM              30 non-null     object
#  6   SCALAR_FACTOR    30 non-null     object
#  7   VALUE            30 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.1+ KB
# None
#
# Grab the dataset only in Ontario
#                              sum         mean    amin  median    amax  size
# Characteristics
# Immigrant employees      23968.0  1597.866667  1477.0  1588.0  1697.0    15
# Non-immigrant employees  23869.0  1591.266667  1494.0  1576.0  1691.0    15
#
# Overall,
# Sum :  47837.0
# Mean :  1594.5666666666666
# Min/median/max : 1477.0 / 1586.5 / 1697.0
# Skewnewss :  0.05897117710976009
# Total size :  30

# %% [markdown]
# Panda Profiling based on ProCode and indicator given above. <br />
# Must run the code above to run this code. <br />

# %%
# # df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[0], ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[1], ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[2], ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[3], ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[4], ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[5], ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[6], ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[7], ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[8], ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[9], ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[10], ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[11], ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()

# # df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[12], ProCode, "2010", pd, np, pp)
# # df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[13], ProCode, "2013", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[14], ProCode, "2016", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
# df_Display_Output_Result = OutputProvinceAnalysis(categorized_indicator_analysis[15], ProCode, "2019", pd, np, pp)
# df_Display_Output_Result.OutputPandaProfiling()
